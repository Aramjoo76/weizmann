# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc

# %% [markdown]
# ## Colorectal

# %% [markdown]
# #### 1. Chen2021_Colorectal

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Chen2021_Colorectal"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 57723 × 31412
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'source_x', 'HTAN.Parent.Data.File.ID', 'Polyp_Type_x', 'cancer_type', 'technology', 'n_cells', 'patient_y', 'source_y', 'Polyp_Type_y'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'HTAN.Parent.Data.File.ID', 
            'patient_y', 'source_y', 'Polyp_Type_y'        
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['source_x'].value_counts()
# Out:
# source_x
# normal            34008
# adenoma           11138
# serrated_polyp     8671
# unconfirmed        3906
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                          cell_name                  sample    patient_x  \
# 0          CCAACCGTATATACCT_0_5607  HTA11_10167_2000001011  HTA11_10167
# 1         AATGGATTAAAACCTCC_0_5607  HTA11_10167_2000001011  HTA11_10167
# 2       TGAAGGAGCTTACCACGCT_0_5607  HTA11_10167_2000001011  HTA11_10167
# 3       TGATTCGCTGGATACCCAG_0_5607  HTA11_10167_2000001011  HTA11_10167
# 4       TGATCGACGGTTTGGACTT_0_5607  HTA11_10167_2000001011  HTA11_10167
# ...                            ...                     ...          ...
# 57718     ACCTTGCCTTGATTCT_22_5898   HTA11_8504_2000002011   HTA11_8504
# 57719  TGACAATACTTGCAAAGCC_22_5898   HTA11_8504_2000002011   HTA11_8504
# 57720  TGATACGTGCTATCCGCTA_22_5898   HTA11_8504_2000002011   HTA11_8504
# 57721  TGACAAGTCATTAGTCGCA_22_5898   HTA11_8504_2000002011   HTA11_8504
# 57722   GATCTCACTTGTCCATGT_22_5898   HTA11_8504_2000002011   HTA11_8504
#
#                      cell_type cell_subtype  complexity cell_cycle_phase  \
# 0                   Epithelial          ABS        6713      Not cycling
# 1                   Epithelial          ABS        5368      Not cycling
# 2                   Epithelial          ABS        5076      Not cycling
# 3      Serrated_specific_cells          SSC        5384      Not cycling
# 4                   Epithelial          ABS        4578      Not cycling
# ...                        ...          ...         ...              ...
# 57718               Epithelial          GOB         798              NaN
# 57719               Epithelial          ABS         773              NaN
# 57720               Epithelial          GOB         979              NaN
# 57721               Epithelial          ABS         850              NaN
# 57722               Epithelial          GOB         832              NaN
#
#              source_x   cancer_type                technology  n_cells  sex  \
# 0      serrated_polyp  Premalignant  modified inDrop platform      543  NaN
# 1      serrated_polyp  Premalignant  modified inDrop platform      543  NaN
# 2      serrated_polyp  Premalignant  modified inDrop platform      543  NaN
# 3      serrated_polyp  Premalignant  modified inDrop platform      543  NaN
# 4      serrated_polyp  Premalignant  modified inDrop platform      543  NaN
# ...               ...           ...                       ...      ...  ...
# 57718          normal        Normal  modified inDrop platform      511  NaN
# 57719          normal        Normal  modified inDrop platform      511  NaN
# 57720          normal        Normal  modified inDrop platform      511  NaN
# 57721          normal        Normal  modified inDrop platform      511  NaN
# 57722          normal        Normal  modified inDrop platform      511  NaN
#
#        age disease_extent sample_primary_met          site treated_naive  \
# 0      NaN            NaN                NaN  Colon polyps           NaN
# 1      NaN            NaN                NaN  Colon polyps           NaN
# 2      NaN            NaN                NaN  Colon polyps           NaN
# 3      NaN            NaN                NaN  Colon polyps           NaN
# 4      NaN            NaN                NaN  Colon polyps           NaN
# ...    ...            ...                ...           ...           ...
# 57718  NaN            NaN                NaN  Colon polyps           NaN
# 57719  NaN            NaN                NaN  Colon polyps           NaN
# 57720  NaN            NaN                NaN  Colon polyps           NaN
# 57721  NaN            NaN                NaN  Colon polyps           NaN
# 57722  NaN            NaN                NaN  Colon polyps           NaN
#
#                           study    category
# 0      Data_Chen2021_Colorectal  Colorectal
# 1      Data_Chen2021_Colorectal  Colorectal
# 2      Data_Chen2021_Colorectal  Colorectal
# 3      Data_Chen2021_Colorectal  Colorectal
# 4      Data_Chen2021_Colorectal  Colorectal
# ...                         ...         ...
# 57718  Data_Chen2021_Colorectal  Colorectal
# 57719  Data_Chen2021_Colorectal  Colorectal
# 57720  Data_Chen2021_Colorectal  Colorectal
# 57721  Data_Chen2021_Colorectal  Colorectal
# 57722  Data_Chen2021_Colorectal  Colorectal
#
# [57723 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['site'] = 'Colon polyps'

# %%
del adata.obs['Polyp_Type_x']

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['study'] = 'Data_Chen2021_Colorectal'

# %%
adata.obs['category'] = 'Colorectal'

# %%
output_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Chen2021_Colorectal.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Colorectal/Data_Chen2021_Colorectal.h5ad

# %% [markdown]
# #### 2.Lee2020_Colorectal

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Lee2020_Colorectal"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 21657 × 22276
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['treated_naive'].value_counts()
# Out:
# treated_naive
# naive    21657
# Name: count, dtype: int64

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"type_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "site"})

# %%
adata.obs = adata.obs.rename(columns={"treatment_x": "treated_naive"})

# %%
adata.obs
# Out:
#                       cell_name sample   cell_type  complexity  \
# 0      SMC01-T_AAACCTGAGAAGGTTT  SMC01      T_cell        1400
# 1      SMC01-T_AAACCTGAGGTAGCTG  SMC01      T_cell        1249
# 2      SMC01-T_AAACCTGCATACGCCG  SMC01   Malignant        4787
# 3      SMC01-T_AAACCTGGTCGCATAT  SMC01   Malignant        5175
# 4      SMC01-T_AAACCTGGTTCCTCCA  SMC01      T_cell        1245
# ...                         ...    ...         ...         ...
# 21652  SMC25-T_TTTGCGCAGACACGAC  SMC25   Malignant        5016
# 21653  SMC25-T_TTTGCGCCATGGAATA  SMC25         NaN        3376
# 21654  SMC25-T_TTTGGTTCAACGCACC  SMC25      B_cell        1745
# 21655  SMC25-T_TTTGGTTGTAGGGTAC  SMC25  Epithelial        2765
# 21656  SMC25-T_TTTGTCAAGAGGGATA  SMC25   Malignant        4953
#
#       cell_cycle_phase technology  n_cells patient        cancer_type sex  \
# 0          Not cycling        10x     1742   SMC01  Colorectal Cancer   F
# 1          Not cycling        10x     1742   SMC01  Colorectal Cancer   F
# 2         Intermediate        10x     1742   SMC01  Colorectal Cancer   F
# 3          Not cycling        10x     1742   SMC01  Colorectal Cancer   F
# 4          Not cycling        10x     1742   SMC01  Colorectal Cancer   F
# ...                ...        ...      ...     ...                ...  ..
# 21652      Not cycling        10x      673   SMC25  Colorectal Cancer   F
# 21653              NaN        10x      673   SMC25  Colorectal Cancer   F
# 21654      Not cycling        10x      673   SMC25  Colorectal Cancer   F
# 21655             G2/M        10x      673   SMC25  Colorectal Cancer   F
# 21656      Not cycling        10x      673   SMC25  Colorectal Cancer   F
#
#        age disease_extent sample_primary_met     site treated_naive  \
# 0       64          local            primary   rectum         naive
# 1       64          local            primary   rectum         naive
# 2       64          local            primary   rectum         naive
# 3       64          local            primary   rectum         naive
# 4       64          local            primary   rectum         naive
# ...    ...            ...                ...      ...           ...
# 21652   57     metastatic            primary  sigmoid         naive
# 21653   57     metastatic            primary  sigmoid         naive
# 21654   57     metastatic            primary  sigmoid         naive
# 21655   57     metastatic            primary  sigmoid         naive
# 21656   57     metastatic            primary  sigmoid         naive
#
#       cell_subtype    category source                    study
# 0              NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# 1              NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# 2              NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# 3              NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# 4              NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# ...            ...         ...    ...                      ...
# 21652          NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# 21653          NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# 21654          NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# 21655          NaN  Colorectal  tumor  Data_Lee2020_Colorectal
# 21656          NaN  Colorectal  tumor  Data_Lee2020_Colorectal
#
# [21657 rows x 19 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'tumor'

# %%
adata.obs['study'] = 'Data_Lee2020_Colorectal'

# %%
adata.obs['category'] = 'Colorectal'

# %%
output_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Lee2020_Colorectal.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Colorectal/Data_Lee2020_Colorectal.h5ad

# %% [markdown]
# #### 3.Li2017_Colorectal

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Li2017_Colorectal"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Step 4: Ensure columns are strings
cells['sample'] = cells['sample'].astype(str).str.strip()
samples['sample'] = samples['sample'].astype(str).str.strip()

# Step 5: Extract base sample ID (e.g., 'CRC04' from 'CRC04_tumour')
cells['sample_base'] = cells['sample'].str.extract(r'^(CRC\d+)')

# Step 6: Merge on base sample ID
cells_merged = cells.merge(samples, left_on='sample_base', right_on='sample', how='left')

# Step 7: Drop helper column used for merge
cells_merged = cells_merged.drop(columns=['sample_base'])

# Step 8: Assign metadata to AnnData
adata.obs = cells_merged

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 590 × 55017
#     obs: 'cell_name', 'sample_x', 'patient_x', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'source', 'sample_y', 'technology', 'n_cells', 'patient_y', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'sample_x'     
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['technology'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"sample_y": "sample"})

# %%
adata.obs['category'] = 'Colorectal'

# %%
adata.obs['study'] = 'Data_Li2017_Colorectal'

# %%
adata.obs
# Out:
#     cell_name patient   cell_type  complexity cell_cycle_phase         source  \
# 0     RHC3546   CRC01         NaN        4544              NaN         tumour
# 1     RHC3552   CRC01   Malignant        1868              NaN         tumour
# 2     RHC3553   CRC01   Malignant        2004              NaN         tumour
# 3     RHC3555   CRC01         NaN        2311              NaN         tumour
# 4     RHC3556   CRC01   Malignant        4305              NaN         tumour
# ..        ...     ...         ...         ...              ...            ...
# 585   RHL2871   CRC08  Fibroblast        2560              NaN  normal mucosa
# 586   RHL2873   CRC08  Epithelial        3190      Not cycling  normal mucosa
# 587   RHL2875   CRC08  Epithelial        3176      Not cycling  normal mucosa
# 588   RHL2879   CRC08      B_cell        3535              NaN  normal mucosa
# 589   RHL2880   CRC08  Epithelial        2190      Not cycling  normal mucosa
#
#     sample technology  n_cells        cancer_type sex  age disease_extent  \
# 0    CRC01  SmartSeq2       44  Colorectal Cancer   M   52          local
# 1    CRC01  SmartSeq2       44  Colorectal Cancer   M   52          local
# 2    CRC01  SmartSeq2       44  Colorectal Cancer   M   52          local
# 3    CRC01  SmartSeq2       44  Colorectal Cancer   M   52          local
# 4    CRC01  SmartSeq2       44  Colorectal Cancer   M   52          local
# ..     ...        ...      ...                ...  ..  ...            ...
# 585  CRC08  SmartSeq2       63  Colorectal Cancer   M   75          local
# 586  CRC08  SmartSeq2       63  Colorectal Cancer   M   75          local
# 587  CRC08  SmartSeq2       63  Colorectal Cancer   M   75          local
# 588  CRC08  SmartSeq2       63  Colorectal Cancer   M   75          local
# 589  CRC08  SmartSeq2       63  Colorectal Cancer   M   75          local
#
#     sample_primary_met           site treated_naive cell_subtype    category  \
# 0              primary   Rectosigmoid         NAIVE          NaN  Colorectal
# 1              primary   Rectosigmoid         NAIVE          NaN  Colorectal
# 2              primary   Rectosigmoid         NAIVE          NaN  Colorectal
# 3              primary   Rectosigmoid         NAIVE          NaN  Colorectal
# 4              primary   Rectosigmoid         NAIVE          NaN  Colorectal
# ..                 ...            ...           ...          ...         ...
# 585            primary  Lower Rectum          NAIVE          NaN  Colorectal
# 586            primary  Lower Rectum          NAIVE          NaN  Colorectal
# 587            primary  Lower Rectum          NAIVE          NaN  Colorectal
# 588            primary  Lower Rectum          NAIVE          NaN  Colorectal
# 589            primary  Lower Rectum          NAIVE          NaN  Colorectal
#
#                       study
# 0    Data_Li2017_Colorectal
# 1    Data_Li2017_Colorectal
# 2    Data_Li2017_Colorectal
# 3    Data_Li2017_Colorectal
# 4    Data_Li2017_Colorectal
# ..                      ...
# 585  Data_Li2017_Colorectal
# 586  Data_Li2017_Colorectal
# 587  Data_Li2017_Colorectal
# 588  Data_Li2017_Colorectal
# 589  Data_Li2017_Colorectal
#
# [590 rows x 19 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Li2017_Colorectal.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Colorectal/Data_Li2017_Colorectal.h5ad

# %% [markdown]
# #### 4. Zhang2018_Colorectal

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Zhang2018_Colorectal"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 11138 × 22902
#     obs: 'cell_name', 'sample', 'patient', 'source', 'cell_type', 'cell_subtype', 'complexity', 'n_cells', 'technology', 'cancer_type', 'age', 'sex'

# %%
adata.obs['msi_status'].value_counts()
# Out:
# msi_status
# MSS    6777
# MSI    4361
# Name: count, dtype: int64

# %%
for col in ['histology', 'tnm_stage', 'stage', 'size', 'grade', 'msi_status',
            'patient_y', 'source_y', 'sorting', 'msi_status', 'cluster'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs
# Out:
#             cell_name   sample patient           source cell_type  \
# 0       NP71-20180123  P0123_N   P0123  Adjacent normal    T_cell
# 1      NP710-20180123  P0123_N   P0123  Adjacent normal    T_cell
# 2      NP711-20180123  P0123_N   P0123  Adjacent normal    T_cell
# 3      NP712-20180123  P0123_N   P0123  Adjacent normal    T_cell
# 4      NP713-20180123  P0123_N   P0123  Adjacent normal    T_cell
# ...               ...      ...     ...              ...       ...
# 11133  TTR92-20161228  P1228_T   P1228            Tumor    T_cell
# 11134  TTR93-20161228  P1228_T   P1228            Tumor    T_cell
# 11135  TTR94-20161228  P1228_T   P1228            Tumor    T_cell
# 11136  TTR95-20161228  P1228_T   P1228            Tumor    T_cell
# 11137  TTR96-20161228  P1228_T   P1228            Tumor    T_cell
#
#           cell_subtype  complexity  n_cells  technology        cancer_type  \
# 0                  CD4        2182      360  Smart-seq2  Colorectal Cancer
# 1                  CD4        4759      360  Smart-seq2  Colorectal Cancer
# 2      double-negative        1851      360  Smart-seq2  Colorectal Cancer
# 3                  NaN        1675      360  Smart-seq2  Colorectal Cancer
# 4      double-negative        2107      360  Smart-seq2  Colorectal Cancer
# ...                ...         ...      ...         ...                ...
# 11133              NaN        3626      390  Smart-seq2  Colorectal Cancer
# 11134              NaN        3902      390  Smart-seq2  Colorectal Cancer
# 11135              NaN        3996      390  Smart-seq2  Colorectal Cancer
# 11136              CD4        4740      390  Smart-seq2  Colorectal Cancer
# 11137              CD4        4173      390  Smart-seq2  Colorectal Cancer
#
#        age     sex cell_cycle_phase disease_extent sample_primary_met site  \
# 0       65  Female              NaN            NaN                NaN  NaN
# 1       65  Female              NaN            NaN                NaN  NaN
# 2       65  Female              NaN            NaN                NaN  NaN
# 3       65  Female              NaN            NaN                NaN  NaN
# 4       65  Female              NaN            NaN                NaN  NaN
# ...    ...     ...              ...            ...                ...  ...
# 11133   77  Female              NaN            NaN                NaN  NaN
# 11134   77  Female              NaN            NaN                NaN  NaN
# 11135   77  Female              NaN            NaN                NaN  NaN
# 11136   77  Female              NaN            NaN                NaN  NaN
# 11137   77  Female              NaN            NaN                NaN  NaN
#
#       treated_naive    category                      study
# 0               NaN  Colorectal  Data_Zhang2018_Colorectal
# 1               NaN  Colorectal  Data_Zhang2018_Colorectal
# 2               NaN  Colorectal  Data_Zhang2018_Colorectal
# 3               NaN  Colorectal  Data_Zhang2018_Colorectal
# 4               NaN  Colorectal  Data_Zhang2018_Colorectal
# ...             ...         ...                        ...
# 11133           NaN  Colorectal  Data_Zhang2018_Colorectal
# 11134           NaN  Colorectal  Data_Zhang2018_Colorectal
# 11135           NaN  Colorectal  Data_Zhang2018_Colorectal
# 11136           NaN  Colorectal  Data_Zhang2018_Colorectal
# 11137           NaN  Colorectal  Data_Zhang2018_Colorectal
#
# [11138 rows x 19 columns]

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['site'] = 'NaN'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['category'] = 'Colorectal'

# %%
adata.obs['study'] = 'Data_Zhang2018_Colorectal'

# %%
output_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Zhang2018_Colorectal.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Colorectal/Data_Zhang2018_Colorectal.h5ad

# %% [markdown]
# #### 5.Pelka2021_Colorectal

# %%
import os
import pandas as pd
import scanpy as sc
import scipy.io
import gc
from scipy.sparse import vstack

# Base path
base_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Pelka2021_Colorectal"

# Step 1: Read gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
gene_names = genes[0].values

# Step 2: Read and concatenate expression matrices and cell metadata
all_exprs = []
all_cells = []

for i in range(1, 5):  # Group1 to Group4
    group_path = os.path.join(base_path, f"Group{i}")
    
    # Load matrix
    mtx_path = os.path.join(group_path, f"Exp_data_UMIcounts{i}.mtx")
    expr = sc.read_mtx(mtx_path).T  # transpose: cells x genes
    all_exprs.append(expr.X)
    
    # Load cell metadata
    cells_path = os.path.join(group_path, f"Cells{i}.csv")
    cells_df = pd.read_csv(cells_path)
    all_cells.append(cells_df)

# Combine all groups
combined_expr = vstack(all_exprs)
combined_cells = pd.concat(all_cells, ignore_index=True)

# Create AnnData object
adata = sc.AnnData(X=combined_expr)
adata.var_names = gene_names
adata.var_names_make_unique()
adata.obs = combined_cells

# Step 3: Read and merge sample metadata
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))
adata.obs = adata.obs.merge(samples, on="sample", how="left")

gc.collect()
# Out:
# /tmp/ipykernel_1270453/3072722585.py:29: DtypeWarning: Columns (15,16,17,18,21,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   cells_df = pd.read_csv(cells_path)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/utils.py:268: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-5', 'SNORD116-6']
#   warnings.warn(
# 1315

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 370115 × 43113
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'sample_type_x', 'HistologicTypeSimple_x', 'MMR_IHC_x', 'MMRStatus_x', 'MLH1Status_x', 'MMRMLH1Tumor_x', 'TissueSite_detailed_x', 'TissueSiteSimple_x', 'HistologicGrade_detailed_x', 'HistologicGradeSimple_x', 'TumorStage_x', 'NodeStatus_detailed_x', 'NodeStatusSimple_x', 'MetastasisStatus_x', 'TumorSize_x', 'SizeQuantile_x', 'PID_x', 'Sex_x', 'Age_x', 'Ethnicity_x', 'Race_x', 'patient', 'cancer_type', 'technology', 'n_cells', 'sample_type_y', 'HistologicTypeSimple_y', 'MSIStatus', 'MMR_IHC_y', 'MMRStatus_y', 'MLH1Status_y', 'MMRMLH1Tumor_y', 'TissueSite_detailed_y', 'TissueSiteSimple_y', 'HistologicGrade_detailed_y', 'HistologicGradeSimple_y', 'TumorStage_y', 'NodeStatus_detailed_y', 'NodeStatusSimple_y', 'MetastasisStatus_y', 'TumorSize_y', 'SizeQuantile_y', 'PID_y', 'Sex_y', 'Age_y', 'Ethnicity_y', 'Race_y'

# %%
adata.obs['MetastasisStatus_x'].value_counts()
# Out:
# MetastasisStatus_x
# not entered (Mx)                                                                                                                 247098
# M1a                                                                                                                                4085
# pM1c (Metastases the peritoneal surface, alone or with other site or organ metastases): Sites involved: Liver and peritoneum.      3091
# M1c                                                                                                                                2977
# Name: count, dtype: int64

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'MMR_IHC_x', 'MMRStatus_x', 'MLH1Status_x', 'MMRMLH1Tumor_x',
            'HistologicGrade_detailed_x', 'HistologicGradeSimple_x', 'TumorStage_x',
            'NodeStatus_detailed_x', 'NodeStatusSimple_x', 'TumorSize_x', 'SizeQuantile_x', 'PID_x',
            'Ethnicity_x', 'Race_x', 'sample_type_y', 'HistologicTypeSimple_y', 'MSIStatus', 'MMR_IHC_y',
            'MMRStatus_y', 'MLH1Status_y', 'MMRMLH1Tumor_y', 'TissueSite_detailed_y', 'TissueSiteSimple_y',
            'HistologicGrade_detailed_y', 'HistologicGradeSimple_y', 'TumorStage_y', 'NodeStatus_detailed_y',
            'NodeStatusSimple_y', 'MetastasisStatus_y', 'TumorSize_y', 'SizeQuantile_y', 'PID_y', 'Sex_y',
            'Age_y', 'Ethnicity_y', 'Race_y', 'HistologicTypeSimple_x', 'TissueSiteSimple_x'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                                      cell_name  sample   cell_type  \
# 0       C103_T_1_1_0_c1_v2_id-AAACCTGCATGCTAGT  C103_T   Malignant
# 1       C103_T_1_1_0_c1_v2_id-AAACCTGGTAGCCTAT  C103_T   Malignant
# 2       C103_T_1_1_0_c1_v2_id-AAACCTGGTTGTCGCG  C103_T   Malignant
# 3       C103_T_1_1_0_c1_v2_id-AAACCTGTCATGTGGT  C103_T   Malignant
# 4       C103_T_1_1_0_c1_v2_id-AAACCTGTCCTTGGTC  C103_T   Malignant
# ...                                        ...     ...         ...
# 370110  C173_T_0_0_0_c1_v3_id-TTTGGAGTCATCGGGC  C173_T  Macrophage
# 370111  C173_T_0_0_0_c1_v3_id-TTTGGAGTCTAGTGTG  C173_T   Malignant
# 370112  C173_T_0_0_0_c1_v3_id-TTTGTTGCAGCAATTC  C173_T   Malignant
# 370113  C173_T_0_0_0_c1_v3_id-TTTGTTGGTTCTGAGT  C173_T      T_cell
# 370114  C173_T_0_0_0_c1_v3_id-TTTGTTGTCGTTCCCA  C173_T   Malignant
#
#                                cell_subtype  complexity cell_cycle_phase  \
# 0                       cE01 (Stem/TA-like)        2950      Not cycling
# 1                       cE01 (Stem/TA-like)         406              NaN
# 2                cE03 (Stem/TA-like prolif)        6509             G1/S
# 3                       cE01 (Stem/TA-like)        3357      Not cycling
# 4                       cE01 (Stem/TA-like)        6147      Not cycling
# ...                                     ...         ...              ...
# 370110               cM02 (Macrophage-like)        3006      Not cycling
# 370111           cE03 (Stem/TA-like prolif)        4216             G1/S
# 370112           cE03 (Stem/TA-like prolif)         772              NaN
# 370113                   cTNI08 (CD4+ Treg)         504              NaN
# 370114  cE02 (Stem/TA-like/Immature Goblet)        5145      Not cycling
#
#        source                        site    disease_extent sex  age patient  \
# 0       Tumor  LEFT colon (sigmoid colon)  not entered (Mx)   M   45    C103
# 1       Tumor  LEFT colon (sigmoid colon)  not entered (Mx)   M   45    C103
# 2       Tumor  LEFT colon (sigmoid colon)  not entered (Mx)   M   45    C103
# 3       Tumor  LEFT colon (sigmoid colon)  not entered (Mx)   M   45    C103
# 4       Tumor  LEFT colon (sigmoid colon)  not entered (Mx)   M   45    C103
# ...       ...                         ...               ...  ..  ...     ...
# 370110  Tumor            LEFT(descending)  not entered (Mx)   F   49    C173
# 370111  Tumor            LEFT(descending)  not entered (Mx)   F   49    C173
# 370112  Tumor            LEFT(descending)  not entered (Mx)   F   49    C173
# 370113  Tumor            LEFT(descending)  not entered (Mx)   F   49    C173
# 370114  Tumor            LEFT(descending)  not entered (Mx)   F   49    C173
#
#               cancer_type technology  n_cells sample_primary_met  \
# 0       Colorectal Cancer        10x     6096                NaN
# 1       Colorectal Cancer        10x     6096                NaN
# 2       Colorectal Cancer        10x     6096                NaN
# 3       Colorectal Cancer        10x     6096                NaN
# 4       Colorectal Cancer        10x     6096                NaN
# ...                   ...        ...      ...                ...
# 370110  Colorectal Cancer        10x     2649                NaN
# 370111  Colorectal Cancer        10x     2649                NaN
# 370112  Colorectal Cancer        10x     2649                NaN
# 370113  Colorectal Cancer        10x     2649                NaN
# 370114  Colorectal Cancer        10x     2649                NaN
#
#        treated_naive                 study    category
# 0                NaN  Pelka2021_Colorectal  Colorectal
# 1                NaN  Pelka2021_Colorectal  Colorectal
# 2                NaN  Pelka2021_Colorectal  Colorectal
# 3                NaN  Pelka2021_Colorectal  Colorectal
# 4                NaN  Pelka2021_Colorectal  Colorectal
# ...              ...                   ...         ...
# 370110           NaN  Pelka2021_Colorectal  Colorectal
# 370111           NaN  Pelka2021_Colorectal  Colorectal
# 370112           NaN  Pelka2021_Colorectal  Colorectal
# 370113           NaN  Pelka2021_Colorectal  Colorectal
# 370114           NaN  Pelka2021_Colorectal  Colorectal
#
# [370115 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"sample_type_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"Sex_x": "sex"})

# %%
adata.obs = adata.obs.rename(columns={"Age_x": "age"})

# %%
adata.obs = adata.obs.rename(columns={"TissueSite_detailed_x": "site"})

# %%
adata.obs = adata.obs.rename(columns={"MetastasisStatus_x": "disease_extent"})

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['study'] = 'Pelka2021_Colorectal'

# %%
adata.obs['category'] = 'Colorectal'

# %%
output_path = "/home/ubuntu/Downloads/Data_Colorectal/Data_Pelka2021_Colorectal.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Colorectal/Data_Pelka2021_Colorectal.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Colorectal/Data_Chen2021_Colorectal.h5ad",
    "/home/ubuntu/Downloads/Data_Colorectal/Data_Lee2020_Colorectal.h5ad",
    "/home/ubuntu/Downloads/Data_Colorectal/Data_Li2017_Colorectal.h5ad",
    "/home/ubuntu/Downloads/Data_Colorectal/Data_Zhang2018_Colorectal.h5ad",
    "/home/ubuntu/Downloads/Data_Colorectal/Data_Pelka2021_Colorectal.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

gc.collect()
# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

gc.collect()
# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

gc.collect()
# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Colorectal/Colorectal_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Colorectal/Colorectal_Combined.h5ad
