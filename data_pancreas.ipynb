# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc
import scipy.io
from scipy.sparse import vstack

# %% [markdown]
# ## Pancreas

# %% [markdown]
# #### 1. Hwang2022_Pancreas

# %%
import os
import gc
import pandas as pd
import scanpy as sc
from scipy.sparse import vstack, csr_matrix

# Base path
base_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Hwang2022_Pancreas"

# Step 1: Read gene names
genes_path = os.path.join(base_path, "genes.txt")
genes = pd.read_csv(genes_path, header=None)
gene_names = genes[0].values

# Step 2: Read and concatenate expression matrices and cell metadata
all_exprs = []
all_cells = []

for i in range(1, 4):  # Group1 to Group3
    group_path = os.path.join(base_path, f"Group{i}")
    
    # Load expression matrix (Matrix Market format assumed)
    mtx_path = os.path.join(group_path, f"Exp_data_UMIcounts{i}.mtx")
    expr = sc.read_mtx(mtx_path).T  # Transpose to shape: cells x genes
    all_exprs.append(expr.X)
    
    # Load cell metadata
    cells_path = os.path.join(group_path, f"Cells{i}.csv")
    cells_df = pd.read_csv(cells_path)
    all_cells.append(cells_df)

# Combine all expression matrices and metadata
combined_expr = vstack(all_exprs)
combined_cells = pd.concat(all_cells, ignore_index=True)

# Step 3: Create AnnData object
adata = sc.AnnData(X=combined_expr)
adata.var_names = gene_names
adata.var_names_make_unique()
adata.obs = combined_cells

gc.collect()

# Step 4: Merge with sample metadata
samples_path = os.path.join(base_path, "Samples.csv")
samples = pd.read_csv(samples_path)

# Merge on the 'sample' column
adata.obs = adata.obs.merge(samples, on="sample", how="left")

# Optional: Check for non-string types that could break .write()
for col in adata.obs.columns:
    if adata.obs[col].dtype.name not in ["category", "object", "bool"]:
        adata.obs[col] = adata.obs[col].astype(str)

# Optional: Save as h5ad
#output_path = os.path.join(base_path, "Data_Pelka2021_Colorectal.h5ad")
#adata.write(output_path)
#print(f"✅ AnnData object saved to: {output_path}")

gc.collect()
# Out:
# 0

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 224988 × 22164
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'disease', 'source_x', 'cancer_type', 'source_y', 'no_cells', 'technology'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'HTAN.Parent.Data.File.ID', 'source_y','disease',
            'patient_y', 'source_y', 'Polyp_Type_y'        
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['technology'].value_counts()
# Out:
# technology
# 10X    224988
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                     cell_name sample   cell_type       cell_subtype  \
# 0        AGAACCTTCTGGGCAC-1-0    T25  Epithelial  Ductal (atypical)
# 1        AAAGGTATCTCTCTAA-1-0    T25   Malignant          Malignant
# 2        TGAATGCGTCGCTCGA-1-0    T25   Malignant          Malignant
# 3        CGTGCTTTCACTGATG-1-0    T25   Malignant          Malignant
# 4        TTGGGCGAGTTGCTCA-1-0    T25   Malignant          Malignant
# ...                       ...    ...         ...                ...
# 224983  CTGTAGAAGATCGACG-1-45     T9  Epithelial             Ductal
# 224984  GTGGAAGTCAGAGTTC-1-45     T9  Epithelial             Ductal
# 224985  CTAACCCAGCTCGAAG-1-45     T9  Epithelial             Ductal
# 224986  CTCCTTTCACAATGAA-1-45     T9  Epithelial             Ductal
# 224987  TCGTGCTAGCGATGCA-1-45     T9  Epithelial             Ductal
#
#        complexity cell_cycle_phase            source  \
# 0            3590      Not cycling  Pancreas Primary
# 1            3533      Not cycling  Pancreas Primary
# 2            3800      Not cycling  Pancreas Primary
# 3            3722      Not cycling  Pancreas Primary
# 4            3859      Not cycling  Pancreas Primary
# ...           ...              ...               ...
# 224983        130              NaN  Pancreas Primary
# 224984        143              NaN  Pancreas Primary
# 224985        111              NaN  Pancreas Primary
# 224986        149              NaN  Pancreas Primary
# 224987        123              NaN  Pancreas Primary
#
#                              cancer_type no_cells technology patient  sex  \
# 0       Pancreatic Ductal Adenocarcinoma     2921        10X     T25  NaN
# 1       Pancreatic Ductal Adenocarcinoma     2921        10X     T25  NaN
# 2       Pancreatic Ductal Adenocarcinoma     2921        10X     T25  NaN
# 3       Pancreatic Ductal Adenocarcinoma     2921        10X     T25  NaN
# 4       Pancreatic Ductal Adenocarcinoma     2921        10X     T25  NaN
# ...                                  ...      ...        ...     ...  ...
# 224983  Pancreatic Ductal Adenocarcinoma     3276        10X      T9  NaN
# 224984  Pancreatic Ductal Adenocarcinoma     3276        10X      T9  NaN
# 224985  Pancreatic Ductal Adenocarcinoma     3276        10X      T9  NaN
# 224986  Pancreatic Ductal Adenocarcinoma     3276        10X      T9  NaN
# 224987  Pancreatic Ductal Adenocarcinoma     3276        10X      T9  NaN
#
#         age disease_extent sample_primary_met      site treated_naive  \
# 0       NaN            NaN                NaN  Pancreas           NaN
# 1       NaN            NaN                NaN  Pancreas           NaN
# 2       NaN            NaN                NaN  Pancreas           NaN
# 3       NaN            NaN                NaN  Pancreas           NaN
# 4       NaN            NaN                NaN  Pancreas           NaN
# ...     ...            ...                ...       ...           ...
# 224983  NaN            NaN                NaN  Pancreas           NaN
# 224984  NaN            NaN                NaN  Pancreas           NaN
# 224985  NaN            NaN                NaN  Pancreas           NaN
# 224986  NaN            NaN                NaN  Pancreas           NaN
# 224987  NaN            NaN                NaN  Pancreas           NaN
#
#                      study  category
# 0       Hwang2022_Pancreas  Pancreas
# 1       Hwang2022_Pancreas  Pancreas
# 2       Hwang2022_Pancreas  Pancreas
# 3       Hwang2022_Pancreas  Pancreas
# 4       Hwang2022_Pancreas  Pancreas
# ...                    ...       ...
# 224983  Hwang2022_Pancreas  Pancreas
# 224984  Hwang2022_Pancreas  Pancreas
# 224985  Hwang2022_Pancreas  Pancreas
# 224986  Hwang2022_Pancreas  Pancreas
# 224987  Hwang2022_Pancreas  Pancreas
#
# [224988 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"no_cells": "n_cells"})

# %%
adata.obs['patient'] = adata.obs['sample']

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['site'] = 'Pancreas'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['study'] = 'Hwang2022_Pancreas'

# %%
adata.obs['category'] = 'Pancreas'

# %%
output_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Hwang2022_Pancreas.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Pancreas/Data_Hwang2022_Pancreas.h5ad

# %% [markdown]
# #### 2.Lin2020_Pancreas

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Lin2020_Pancreas"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 14926 × 22217
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#         cell_name sample   cell_type          cell_subtype  complexity  \
# 0           P03:1    P03   Malignant         Malignant-EMT        3781
# 1           P03:2    P03   Malignant         Malignant-EMT        2055
# 2           P03:3    P03   Malignant         Malignant-EMT        1397
# 3           P03:4    P03  Fibroblast            Fibroblast        3468
# 4           P03:5    P03   Malignant         Malignant-EMT        6130
# ...           ...    ...         ...                   ...         ...
# 14921  MET06:2490  MET06   Malignant  Malignant-epithelial        2264
# 14922  MET06:2491  MET06   Malignant  Malignant-epithelial        1177
# 14923  MET06:2492  MET06   Malignant  Malignant-epithelial        1619
# 14924  MET06:2493  MET06   Malignant  Malignant-epithelial        1996
# 14925  MET06:2494  MET06   Malignant  Malignant-epithelial        1424
#
#       cell_cycle_phase technology  n_cells patient  \
# 0          Not cycling        10x      830     P03
# 1          Not cycling        10x      830     P03
# 2          Not cycling        10x      830     P03
# 3          Not cycling        10x      830     P03
# 4         Intermediate        10x      830     P03
# ...                ...        ...      ...     ...
# 14921      Not cycling        10x     2494   MET06
# 14922      Not cycling        10x     2494   MET06
# 14923      Not cycling        10x     2494   MET06
# 14924      Not cycling        10x     2494   MET06
# 14925      Not cycling        10x     2494   MET06
#
#                             cancer_type sex  age disease_extent  \
# 0      Pancreatic Ductal Adenocarcinoma   M   72  node positive
# 1      Pancreatic Ductal Adenocarcinoma   M   72  node positive
# 2      Pancreatic Ductal Adenocarcinoma   M   72  node positive
# 3      Pancreatic Ductal Adenocarcinoma   M   72  node positive
# 4      Pancreatic Ductal Adenocarcinoma   M   72  node positive
# ...                                 ...  ..  ...            ...
# 14921  Pancreatic Ductal Adenocarcinoma   M   67     metastatic
# 14922  Pancreatic Ductal Adenocarcinoma   M   67     metastatic
# 14923  Pancreatic Ductal Adenocarcinoma   M   67     metastatic
# 14924  Pancreatic Ductal Adenocarcinoma   M   67     metastatic
# 14925  Pancreatic Ductal Adenocarcinoma   M   67     metastatic
#
#       sample_primary_met      site  treated_naive
# 0                primary  Pancreas            NaN
# 1                primary  Pancreas            NaN
# 2                primary  Pancreas            NaN
# 3                primary  Pancreas            NaN
# 4                primary  Pancreas            NaN
# ...                  ...       ...            ...
# 14921                met     Liver            NaN
# 14922                met     Liver            NaN
# 14923                met     Liver            NaN
# 14924                met     Liver            NaN
# 14925                met     Liver            NaN
#
# [14926 rows x 16 columns]

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['study'] = 'Lin2020_Pancreas'

# %%
adata.obs['category'] = 'Pancreas'

# %%
output_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Lin2020_Pancreas.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Pancreas/Data_Lin2020_Pancreas.h5ad

# %% [markdown]
# #### 3.Moncada2020_Pancreas

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Moncada2020_Pancreas"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3659 × 19738
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'sample_x'     
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#         cell_name  sample    cell_type  \
# 0        PDAC_A_1  PDAC_A   Epithelial
# 1        PDAC_A_2  PDAC_A   Epithelial
# 2        PDAC_A_3  PDAC_A   Epithelial
# 3        PDAC_A_4  PDAC_A   Epithelial
# 4        PDAC_A_5  PDAC_A    Malignant
# ...           ...     ...          ...
# 3654  PDAC_B_1729  PDAC_B     Monocyte
# 3655  PDAC_B_1730  PDAC_B    Malignant
# 3656  PDAC_B_1731  PDAC_B   Epithelial
# 3657  PDAC_B_1732  PDAC_B     Monocyte
# 3658  PDAC_B_1733  PDAC_B  Erythrocyte
#
#                                 cell_subtype  complexity cell_cycle_phase  \
# 0                                     Acinar        1951      Not cycling
# 1              Ductal - terminal ductal like        4266      Not cycling
# 2              Ductal - terminal ductal like        3948     Intermediate
# 3     Ductal - CRISP3 high/centroacinar like        4314      Not cycling
# 4                                  Malignant        3542      Not cycling
# ...                                      ...         ...              ...
# 3654                                Monocyte         590              NaN
# 3655                               Malignant         791              NaN
# 3656           Ductal - terminal ductal like         785              NaN
# 3657                                Monocyte         524              NaN
# 3658                             Erythrocyte          48              NaN
#
#      technology  n_cells patient                       cancer_type  sex  age  \
# 0        inDrop     1926  PDAC_A  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# 1        inDrop     1926  PDAC_A  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# 2        inDrop     1926  PDAC_A  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# 3        inDrop     1926  PDAC_A  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# 4        inDrop     1926  PDAC_A  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# ...         ...      ...     ...                               ...  ...  ...
# 3654     inDrop     1733  PDAC_B  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# 3655     inDrop     1733  PDAC_B  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# 3656     inDrop     1733  PDAC_B  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# 3657     inDrop     1733  PDAC_B  Pancreatic Ductal Adenocarcinoma  NaN  NaN
# 3658     inDrop     1733  PDAC_B  Pancreatic Ductal Adenocarcinoma  NaN  NaN
#
#       disease_extent sample_primary_met      site treated_naive source  \
# 0                NaN            primary  pancreas         naive    NaN
# 1                NaN            primary  pancreas         naive    NaN
# 2                NaN            primary  pancreas         naive    NaN
# 3                NaN            primary  pancreas         naive    NaN
# 4                NaN            primary  pancreas         naive    NaN
# ...              ...                ...       ...           ...    ...
# 3654             NaN            primary  pancreas         naive    NaN
# 3655             NaN            primary  pancreas         naive    NaN
# 3656             NaN            primary  pancreas         naive    NaN
# 3657             NaN            primary  pancreas         naive    NaN
# 3658             NaN            primary  pancreas         naive    NaN
#
#       category                 study
# 0     Pancreas  Moncada2020_Pancreas
# 1     Pancreas  Moncada2020_Pancreas
# 2     Pancreas  Moncada2020_Pancreas
# 3     Pancreas  Moncada2020_Pancreas
# 4     Pancreas  Moncada2020_Pancreas
# ...        ...                   ...
# 3654  Pancreas  Moncada2020_Pancreas
# 3655  Pancreas  Moncada2020_Pancreas
# 3656  Pancreas  Moncada2020_Pancreas
# 3657  Pancreas  Moncada2020_Pancreas
# 3658  Pancreas  Moncada2020_Pancreas
#
# [3659 rows x 19 columns]

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Pancreas'

# %%
adata.obs['study'] = 'Moncada2020_Pancreas'

# %%
output_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Moncada2020_Pancreas.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Pancreas/Data_Moncada2020_Pancreas.h5ad

# %% [markdown]
# #### 4. Peng2019_Pancreas

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Peng2019_Pancreas"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 27953 × 18302
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'sample_x'     
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                   cell_name sample   cell_type cell_subtype  complexity  \
# 0      T11_AAACCTGAGTCATCCA    T11  Fibroblast   Fibroblast        3940
# 1      T11_AAACCTGCATGCAACT    T11  Epithelial     Ductal_1        2189
# 2      T11_AAACCTGGTATATGGA    T11  Fibroblast   Fibroblast        2434
# 3      T11_AAACCTGGTGAGTGAC    T11         NaN          NaN        1248
# 4      T11_AAACCTGGTGCACCAC    T11  Macrophage   Macrophage        2422
# ...                     ...    ...         ...          ...         ...
# 27948   T9_TTTGTCAGTCTCCACT     T9   Malignant    Malignant        4828
# 27949   T9_TTTGTCAGTTACCAGT     T9  Macrophage   Macrophage        1744
# 27950   T9_TTTGTCAGTTGCGCAC     T9  Epithelial     Ductal_1        2146
# 27951   T9_TTTGTCATCCGCATAA     T9   Malignant    Malignant        2505
# 27952   T9_TTTGTCATCTTACCGC     T9   Malignant    Malignant        4146
#
#       cell_cycle_phase technology  n_cells patient  \
# 0          Not cycling        10x     3133     T11
# 1          Not cycling        10x     3133     T11
# 2          Not cycling        10x     3133     T11
# 3          Not cycling        10x     3133     T11
# 4          Not cycling        10x     3133     T11
# ...                ...        ...      ...     ...
# 27948      Not cycling        10x     2354      T9
# 27949      Not cycling        10x     2354      T9
# 27950      Not cycling        10x     2354      T9
# 27951      Not cycling        10x     2354      T9
# 27952      Not cycling        10x     2354      T9
#
#                             cancer_type sex  age disease_extent  \
# 0      Pancreatic Ductal Adenocarcinoma   M   51  node positive
# 1      Pancreatic Ductal Adenocarcinoma   M   51  node positive
# 2      Pancreatic Ductal Adenocarcinoma   M   51  node positive
# 3      Pancreatic Ductal Adenocarcinoma   M   51  node positive
# 4      Pancreatic Ductal Adenocarcinoma   M   51  node positive
# ...                                 ...  ..  ...            ...
# 27948  Pancreatic Ductal Adenocarcinoma   M   36         local
# 27949  Pancreatic Ductal Adenocarcinoma   M   36         local
# 27950  Pancreatic Ductal Adenocarcinoma   M   36         local
# 27951  Pancreatic Ductal Adenocarcinoma   M   36         local
# 27952  Pancreatic Ductal Adenocarcinoma   M   36         local
#
#       sample_primary_met           site treated_naive source  category  \
# 0                Primary  body and tail         NAIVE    NaN  Pancreas
# 1                Primary  body and tail         NAIVE    NaN  Pancreas
# 2                Primary  body and tail         NAIVE    NaN  Pancreas
# 3                Primary  body and tail         NAIVE    NaN  Pancreas
# 4                Primary  body and tail         NAIVE    NaN  Pancreas
# ...                  ...            ...           ...    ...       ...
# 27948            Primary           head         NAIVE    NaN  Pancreas
# 27949            Primary           head         NAIVE    NaN  Pancreas
# 27950            Primary           head         NAIVE    NaN  Pancreas
# 27951            Primary           head         NAIVE    NaN  Pancreas
# 27952            Primary           head         NAIVE    NaN  Pancreas
#
#                    study
# 0      Peng2019_Pancreas
# 1      Peng2019_Pancreas
# 2      Peng2019_Pancreas
# 3      Peng2019_Pancreas
# 4      Peng2019_Pancreas
# ...                  ...
# 27948  Peng2019_Pancreas
# 27949  Peng2019_Pancreas
# 27950  Peng2019_Pancreas
# 27951  Peng2019_Pancreas
# 27952  Peng2019_Pancreas
#
# [27953 rows x 19 columns]

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Pancreas'

# %%
adata.obs['study'] = 'Peng2019_Pancreas'

# %%
output_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Peng2019_Pancreas.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Pancreas/Data_Peng2019_Pancreas.h5ad

# %% [markdown]
# #### 5.Raghavan2021_Pancreas

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Raghavan2021_Pancreas"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 24412 × 16814
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'disease', 'source', 'cancer_type', 'technology', 'n_cells'

# %%
adata.obs['MetastasisStatus_x'].value_counts()
# Out:
# MetastasisStatus_x
# not entered (Mx)                                                                                                                 247098
# M1a                                                                                                                                4085
# pM1c (Metastases the peritoneal surface, alone or with other site or organ metastases): Sites involved: Liver and peritoneum.      3091
# M1c                                                                                                                                2977
# Name: count, dtype: int64

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 'patient_y',
            'mp_assignment', 'MMR_IHC_x', 'MMRStatus_x', 'MLH1Status_x', 'MMRMLH1Tumor_x',
            'HistologicGrade_detailed_x', 'HistologicGradeSimple_x', 'TumorStage_x', 'disease',
            'NodeStatus_detailed_x', 'NodeStatusSimple_x', 'TumorSize_x', 'SizeQuantile_x', 'PID_x',
            'Ethnicity_x', 'Race_x', 'sample_type_y', 'HistologicTypeSimple_y', 'MSIStatus', 'MMR_IHC_y',
            'MMRStatus_y', 'MLH1Status_y', 'MMRMLH1Tumor_y', 'TissueSite_detailed_y', 'TissueSiteSimple_y',
            'HistologicGrade_detailed_y', 'HistologicGradeSimple_y', 'TumorStage_y', 'NodeStatus_detailed_y',
            'NodeStatusSimple_y', 'MetastasisStatus_y', 'TumorSize_y', 'SizeQuantile_y', 'PID_y', 'Sex_y',
            'Age_y', 'Ethnicity_y', 'Race_y', 'HistologicTypeSimple_x', 'TissueSiteSimple_x'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                                       cell_name                 sample  \
# 0      Biopsy_PANFR0383_T2_1digest_AAACAATCTAGT  PANFR0383_Biopsy_None
# 1      Biopsy_PANFR0383_T2_1digest_AAACACAGCTTT  PANFR0383_Biopsy_None
# 2      Biopsy_PANFR0383_T2_1digest_AAACGTTGAGTG  PANFR0383_Biopsy_None
# 3      Biopsy_PANFR0383_T2_1digest_AAAGCAGCATCC  PANFR0383_Biopsy_None
# 4      Biopsy_PANFR0383_T2_1digest_AAATACAAGGAC  PANFR0383_Biopsy_None
# ...                                         ...                    ...
# 24407        Biopsy_PANFR0473_T3_1_TGTCCTACTACC  PANFR0473_Biopsy_None
# 24408        Biopsy_PANFR0473_T3_1_TGTGGATCCTAG  PANFR0473_Biopsy_None
# 24409        Biopsy_PANFR0473_T3_1_TTATCGGTAACA  PANFR0473_Biopsy_None
# 24410        Biopsy_PANFR0473_T3_1_TTCACCTAATGT  PANFR0473_Biopsy_None
# 24411        Biopsy_PANFR0473_T3_1_TTGCAGGATCGT  PANFR0473_Biopsy_None
#
#          patient   cell_type cell_subtype  complexity cell_cycle_phase source  \
# 0      PANFR0383   Malignant    Malignant         499              NaN  Liver
# 1      PANFR0383   Malignant    Malignant        1960      Not cycling  Liver
# 2      PANFR0383   Malignant    Malignant        1317      Not cycling  Liver
# 3      PANFR0383  Macrophage   Macrophage         614              NaN  Liver
# 4      PANFR0383   Malignant    Malignant        1336      Not cycling  Liver
# ...          ...         ...          ...         ...              ...    ...
# 24407  PANFR0473      T_cell         T_NK         918              NaN   Lung
# 24408  PANFR0473      Plasma       Plasma        1229      Not cycling   Lung
# 24409  PANFR0473      T_cell         T_NK         743              NaN   Lung
# 24410  PANFR0473      B_cell       B_cell        1554      Not cycling   Lung
# 24411  PANFR0473      T_cell         T_NK         924              NaN   Lung
#
#                             cancer_type technology  n_cells  sex  age  \
# 0      Pancreatic Ductal Adenocarcinoma   Seq-Well     1008  NaN  NaN
# 1      Pancreatic Ductal Adenocarcinoma   Seq-Well     1008  NaN  NaN
# 2      Pancreatic Ductal Adenocarcinoma   Seq-Well     1008  NaN  NaN
# 3      Pancreatic Ductal Adenocarcinoma   Seq-Well     1008  NaN  NaN
# 4      Pancreatic Ductal Adenocarcinoma   Seq-Well     1008  NaN  NaN
# ...                                 ...        ...      ...  ...  ...
# 24407  Pancreatic Ductal Adenocarcinoma   Seq-Well     1370  NaN  NaN
# 24408  Pancreatic Ductal Adenocarcinoma   Seq-Well     1370  NaN  NaN
# 24409  Pancreatic Ductal Adenocarcinoma   Seq-Well     1370  NaN  NaN
# 24410  Pancreatic Ductal Adenocarcinoma   Seq-Well     1370  NaN  NaN
# 24411  Pancreatic Ductal Adenocarcinoma   Seq-Well     1370  NaN  NaN
#
#       disease_extent sample_primary_met treated_naive                  study  \
# 0                NaN                NaN           NaN  Raghavan2021_Pancreas
# 1                NaN                NaN           NaN  Raghavan2021_Pancreas
# 2                NaN                NaN           NaN  Raghavan2021_Pancreas
# 3                NaN                NaN           NaN  Raghavan2021_Pancreas
# 4                NaN                NaN           NaN  Raghavan2021_Pancreas
# ...              ...                ...           ...                    ...
# 24407            NaN                NaN           NaN  Raghavan2021_Pancreas
# 24408            NaN                NaN           NaN  Raghavan2021_Pancreas
# 24409            NaN                NaN           NaN  Raghavan2021_Pancreas
# 24410            NaN                NaN           NaN  Raghavan2021_Pancreas
# 24411            NaN                NaN           NaN  Raghavan2021_Pancreas
#
#        category   site
# 0      Pancreas  Liver
# 1      Pancreas  Liver
# 2      Pancreas  Liver
# 3      Pancreas  Liver
# 4      Pancreas  Liver
# ...         ...    ...
# 24407  Pancreas   Lung
# 24408  Pancreas   Lung
# 24409  Pancreas   Lung
# 24410  Pancreas   Lung
# 24411  Pancreas   Lung
#
# [24412 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs['site']=adata.obs['source'].copy()

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['study'] = 'Raghavan2021_Pancreas'

# %%
adata.obs['category'] = 'Pancreas'

# %%
output_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Raghavan2021_Pancreas.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Pancreas/Data_Raghavan2021_Pancreas.h5ad

# %% [markdown]
# #### 6.Steele2020_Pancreas

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Steele2020_Pancreas"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 48570 × 32738
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'additional_tumor_characterisics', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                                cell_name          sample   cell_type  \
# 0       PDAC_TISSUE_1_AAACGAAAGTGGAAAG-1   PDAC_TISSUE_1         NaN
# 1       PDAC_TISSUE_1_AAACGAAGTAGGGTAC-1   PDAC_TISSUE_1   Malignant
# 2       PDAC_TISSUE_1_AAACGAAGTCATAGTC-1   PDAC_TISSUE_1   Malignant
# 3       PDAC_TISSUE_1_AAACGCTGTAATCAGA-1   PDAC_TISSUE_1         NaN
# 4       PDAC_TISSUE_1_AAAGAACCATTAAAGG-1   PDAC_TISSUE_1  Macrophage
# ...                                  ...             ...         ...
# 48565  PDAC_TISSUE_16_TTTCCTCTCTGGTATG-1  PDAC_TISSUE_16  Macrophage
# 48566  PDAC_TISSUE_16_TTTGCGCGTAGCGTCC-1  PDAC_TISSUE_16   Malignant
# 48567  PDAC_TISSUE_16_TTTGGTTCATGCATGT-1  PDAC_TISSUE_16  Fibroblast
# 48568  PDAC_TISSUE_16_TTTGGTTTCAACGGCC-1  PDAC_TISSUE_16   Malignant
# 48569  PDAC_TISSUE_16_TTTGTCACAGATGGCA-1  PDAC_TISSUE_16  Epithelial
#
#        complexity cell_cycle_phase technology  n_cells         patient  \
# 0             267              NaN        10x     1633   PDAC_TISSUE_1
# 1            4630      Not cycling        10x     1633   PDAC_TISSUE_1
# 2            7961      Not cycling        10x     1633   PDAC_TISSUE_1
# 3             158              NaN        10x     1633   PDAC_TISSUE_1
# 4            4032      Not cycling        10x     1633   PDAC_TISSUE_1
# ...           ...              ...        ...      ...             ...
# 48565        2726      Not cycling        10x      962  PDAC_TISSUE_16
# 48566        6013      Not cycling        10x      962  PDAC_TISSUE_16
# 48567        3309      Not cycling        10x      962  PDAC_TISSUE_16
# 48568        3680      Not cycling        10x      962  PDAC_TISSUE_16
# 48569        5664      Not cycling        10x      962  PDAC_TISSUE_16
#
#                             cancer_type  sex  age  disease_extent  \
# 0      Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# 1      Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# 2      Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# 3      Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# 4      Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# ...                                 ...  ...  ...             ...
# 48565  Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# 48566  Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# 48567  Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# 48568  Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
# 48569  Pancreatic Ductal Adenocarcinoma  NaN  NaN             NaN
#
#        sample_primary_met  site  additional_tumor_characterisics  \
# 0                     NaN   NaN                              NaN
# 1                     NaN   NaN                              NaN
# 2                     NaN   NaN                              NaN
# 3                     NaN   NaN                              NaN
# 4                     NaN   NaN                              NaN
# ...                   ...   ...                              ...
# 48565                 NaN   NaN                              NaN
# 48566                 NaN   NaN                              NaN
# 48567                 NaN   NaN                              NaN
# 48568                 NaN   NaN                              NaN
# 48569                 NaN   NaN                              NaN
#
#        treated_naive source  category                study
# 0                NaN    NaN  Pancreas  Steele2020_Pancreas
# 1                NaN    NaN  Pancreas  Steele2020_Pancreas
# 2                NaN    NaN  Pancreas  Steele2020_Pancreas
# 3                NaN    NaN  Pancreas  Steele2020_Pancreas
# 4                NaN    NaN  Pancreas  Steele2020_Pancreas
# ...              ...    ...       ...                  ...
# 48565            NaN    NaN  Pancreas  Steele2020_Pancreas
# 48566            NaN    NaN  Pancreas  Steele2020_Pancreas
# 48567            NaN    NaN  Pancreas  Steele2020_Pancreas
# 48568            NaN    NaN  Pancreas  Steele2020_Pancreas
# 48569            NaN    NaN  Pancreas  Steele2020_Pancreas
#
# [48570 rows x 19 columns]

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Pancreas'

# %%
adata.obs['study'] = 'Steele2020_Pancreas'

# %%
output_path = "/home/ubuntu/Downloads/Data_Pancreas/Data_Steele2020_Pancreas.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Pancreas/Data_Steele2020_Pancreas.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Pancreas/Data_Hwang2022_Pancreas.h5ad",
    "/home/ubuntu/Downloads/Data_Pancreas/Data_Lin2020_Pancreas.h5ad",
    "/home/ubuntu/Downloads/Data_Pancreas/Data_Moncada2020_Pancreas.h5ad",
    "/home/ubuntu/Downloads/Data_Pancreas/Data_Peng2019_Pancreas.h5ad",
    "/home/ubuntu/Downloads/Data_Pancreas/Data_Raghavan2021_Pancreas.h5ad",
    "/home/ubuntu/Downloads/Data_Pancreas/Data_Steele2020_Pancreas.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

gc.collect()
# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

gc.collect()
# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

gc.collect()
# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Pancreas/Pancreas_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Pancreas/Pancreas_Combined.h5ad

# %%
adata_merged
# Out:
# AnnData object with n_obs × n_vars = 344508 × 36388
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'cancer_type', 'n_cells', 'technology', 'patient', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive', 'study', 'category'

# %%
del adata_merged.obs['additional_tumor_characterisics']

# %%
# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Pancreas/Pancreas_Combined.h5ad"
adata_merged.write(output_path)
