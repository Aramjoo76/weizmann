# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc
import scipy
from scipy.sparse import vstack, csr_matrix

# %% [markdown]
# ## Neuroendocrine

# %% [markdown]
# #### 1. Dong2020_Neuroendocrine

# %%
import os
import pandas as pd
import scanpy as sc
import scipy.io
import numpy as np
import gc

# Base path
base_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Dong2020_Neuroendocrine"

# Paths to Group1 and Group2
group_paths = {
    "Group1": os.path.join(base_path, "Group1"),
    "Group2": os.path.join(base_path, "Group2"),
}

# Initialize lists to collect group-wise data
adatas = []
for group_name, group_path in group_paths.items():
    # Read mtx and transpose (cells x genes)
    adata = sc.read_mtx(os.path.join(group_path, f"Exp_data_UMIcounts{group_name[-1]}.mtx")).transpose()
    
    # Add gene names
    genes = pd.read_csv(os.path.join(group_path, f"Genes{group_name[-1]}.txt"), header=None)
    adata.var_names = genes[0].values
    adata.var_names_make_unique()
    
    # Add cell metadata
    cells = pd.read_csv(os.path.join(group_path, f"Cells{group_name[-1]}.csv"))
    adata.obs = cells
    
    # Tag group info
    adata.obs["group"] = group_name

    # Collect this group's AnnData
    adatas.append(adata)

# Concatenate all groups into one AnnData object
adata = adatas[0].concatenate(adatas[1:], join='outer', index_unique=None)

# Read sample metadata
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge adata.obs with sample metadata on 'sample'
adata.obs = adata.obs.merge(samples, on="sample", how="left")

# Optional: garbage collection
gc.collect()
# Out:
# /tmp/ipykernel_1390902/444838888.py:39: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata = adatas[0].concatenate(adatas[1:], join='outer', index_unique=None)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# 2296

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 55190 × 33972
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'group', 'batch', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'treatment_exposure', 'treatment_response', 'cell_lineage',
            'smoking_status', 'PY', 'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'group', 'batch'      
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                 cell_name     sample  cell_type  complexity cell_cycle_phase  \
# 0      AAACCTGTCTTTAGTC.1   Tumor_10  Malignant        2248             G1/S
# 1      AAACGGGGTTTCCACC.1   Tumor_10  Malignant        3165      Not cycling
# 2      AAAGATGCAGAGTGTG.1   Tumor_10  Malignant        3442             G2/M
# 3      AAAGATGGTACTTCTT.1   Tumor_10  Malignant        3531      Not cycling
# 4      AAAGCAAAGAGCTTCT.1   Tumor_10  Malignant        3106             G1/S
# ...                   ...        ...        ...         ...              ...
# 55185  TTTGTTGCATGATAGA-1  Tumor_230  Malignant        2620      Not cycling
# 55186  TTTGTTGCATTGCTTT-1  Tumor_230  Malignant        2764      Not cycling
# 55187  TTTGTTGGTAACTTCG-1  Tumor_230  Malignant        4465             G1/S
# 55188  TTTGTTGGTAGAGATT-1  Tumor_230        NaN        2255              NaN
# 55189  TTTGTTGTCTACACAG-1  Tumor_230  Malignant        3270      Not cycling
#
#       technology  n_cells    patient    cancer_type sex   age disease_extent  \
# 0            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# 1            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# 2            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# 3            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# 4            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# ...          ...      ...        ...            ...  ..   ...            ...
# 55185        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
# 55186        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
# 55187        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
# 55188        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
# 55189        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
#
#       sample_primary_met     site treated_naive source
# 0                primary  adrenal         naive    NaN
# 1                primary  adrenal         naive    NaN
# 2                primary  adrenal         naive    NaN
# 3                primary  adrenal         naive    NaN
# 4                primary  adrenal         naive    NaN
# ...                  ...      ...           ...    ...
# 55185            primary  adrenal         naive    NaN
# 55186            primary  adrenal         naive    NaN
# 55187            primary  adrenal         naive    NaN
# 55188            primary  adrenal         naive    NaN
# 55189            primary  adrenal         naive    NaN
#
# [55190 rows x 16 columns]

# %%
adata.obs['source'].value_counts()
# Out:
# source
# kidney        22879
# abdomen        4637
# lung           3744
# lymph node     3066
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                 cell_name     sample  cell_type  complexity cell_cycle_phase  \
# 0      AAACCTGTCTTTAGTC.1   Tumor_10  Malignant        2248             G1/S
# 1      AAACGGGGTTTCCACC.1   Tumor_10  Malignant        3165      Not cycling
# 2      AAAGATGCAGAGTGTG.1   Tumor_10  Malignant        3442             G2/M
# 3      AAAGATGGTACTTCTT.1   Tumor_10  Malignant        3531      Not cycling
# 4      AAAGCAAAGAGCTTCT.1   Tumor_10  Malignant        3106             G1/S
# ...                   ...        ...        ...         ...              ...
# 55185  TTTGTTGCATGATAGA-1  Tumor_230  Malignant        2620      Not cycling
# 55186  TTTGTTGCATTGCTTT-1  Tumor_230  Malignant        2764      Not cycling
# 55187  TTTGTTGGTAACTTCG-1  Tumor_230  Malignant        4465             G1/S
# 55188  TTTGTTGGTAGAGATT-1  Tumor_230        NaN        2255              NaN
# 55189  TTTGTTGTCTACACAG-1  Tumor_230  Malignant        3270      Not cycling
#
#       technology  n_cells    patient    cancer_type sex   age disease_extent  \
# 0            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# 1            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# 2            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# 3            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# 4            10x      886   Tumor_10  Neuroblastoma   M  3Y3M     metastatic
# ...          ...      ...        ...            ...  ..   ...            ...
# 55185        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
# 55186        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
# 55187        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
# 55188        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
# 55189        10x    12125  Tumor_230  Neuroblastoma   M  4Y8M          local
#
#       sample_primary_met     site treated_naive source  \
# 0                primary  adrenal         naive    NaN
# 1                primary  adrenal         naive    NaN
# 2                primary  adrenal         naive    NaN
# 3                primary  adrenal         naive    NaN
# 4                primary  adrenal         naive    NaN
# ...                  ...      ...           ...    ...
# 55185            primary  adrenal         naive    NaN
# 55186            primary  adrenal         naive    NaN
# 55187            primary  adrenal         naive    NaN
# 55188            primary  adrenal         naive    NaN
# 55189            primary  adrenal         naive    NaN
#
#                          study        category cell-subtype
# 0      Dong2020_Neuroendocrine  Neuroendocrine          NaN
# 1      Dong2020_Neuroendocrine  Neuroendocrine          NaN
# 2      Dong2020_Neuroendocrine  Neuroendocrine          NaN
# 3      Dong2020_Neuroendocrine  Neuroendocrine          NaN
# 4      Dong2020_Neuroendocrine  Neuroendocrine          NaN
# ...                        ...             ...          ...
# 55185  Dong2020_Neuroendocrine  Neuroendocrine          NaN
# 55186  Dong2020_Neuroendocrine  Neuroendocrine          NaN
# 55187  Dong2020_Neuroendocrine  Neuroendocrine          NaN
# 55188  Dong2020_Neuroendocrine  Neuroendocrine          NaN
# 55189  Dong2020_Neuroendocrine  Neuroendocrine          NaN
#
# [55190 rows x 19 columns]

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['cell-subtype'] = 'NaN'

# %%
adata.obs['study'] = 'Dong2020_Neuroendocrine'

# %%
adata.obs['category'] = 'Neuroendocrine'

# %%
output_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Dong2020_Neuroendocrine.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Neuroendocrine/Data_Dong2020_Neuroendocrine.h5ad

# %% [markdown]
# #### 2.Jansky2021_Neuroendocrine

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Jansky2021_Neuroendocrine"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 64769 × 26344
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'authors_cell_type', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'treatment_exposure', 'treatment_response', 'cell_lineage',
            'smoking_status', 'PY', 'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'group', 'batch' , 'authors_cell_type'     
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['authors_cell_type'].value_counts()
# Out:
# authors_cell_type
# Tumor cells          59312
# Immune cells          2655
# Mesenchymal cells     1297
# Liver cells            669
# Endothelial cells      559
# Schwann cells          277
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                  cell_name sample  cell_type  complexity cell_cycle_phase  \
# 0       AAACCTGAGCAATATG_1   NB03  Malignant        1165      Not cycling
# 1       AAACCTGAGCGCTTAT_1   NB03        NaN         901              NaN
# 2       AAACCTGAGGCACATG_1   NB03  Malignant        1414      Not cycling
# 3       AAACCTGAGTGGCACA_1   NB03  Malignant        1051      Not cycling
# 4       AAACCTGAGTTCGCAT_1   NB03        NaN         958              NaN
# ...                    ...    ...        ...         ...              ...
# 64764  TTTGTCATCACGATGT_14   NB14        NaN         380              NaN
# 64765  TTTGTCATCAGTGTTG_14   NB14  Malignant         612              NaN
# 64766  TTTGTCATCCACGCAG_14   NB14        NaN         443              NaN
# 64767  TTTGTCATCCTAGAAC_14   NB14  Malignant         519              NaN
# 64768  TTTGTCATCTGCTTGC_14   NB14        NaN         420              NaN
#
#       technology  n_cells patient    cancer_type sex          age  \
# 0            10x     5052    NB03  Neuroblastoma   F  > 18 months
# 1            10x     5052    NB03  Neuroblastoma   F  > 18 months
# 2            10x     5052    NB03  Neuroblastoma   F  > 18 months
# 3            10x     5052    NB03  Neuroblastoma   F  > 18 months
# 4            10x     5052    NB03  Neuroblastoma   F  > 18 months
# ...          ...      ...     ...            ...  ..          ...
# 64764        10x     7964    NB14  Neuroblastoma   M  > 18 months
# 64765        10x     7964    NB14  Neuroblastoma   M  > 18 months
# 64766        10x     7964    NB14  Neuroblastoma   M  > 18 months
# 64767        10x     7964    NB14  Neuroblastoma   M  > 18 months
# 64768        10x     7964    NB14  Neuroblastoma   M  > 18 months
#
#       disease_extent sample_primary_met  \
# 0                NaN            primary
# 1                NaN            primary
# 2                NaN            primary
# 3                NaN            primary
# 4                NaN            primary
# ...              ...                ...
# 64764     metastatic                met
# 64765     metastatic                met
# 64766     metastatic                met
# 64767     metastatic                met
# 64768     metastatic                met
#
#                                          site treated_naive source  \
# 0                              thorax/abdomen         naive    NaN
# 1                              thorax/abdomen         naive    NaN
# 2                              thorax/abdomen         naive    NaN
# 3                              thorax/abdomen         naive    NaN
# 4                              thorax/abdomen         naive    NaN
# ...                                       ...           ...    ...
# 64764  occipital subcutaneous bone metastasis           NaN    NaN
# 64765  occipital subcutaneous bone metastasis           NaN    NaN
# 64766  occipital subcutaneous bone metastasis           NaN    NaN
# 64767  occipital subcutaneous bone metastasis           NaN    NaN
# 64768  occipital subcutaneous bone metastasis           NaN    NaN
#
#       cell_subtype                      study        category
# 0              NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# 1              NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# 2              NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# 3              NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# 4              NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# ...            ...                        ...             ...
# 64764          NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# 64765          NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# 64766          NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# 64767          NaN  Jansky2021_Neuroendocrine  Neuroendocrine
# 64768          NaN  Jansky2021_Neuroendocrine  Neuroendocrine
#
# [64769 rows x 19 columns]

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['study'] = 'Jansky2021_Neuroendocrine'

# %%
adata.obs['category'] = 'Neuroendocrine'

# %%
output_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Jansky2021_Neuroendocrine.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Neuroendocrine/Data_Jansky2021_Neuroendocrine.h5ad

# %% [markdown]
# #### 3.Rao2020_Neuroendocrine

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Rao2020_Neuroendocrine"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4739 × 25006
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'complexity', 'patient_y', 'n_cells', 'technology', 'cancer_type', 'age', 'sex', 'disease_extent', 'sample_primary_met', 'site', 'additional_tumor_characterisics', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'additional_tumor_characterisics' , 'patient_y'     
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Neuroendocrine'

# %%
adata.obs['study'] = 'Rao2020_Neuroendocrine'

# %%
adata.obs
# Out:
#                       cell_name  sample patient_x    cell_type  complexity  \
# 0     PriNET_AAACCTGAGAAACGCC-1  PriNET       NET   Fibroblast         959
# 1     PriNET_AAACCTGAGTGGGATC-1  PriNET       NET    Malignant        4707
# 2     PriNET_AAACCTGAGTGTACGG-1  PriNET       NET          NaN         540
# 3     PriNET_AAACCTGTCTATCCCG-1  PriNET       NET  Endothelial        1027
# 4     PriNET_AAACGGGAGCCACCTG-1  PriNET       NET   Macrophage        1152
# ...                         ...     ...       ...          ...         ...
# 4734  livMET_TTTGTCAGTCCGAGTC-1  livMET       NET          NaN         450
# 4735  livMET_TTTGTCAGTTATCACG-1  livMET       NET    Malignant         856
# 4736  livMET_TTTGTCATCATACGGT-1  livMET       NET   Fibroblast         707
# 4737  livMET_TTTGTCATCCGTTGTC-1  livMET       NET          NaN         333
# 4738  livMET_TTTGTCATCCTTGGTC-1  livMET       NET          NaN         539
#
#       n_cells technology           cancer_type  age     sex disease_extent  \
# 0        1144        10x  Neuroendocrine Tumor   58  female     metastatic
# 1        1144        10x  Neuroendocrine Tumor   58  female     metastatic
# 2        1144        10x  Neuroendocrine Tumor   58  female     metastatic
# 3        1144        10x  Neuroendocrine Tumor   58  female     metastatic
# 4        1144        10x  Neuroendocrine Tumor   58  female     metastatic
# ...       ...        ...                   ...  ...     ...            ...
# 4734     3595        10x  Neuroendocrine Tumor   58  female     metastatic
# 4735     3595        10x  Neuroendocrine Tumor   58  female     metastatic
# 4736     3595        10x  Neuroendocrine Tumor   58  female     metastatic
# 4737     3595        10x  Neuroendocrine Tumor   58  female     metastatic
# 4738     3595        10x  Neuroendocrine Tumor   58  female     metastatic
#
#      sample_primary_met             site treated_naive cell_cycle_phase  \
# 0               primary  small intestine         naive              NaN
# 1               primary  small intestine         naive              NaN
# 2               primary  small intestine         naive              NaN
# 3               primary  small intestine         naive              NaN
# 4               primary  small intestine         naive              NaN
# ...                 ...              ...           ...              ...
# 4734                met            liver         naive              NaN
# 4735                met            liver         naive              NaN
# 4736                met            liver         naive              NaN
# 4737                met            liver         naive              NaN
# 4738                met            liver         naive              NaN
#
#      cell_subtype        category                   study source
# 0             NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# 1             NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# 2             NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# 3             NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# 4             NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# ...           ...             ...                     ...    ...
# 4734          NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# 4735          NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# 4736          NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# 4737          NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
# 4738          NaN  Neuroendocrine  Rao2020_Neuroendocrine    NaN
#
# [4739 rows x 19 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Rao2020_Neuroendocrine.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Neuroendocrine/Data_Rao2020_Neuroendocrine.h5ad

# %% [markdown]
# #### 4. Kildisiute2021_Neuroendocrine

# %%
# Set base path
base_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Kildisiute2021_Neuroendocrine"

# === Load 10X Data ===
path_10x = os.path.join(base_path, "10X")
adata_10x = sc.read_mtx(os.path.join(path_10x, "Exp_data_UMIcounts.mtx")).T  # Transpose to cells x genes
genes_10x = pd.read_csv(os.path.join(path_10x, "Genes.txt"), header=None)[0].tolist()
cells_10x = pd.read_csv(os.path.join(path_10x, "Cells.csv"), index_col=0)

adata_10x.var_names = genes_10x
adata_10x.obs = cells_10x
adata_10x.obs['technology'] = '10X'

# === Load CEL-seq2 Data ===
path_ss2 = os.path.join(base_path, "CEL-seq2")
adata_ss2 = sc.read_mtx(os.path.join(path_ss2, "Exp_data_TPM.mtx")).T
genes_ss2 = pd.read_csv(os.path.join(path_ss2, "Genes.txt"), header=None)[0].tolist()
cells_ss2 = pd.read_csv(os.path.join(path_ss2, "Cells.csv"), index_col=0)

adata_ss2.var_names = genes_ss2
adata_ss2.obs = cells_ss2
adata_ss2.obs['technology'] = 'CEL-seq2'

# === Align by common genes ===
common_genes = adata_10x.var_names.intersection(adata_ss2.var_names)
adata_10x = adata_10x[:, common_genes].copy()
adata_ss2 = adata_ss2[:, common_genes].copy()

# === Concatenate ===
adata_combined = adata_10x.concatenate(
    adata_ss2,
    batch_key='batch',
    batch_categories=['10X', 'CEL-seq2'],
    index_unique=None
)

# === Check uniqueness ===
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# === Merge sample metadata ===
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

# Preserve and reset index
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]

# Merge with sample metadata
adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')
assert adata_combined.obs.shape[0] == adata_combined.shape[0], "Row count mismatch after metadata merge"

# Restore index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index.name = None
# Out:
# /tmp/ipykernel_1390902/3488701806.py:30: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adata_10x.concatenate(

# %%
adata = adata_combined

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 19723 × 32118
#     obs: 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology_x', 'batch', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'cell_QCpass', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'batch'  
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Neuroendocrine'

# %%
adata.obs['study'] = 'Kildisiute2021_Neuroendocrine'

# %%
adata.obs = adata.obs.rename(columns={"technology_x": "technology"})

# %%
adata.obs
# Out:
#                                sample    cell_type  complexity  \
# STDY7685340_AAACCTGCACATCCGG  PD42184       T_cell        1319
# STDY7685340_AAACGGGGTTGAACTC  PD42184   Fibroblast        3222
# STDY7685340_AAACGGGGTTGTCGCG  PD42184   Fibroblast        2161
# STDY7685340_AAACGGGTCCGCTGTT  PD42184   Fibroblast        1646
# STDY7685340_AACACGTAGCCCTAAT  PD42184  Endothelial        3756
# ...                               ...          ...         ...
# TM231-P7                       000CGH    Malignant        8472
# TM231-P9                       000CGH    Malignant        6243
# TM231-P10                      000CGH    Malignant        3043
# TM231-P11                      000CGH    Malignant        5161
# TM231-P13                      000CGH    Malignant        2444
#
#                              cell_cycle_phase technology  n_cells  patient  \
# STDY7685340_AAACCTGCACATCCGG              NaN        10X     3721  PD42184
# STDY7685340_AAACGGGGTTGAACTC              NaN        10X     3721  PD42184
# STDY7685340_AAACGGGGTTGTCGCG              NaN        10X     3721  PD42184
# STDY7685340_AAACGGGTCCGCTGTT              NaN        10X     3721  PD42184
# STDY7685340_AACACGTAGCCCTAAT              NaN        10X     3721  PD42184
# ...                                       ...        ...      ...      ...
# TM231-P7                                  NaN   CEL-seq2      584   000CGH
# TM231-P9                                  NaN   CEL-seq2      584   000CGH
# TM231-P10                                 NaN   CEL-seq2      584   000CGH
# TM231-P11                                 NaN   CEL-seq2      584   000CGH
# TM231-P13                                 NaN   CEL-seq2      584   000CGH
#
#                                 cancer_type  sex  age disease_extent  \
# STDY7685340_AAACCTGCACATCCGG         Normal  NaN  NaN            NaN
# STDY7685340_AAACGGGGTTGAACTC         Normal  NaN  NaN            NaN
# STDY7685340_AAACGGGGTTGTCGCG         Normal  NaN  NaN            NaN
# STDY7685340_AAACGGGTCCGCTGTT         Normal  NaN  NaN            NaN
# STDY7685340_AACACGTAGCCCTAAT         Normal  NaN  NaN            NaN
# ...                                     ...  ...  ...            ...
# TM231-P7                      Neuroblastoma  NaN  NaN     metastatic
# TM231-P9                      Neuroblastoma  NaN  NaN     metastatic
# TM231-P10                     Neuroblastoma  NaN  NaN     metastatic
# TM231-P11                     Neuroblastoma  NaN  NaN     metastatic
# TM231-P13                     Neuroblastoma  NaN  NaN     metastatic
#
#                              sample_primary_met  site treated_naive  \
# STDY7685340_AAACCTGCACATCCGG            primary   NaN         Naive
# STDY7685340_AAACGGGGTTGAACTC            primary   NaN         Naive
# STDY7685340_AAACGGGGTTGTCGCG            primary   NaN         Naive
# STDY7685340_AAACGGGTCCGCTGTT            primary   NaN         Naive
# STDY7685340_AACACGTAGCCCTAAT            primary   NaN         Naive
# ...                                         ...   ...           ...
# TM231-P7                                primary   NaN       Treated
# TM231-P9                                primary   NaN       Treated
# TM231-P10                               primary   NaN       Treated
# TM231-P11                               primary   NaN       Treated
# TM231-P13                               primary   NaN       Treated
#
#                                                  cell_name cell_subtype  \
# STDY7685340_AAACCTGCACATCCGG  STDY7685340_AAACCTGCACATCCGG          NaN
# STDY7685340_AAACGGGGTTGAACTC  STDY7685340_AAACGGGGTTGAACTC          NaN
# STDY7685340_AAACGGGGTTGTCGCG  STDY7685340_AAACGGGGTTGTCGCG          NaN
# STDY7685340_AAACGGGTCCGCTGTT  STDY7685340_AAACGGGTCCGCTGTT          NaN
# STDY7685340_AACACGTAGCCCTAAT  STDY7685340_AACACGTAGCCCTAAT          NaN
# ...                                                    ...          ...
# TM231-P7                                          TM231-P7          NaN
# TM231-P9                                          TM231-P9          NaN
# TM231-P10                                        TM231-P10          NaN
# TM231-P11                                        TM231-P11          NaN
# TM231-P13                                        TM231-P13          NaN
#
#                              source        category  \
# STDY7685340_AAACCTGCACATCCGG    NaN  Neuroendocrine
# STDY7685340_AAACGGGGTTGAACTC    NaN  Neuroendocrine
# STDY7685340_AAACGGGGTTGTCGCG    NaN  Neuroendocrine
# STDY7685340_AAACGGGTCCGCTGTT    NaN  Neuroendocrine
# STDY7685340_AACACGTAGCCCTAAT    NaN  Neuroendocrine
# ...                             ...             ...
# TM231-P7                        NaN  Neuroendocrine
# TM231-P9                        NaN  Neuroendocrine
# TM231-P10                       NaN  Neuroendocrine
# TM231-P11                       NaN  Neuroendocrine
# TM231-P13                       NaN  Neuroendocrine
#
#                                                       study
# STDY7685340_AAACCTGCACATCCGG  Kildisiute2021_Neuroendocrine
# STDY7685340_AAACGGGGTTGAACTC  Kildisiute2021_Neuroendocrine
# STDY7685340_AAACGGGGTTGTCGCG  Kildisiute2021_Neuroendocrine
# STDY7685340_AAACGGGTCCGCTGTT  Kildisiute2021_Neuroendocrine
# STDY7685340_AACACGTAGCCCTAAT  Kildisiute2021_Neuroendocrine
# ...                                                     ...
# TM231-P7                      Kildisiute2021_Neuroendocrine
# TM231-P9                      Kildisiute2021_Neuroendocrine
# TM231-P10                     Kildisiute2021_Neuroendocrine
# TM231-P11                     Kildisiute2021_Neuroendocrine
# TM231-P13                     Kildisiute2021_Neuroendocrine
#
# [19723 rows x 19 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Kildisiute2021_Neuroendocrine.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Neuroendocrine/Data_Kildisiute2021_Neuroendocrine.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Kildisiute2021_Neuroendocrine.h5ad",
    "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Dong2020_Neuroendocrine.h5ad",
    "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Jansky2021_Neuroendocrine.h5ad",
    "/home/ubuntu/Downloads/Data_Neuroendocrine/Data_Rao2020_Neuroendocrine.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Neuroendocrine/Neuroendocrine_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Neuroendocrine/Neuroendocrine_Combined.h5ad
