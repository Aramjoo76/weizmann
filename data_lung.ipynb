# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc
import scipy.io
from scipy.sparse import vstack

# %% [markdown]
# ## Lung

# %% [markdown]
# #### 1. Data_Bischoff2021_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Bischoff2021_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 120961 × 33514
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'source', 'technology', 'n_cells', 'patient_y', 'cancer_type', 'sample_type'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score',
            'mp_top_score', 'mp_top', 'mp_assignment', 
            'patient_y', 'sample_type'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                         cell_name  sample patient   cell_type  \
# 0            AAACCCAAGACGACGT-1_1  p018_N    p018         NaN
# 1            AAACCCAAGCACTCTA-1_2  p018_N    p018  Macrophage
# 2            AAACCCAAGCTGAAGC-1_3  p018_N    p018  Macrophage
# 3            AAACCCACAACTTGGT-1_4  p018_N    p018  Macrophage
# 4            AAACCCACAAGAATAC-1_5  p018_N    p018  Macrophage
# ...                           ...     ...     ...         ...
# 120956  TTTGGTTAGAGTGTTA-1_120957  p034_T    p034  Macrophage
# 120957  TTTGGTTGTCCCTCAT-1_120958  p034_T    p034      T_cell
# 120958  TTTGTTGCAGTAGAAT-1_120959  p034_T    p034      T_cell
# 120959  TTTGTTGTCAAAGGAT-1_120960  p034_T    p034      T_cell
# 120960  TTTGTTGTCATCACCC-1_120961  p034_T    p034      T_cell
#
#                  cell_subtype  complexity cell_cycle_phase  source technology  \
# 0                         NaN         519              NaN  Normal        10x
# 1       Alveolar_Macrophages1         618              NaN  Normal        10x
# 2       Alveolar_Macrophages1         660              NaN  Normal        10x
# 3       Alveolar_Macrophages1         843              NaN  Normal        10x
# 4       Alveolar_Macrophages1        1060      Not cycling  Normal        10x
# ...                       ...         ...              ...     ...        ...
# 120956      CD14_Macrophages2        5310             G1/S   Tumor        10x
# 120957                T_CD8_1        1648      Not cycling   Tumor        10x
# 120958                T_CD8_1        1801      Not cycling   Tumor        10x
# 120959                T_CD8_1        1499      Not cycling   Tumor        10x
# 120960                T_CD8_1        1673      Not cycling   Tumor        10x
#
#         n_cells          cancer_type              study category
# 0         11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# 1         11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# 2         11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# 3         11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# 4         11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# ...         ...                  ...                ...      ...
# 120956     4480  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# 120957     4480  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# 120958     4480  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# 120959     4480  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
# 120960     4480  Lung Adenocarcinoma  Bischoff2021_Lung     Lung
#
# [120961 rows x 13 columns]

# %%
adata.obs['study'] = 'Bischoff2021_Lung'

# %%
adata.obs['category'] = 'Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Bischoff2021_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Bischoff2021_Lung.h5ad

# %% [markdown]
# #### 2.Data_Chan2021_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Chan2021_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 86662 × 26036
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'source_x', 'treatment_x', 'procedure_x', 'disease', 'technology', 'n_cells', 'patient_y', 'cancer_type', 'sample_type', 'source_y', 'treatment_y', 'procedure_y', 'sample_primary_met', 'diagnosis_recurrence'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'procedure_x', 'disease','diagnosis_recurrence',
            'sample_type', 'source_y', 'treatment_y', 'procedure_y', 'patient_y',
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['procedure_x'].value_counts()
# Out:
# procedure_x
# Resection        46870
# Biopsy           33881
# Thoracentesis     5911
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                                       cell_name                    sample  \
# 0                        RU1215_192110488599350                    RU1215
# 1                      RU1057_T_231270811326245                  RU1057_T
# 2                        RU1152_130751366121844                    RU1152
# 3               PleuralEffusion_235007433161052           PleuralEffusion
# 4                        RU1128_169014021282219                    RU1128
# ...                                         ...                       ...
# 86657                    RU1128_126765648178078                    RU1128
# 86658                  RU1057_T_235559336667493                  RU1057_T
# 86659  RU1108a_Bambanker_Frozen_231897696155998  RU1108a_Bambanker_Frozen
# 86660                    RU1138_235198540340019                    RU1138
# 86661                   RU1181B_236168014327141                   RU1181B
#
#              patient_x    cell_type cell_subtype  complexity cell_cycle_phase  \
# 0               RU1215    Malignant       SCLC-N        3719      Not cycling
# 1               RU1057  Endothelial  Endothelial        2293      Not cycling
# 2               RU1152    Malignant       SCLC-A        5093      Not cycling
# 3      PleuralEffusion       T_cell       T_cell        1011      Not cycling
# 4               RU1128       T_cell       T_cell        1386      Not cycling
# ...                ...          ...          ...         ...              ...
# 86657           RU1128   Macrophage   Macrophage        2808      Not cycling
# 86658           RU1057       T_cell       T_cell        1062      Not cycling
# 86659          RU1108a    Malignant       SCLC-A        3532      Not cycling
# 86660           RU1138       T_cell       T_cell        1131      Not cycling
# 86661           RU1181    Malignant       SCLC-N        5438     Intermediate
#
#                source_x                                        treatment_x  \
# 0      pleural_effusion                                              Naive
# 1                  lung                                              Naive
# 2                    LN                                              Naive
# 3      pleural_effusion  Platinum Doublet,Immunotherapy,TMZ,Other chemo...
# 4                  lung                                              Naive
# ...                 ...                                                ...
# 86657              lung                                              Naive
# 86658              lung                                              Naive
# 86659              lung                Platinum Doublet,PARP inhibitor,TMZ
# 86660             liver                 Platinum Doublet,Immunotherapy,TKI
# 86661              lung                                   Platinum Doublet
#
#       technology  n_cells             cancer_type sample_primary_met
# 0            10x     3843  Small Cell Lung Cancer         Metastasis
# 1            10x     2413     Lung Adenocarcinoma            Primary
# 2            10x     1926  Small Cell Lung Cancer         Metastasis
# 3            10x     2068  Small Cell Lung Cancer         Metastasis
# 4            10x     1373     Lung Adenocarcinoma            Primary
# ...          ...      ...                     ...                ...
# 86657        10x     1373     Lung Adenocarcinoma            Primary
# 86658        10x     2413     Lung Adenocarcinoma            Primary
# 86659        10x     4008  Small Cell Lung Cancer            Primary
# 86660        10x     2260  Small Cell Lung Cancer         Metastasis
# 86661        10x     1871  Small Cell Lung Cancer            Primary
#
# [86662 rows x 13 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"treatment_x": "treated_naive"})

# %%
adata.obs['study'] = 'Chan2021_Lung'

# %%
adata.obs['category'] = 'Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Chan2021_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Chan2021_Lung.h5ad

# %% [markdown]
# #### 3.Data_Guo2018_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Guo2018_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12346 × 22669
#     obs: 'cell_name', 'sample', 'patient_x', 'source_x', 'sorting', 'cell_type', 'cell_subtype', 'cluster', 'complexity', 'patient_y', 'source_y', 'n_cells', 'cancer_type', 'technology', 'age', 'sex', 'stage', 'tnm_stage'

# %%
for col in ['sorting',  'stage', 'tnm_stage','patient_y', 'source_y','cluster',
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#             cell_name    sample patient_x         source_x cell_type  \
# 0         NTH10-0616A  P0616A_N    P0616A  Adjacent normal    T_cell
# 1         NTH11-0616A  P0616A_N    P0616A  Adjacent normal    T_cell
# 2         NTH15-0616A  P0616A_N    P0616A  Adjacent normal    T_cell
# 3         NTH17-0616A  P0616A_N    P0616A  Adjacent normal    T_cell
# 4          NTH2-0616A  P0616A_N    P0616A  Adjacent normal    T_cell
# ...               ...       ...       ...              ...       ...
# 12341  TTY63-20171219   P1219_T     P1219            Tumor    T_cell
# 12342  TTY65-20171219   P1219_T     P1219            Tumor    T_cell
# 12343   TTY7-20171219   P1219_T     P1219            Tumor    T_cell
# 12344   TTY8-20171219   P1219_T     P1219            Tumor    T_cell
# 12345   TTY9-20171219   P1219_T     P1219            Tumor    T_cell
#
#           cell_subtype  complexity  n_cells          cancer_type technology  \
# 0                 CD4+        3540       15  Lung Adenocarcinoma  SmartSeq2
# 1                other        3710       15  Lung Adenocarcinoma  SmartSeq2
# 2      double-negative        3707       15  Lung Adenocarcinoma  SmartSeq2
# 3                 CD4+        3427       15  Lung Adenocarcinoma  SmartSeq2
# 4                 CD4+        3482       15  Lung Adenocarcinoma  SmartSeq2
# ...                ...         ...      ...                  ...        ...
# 12341  double-negative        2471      128  Lung Adenocarcinoma  SmartSeq2
# 12342             CD4+        1373      128  Lung Adenocarcinoma  SmartSeq2
# 12343             CD4+        1682      128  Lung Adenocarcinoma  SmartSeq2
# 12344             CD4+        1725      128  Lung Adenocarcinoma  SmartSeq2
# 12345            other        2152      128  Lung Adenocarcinoma  SmartSeq2
#
#        age     sex
# 0       74  Female
# 1       74  Female
# 2       74  Female
# 3       74  Female
# 4       74  Female
# ...    ...     ...
# 12341   63  Female
# 12342   63  Female
# 12343   63  Female
# 12344   63  Female
# 12345   63  Female
#
# [12346 rows x 12 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs['category'] = 'Lung'

# %%
adata.obs['study'] = 'Guo2018_Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Guo2018_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Guo2018_Lung.h5ad

# %% [markdown]
# #### 4. Data_Ireland2020_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Ireland2020_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read cell and sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Add cell-level metadata
adata.obs = cells

# Broadcast sample-level metadata to all cells
for col in samples.columns:
    if col != "Unnamed: 0":
        adata.obs[col] = samples.at[0, col]

# Optional: Clean memory
gc.collect()
# Out:
# 0

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2201 × 33538
#     obs: 'cell_name', 'complexity', 'cell_cycle_phase', 'sample', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
adata.obs['technology'].value_counts()
# Out:
# technology
# 10X    2201
# Name: count, dtype: int64

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score',
            'mp_top_score', 'mp_top', 'mp_assignment', 'source',
            'smoking_status', 'PY', 'diagnosis_recurrence', 
            'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage','size', 
           'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                cell_name  complexity  cell_cycle_phase                sample  \
# 0     AAACCTGAGTCGTTTG-1        2077               NaN  Human_liver_SCLC_met
# 1     AAACCTGGTCAACATC-1        1911               NaN  Human_liver_SCLC_met
# 2     AAACCTGTCAAACGGG-1        6966               NaN  Human_liver_SCLC_met
# 3     AAACGGGAGCGTAATA-1        1385               NaN  Human_liver_SCLC_met
# 4     AAACGGGGTGGGTATG-1        6834               NaN  Human_liver_SCLC_met
# ...                  ...         ...               ...                   ...
# 2196  TTTGGTTTCGAGCCCA-1         507               NaN  Human_liver_SCLC_met
# 2197  TTTGTCAAGGTTACCT-1        1942               NaN  Human_liver_SCLC_met
# 2198  TTTGTCAAGTACACCT-1        7872               NaN  Human_liver_SCLC_met
# 2199  TTTGTCAGTCTTGTCC-1        1337               NaN  Human_liver_SCLC_met
# 2200  TTTGTCATCGGTCCGA-1        6321               NaN  Human_liver_SCLC_met
#
#      technology  n_cells               patient cancer_type  sex  age  \
# 0           10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# 1           10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# 2           10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# 3           10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# 4           10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# ...         ...      ...                   ...         ...  ...  ...
# 2196        10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# 2197        10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# 2198        10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# 2199        10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
# 2200        10X     2201  Human_liver_SCLC_met        SCLC  NaN  NaN
#
#      disease_extent sample_primary_met   site treated_naive
# 0        metastatic                met  liver       treated
# 1        metastatic                met  liver       treated
# 2        metastatic                met  liver       treated
# 3        metastatic                met  liver       treated
# 4        metastatic                met  liver       treated
# ...             ...                ...    ...           ...
# 2196     metastatic                met  liver       treated
# 2197     metastatic                met  liver       treated
# 2198     metastatic                met  liver       treated
# 2199     metastatic                met  liver       treated
# 2200     metastatic                met  liver       treated
#
# [2201 rows x 14 columns]

# %%
adata.obs['category'] = 'Lung'

# %%
adata.obs['study'] = 'Ireland2020_Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Ireland2020_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Ireland2020_Lung.h5ad

# %% [markdown]
# #### 5.Kim2020_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Kim2020_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 32493 × 20793
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'source', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                        cell_name sample   cell_type  complexity  \
# 0      AAACCTGAGACGACGT_LUNG_T34  P0034      B_cell        1287
# 1      AAACCTGAGACTGTAA_LUNG_T34  P0034   Malignant        5804
# 2      AAACCTGAGATGTCGG_LUNG_T31  P0031  Epithelial        1162
# 3       AAACCTGAGCCAGGAT_EBUS_28  P1028   Malignant        1728
# 4      AAACCTGAGCGCTTAT_LUNG_T19  P0019  Macrophage        1509
# ...                          ...    ...         ...         ...
# 32488  TTTGTCATCGGTGTTA_LUNG_T28  P0028         NaN        1027
# 32489   TTTGTCATCTGGGCCA_EBUS_06  P1006         NaN        1128
# 32490   TTTGTCATCTTACCGC_EBUS_49  P1049      T_cell        1304
# 32491  TTTGTCATCTTGCCGT_LUNG_T30  P0030   Malignant        2202
# 32492  TTTGTCATCTTTAGGG_LUNG_T31  P0031   Malignant        5603
#
#       cell_cycle_phase source technology  n_cells patient  \
# 0          Not cycling  tLung        10x     2704   P0034
# 1          Not cycling  tLung        10x     2704   P0034
# 2          Not cycling  tLung        10x     1898   P0031
# 3          Not cycling   tL/B        10x     4445   P1028
# 4          Not cycling  tLung        10x     3127   P0019
# ...                ...    ...        ...      ...     ...
# 32488              NaN  tLung        10x     2642   P0028
# 32489              NaN   tL/B        10x     1264   P1006
# 32490      Not cycling   tL/B        10x     1458   P1049
# 32491      Not cycling  tLung        10x     2111   P0030
# 32492      Not cycling  tLung        10x     1898   P0031
#
#                cancer_type  sex  age disease_extent sample_primary_met  site  \
# 0      Lung Adenocarcinoma  NaN  NaN            NaN            primary  Lung
# 1      Lung Adenocarcinoma  NaN  NaN            NaN            primary  Lung
# 2      Lung Adenocarcinoma  NaN  NaN            NaN            primary  Lung
# 3      Lung Adenocarcinoma  NaN  NaN     metastatic            primary  Lung
# 4      Lung Adenocarcinoma  NaN  NaN            NaN            primary  Lung
# ...                    ...  ...  ...            ...                ...   ...
# 32488  Lung Adenocarcinoma  NaN  NaN            NaN            primary  Lung
# 32489  Lung Adenocarcinoma  NaN  NaN     metastatic            primary  Lung
# 32490  Lung Adenocarcinoma  NaN  NaN     metastatic            primary  Lung
# 32491  Lung Adenocarcinoma  NaN  NaN            NaN            primary  Lung
# 32492  Lung Adenocarcinoma  NaN  NaN            NaN            primary  Lung
#
#        treated_naive
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 32488            NaN
# 32489            NaN
# 32490            NaN
# 32491            NaN
# 32492            NaN
#
# [32493 rows x 16 columns]

# %%
adata.obs['study'] = 'Kim2020_Lung'

# %%
adata.obs['category'] = 'Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Kim2020_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Kim2020_Lung.h5ad

# %% [markdown]
# #### 6.Laughney2020_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Laughney2020_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 40505 × 19222
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#        cell_name sample   cell_type cell_subtype  complexity cell_cycle_phase  \
# 0              0  RU653      T_cell           Tm         856              NaN
# 1             10  RU653  Macrophage   Macrophage        2732      Not cycling
# 2          10000  RU653   Dendritic    Dendritic        2012      Not cycling
# 3          10001  RU653      T_cell           Tm         646              NaN
# 4          10002  RU653      T_cell           Tm        1025      Not cycling
# ...          ...    ...         ...          ...         ...              ...
# 40500       9994  RU701      T_cell           Tm         950              NaN
# 40501       9995  RU701      T_cell           Tm         540              NaN
# 40502       9996  RU701      T_cell           Tm        1267      Not cycling
# 40503       9997  RU701      T_cell           Tm         900              NaN
# 40504       9999  RU701  Macrophage   Macrophage         701              NaN
#
#                     source technology  n_cells patient          cancer_type  \
# 0      RU653_TUMOR_1AS_UTR        10x     2381   RU653  Lung Adenocarcinoma
# 1      RU653_TUMOR_1AS_UTR        10x     2381   RU653  Lung Adenocarcinoma
# 2      RU653_TUMOR_1AS_UTR        10x     2381   RU653  Lung Adenocarcinoma
# 3      RU653_TUMOR_1AS_UTR        10x     2381   RU653  Lung Adenocarcinoma
# 4      RU653_TUMOR_1AS_UTR        10x     2381   RU653  Lung Adenocarcinoma
# ...                    ...        ...      ...     ...                  ...
# 40500     RU701_BRAINMET_4        10x     2546   RU701  Lung Adenocarcinoma
# 40501     RU701_BRAINMET_4        10x     2546   RU701  Lung Adenocarcinoma
# 40502     RU701_BRAINMET_4        10x     2546   RU701  Lung Adenocarcinoma
# 40503     RU701_BRAINMET_4        10x     2546   RU701  Lung Adenocarcinoma
# 40504     RU701_BRAINMET_4        10x     2546   RU701  Lung Adenocarcinoma
#
#        sex  age disease_extent sample_primary_met      site treated_naive  \
# 0      NaN  NaN          local            primary  Primary          NAIVE
# 1      NaN  NaN          local            primary  Primary          NAIVE
# 2      NaN  NaN          local            primary  Primary          NAIVE
# 3      NaN  NaN          local            primary  Primary          NAIVE
# 4      NaN  NaN          local            primary  Primary          NAIVE
# ...    ...  ...            ...                ...       ...           ...
# 40500  NaN  NaN     metastatic                met  M(Brain)       TREATED
# 40501  NaN  NaN     metastatic                met  M(Brain)       TREATED
# 40502  NaN  NaN     metastatic                met  M(Brain)       TREATED
# 40503  NaN  NaN     metastatic                met  M(Brain)       TREATED
# 40504  NaN  NaN     metastatic                met  M(Brain)       TREATED
#
#       category              study
# 0         Lung  Laughney2020_Lung
# 1         Lung  Laughney2020_Lung
# 2         Lung  Laughney2020_Lung
# 3         Lung  Laughney2020_Lung
# 4         Lung  Laughney2020_Lung
# ...        ...                ...
# 40500     Lung  Laughney2020_Lung
# 40501     Lung  Laughney2020_Lung
# 40502     Lung  Laughney2020_Lung
# 40503     Lung  Laughney2020_Lung
# 40504     Lung  Laughney2020_Lung
#
# [40505 rows x 19 columns]

# %%
adata.obs['category'] = 'Lung'

# %%
adata.obs['study'] = 'Laughney2020_Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Laughney2020_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Laughney2020_Lung.h5ad

# %% [markdown]
# #### 7.Maynard2020_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Maynard2020_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 19777 × 26577
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'n_cells', 'technology', 'cancer_type', 'sex', 'age', 'sample_primary_met', 'site', 'disease_extent', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67','source_y',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch','time_rx_to_sampling',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs
# Out:
#            cell_name  sample patient       cell_type    cell_subtype  \
# 0      A1_1001000292  LT_S03   TH156       Dendritic       Dendritic
# 1      A1_1001000295  LT_S03   TH156       Dendritic       Dendritic
# 2      A1_1001000315  LT_S07   TH103      Macrophage      Macrophage
# 3      A1_1001000376  LT_S14   TH153         NK_cell         NK_cell
# 4         A1_B000278  LT_S41   TH210      Macrophage      Macrophage
# ...              ...     ...     ...             ...             ...
# 19772     P9_B003658  LT_S50   TH225          Plasma          Plasma
# 19773     P9_B003771  LT_S71   TH236          Plasma          Plasma
# 19774     P9_B003894  LT_S71   TH236            Mast            Mast
# 19775     P9_B003920  LT_S71   TH236            Mast            Mast
# 19776     P9_B003995  LT_S71   TH236  Lymphovascular  Lymphovascular
#
#        complexity cell_cycle_phase source  n_cells technology  \
# 0            2648      Not cycling  tumor      193  SmartSeq2
# 1            1406      Not cycling  tumor      193  SmartSeq2
# 2            2270      Not cycling  tumor      137  SmartSeq2
# 3            1834      Not cycling  tumor       62  SmartSeq2
# 4            2064      Not cycling  tumor       61  SmartSeq2
# ...           ...              ...    ...      ...        ...
# 19772        3779      Not cycling  tumor      348  SmartSeq2
# 19773        2364      Not cycling  tumor     1007  SmartSeq2
# 19774        2286      Not cycling  tumor     1007  SmartSeq2
# 19775        2807      Not cycling  tumor     1007  SmartSeq2
# 19776        2274      Not cycling  tumor     1007  SmartSeq2
#
#                cancer_type     sex   age sample_primary_met     site  \
# 0      Lung Adenocarcinoma    Male  43.0         Metastatic   Pleura
# 1      Lung Adenocarcinoma    Male  43.0         Metastatic   Pleura
# 2      Lung Adenocarcinoma  Female  45.0         Metastatic   Pleura
# 3      Lung Adenocarcinoma  Female  63.0         Metastatic    Liver
# 4      Lung Adenocarcinoma    Male  56.0         Metastatic  Adrenal
# ...                    ...     ...   ...                ...      ...
# 19772  Lung Adenocarcinoma  Female  77.0         Metastatic       LN
# 19773  Lung Adenocarcinoma  Female  58.0            Primary     Lung
# 19774  Lung Adenocarcinoma  Female  58.0            Primary     Lung
# 19775  Lung Adenocarcinoma  Female  58.0            Primary     Lung
# 19776  Lung Adenocarcinoma  Female  58.0            Primary     Lung
#
#       disease_extent treated_naive
# 0         metastatic       treated
# 1         metastatic       treated
# 2         metastatic       treated
# 3         metastatic       treated
# 4         metastatic       treated
# ...              ...           ...
# 19772     metastatic         naive
# 19773     metastatic       treated
# 19774     metastatic       treated
# 19775     metastatic       treated
# 19776     metastatic       treated
#
# [19777 rows x 17 columns]

# %%
adata.obs['category'] = 'Lung'

# %%
adata.obs['study'] = 'Maynard2020_Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Maynard2020_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Maynard2020_Lung.h5ad

# %% [markdown]
# #### 8.Qian2020_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Qian2020_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 27262 × 22276
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'disease', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'disease',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67','source_y',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch','time_rx_to_sampling',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                         cell_name  sample   cell_type cell_subtype  \
# 0           BT1238_AACTTGCTACTCTT       1   Malignant    Malignant
# 1           BT1238_AAGCCTGATTCCAT       1      T_cell       T_cell
# 2           BT1238_ACAATAACCGATAC       1        Mast         Mast
# 3           BT1238_ACCCTCGATTGGTG       1      T_cell       T_cell
# 4           BT1238_ACGAAGCTTGGGAG       1  Macrophage   Macrophage
# ...                           ...     ...         ...          ...
# 27257  scrBT1432_TTTATGCCATTGTGCA       8      T_cell       T_cell
# 27258  scrBT1432_TTTCCTCCACTTGGAT       8      T_cell       T_cell
# 27259  scrBT1432_TTTCCTCGTTCGGGCT       8      T_cell       T_cell
# 27260  scrBT1432_TTTGCGCTCTTCAACT       8      T_cell       T_cell
# 27261  scrBT1432_TTTGGTTCATTCTCAT       8      T_cell       T_cell
#
#        complexity cell_cycle_phase source technology  n_cells patient  \
# 0            2266      Not cycling   core        10x      465    LC_1
# 1            2437             G1/S   core        10x      465    LC_1
# 2            1047      Not cycling   core        10x      465    LC_1
# 3            2067             G1/S   core        10x      465    LC_1
# 4            1087      Not cycling   core        10x      465    LC_1
# ...           ...              ...    ...        ...      ...     ...
# 27257        2365      Not cycling   core        10x     4868    LC_8
# 27258        1185      Not cycling   core        10x     4868    LC_8
# 27259        1012      Not cycling   core        10x     4868    LC_8
# 27260        1600      Not cycling   core        10x     4868    LC_8
# 27261        1378      Not cycling   core        10x     4868    LC_8
#
#                         cancer_type sex    age disease_extent  \
# 0      Lung Squamous Cell Carcinoma   F  70-75          local
# 1      Lung Squamous Cell Carcinoma   F  70-75          local
# 2      Lung Squamous Cell Carcinoma   F  70-75          local
# 3      Lung Squamous Cell Carcinoma   F  70-75          local
# 4      Lung Squamous Cell Carcinoma   F  70-75          local
# ...                             ...  ..    ...            ...
# 27257   Lung Pleiomorphic Carcinoma   F  50-55          local
# 27258   Lung Pleiomorphic Carcinoma   F  50-55          local
# 27259   Lung Pleiomorphic Carcinoma   F  50-55          local
# 27260   Lung Pleiomorphic Carcinoma   F  50-55          local
# 27261   Lung Pleiomorphic Carcinoma   F  50-55          local
#
#       sample_primary_met  site treated_naive
# 0                      P   NaN         naive
# 1                      P   NaN         naive
# 2                      P   NaN         naive
# 3                      P   NaN         naive
# 4                      P   NaN         naive
# ...                  ...   ...           ...
# 27257                  P   NaN         naive
# 27258                  P   NaN         naive
# 27259                  P   NaN         naive
# 27260                  P   NaN         naive
# 27261                  P   NaN         naive
#
# [27262 rows x 17 columns]

# %%
adata.obs['category'] = 'Lung'

# %%
adata.obs['study'] = 'Qian2020_Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Qian2020_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Qian2020_Lung.h5ad

# %% [markdown]
# #### 9.Song2019_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Song2019_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 8772 × 10147
#     obs: 'cell_name', 'sample', 'patient', 'source', 'cell_type', 'cell_subtype', 'complexity', 'n_cells', 'technology', 'cancer_type', 'sex'

# %%
for col in ['sample_id_x', 'sample_id_y', 'patient_y', 'source_y','tnm_stage','race', 'smoking_status'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs
# Out:
#                            cell_name     sample patient           source  \
# 0      Tumor_5258_AAACCTGGTACAGACG-1   P1_Tumor      P1            tumor
# 1      Tumor_5258_AAACGGGGTAGCGCTC-1   P1_Tumor      P1            tumor
# 2      Tumor_5258_AAACGGGGTCCTCTTG-1   P1_Tumor      P1            tumor
# 3      Tumor_5258_AAACGGGTCCAAACAC-1   P1_Tumor      P1            tumor
# 4      Tumor_5258_AAACGGGTCTTTAGTC-1   P1_Tumor      P1            tumor
# ...                              ...        ...     ...              ...
# 8767  Normal_5489_TTTGGTTTCTGCGTAA-1  P4_Normal      P4  adjacent normal
# 8768  Normal_5489_TTTGTCACAAGTCATC-1  P4_Normal      P4  adjacent normal
# 8769  Normal_5489_TTTGTCAGTATGAATG-1  P4_Normal      P4  adjacent normal
# 8770  Normal_5489_TTTGTCATCACTGGGC-1  P4_Normal      P4  adjacent normal
# 8771  Normal_5489_TTTGTCATCGTGACAT-1  P4_Normal      P4  adjacent normal
#
#      cell_type    cell_subtype  complexity  n_cells technology  \
# 0     Monocyte  CD14+ Monocyte        1224     1832        10x
# 1      NK_cell              NK        2456     1832        10x
# 2       T_cell          T-cell         726     1832        10x
# 3       T_cell              Th         986     1832        10x
# 4     Monocyte  CD14+ Monocyte        1590     1832        10x
# ...        ...             ...         ...      ...        ...
# 8767    T_cell          T-cell         430     2027        10x
# 8768    T_cell     CD8+ T-cell         779     2027        10x
# 8769    T_cell              Th        1115     2027        10x
# 8770   NK_cell              NK         706     2027        10x
# 8771    T_cell     CD8+ T-cell         661     2027        10x
#
#               cancer_type     sex  site category          study
# 0     Lung Adenocarcinoma    male  Lung     Lung  Song2019_Lung
# 1     Lung Adenocarcinoma    male  Lung     Lung  Song2019_Lung
# 2     Lung Adenocarcinoma    male  Lung     Lung  Song2019_Lung
# 3     Lung Adenocarcinoma    male  Lung     Lung  Song2019_Lung
# 4     Lung Adenocarcinoma    male  Lung     Lung  Song2019_Lung
# ...                   ...     ...   ...      ...            ...
# 8767  Lung Adenocarcinoma  female  Lung     Lung  Song2019_Lung
# 8768  Lung Adenocarcinoma  female  Lung     Lung  Song2019_Lung
# 8769  Lung Adenocarcinoma  female  Lung     Lung  Song2019_Lung
# 8770  Lung Adenocarcinoma  female  Lung     Lung  Song2019_Lung
# 8771  Lung Adenocarcinoma  female  Lung     Lung  Song2019_Lung
#
# [8772 rows x 14 columns]

# %%
adata.obs['site'] = 'Lung'

# %%
adata.obs['category'] = 'Lung'

# %%
adata.obs['study'] = 'Song2019_Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Song2019_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Song2019_Lung.h5ad

# %% [markdown]
# #### 10.Xing2021_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Xing2021_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 118293 × 17541
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'disease',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67','source_y',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed','cell_subtype_clusters',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch','time_rx_to_sampling',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                           cell_name sample   cell_type  cell_subtype  \
# 0       NM3N_nLung_AAACCTGCACGTCTCT   NM3N      T_cell   CD4+_Tcells
# 1       NM3N_nLung_AAACCTGCAGCTGCTG   NM3N      T_cell   CD4+_Tcells
# 2       NM3N_nLung_AAACCTGCAGTACACT   NM3N      T_cell   CD4+_Tcells
# 3       NM3N_nLung_AAACCTGGTAAGCACG   NM3N      T_cell   CD8+_Tcells
# 4       NM3N_nLung_AAACCTGGTCCCTTGT   NM3N      T_cell   CD8+_Tcells
# ...                             ...    ...         ...           ...
# 118288  NM6E_mLUAD_TACTTACCAAGTAGTA   NM6E   Malignant     Malignant
# 118289  NM6E_mLUAD_TAGTTGGGTCCTGCTT   NM6E   Malignant     Malignant
# 118290  NM6E_mLUAD_TCAGCTCCAGTGGGAT   NM6E  Epithelial  EPCAM+_cells
# 118291  NM6E_mLUAD_TGGGCGTCAGGTCCAC   NM6E   Malignant     Malignant
# 118292  NM6E_mLUAD_TTAGTTCCACGGCGTT   NM6E  Epithelial  EPCAM+_cells
#
#         complexity cell_cycle_phase                 source technology  \
# 0              884              NaN            Normal_Lung        10x
# 1              948              NaN            Normal_Lung        10x
# 2             1232      Not cycling            Normal_Lung        10x
# 3             1097      Not cycling            Normal_Lung        10x
# 4              761              NaN            Normal_Lung        10x
# ...            ...              ...                    ...        ...
# 118288        1589             G2/M  Primary_LUAD_with_Met        10x
# 118289        2131             G2/M  Primary_LUAD_with_Met        10x
# 118290         377              NaN  Primary_LUAD_with_Met        10x
# 118291        1703             G2/M  Primary_LUAD_with_Met        10x
# 118292         536              NaN  Primary_LUAD_with_Met        10x
#
#         n_cells patient cancer_type  sex  age disease_extent  \
# 0          3835     NaN         NaN  NaN  NaN            NaN
# 1          3835     NaN         NaN  NaN  NaN            NaN
# 2          3835     NaN         NaN  NaN  NaN            NaN
# 3          3835     NaN         NaN  NaN  NaN            NaN
# 4          3835     NaN         NaN  NaN  NaN            NaN
# ...         ...     ...         ...  ...  ...            ...
# 118288     1700     NaN         NaN  NaN  NaN            NaN
# 118289     1700     NaN         NaN  NaN  NaN            NaN
# 118290     1700     NaN         NaN  NaN  NaN            NaN
# 118291     1700     NaN         NaN  NaN  NaN            NaN
# 118292     1700     NaN         NaN  NaN  NaN            NaN
#
#        sample_primary_met site treated_naive category          study
# 0                     NaN  NaN           NaN     Lung  Xing2021_Lung
# 1                     NaN  NaN           NaN     Lung  Xing2021_Lung
# 2                     NaN  NaN           NaN     Lung  Xing2021_Lung
# 3                     NaN  NaN           NaN     Lung  Xing2021_Lung
# 4                     NaN  NaN           NaN     Lung  Xing2021_Lung
# ...                   ...  ...           ...      ...            ...
# 118288                NaN  NaN           NaN     Lung  Xing2021_Lung
# 118289                NaN  NaN           NaN     Lung  Xing2021_Lung
# 118290                NaN  NaN           NaN     Lung  Xing2021_Lung
# 118291                NaN  NaN           NaN     Lung  Xing2021_Lung
# 118292                NaN  NaN           NaN     Lung  Xing2021_Lung
#
# [118293 rows x 19 columns]

# %%
adata.obs['site'].value_counts()
# Out:
# site
# LU    46924
# RU    13705
# RM     5394
# RL     4438
# Name: count, dtype: int64

# %%
adata.obs['category'] = 'Lung'

# %%
adata.obs['study'] = 'Xing2021_Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Xing2021_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Xing2021_Lung.h5ad

# %% [markdown]
# #### 11.Zilionis2019_Lung

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Lung/Data_Zilionis2019_Lung"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 31179 × 31797
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'age', 'gender', 'cancer_type', 'technology', 'n_cells'

# %%
for col in [ 'umap1', 'umap2', 'g1s_score', 'g2m_score',
             'mp_top_score', 'mp_top', 'mp_assignment',
              'tnm_stage','Age', 'Gender', 'Stage', 'TNMstage'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"gender": "sex"})

# %%
adata.obs
# Out:
#          cell_name sample cell_type cell_subtype  complexity cell_cycle_phase  \
# 0      p1t3_bcBNQJ     p1    B_cell            B         621              NaN
# 1      p1t3_bcDBBH     p1    B_cell            B         540              NaN
# 2      p1t3_bcAKOO     p1    B_cell            B        1790      Not cycling
# 3      p1t3_bcFHAR     p1    B_cell            B        1737      Not cycling
# 4      p1t3_bcAPCM     p1    B_cell            B         857              NaN
# ...            ...    ...       ...          ...         ...              ...
# 31174  p5t2_bcHHQY     p5    Plasma       Plasma         820              NaN
# 31175  p5t2_bcGRWT     p5    Plasma       Plasma         785              NaN
# 31176  p5t2_bcEZCR     p5    Plasma       Plasma         861              NaN
# 31177  p5t2_bcHLFS     p5    Plasma       Plasma        1153      Not cycling
# 31178  p5t2_bcCGCR     p5    Plasma       Plasma         516              NaN
#
#       source  age     sex                   cancer_type technology  n_cells
# 0      Tumor   79    Male  Lung Squamous Cell Carcinoma     inDrop     9508
# 1      Tumor   79    Male  Lung Squamous Cell Carcinoma     inDrop     9508
# 2      Tumor   79    Male  Lung Squamous Cell Carcinoma     inDrop     9508
# 3      Tumor   79    Male  Lung Squamous Cell Carcinoma     inDrop     9508
# 4      Tumor   79    Male  Lung Squamous Cell Carcinoma     inDrop     9508
# ...      ...  ...     ...                           ...        ...      ...
# 31174  Tumor   72  Female           Lung Adenocarcinoma     inDrop     2197
# 31175  Tumor   72  Female           Lung Adenocarcinoma     inDrop     2197
# 31176  Tumor   72  Female           Lung Adenocarcinoma     inDrop     2197
# 31177  Tumor   72  Female           Lung Adenocarcinoma     inDrop     2197
# 31178  Tumor   72  Female           Lung Adenocarcinoma     inDrop     2197
#
# [31179 rows x 12 columns]

# %%
adata.obs['category'] = 'Lung'

# %%
adata.obs['study'] = 'Zilionis2019_Lung'

# %%
output_path = "/home/ubuntu/Downloads/Data_Lung/Data_Zilionis2019_Lung.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Lung/Data_Zilionis2019_Lung.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Lung/Data_Bischoff2021_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Chan2021_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Guo2018_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Ireland2020_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Kim2020_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Laughney2020_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Maynard2020_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Qian2020_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Song2019_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Xing2021_Lung.h5ad",
    "/home/ubuntu/Downloads/Data_Lung/Data_Zilionis2019_Lung.h5ad"
]

gc.collect()
# Load datasets
adatas = [sc.read(file) for file in files]

gc.collect()
# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

gc.collect()
# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

gc.collect()
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# 0

# %%
adata_merged
# Out:
# AnnData object with n_obs × n_vars = 500451 × 50504
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'technology', 'n_cells', 'cancer_type', 'study', 'category', 'treated_naive', 'sample_primary_met', 'age', 'sex', 'disease_extent', 'site'

# %%
adata_merged.obs
# Out:
#                   cell_name  sample patient   cell_type  \
# 0      AAACCCAAGACGACGT-1_1  p018_N    p018         NaN
# 1      AAACCCAAGCACTCTA-1_2  p018_N    p018  Macrophage
# 2      AAACCCAAGCTGAAGC-1_3  p018_N    p018  Macrophage
# 3      AAACCCACAACTTGGT-1_4  p018_N    p018  Macrophage
# 4      AAACCCACAAGAATAC-1_5  p018_N    p018  Macrophage
# ...                     ...     ...     ...         ...
# 31174           p5t2_bcHHQY      p5     NaN      Plasma
# 31175           p5t2_bcGRWT      p5     NaN      Plasma
# 31176           p5t2_bcEZCR      p5     NaN      Plasma
# 31177           p5t2_bcHLFS      p5     NaN      Plasma
# 31178           p5t2_bcCGCR      p5     NaN      Plasma
#
#                 cell_subtype  complexity cell_cycle_phase  source technology  \
# 0                        NaN         519              NaN  Normal        10x
# 1      Alveolar_Macrophages1         618              NaN  Normal        10x
# 2      Alveolar_Macrophages1         660              NaN  Normal        10x
# 3      Alveolar_Macrophages1         843              NaN  Normal        10x
# 4      Alveolar_Macrophages1        1060      Not cycling  Normal        10x
# ...                      ...         ...              ...     ...        ...
# 31174                 Plasma         820              NaN   Tumor     inDrop
# 31175                 Plasma         785              NaN   Tumor     inDrop
# 31176                 Plasma         861              NaN   Tumor     inDrop
# 31177                 Plasma        1153      Not cycling   Tumor     inDrop
# 31178                 Plasma         516              NaN   Tumor     inDrop
#
#        n_cells          cancer_type              study category treated_naive  \
# 0        11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung           nan
# 1        11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung           nan
# 2        11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung           nan
# 3        11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung           nan
# 4        11173  Lung Adenocarcinoma  Bischoff2021_Lung     Lung           nan
# ...        ...                  ...                ...      ...           ...
# 31174     2197  Lung Adenocarcinoma  Zilionis2019_Lung     Lung           nan
# 31175     2197  Lung Adenocarcinoma  Zilionis2019_Lung     Lung           nan
# 31176     2197  Lung Adenocarcinoma  Zilionis2019_Lung     Lung           nan
# 31177     2197  Lung Adenocarcinoma  Zilionis2019_Lung     Lung           nan
# 31178     2197  Lung Adenocarcinoma  Zilionis2019_Lung     Lung           nan
#
#       sample_primary_met  age     sex disease_extent site
# 0                    NaN  nan     nan            NaN  nan
# 1                    NaN  nan     nan            NaN  nan
# 2                    NaN  nan     nan            NaN  nan
# 3                    NaN  nan     nan            NaN  nan
# 4                    NaN  nan     nan            NaN  nan
# ...                  ...  ...     ...            ...  ...
# 31174                NaN   72  Female            NaN  nan
# 31175                NaN   72  Female            NaN  nan
# 31176                NaN   72  Female            NaN  nan
# 31177                NaN   72  Female            NaN  nan
# 31178                NaN   72  Female            NaN  nan
#
# [500451 rows x 19 columns]

# %%
# Optional: Save to disk
adata_merged.write("/home/ubuntu/Downloads/Data_Lung/Lung_Combined.h5ad")
print("Merged dataset saved.")
# Out:
# Merged dataset saved.

# %%
adata_merged.obs['study'].value_counts()
# Out:
# study
# Bischoff2021_Lung    120961
# Xing2021_Lung        118293
# Chan2021_Lung         86662
# Laughney2020_Lung     40505
# Kim2020_Lung          32493
# Zilionis2019_Lung     31179
# Qian2020_Lung         27262
# Maynard2020_Lung      19777
# Guo2018_Lung          12346
# Song2019_Lung          8772
# Ireland2020_Lung       2201
# Name: count, dtype: int64
