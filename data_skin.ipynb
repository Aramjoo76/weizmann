# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc
import scipy.io
from scipy.sparse import vstack

# %% [markdown]
# ## Skin

# %% [markdown]
# #### 1. Jerby-Arnon2018_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Jerby-Arnon2018_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect()
# Out:
# 33451

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 7186 × 23686
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'cell_cohort', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'cell_cohort'      
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['subtype'].value_counts()
# Out:
# subtype
# DIF    30619
# MES     4590
# IMR     4078
# PRO     1744
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                                             cell_name sample  cell_type  \
# 0                       cy78_CD45_neg_1_B04_S496_comb  Mel78  Malignant
# 1            cy79_p4_CD45_neg_PDL1_neg_E11_S1115_comb  Mel79  Malignant
# 2                                CY88_5_B10_S694_comb  Mel88  Malignant
# 3     cy79_p1_CD45_neg_PDL1_pos_AS_C1_R1_F07_S67_comb  Mel79  Malignant
# 4                       cy78_CD45_neg_3_H06_S762_comb  Mel78  Malignant
# ...                                               ...    ...        ...
# 7181                CY75_1_CD45_CD8_3__S168_comb_BCD8  Mel75     T_cell
# 7182                CY75_1_CD45_CD8_8__S338_comb_BCD8  Mel75     T_cell
# 7183                       monika_D7_S132_comb_BCD8_3  Mel75     T_cell
# 7184                CY75_1_CD45_CD8_8__S289_comb_BCD8  Mel75     T_cell
# 7185                CY75_1_CD45_CD8_8__S351_comb_BCD8  Mel75     T_cell
#
#      cell_subtype  complexity cell_cycle_phase           source technology  \
# 0       Malignant        8258     Intermediate   post.treatment  SmartSeq2
# 1       Malignant        2047      Not cycling  treatment.naive  SmartSeq2
# 2       Malignant        5375      Not cycling   post.treatment  SmartSeq2
# 3       Malignant        5648      Not cycling  treatment.naive  SmartSeq2
# 4       Malignant        7409      Not cycling   post.treatment  SmartSeq2
# ...           ...         ...              ...              ...        ...
# 7181   T_Cell_CD8        3530      Not cycling   post.treatment  SmartSeq2
# 7182   T_Cell_CD8        3872      Not cycling   post.treatment  SmartSeq2
# 7183   T_Cell_CD8        4589      Not cycling   post.treatment  SmartSeq2
# 7184   T_Cell_CD8        4614      Not cycling   post.treatment  SmartSeq2
# 7185   T_Cell_CD8        3859      Not cycling   post.treatment  SmartSeq2
#
#       n_cells patient cancer_type sex  age disease_extent sample_primary_met  \
# 0         124   Mel78    Melanoma   M   73     metastatic                met
# 1         894   Mel79    Melanoma   M   74     metastatic                met
# 2         352   Mel88    Melanoma   F   54     metastatic                met
# 3         894   Mel79    Melanoma   M   74     metastatic                met
# 4         124   Mel78    Melanoma   M   73     metastatic                met
# ...       ...     ...         ...  ..  ...            ...                ...
# 7181      506   Mel75    Melanoma   M   80     metastatic                met
# 7182      506   Mel75    Melanoma   M   80     metastatic                met
# 7183      506   Mel75    Melanoma   M   80     metastatic                met
# 7184      506   Mel75    Melanoma   M   80     metastatic                met
# 7185      506   Mel75    Melanoma   M   80     metastatic                met
#
#                           site         treated_naive                 study  \
# 0                 Small bowel   Post-ICI (resistant)  Jerby-Arnon2018_Skin
# 1          Axillary lymph node             Untreated  Jerby-Arnon2018_Skin
# 2               Cutanoues met   Post-ICI (resistant)  Jerby-Arnon2018_Skin
# 3          Axillary lymph node             Untreated  Jerby-Arnon2018_Skin
# 4                 Small bowel   Post-ICI (resistant)  Jerby-Arnon2018_Skin
# ...                        ...                   ...                   ...
# 7181  Subcutaneous leg lesion   Post-ICI (resistant)  Jerby-Arnon2018_Skin
# 7182  Subcutaneous leg lesion   Post-ICI (resistant)  Jerby-Arnon2018_Skin
# 7183  Subcutaneous leg lesion   Post-ICI (resistant)  Jerby-Arnon2018_Skin
# 7184  Subcutaneous leg lesion   Post-ICI (resistant)  Jerby-Arnon2018_Skin
# 7185  Subcutaneous leg lesion   Post-ICI (resistant)  Jerby-Arnon2018_Skin
#
#      category
# 0        Skin
# 1        Skin
# 2        Skin
# 3        Skin
# 4        Skin
# ...       ...
# 7181     Skin
# 7182     Skin
# 7183     Skin
# 7184     Skin
# 7185     Skin
#
# [7186 rows x 19 columns]

# %%
adata.obs['study'] = 'Jerby-Arnon2018_Skin'

# %%
adata.obs['category'] = 'Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Jerby-Arnon2018_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Jerby-Arnon2018_Skin.h5ad

# %% [markdown]
# #### 2.Biermann2022_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Biermann2022_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 136973 × 35652
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'disease', 'source', 'technology', 'n_cells', 'patient_y', 'cancer_type', 'sample_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'mutation_hormonal_status', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'disease', 'patient_y', 'mutation_hormonal_status', 'sample_type'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                     cell_name    sample patient  cell_type  cell_subtype  \
# 0        CTCGTACCAAGCTGGA-1_1  MBM01_sc   MBM01     Plasma  Plasma cells
# 1        AGATTGCAGTGGGTTG-1_1  MBM01_sc   MBM01     Plasma  Plasma cells
# 2        TCGGGACTCAACACTG-1_1  MBM01_sc   MBM01  Malignant   Tumor cells
# 3        CTCGGAGCAGCTATTG-1_1  MBM01_sc   MBM01  Malignant   Tumor cells
# 4        TGGGAAGAGAACAACT-1_1  MBM01_sc   MBM01     Plasma  Plasma cells
# ...                       ...       ...     ...        ...           ...
# 136968  TACTGCCCATCGAGCC-1_32  MPM11_sn   MPM11  Malignant   Tumor cells
# 136969  GCACGTGTCGTAATGC-1_32  MPM11_sn   MPM11  Malignant   Tumor cells
# 136970  ATGGAGGAGTTTGTCG-1_32  MPM11_sn   MPM11  Malignant   Tumor cells
# 136971  ACCATTTTCCAAGCAT-1_32  MPM11_sn   MPM11  Malignant   Tumor cells
# 136972  CCGGACATCAAGGCTT-1_32  MPM11_sn   MPM11  Malignant   Tumor cells
#
#         complexity cell_cycle_phase                 source technology  \
# 0             4017      Not cycling       Brain_Metastasis        10X
# 1             4269      Not cycling       Brain_Metastasis        10X
# 2             8319             G1/S       Brain_Metastasis        10X
# 3             8229      Not cycling       Brain_Metastasis        10X
# 4             4396      Not cycling       Brain_Metastasis        10X
# ...            ...              ...                    ...        ...
# 136968         770              NaN  Peripheral_Metastasis        10X
# 136969         718              NaN  Peripheral_Metastasis        10X
# 136970         862              NaN  Peripheral_Metastasis        10X
# 136971         705              NaN  Peripheral_Metastasis        10X
# 136972         760              NaN  Peripheral_Metastasis        10X
#
#         n_cells cancer_type  sex  age  disease_extent sample_primary_met  \
# 0          3515    Melanoma  NaN  NaN             NaN                met
# 1          3515    Melanoma  NaN  NaN             NaN                met
# 2          3515    Melanoma  NaN  NaN             NaN                met
# 3          3515    Melanoma  NaN  NaN             NaN                met
# 4          3515    Melanoma  NaN  NaN             NaN                met
# ...         ...         ...  ...  ...             ...                ...
# 136968     8789    Melanoma  NaN  NaN             NaN                met
# 136969     8789    Melanoma  NaN  NaN             NaN                met
# 136970     8789    Melanoma  NaN  NaN             NaN                met
# 136971     8789    Melanoma  NaN  NaN             NaN                met
# 136972     8789    Melanoma  NaN  NaN             NaN                met
#
#                     site treated_naive
# 0       brain metastasis         naive
# 1       brain metastasis         naive
# 2       brain metastasis         naive
# 3       brain metastasis         naive
# 4       brain metastasis         naive
# ...                  ...           ...
# 136968  brain metastasis       treated
# 136969  brain metastasis       treated
# 136970  brain metastasis       treated
# 136971  brain metastasis       treated
# 136972  brain metastasis       treated
#
# [136973 rows x 17 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs['study'] = 'Biermann2022_Skin'

# %%
adata.obs['category'] = 'Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Biermann2022_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Biermann2022_Skin.h5ad

# %% [markdown]
# #### 3.Ferrari de Andrade2019_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Ferrari de Andrade2019_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 40823 × 24770
#     obs: 'cell_name', 'sample', 'patient_x', 'source_x', 'cell_type', 'complexity', 'n_cells', 'cancer_type', 'technology', 'disease_extent', 'age', 'sex'

# %%
for col in ['patient_y', 'source_y',    
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                                cell_name          sample patient  source  \
# 0         CY155_blood_AAACCTGCATGATCCA-1     CY155_blood   CY155   blood
# 1         CY155_blood_AAACCTGGTAAGTGGC-1     CY155_blood   CY155   blood
# 2         CY155_blood_AAACCTGGTACTTCTT-1     CY155_blood   CY155   blood
# 3         CY155_blood_AAACGGGAGCTATGCT-1     CY155_blood   CY155   blood
# 4         CY155_blood_AAACGGGAGCTTATCG-1     CY155_blood   CY155   blood
# ...                                  ...             ...     ...     ...
# 40818  CY129-2-Nodule_TTTGGTTAGTTGAGTA-1  CY129-2-Nodule   CY129  nodule
# 40819  CY129-2-Nodule_TTTGGTTTCAACCATG-1  CY129-2-Nodule   CY129  nodule
# 40820  CY129-2-Nodule_TTTGGTTTCGTTTGCC-1  CY129-2-Nodule   CY129  nodule
# 40821  CY129-2-Nodule_TTTGTCAAGTGCCAGA-1  CY129-2-Nodule   CY129  nodule
# 40822  CY129-2-Nodule_TTTGTCAGTGAGGGAG-1  CY129-2-Nodule   CY129  nodule
#
#       cell_type  complexity  n_cells cancer_type technology disease_extent  \
# 0       NK_cell        1150     3169    Melanoma        10x     metastatic
# 1       NK_cell        1735     3169    Melanoma        10x     metastatic
# 2       NK_cell        1117     3169    Melanoma        10x     metastatic
# 3       NK_cell        2090     3169    Melanoma        10x     metastatic
# 4       NK_cell         964     3169    Melanoma        10x     metastatic
# ...         ...         ...      ...         ...        ...            ...
# 40818   NK_cell        2427     1178    Melanoma        10x     metastatic
# 40819   NK_cell        2270     1178    Melanoma        10x     metastatic
# 40820   NK_cell        2094     1178    Melanoma        10x     metastatic
# 40821   NK_cell        1668     1178    Melanoma        10x     metastatic
# 40822   NK_cell        2094     1178    Melanoma        10x     metastatic
#
#        age     sex cell_subtype    site cell_cycle_phase sample_primary_met  \
# 0       66  Female          NaN   blood              NaN                NaN
# 1       66  Female          NaN   blood              NaN                NaN
# 2       66  Female          NaN   blood              NaN                NaN
# 3       66  Female          NaN   blood              NaN                NaN
# 4       66  Female          NaN   blood              NaN                NaN
# ...    ...     ...          ...     ...              ...                ...
# 40818   65    Male          NaN  nodule              NaN                NaN
# 40819   65    Male          NaN  nodule              NaN                NaN
# 40820   65    Male          NaN  nodule              NaN                NaN
# 40821   65    Male          NaN  nodule              NaN                NaN
# 40822   65    Male          NaN  nodule              NaN                NaN
#
#       treated_naive category                        study
# 0               NaN     Skin  Ferrari de Andrade2019_Skin
# 1               NaN     Skin  Ferrari de Andrade2019_Skin
# 2               NaN     Skin  Ferrari de Andrade2019_Skin
# 3               NaN     Skin  Ferrari de Andrade2019_Skin
# 4               NaN     Skin  Ferrari de Andrade2019_Skin
# ...             ...      ...                          ...
# 40818           NaN     Skin  Ferrari de Andrade2019_Skin
# 40819           NaN     Skin  Ferrari de Andrade2019_Skin
# 40820           NaN     Skin  Ferrari de Andrade2019_Skin
# 40821           NaN     Skin  Ferrari de Andrade2019_Skin
# 40822           NaN     Skin  Ferrari de Andrade2019_Skin
#
# [40823 rows x 19 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['site'] = adata.obs['source_x'].copy()

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['category'] = 'Skin'

# %%
adata.obs['study'] = 'Ferrari de Andrade2019_Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Ferrari de Andrade2019_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Ferrari de Andrade2019_Skin.h5ad

# %% [markdown]
# #### 4. Ji2020_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Ji2020_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 48164 × 32738
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'source', 'cell_subtype_level1', 'cell_subtype_level2', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'cell_subtype_level2'    
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                          cell_name sample   cell_type  complexity  \
# 0        P1_Tumor_AAACCTGAGTCAAGCG     P1   Malignant        5206
# 1        P1_Tumor_AAACCTGCAAATTGCC     P1  Epithelial        3468
# 2        P1_Tumor_AAACCTGGTAGGAGTC     P1   Malignant        4154
# 3        P1_Tumor_AAACGGGAGATGTAAC     P1   Malignant        4334
# 4        P1_Tumor_AAACGGGAGCTGCAAG     P1   Malignant        4822
# ...                            ...    ...         ...         ...
# 48159  P10_Normal_TTTGTCAAGAGTCTGG    P10  Epithelial        1659
# 48160  P10_Normal_TTTGTCAAGTCGTTTG    P10  Langerhans        3541
# 48161  P10_Normal_TTTGTCACAGTGGGAT    P10  Langerhans        2540
# 48162  P10_Normal_TTTGTCATCCAGGGCT    P10  Langerhans        1849
# 48163  P10_Normal_TTTGTCATCGAGGTAG    P10  Epithelial        1598
#
#       cell_cycle_phase source     cell_subtype technology  n_cells patient  \
# 0          Not cycling    NaN    Tumor_KC_Diff        10x     2382      P1
# 1          Not cycling    NaN     Keratinocyte        10x     2382      P1
# 2          Not cycling    NaN   Tumor_KC_Basal        10x     2382      P1
# 3          Not cycling    NaN   Tumor_KC_Basal        10x     2382      P1
# 4         Intermediate    NaN     Tumor_KC_Cyc        10x     2382      P1
# ...                ...    ...              ...        ...      ...     ...
# 48159      Not cycling    NaN   Normal_KC_Diff        10x     4569     P10
# 48160             G1/S    NaN  Langerhans_cell        10x     4569     P10
# 48161      Not cycling    NaN  Langerhans_cell        10x     4569     P10
# 48162      Not cycling    NaN  Langerhans_cell        10x     4569     P10
# 48163      Not cycling    NaN  Normal_KC_Basal        10x     4569     P10
#
#                              cancer_type sex  age  disease_extent  \
# 0      Cutaneous Squamous Cell Carcinoma   M   83             NaN
# 1      Cutaneous Squamous Cell Carcinoma   M   83             NaN
# 2      Cutaneous Squamous Cell Carcinoma   M   83             NaN
# 3      Cutaneous Squamous Cell Carcinoma   M   83             NaN
# 4      Cutaneous Squamous Cell Carcinoma   M   83             NaN
# ...                                  ...  ..  ...             ...
# 48159  Cutaneous Squamous Cell Carcinoma   M   71             NaN
# 48160  Cutaneous Squamous Cell Carcinoma   M   71             NaN
# 48161  Cutaneous Squamous Cell Carcinoma   M   71             NaN
# 48162  Cutaneous Squamous Cell Carcinoma   M   71             NaN
# 48163  Cutaneous Squamous Cell Carcinoma   M   71             NaN
#
#       sample_primary_met              site treated_naive category        study
# 0                primary  Rt. Dorsal Hand          naive     Skin  Ji2020_Skin
# 1                primary  Rt. Dorsal Hand          naive     Skin  Ji2020_Skin
# 2                primary  Rt. Dorsal Hand          naive     Skin  Ji2020_Skin
# 3                primary  Rt. Dorsal Hand          naive     Skin  Ji2020_Skin
# 4                primary  Rt. Dorsal Hand          naive     Skin  Ji2020_Skin
# ...                  ...               ...           ...      ...          ...
# 48159            primary        Rt. Tragus           NaN     Skin  Ji2020_Skin
# 48160            primary        Rt. Tragus           NaN     Skin  Ji2020_Skin
# 48161            primary        Rt. Tragus           NaN     Skin  Ji2020_Skin
# 48162            primary        Rt. Tragus           NaN     Skin  Ji2020_Skin
# 48163            primary        Rt. Tragus           NaN     Skin  Ji2020_Skin
#
# [48164 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"cell_subtype_level1": "cell_subtype"})

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Skin'

# %%
adata.obs['study'] = 'Ji2020_Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Ji2020_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Ji2020_Skin.h5ad

# %% [markdown]
# #### 5.Li2019_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Li2019_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 78336 × 40979
#     obs: 'cell_name', 'sample', 'patient_x', 'amp_batch', 'cell_type', 'cell_subtype', 'location_x', 'stage_x', 'complexity', 'patient_y', 'cancer_type', 'technology', 'n_cells', 'location_y', 'stage_y', 'prior_treatment', 'on_treatment'

# %%
adata.obs['on_treatment'].value_counts()
# Out:
# on_treatment
# aPD1    7457
# Name: count, dtype: int64

# %%
for col in ['amp_batch','stage_x','location_y', 'stage_y', 'prior_treatment', 'on_treatment', 'patient_y'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#        cell_name sample patient cell_type  cell_subtype        site  \
# 0        W461969    NaN     NaN       NaN           NaN         NaN
# 1        W461970     p2      p2    T_cell  transitional  lymph node
# 2        W461971     p2      p2    T_cell  transitional  lymph node
# 3        W461972     p2      p2    T_cell  transitional  lymph node
# 4        W461973     p2      p2    T_cell  transitional  lymph node
# ...          ...    ...     ...       ...           ...         ...
# 78331  WMC810396    NaN     NaN       NaN           NaN         NaN
# 78332  WMC810397    NaN     NaN       NaN           NaN         NaN
# 78333  WMC810398    NaN     NaN       NaN           NaN         NaN
# 78334  WMC810399    NaN     NaN       NaN           NaN         NaN
# 78335  WMC810400    NaN     NaN       NaN           NaN         NaN
#
#        complexity cancer_type technology  n_cells      source  \
# 0             340         NaN        NaN      NaN         NaN
# 1             591    Melanoma   MARS-seq   2270.0  lymph node
# 2            1074    Melanoma   MARS-seq   2270.0  lymph node
# 3             620    Melanoma   MARS-seq   2270.0  lymph node
# 4             390    Melanoma   MARS-seq   2270.0  lymph node
# ...           ...         ...        ...      ...         ...
# 78331         640         NaN        NaN      NaN         NaN
# 78332         702         NaN        NaN      NaN         NaN
# 78333         563         NaN        NaN      NaN         NaN
# 78334        2106         NaN        NaN      NaN         NaN
# 78335         378         NaN        NaN      NaN         NaN
#
#       cell_cycle_phase  sex  age disease_extent sample_primary_met  \
# 0                  NaN  NaN  NaN            NaN                NaN
# 1                  NaN  NaN  NaN            NaN                NaN
# 2                  NaN  NaN  NaN            NaN                NaN
# 3                  NaN  NaN  NaN            NaN                NaN
# 4                  NaN  NaN  NaN            NaN                NaN
# ...                ...  ...  ...            ...                ...
# 78331              NaN  NaN  NaN            NaN                NaN
# 78332              NaN  NaN  NaN            NaN                NaN
# 78333              NaN  NaN  NaN            NaN                NaN
# 78334              NaN  NaN  NaN            NaN                NaN
# 78335              NaN  NaN  NaN            NaN                NaN
#
#       treated_naive        study category
# 0               NaN  Li2019_Skin     Skin
# 1               NaN  Li2019_Skin     Skin
# 2               NaN  Li2019_Skin     Skin
# 3               NaN  Li2019_Skin     Skin
# 4               NaN  Li2019_Skin     Skin
# ...             ...          ...      ...
# 78331           NaN  Li2019_Skin     Skin
# 78332           NaN  Li2019_Skin     Skin
# 78333           NaN  Li2019_Skin     Skin
# 78334           NaN  Li2019_Skin     Skin
# 78335           NaN  Li2019_Skin     Skin
#
# [78336 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"location_x": "site"})

# %%
adata.obs['source']=adata.obs['site'].copy()

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['study'] = 'Li2019_Skin'

# %%
adata.obs['category'] = 'Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Li2019_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Li2019_Skin.h5ad

# %% [markdown]
# #### 6.Mahuron2020_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Mahuron2020_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 27935 × 24892
#     obs: 'cell_name', 'sample', 'patient_x', 'source_x', 'cell_type', 'complexity', 'patient_y', 'cancer_type', 'technology', 'n_cells', 'source_y', 'location', 'age', 'sex', 'disease_extent', 'treated_naive', 'sample_primary_met'

# %%
for col in ['patient_y',  'source_y',      
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                             cell_name       sample patient      source  \
# 0      K383_LN_GEX_AAACCTGAGGACGAAA-1  K383_LN_GEX    K383  lymph node
# 1      K383_LN_GEX_AAACCTGAGGGTGTTG-1  K383_LN_GEX    K383  lymph node
# 2      K383_LN_GEX_AAACCTGCAAGGACTG-1  K383_LN_GEX    K383  lymph node
# 3      K383_LN_GEX_AAACCTGCAATCTGCA-1  K383_LN_GEX    K383  lymph node
# 4      K383_LN_GEX_AAACCTGCACTGTTAG-1  K383_LN_GEX    K383  lymph node
# ...                               ...          ...     ...         ...
# 27930  K411_LN_GEX_TTTGTCAGTTGGTAAA-1  K411_LN_GEX    K411  lymph node
# 27931  K411_LN_GEX_TTTGTCATCACAAACC-1  K411_LN_GEX    K411  lymph node
# 27932  K411_LN_GEX_TTTGTCATCTCGATGA-1  K411_LN_GEX    K411  lymph node
# 27933  K411_LN_GEX_TTTGTCATCTGACCTC-1  K411_LN_GEX    K411  lymph node
# 27934  K411_LN_GEX_TTTGTCATCTTGTACT-1  K411_LN_GEX    K411  lymph node
#
#       cell_type  complexity cancer_type technology  n_cells         site  age  \
# 0        T_cell        1268    Melanoma        10x     3116  inguinal LN   45
# 1        T_cell        2735    Melanoma        10x     3116  inguinal LN   45
# 2        T_cell        1186    Melanoma        10x     3116  inguinal LN   45
# 3        B_cell         818    Melanoma        10x     3116  inguinal LN   45
# 4        B_cell        1778    Melanoma        10x     3116  inguinal LN   45
# ...         ...         ...         ...        ...      ...          ...  ...
# 27930    T_cell        1650    Melanoma        10x     4032      neck LN   58
# 27931    T_cell        1557    Melanoma        10x     4032      neck LN   58
# 27932    T_cell        2281    Melanoma        10x     4032      neck LN   58
# 27933    T_cell        1139    Melanoma        10x     4032      neck LN   58
# 27934    T_cell        1312    Melanoma        10x     4032      neck LN   58
#
#           sex disease_extent treated_naive sample_primary_met
# 0        male     metastatic         naive                NaN
# 1        male     metastatic         naive                NaN
# 2        male     metastatic         naive                NaN
# 3        male     metastatic         naive                NaN
# 4        male     metastatic         naive                NaN
# ...       ...            ...           ...                ...
# 27930  female     metastatic         naive                NaN
# 27931  female     metastatic         naive                NaN
# 27932  female     metastatic         naive                NaN
# 27933  female     metastatic         naive                NaN
# 27934  female     metastatic         naive                NaN
#
# [27935 rows x 15 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"location": "site"})

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['category'] = 'Skin'

# %%
adata.obs['study'] = 'Mahuron2020_Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Mahuron2020_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Mahuron2020_Skin.h5ad

# %% [markdown]
# #### 7.Paulson2020_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Paulson2020_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 31376 × 16373
#     obs: 'cell_name', 'sample', 'patient_x', 'source_x', 'cell_type', 'complexity', 'technology', 'n_cells', 'cancer_type', 'disease_extent', 'response', 'age', 'sex'

# %%
for col in ['timepoint_x', 'patient_y', 'source_y', 'timepoint_y',    
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"response": "treated_naive"})

# %%
adata.obs
# Out:
#                                     cell_name               sample patient  \
# 0      2586-4_Tumor_Before_AAACCTGAGGATGTAT-1  2586-4_Tumor_Before  2586-4
# 1      2586-4_Tumor_Before_AAACCTGCAGCGATCC-1  2586-4_Tumor_Before  2586-4
# 2      2586-4_Tumor_Before_AAACCTGGTACGAAAT-1  2586-4_Tumor_Before  2586-4
# 3      2586-4_Tumor_Before_AAACGGGAGCTGGAAC-1  2586-4_Tumor_Before  2586-4
# 4      2586-4_Tumor_Before_AAACGGGAGGAGTTGC-1  2586-4_Tumor_Before  2586-4
# ...                                       ...                  ...     ...
# 31371         9245-3_Tumor_TTTGTCAGTCGGCTCA-2         9245-3_Tumor  9245-3
# 31372         9245-3_Tumor_TTTGTCAGTGCAGACA-2         9245-3_Tumor  9245-3
# 31373         9245-3_Tumor_TTTGTCAGTGGTTTCA-2         9245-3_Tumor  9245-3
# 31374         9245-3_Tumor_TTTGTCAGTTCCCGAG-2         9245-3_Tumor  9245-3
# 31375         9245-3_Tumor_TTTGTCATCCTAAGTG-2         9245-3_Tumor  9245-3
#
#       source  cell_type  complexity technology  n_cells  \
# 0      Tumor  Malignant        1125        10x     2243
# 1      Tumor  Malignant        1537        10x     2243
# 2      Tumor  Malignant         854        10x     2243
# 3      Tumor  Malignant         819        10x     2243
# 4      Tumor  Malignant        1131        10x     2243
# ...      ...        ...         ...        ...      ...
# 31371  Tumor        NaN        2602        10x     5323
# 31372  Tumor  Malignant        4309        10x     5323
# 31373  Tumor  Malignant        4978        10x     5323
# 31374  Tumor  Malignant        3291        10x     5323
# 31375  Tumor  Malignant        3397        10x     5323
#
#                  cancer_type disease_extent        treated_naive  age   sex  \
# 0      Merkel Cell Carcinoma     metastatic                  NaN   59  male
# 1      Merkel Cell Carcinoma     metastatic                  NaN   59  male
# 2      Merkel Cell Carcinoma     metastatic                  NaN   59  male
# 3      Merkel Cell Carcinoma     metastatic                  NaN   59  male
# 4      Merkel Cell Carcinoma     metastatic                  NaN   59  male
# ...                      ...            ...                  ...  ...   ...
# 31371  Merkel Cell Carcinoma     metastatic  Acquired resistance   59  male
# 31372  Merkel Cell Carcinoma     metastatic  Acquired resistance   59  male
# 31373  Merkel Cell Carcinoma     metastatic  Acquired resistance   59  male
# 31374  Merkel Cell Carcinoma     metastatic  Acquired resistance   59  male
# 31375  Merkel Cell Carcinoma     metastatic  Acquired resistance   59  male
#
#       cell_subtype cell_cycle_phase sample_primary_met  site  \
# 0              NaN              NaN                NaN  Skin
# 1              NaN              NaN                NaN  Skin
# 2              NaN              NaN                NaN  Skin
# 3              NaN              NaN                NaN  Skin
# 4              NaN              NaN                NaN  Skin
# ...            ...              ...                ...   ...
# 31371          NaN              NaN                NaN  Skin
# 31372          NaN              NaN                NaN  Skin
# 31373          NaN              NaN                NaN  Skin
# 31374          NaN              NaN                NaN  Skin
# 31375          NaN              NaN                NaN  Skin
#
#                   study category
# 0      Paulson2020_Skin     Skin
# 1      Paulson2020_Skin     Skin
# 2      Paulson2020_Skin     Skin
# 3      Paulson2020_Skin     Skin
# 4      Paulson2020_Skin     Skin
# ...                 ...      ...
# 31371  Paulson2020_Skin     Skin
# 31372  Paulson2020_Skin     Skin
# 31373  Paulson2020_Skin     Skin
# 31374  Paulson2020_Skin     Skin
# 31375  Paulson2020_Skin     Skin
#
# [31376 rows x 19 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['site'] = 'Skin'

# %%
adata.obs['study'] = 'Paulson2020_Skin'

# %%
adata.obs['category'] = 'Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Paulson2020_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Paulson2020_Skin.h5ad

# %% [markdown]
# #### 8.Sade-Feldman2018_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Sade-Feldman2018_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 16291 × 50513
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'n_cells', 'technology', 'cancer_type', 'sex', 'age', 'disease_extent', 'source', 'site', 'treatment'

# %%
for col in ['timepoint_x', 'cluster', 'cluster_cd8_2', 'cluster_cd8_6', 'patient_y', 'timepoint_y',
            'days_from_baseline', 'response_lesion', 'response_patient',
            'overall_survival_days', 'vital_status', 'mutations_indels_drivers', 'mutations_indels_immune'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                        cell_name   sample patient cell_type  \
# 0                     A10_P3_M11   Pre_P1      P1    T_cell
# 1                     A11_P1_M11   Pre_P1      P1    T_cell
# 2                     A11_P3_M11   Pre_P1      P1    T_cell
# 3                     A11_P4_M11   Pre_P1      P1    T_cell
# 4                     A12_P3_M11   Pre_P1      P1    T_cell
# ...                          ...      ...     ...       ...
# 16286  H5_P5_M67_L001_T_enriched  Post_P6      P6    T_cell
# 16287  H6_P5_M67_L001_T_enriched  Post_P6      P6    T_cell
# 16288  H7_P5_M67_L001_T_enriched  Post_P6      P6    T_cell
# 16289  H8_P5_M67_L001_T_enriched  Post_P6      P6    T_cell
# 16290  H9_P5_M67_L001_T_enriched  Post_P6      P6    T_cell
#
#             cell_subtype  complexity  n_cells  technology cancer_type sex  \
# 0                 T cell        2050      229  Smart-seq2    Melanoma   M
# 1                 T cell        1573      229  Smart-seq2    Melanoma   M
# 2                 T cell        1591      229  Smart-seq2    Melanoma   M
# 3      Regulatory T cell        2909      229  Smart-seq2    Melanoma   M
# 4                 T cell        1211      229  Smart-seq2    Melanoma   M
# ...                  ...         ...      ...         ...         ...  ..
# 16286   Exhausted T cell        4355      400  Smart-seq2    Melanoma   F
# 16287   Exhausted T cell        4948      400  Smart-seq2    Melanoma   F
# 16288   Exhausted T cell        3208      400  Smart-seq2    Melanoma   F
# 16289   Exhausted T cell        1355      400  Smart-seq2    Melanoma   F
# 16290             T cell        1686      400  Smart-seq2    Melanoma   F
#
#        age disease_extent source                           site treated_naive  \
# 0       49     metastatic  tumor                    right chest    anti-CTLA4
# 1       49     metastatic  tumor                    right chest    anti-CTLA4
# 2       49     metastatic  tumor                    right chest    anti-CTLA4
# 3       49     metastatic  tumor                    right chest    anti-CTLA4
# 4       49     metastatic  tumor                    right chest    anti-CTLA4
# ...    ...            ...    ...                            ...           ...
# 16286   66     metastatic  tumor  right colectomy mass in cecum      anti-PD1
# 16287   66     metastatic  tumor  right colectomy mass in cecum      anti-PD1
# 16288   66     metastatic  tumor  right colectomy mass in cecum      anti-PD1
# 16289   66     metastatic  tumor  right colectomy mass in cecum      anti-PD1
# 16290   66     metastatic  tumor  right colectomy mass in cecum      anti-PD1
#
#       cell_cycle_phase sample_primary_met category                  study
# 0                  NaN                NaN     Skin  Sade-Feldman2018_Skin
# 1                  NaN                NaN     Skin  Sade-Feldman2018_Skin
# 2                  NaN                NaN     Skin  Sade-Feldman2018_Skin
# 3                  NaN                NaN     Skin  Sade-Feldman2018_Skin
# 4                  NaN                NaN     Skin  Sade-Feldman2018_Skin
# ...                ...                ...      ...                    ...
# 16286              NaN                NaN     Skin  Sade-Feldman2018_Skin
# 16287              NaN                NaN     Skin  Sade-Feldman2018_Skin
# 16288              NaN                NaN     Skin  Sade-Feldman2018_Skin
# 16289              NaN                NaN     Skin  Sade-Feldman2018_Skin
# 16290              NaN                NaN     Skin  Sade-Feldman2018_Skin
#
# [16291 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"treatment": "treated_naive"})

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['category'] = 'Skin'

# %%
adata.obs['study'] = 'Sade-Feldman2018_Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Sade-Feldman2018_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Sade-Feldman2018_Skin.h5ad

# %% [markdown]
# #### 9.Tirosh2016_Skin

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Tirosh2016_Skin"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4645 × 23686
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                          cell_name  sample  cell_type  complexity  \
# 0          Cy72_CD45_H02_S758_comb      72     B_cell        3365
# 1        CY58_1_CD45_B02_S974_comb      58     T_cell        3637
# 2          Cy71_CD45_D08_S524_comb      71  Malignant        4660
# 3      Cy81_FNA_CD45_B01_S301_comb      81  Malignant        6387
# 4       Cy80_II_CD45_B07_S883_comb      80  Malignant        5913
# ...                            ...     ...        ...         ...
# 4640  CY75_1_CD45_CD8_7__S223_comb      75     T_cell        5385
# 4641   CY75_1_CD45_CD8_1__S65_comb      75     T_cell        4769
# 4642   CY75_1_CD45_CD8_1__S93_comb      75     T_cell        4727
# 4643   CY75_1_CD45_CD8_1__S76_comb      75     T_cell        4976
# 4644  CY75_1_CD45_CD8_7__S274_comb      75        NaN        5881
#
#      cell_cycle_phase technology  n_cells  patient cancer_type sex  age  \
# 0         Not cycling  SmartSeq2      181       72    Melanoma   F  NaN
# 1         Not cycling  SmartSeq2      142       58    Melanoma   F  NaN
# 2         Not cycling  SmartSeq2       89       71    Melanoma   M  NaN
# 3         Not cycling  SmartSeq2      205       81    Melanoma   F  NaN
# 4         Not cycling  SmartSeq2      480       80    Melanoma   F  NaN
# ...               ...        ...      ...      ...         ...  ..  ...
# 4640      Not cycling  SmartSeq2      344       75    Melanoma   M  NaN
# 4641      Not cycling  SmartSeq2      344       75    Melanoma   M  NaN
# 4642      Not cycling  SmartSeq2      344       75    Melanoma   M  NaN
# 4643      Not cycling  SmartSeq2      344       75    Melanoma   M  NaN
# 4644              NaN  SmartSeq2      344       75    Melanoma   M  NaN
#
#      disease_extent sample_primary_met                       site  \
# 0        metastatic                met  External iliac lymph node
# 1        metastatic                met    Subcutaneous leg lesion
# 2        metastatic                met           Transverse colon
# 3        metastatic                met        Axillary lymph node
# 4        metastatic                met        Axillary lymph node
# ...             ...                ...                        ...
# 4640     metastatic                met    Subcutaneous leg lesion
# 4641     metastatic                met    Subcutaneous leg lesion
# 4642     metastatic                met    Subcutaneous leg lesion
# 4643     metastatic                met    Subcutaneous leg lesion
# 4644     metastatic                met    Subcutaneous leg lesion
#
#      treated_naive cell_subtype source category            study
# 0          treated          NaN    NaN     Skin  Tirosh2016_Skin
# 1          treated          NaN    NaN     Skin  Tirosh2016_Skin
# 2            naive          NaN    NaN     Skin  Tirosh2016_Skin
# 3            naive          NaN    NaN     Skin  Tirosh2016_Skin
# 4            naive          NaN    NaN     Skin  Tirosh2016_Skin
# ...            ...          ...    ...      ...              ...
# 4640       treated          NaN    NaN     Skin  Tirosh2016_Skin
# 4641       treated          NaN    NaN     Skin  Tirosh2016_Skin
# 4642       treated          NaN    NaN     Skin  Tirosh2016_Skin
# 4643       treated          NaN    NaN     Skin  Tirosh2016_Skin
# 4644       treated          NaN    NaN     Skin  Tirosh2016_Skin
#
# [4645 rows x 19 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Skin'

# %%
adata.obs['study'] = 'Tirosh2016_Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Tirosh2016_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Tirosh2016_Skin.h5ad

# %% [markdown]
# #### 10.Yost2019_Skin

# %%
import os
import pandas as pd
import scanpy as sc

# Set base path
base_path = "/home/ubuntu/Downloads/Data_Skin/Data_Yost2019_Skin"

# Define cancer type folders and labels
cancer_types = {
    "BCC": "Basal Cell Carcinoma",
    "SCC": "Squamous Cell Carcinoma"
}

# Load sample metadata
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

adatas = []

for folder, label in cancer_types.items():
    path = os.path.join(base_path, folder)
    
    # Load expression matrix
    adata = sc.read_mtx(os.path.join(path, "Exp_data_UMIcounts.mtx")).T  # Transpose to cells x genes
    
    # Load gene and cell information
    genes = pd.read_csv(os.path.join(path, "Genes.txt"), header=None)[0].tolist()
    cells = pd.read_csv(os.path.join(path, "Cells.csv"), index_col=0)

    # Assign gene names and cell metadata
    adata.var_names = genes
    adata.obs = cells
    adata.obs['cancer_folder'] = folder
    adata.obs['cancer_type'] = label
    
    adatas.append(adata)

# Find common genes
common_genes = adatas[0].var_names
for ad in adatas[1:]:
    common_genes = common_genes.intersection(ad.var_names)

# Subset to common genes
adatas = [ad[:, common_genes].copy() for ad in adatas]

# Concatenate all datasets
adata_combined = adatas[0].concatenate(
    *adatas[1:],
    batch_key='batch',
    batch_categories=list(cancer_types.keys()),
    index_unique=None
)

# Ensure unique cell names
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# Merge sample metadata
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]

# Merge by 'sample' column
adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')
assert adata_combined.shape[0] == adata_combined.obs.shape[0], "Mismatch after sample merge"

# Restore index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index.name = None
# Out:
# /tmp/ipykernel_1510865/3609190157.py:46: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adatas[0].concatenate(

# %%
adata = adata_combined

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 79046 × 18189
#     obs: 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'treatment_x', 'source_x', 'sort', 'cancer_folder', 'cancer_type_x', 'technology', 'n_cells'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment',  'disease', 'time_point_x', 'batch', 'patient_y', 'cancer_type_y',
            'time_point_y', 'treatment_y', 'source_y','sort', 'cancer_folder'

           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                                            sample patient cell_type  \
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG  su001_post   su001    T_cell
# bcc.su001.post.tcell_AAACCTGAGGACATTA  su001_post   su001    T_cell
# bcc.su001.post.tcell_AAACCTGCACGCATCG  su001_post   su001    T_cell
# bcc.su001.post.tcell_AAACCTGCAGATGGGT  su001_post   su001    T_cell
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT  su001_post   su001    T_cell
# ...                                           ...     ...       ...
# scc.su014.pre_TTTGTCAAGTGTTGAA          su014_pre   su014    T_cell
# scc.su014.pre_TTTGTCACAAATACAG          su014_pre   su014    T_cell
# scc.su014.pre_TTTGTCAGTCTAACGT          su014_pre   su014    T_cell
# scc.su014.pre_TTTGTCAGTTCAGTAC          su014_pre   su014    T_cell
# scc.su014.pre_TTTGTCATCCTTGCCA          su014_pre   su014    T_cell
#
#                                          cell_subtype  complexity  \
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG  CD8_mem_T_cell        1390
# bcc.su001.post.tcell_AAACCTGAGGACATTA   CD8_ex_T_cell        1887
# bcc.su001.post.tcell_AAACCTGCACGCATCG  CD8_mem_T_cell        1505
# bcc.su001.post.tcell_AAACCTGCAGATGGGT  CD8_mem_T_cell        1748
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT            Treg        1662
# ...                                               ...         ...
# scc.su014.pre_TTTGTCAAGTGTTGAA                   Th17        3352
# scc.su014.pre_TTTGTCACAAATACAG                   Th17        1730
# scc.su014.pre_TTTGTCAGTCTAACGT         CD8_eff_T_cell        1531
# scc.su014.pre_TTTGTCAGTTCAGTAC                   Treg        2619
# scc.su014.pre_TTTGTCATCCTTGCCA         CD8_eff_T_cell        3849
#
#                                       cell_cycle_phase  treated_naive  source  \
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG      Not cycling  Pembrolizumab   L arm
# bcc.su001.post.tcell_AAACCTGAGGACATTA      Not cycling  Pembrolizumab   L arm
# bcc.su001.post.tcell_AAACCTGCACGCATCG      Not cycling  Pembrolizumab   L arm
# bcc.su001.post.tcell_AAACCTGCAGATGGGT      Not cycling  Pembrolizumab   L arm
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT      Not cycling  Pembrolizumab   L arm
# ...                                                ...            ...     ...
# scc.su014.pre_TTTGTCAAGTGTTGAA             Not cycling            NaN  R neck
# scc.su014.pre_TTTGTCACAAATACAG             Not cycling            NaN  R neck
# scc.su014.pre_TTTGTCAGTCTAACGT             Not cycling            NaN  R neck
# scc.su014.pre_TTTGTCAGTTCAGTAC             Not cycling            NaN  R neck
# scc.su014.pre_TTTGTCATCCTTGCCA                    G2/M            NaN  R neck
#
#                                                    cancer_type technology  \
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG     Basal Cell Carcinoma        10x
# bcc.su001.post.tcell_AAACCTGAGGACATTA     Basal Cell Carcinoma        10x
# bcc.su001.post.tcell_AAACCTGCACGCATCG     Basal Cell Carcinoma        10x
# bcc.su001.post.tcell_AAACCTGCAGATGGGT     Basal Cell Carcinoma        10x
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT     Basal Cell Carcinoma        10x
# ...                                                        ...        ...
# scc.su014.pre_TTTGTCAAGTGTTGAA         Squamous Cell Carcinoma        10x
# scc.su014.pre_TTTGTCACAAATACAG         Squamous Cell Carcinoma        10x
# scc.su014.pre_TTTGTCAGTCTAACGT         Squamous Cell Carcinoma        10x
# scc.su014.pre_TTTGTCAGTTCAGTAC         Squamous Cell Carcinoma        10x
# scc.su014.pre_TTTGTCATCCTTGCCA         Squamous Cell Carcinoma        10x
#
#                                        n_cells  \
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG    10429
# bcc.su001.post.tcell_AAACCTGAGGACATTA    10429
# bcc.su001.post.tcell_AAACCTGCACGCATCG    10429
# bcc.su001.post.tcell_AAACCTGCAGATGGGT    10429
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT    10429
# ...                                        ...
# scc.su014.pre_TTTGTCAAGTGTTGAA            2808
# scc.su014.pre_TTTGTCACAAATACAG            2808
# scc.su014.pre_TTTGTCAGTCTAACGT            2808
# scc.su014.pre_TTTGTCAGTTCAGTAC            2808
# scc.su014.pre_TTTGTCATCCTTGCCA            2808
#
#                                                                    cell_name  \
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG  bcc.su001.post.tcell_AAACCTGAGCTTCGCG
# bcc.su001.post.tcell_AAACCTGAGGACATTA  bcc.su001.post.tcell_AAACCTGAGGACATTA
# bcc.su001.post.tcell_AAACCTGCACGCATCG  bcc.su001.post.tcell_AAACCTGCACGCATCG
# bcc.su001.post.tcell_AAACCTGCAGATGGGT  bcc.su001.post.tcell_AAACCTGCAGATGGGT
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT  bcc.su001.post.tcell_AAACCTGCAGTGGAGT
# ...                                                                      ...
# scc.su014.pre_TTTGTCAAGTGTTGAA                scc.su014.pre_TTTGTCAAGTGTTGAA
# scc.su014.pre_TTTGTCACAAATACAG                scc.su014.pre_TTTGTCACAAATACAG
# scc.su014.pre_TTTGTCAGTCTAACGT                scc.su014.pre_TTTGTCAGTCTAACGT
# scc.su014.pre_TTTGTCAGTTCAGTAC                scc.su014.pre_TTTGTCAGTTCAGTAC
# scc.su014.pre_TTTGTCATCCTTGCCA                scc.su014.pre_TTTGTCATCCTTGCCA
#
#                                        sex  age disease_extent  \
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG  NaN  NaN            NaN
# bcc.su001.post.tcell_AAACCTGAGGACATTA  NaN  NaN            NaN
# bcc.su001.post.tcell_AAACCTGCACGCATCG  NaN  NaN            NaN
# bcc.su001.post.tcell_AAACCTGCAGATGGGT  NaN  NaN            NaN
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT  NaN  NaN            NaN
# ...                                    ...  ...            ...
# scc.su014.pre_TTTGTCAAGTGTTGAA         NaN  NaN            NaN
# scc.su014.pre_TTTGTCACAAATACAG         NaN  NaN            NaN
# scc.su014.pre_TTTGTCAGTCTAACGT         NaN  NaN            NaN
# scc.su014.pre_TTTGTCAGTTCAGTAC         NaN  NaN            NaN
# scc.su014.pre_TTTGTCATCCTTGCCA         NaN  NaN            NaN
#
#                                       sample_primary_met          site  \
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG                NaN   L arm tumor
# bcc.su001.post.tcell_AAACCTGAGGACATTA                NaN   L arm tumor
# bcc.su001.post.tcell_AAACCTGCACGCATCG                NaN   L arm tumor
# bcc.su001.post.tcell_AAACCTGCAGATGGGT                NaN   L arm tumor
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT                NaN   L arm tumor
# ...                                                  ...           ...
# scc.su014.pre_TTTGTCAAGTGTTGAA                       NaN  R neck tumor
# scc.su014.pre_TTTGTCACAAATACAG                       NaN  R neck tumor
# scc.su014.pre_TTTGTCAGTCTAACGT                       NaN  R neck tumor
# scc.su014.pre_TTTGTCAGTTCAGTAC                       NaN  R neck tumor
# scc.su014.pre_TTTGTCATCCTTGCCA                       NaN  R neck tumor
#
#                                       category          study
# bcc.su001.post.tcell_AAACCTGAGCTTCGCG     Skin  Yost2019_Skin
# bcc.su001.post.tcell_AAACCTGAGGACATTA     Skin  Yost2019_Skin
# bcc.su001.post.tcell_AAACCTGCACGCATCG     Skin  Yost2019_Skin
# bcc.su001.post.tcell_AAACCTGCAGATGGGT     Skin  Yost2019_Skin
# bcc.su001.post.tcell_AAACCTGCAGTGGAGT     Skin  Yost2019_Skin
# ...                                        ...            ...
# scc.su014.pre_TTTGTCAAGTGTTGAA            Skin  Yost2019_Skin
# scc.su014.pre_TTTGTCACAAATACAG            Skin  Yost2019_Skin
# scc.su014.pre_TTTGTCAGTCTAACGT            Skin  Yost2019_Skin
# scc.su014.pre_TTTGTCAGTTCAGTAC            Skin  Yost2019_Skin
# scc.su014.pre_TTTGTCATCCTTGCCA            Skin  Yost2019_Skin
#
# [79046 rows x 19 columns]

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"cancer_type_x": "cancer_type"})

# %%
adata.obs = adata.obs.rename(columns={"treatment_x": "treated_naive"})

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata_combined.obs['site'] = adata_combined.obs['source'].astype(str) + " tumor"

# %%
adata.obs['category'] = 'Skin'

# %%
adata.obs['study'] = 'Yost2019_Skin'

# %%
output_path = "/home/ubuntu/Downloads/Data_Skin/Data_Yost2019_Skin.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Skin/Data_Yost2019_Skin.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Skin/Data_Biermann2022_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Ferrari de Andrade2019_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Jerby-Arnon2018_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Ji2020_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Li2019_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Mahuron2020_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Paulson2020_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Sade-Feldman2018_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Tirosh2016_Skin.h5ad",
    "/home/ubuntu/Downloads/Data_Skin/Data_Yost2019_Skin.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

gc.collect()
# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

gc.collect()
# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

gc.collect()
# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Skin/Skin_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Skin/Skin_Combined.h5ad

# %%
adata_merged.obs
# Out:
#                                                      cell_name     sample  \
# 0                                         CTCGTACCAAGCTGGA-1_1   MBM01_sc
# 1                                         AGATTGCAGTGGGTTG-1_1   MBM01_sc
# 2                                         TCGGGACTCAACACTG-1_1   MBM01_sc
# 3                                         CTCGGAGCAGCTATTG-1_1   MBM01_sc
# 4                                         TGGGAAGAGAACAACT-1_1   MBM01_sc
# ...                                                        ...        ...
# scc.su014.pre_TTTGTCAAGTGTTGAA  scc.su014.pre_TTTGTCAAGTGTTGAA  su014_pre
# scc.su014.pre_TTTGTCACAAATACAG  scc.su014.pre_TTTGTCACAAATACAG  su014_pre
# scc.su014.pre_TTTGTCAGTCTAACGT  scc.su014.pre_TTTGTCAGTCTAACGT  su014_pre
# scc.su014.pre_TTTGTCAGTTCAGTAC  scc.su014.pre_TTTGTCAGTTCAGTAC  su014_pre
# scc.su014.pre_TTTGTCATCCTTGCCA  scc.su014.pre_TTTGTCATCCTTGCCA  su014_pre
#
#                                patient  cell_type    cell_subtype  complexity  \
# 0                                MBM01     Plasma    Plasma cells        4017
# 1                                MBM01     Plasma    Plasma cells        4269
# 2                                MBM01  Malignant     Tumor cells        8319
# 3                                MBM01  Malignant     Tumor cells        8229
# 4                                MBM01     Plasma    Plasma cells        4396
# ...                                ...        ...             ...         ...
# scc.su014.pre_TTTGTCAAGTGTTGAA   su014     T_cell            Th17        3352
# scc.su014.pre_TTTGTCACAAATACAG   su014     T_cell            Th17        1730
# scc.su014.pre_TTTGTCAGTCTAACGT   su014     T_cell  CD8_eff_T_cell        1531
# scc.su014.pre_TTTGTCAGTTCAGTAC   su014     T_cell            Treg        2619
# scc.su014.pre_TTTGTCATCCTTGCCA   su014     T_cell  CD8_eff_T_cell        3849
#
#                                cell_cycle_phase            source technology  \
# 0                                   Not cycling  Brain_Metastasis        10X
# 1                                   Not cycling  Brain_Metastasis        10X
# 2                                          G1/S  Brain_Metastasis        10X
# 3                                   Not cycling  Brain_Metastasis        10X
# 4                                   Not cycling  Brain_Metastasis        10X
# ...                                         ...               ...        ...
# scc.su014.pre_TTTGTCAAGTGTTGAA      Not cycling            R neck        10x
# scc.su014.pre_TTTGTCACAAATACAG      Not cycling            R neck        10x
# scc.su014.pre_TTTGTCAGTCTAACGT      Not cycling            R neck        10x
# scc.su014.pre_TTTGTCAGTTCAGTAC      Not cycling            R neck        10x
# scc.su014.pre_TTTGTCATCCTTGCCA             G2/M            R neck        10x
#
#                                 n_cells              cancer_type  sex  age  \
# 0                                3515.0                 Melanoma  nan  nan
# 1                                3515.0                 Melanoma  nan  nan
# 2                                3515.0                 Melanoma  nan  nan
# 3                                3515.0                 Melanoma  nan  nan
# 4                                3515.0                 Melanoma  nan  nan
# ...                                 ...                      ...  ...  ...
# scc.su014.pre_TTTGTCAAGTGTTGAA   2808.0  Squamous Cell Carcinoma  NaN  NaN
# scc.su014.pre_TTTGTCACAAATACAG   2808.0  Squamous Cell Carcinoma  NaN  NaN
# scc.su014.pre_TTTGTCAGTCTAACGT   2808.0  Squamous Cell Carcinoma  NaN  NaN
# scc.su014.pre_TTTGTCAGTTCAGTAC   2808.0  Squamous Cell Carcinoma  NaN  NaN
# scc.su014.pre_TTTGTCATCCTTGCCA   2808.0  Squamous Cell Carcinoma  NaN  NaN
#
#                                disease_extent sample_primary_met  \
# 0                                         nan                met
# 1                                         nan                met
# 2                                         nan                met
# 3                                         nan                met
# 4                                         nan                met
# ...                                       ...                ...
# scc.su014.pre_TTTGTCAAGTGTTGAA            NaN                NaN
# scc.su014.pre_TTTGTCACAAATACAG            NaN                NaN
# scc.su014.pre_TTTGTCAGTCTAACGT            NaN                NaN
# scc.su014.pre_TTTGTCAGTTCAGTAC            NaN                NaN
# scc.su014.pre_TTTGTCATCCTTGCCA            NaN                NaN
#
#                                             site treated_naive  \
# 0                               brain metastasis         naive
# 1                               brain metastasis         naive
# 2                               brain metastasis         naive
# 3                               brain metastasis         naive
# 4                               brain metastasis         naive
# ...                                          ...           ...
# scc.su014.pre_TTTGTCAAGTGTTGAA      R neck tumor           NaN
# scc.su014.pre_TTTGTCACAAATACAG      R neck tumor           NaN
# scc.su014.pre_TTTGTCAGTCTAACGT      R neck tumor           NaN
# scc.su014.pre_TTTGTCAGTTCAGTAC      R neck tumor           NaN
# scc.su014.pre_TTTGTCATCCTTGCCA      R neck tumor           NaN
#
#                                             study category
# 0                               Biermann2022_Skin     Skin
# 1                               Biermann2022_Skin     Skin
# 2                               Biermann2022_Skin     Skin
# 3                               Biermann2022_Skin     Skin
# 4                               Biermann2022_Skin     Skin
# ...                                           ...      ...
# scc.su014.pre_TTTGTCAAGTGTTGAA      Yost2019_Skin     Skin
# scc.su014.pre_TTTGTCACAAATACAG      Yost2019_Skin     Skin
# scc.su014.pre_TTTGTCAGTCTAACGT      Yost2019_Skin     Skin
# scc.su014.pre_TTTGTCAGTTCAGTAC      Yost2019_Skin     Skin
# scc.su014.pre_TTTGTCATCCTTGCCA      Yost2019_Skin     Skin
#
# [470775 rows x 19 columns]
