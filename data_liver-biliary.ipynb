# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc

# %% [markdown]
# ## Liver-Biliary

# %% [markdown]
# #### 1. Ma2019

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Ma2019_Liver-Biliary"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3018 × 17917
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'disease', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                 cell_name sample    cell_type  complexity cell_cycle_phase  \
# 0      AAACCTGAGATAGCAT-3    C26  Endothelial        1247      Not cycling
# 1      AAACCTGAGATGTAAC-9    H38    Malignant        3524      Not cycling
# 2      AAACCTGAGGAATTAC-9    H38   Fibroblast        1562      Not cycling
# 3     AAACCTGAGGTACTCT-22    C66    Malignant        2446      Not cycling
# 4      AAACCTGAGTCCAGGA-4    C25    Malignant        1144      Not cycling
# ...                   ...    ...          ...         ...              ...
# 3013  TTTGTCAAGCTGAACG-22    C66    Malignant        1397      Not cycling
# 3014   TTTGTCAAGTGGTAAT-9    H38    Malignant        2200      Not cycling
# 3015   TTTGTCACAATAACGA-9    H38  Endothelial        2895      Not cycling
# 3016   TTTGTCACAGCTGCTG-3    C26    Malignant        4514      Not cycling
# 3017  TTTGTCAGTTTGGGCC-13    H37   Macrophage        3353     Intermediate
#
#      technology  n_cells patient               cancer_type     sex  age  \
# 0           10x      277     C26        Cholangiocarcinoma    male   63
# 1           10x     1001     H38  Hepatocellular Carcinoma    male   74
# 2           10x     1001     H38  Hepatocellular Carcinoma    male   74
# 3           10x      388     C66        Cholangiocarcinoma  female   71
# 4           10x      159     C25        Cholangiocarcinoma  female   47
# ...         ...      ...     ...                       ...     ...  ...
# 3013        10x      388     C66        Cholangiocarcinoma  female   71
# 3014        10x     1001     H38  Hepatocellular Carcinoma    male   74
# 3015        10x     1001     H38  Hepatocellular Carcinoma    male   74
# 3016        10x      277     C26        Cholangiocarcinoma    male   63
# 3017        10x       89     H37  Hepatocellular Carcinoma    male   65
#
#      disease_extent sample_primary_met   site treated_naive  \
# 0        metastatic            primary  liver       treated
# 1             local            primary  liver         naive
# 2             local            primary  liver         naive
# 3        metastatic            primary  liver       treated
# 4        metastatic            primary  liver       treated
# ...             ...                ...    ...           ...
# 3013     metastatic            primary  liver       treated
# 3014          local            primary  liver         naive
# 3015          local            primary  liver         naive
# 3016     metastatic            primary  liver       treated
# 3017     metastatic            primary  liver       treated
#
#                           study       category source cell_subtype
# 0     Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# 1     Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# 2     Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# 3     Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# 4     Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# ...                         ...            ...    ...          ...
# 3013  Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# 3014  Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# 3015  Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# 3016  Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
# 3017  Data_Ma2019_Liver-Biliary  Liver-Biliary    NaN          NaN
#
# [3018 rows x 19 columns]

# %%
adata.obs['study'] = 'Data_Ma2019_Liver-Biliary'

# %%
adata.obs['category'] = 'Liver-Biliary'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
del adata.obs['disease']

# %%
output_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Ma2019_Liver-Biliary.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Liver-Biliary/Data_Ma2019_Liver-Biliary.h5ad

# %% [markdown]
# #### 2.Sharma2020

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Sharma2020_Liver-Biliary"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 73589 × 33694
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source_x', 'cancer_type', 'technology', 'n_cells'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'viral_x', 'patient_y', 'source_y', 'viral_y'       
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['viral_x'].value_counts()
# Out:
# viral_x
# Negative    57588
# Positive    16001
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                  cell_name    sample patient   cell_type cell_subtype  \
# 0       AAACCTGGTCGGGTCT-1      P1_N      P1      T_cell  CD8+ T cell
# 1       AAAGCAAGTTCGAATC-1      P1_N      P1      T_cell  CD4+ T cell
# 2       AACCATGAGTAATCCC-1      P1_N      P1     NK_cell      NK cell
# 3       AACCGCGAGCTCCTCT-1      P1_N      P1      T_cell  CD8+ T cell
# 4       AACCGCGCACATGTGT-1      P1_N      P1      T_cell  CD4+ T cell
# ...                    ...       ...     ...         ...          ...
# 73584  TTTGGTTTCCGCATCT-58  P15_T4T5     P15  Hepatocyte   Hepatocyte
# 73585  TTTGGTTTCTTCAACT-58  P15_T4T5     P15  Hepatocyte   Hepatocyte
# 73586  TTTGTCAAGGATGCGT-58  P15_T4T5     P15  Hepatocyte   Hepatocyte
# 73587  TTTGTCATCGAATGCT-58  P15_T4T5     P15  Hepatocyte   Hepatocyte
# 73588  TTTGTCATCTGTGCAA-58  P15_T4T5     P15  Hepatocyte   Hepatocyte
#
#        complexity cell_cycle_phase source_x               cancer_type  \
# 0             502              NaN   normal  Hepatocellular Carcinoma
# 1             414              NaN   normal  Hepatocellular Carcinoma
# 2            1276      Not cycling   normal  Hepatocellular Carcinoma
# 3             787              NaN   normal  Hepatocellular Carcinoma
# 4             591              NaN   normal  Hepatocellular Carcinoma
# ...           ...              ...      ...                       ...
# 73584        2197      Not cycling    tumor  Hepatocellular Carcinoma
# 73585         428              NaN    tumor  Hepatocellular Carcinoma
# 73586         477              NaN    tumor  Hepatocellular Carcinoma
# 73587         894              NaN    tumor  Hepatocellular Carcinoma
# 73588         507              NaN    tumor  Hepatocellular Carcinoma
#
#       technology  n_cells  age  sex disease_extent sample_primary_met   site  \
# 0            10x      401  NaN  NaN            NaN                NaN  liver
# 1            10x      401  NaN  NaN            NaN                NaN  liver
# 2            10x      401  NaN  NaN            NaN                NaN  liver
# 3            10x      401  NaN  NaN            NaN                NaN  liver
# 4            10x      401  NaN  NaN            NaN                NaN  liver
# ...          ...      ...  ...  ...            ...                ...    ...
# 73584        10x     1865  NaN  NaN            NaN                NaN  liver
# 73585        10x     1865  NaN  NaN            NaN                NaN  liver
# 73586        10x     1865  NaN  NaN            NaN                NaN  liver
# 73587        10x     1865  NaN  NaN            NaN                NaN  liver
# 73588        10x     1865  NaN  NaN            NaN                NaN  liver
#
#       treated_naive                          study       category
# 0               NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# 1               NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# 2               NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# 3               NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# 4               NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# ...             ...                            ...            ...
# 73584           NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# 73585           NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# 73586           NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# 73587           NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
# 73588           NaN  Data_Sharma2020_Liver-Biliary  Liver-Biliary
#
# [73589 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['site'] = 'liver'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['study'] = 'Data_Sharma2020_Liver-Biliary'

# %%
adata.obs['category'] = 'Liver-Biliary'

# %%
output_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Sharma2020_Liver-Biliary.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Liver-Biliary/Data_Sharma2020_Liver-Biliary.h5ad

# %% [markdown]
# #### 3.Sun2021

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Sun2021_Liver-Biliary"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 16498 × 19744
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'source', 'disease', 'cell_subtype', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"cell_subtype_clusters": "cell_subtype"})

# %%
adata.obs['category'] = 'Liver-Biliary'

# %%
adata.obs['study'] = 'Sun2021_Liver-Biliary'

# %%
del adata.obs['disease']

# %%
adata.obs
# Out:
#         cell_name sample    cell_type  complexity cell_cycle_phase source  \
# 0      P01_T_0001    P01    Malignant        8444      Not cycling  Tumor
# 1      P01_T_0003    P01    Malignant        6481      Not cycling  Tumor
# 2      P01_T_0004    P01      NK_cell        7517      Not cycling  Tumor
# 3      P01_T_0007    P01    Malignant        6625      Not cycling  Tumor
# 4      P01_T_0008    P01  Endothelial        7891      Not cycling  Tumor
# ...           ...    ...          ...         ...              ...    ...
# 16493  P19_T_0138    P19       T_cell        8611      Not cycling  Tumor
# 16494  P19_T_0139    P19    Malignant        8255      Not cycling  Tumor
# 16495  P19_T_0143    P19    Malignant        9421      Not cycling  Tumor
# 16496  P19_T_0144    P19       T_cell        8692      Not cycling  Tumor
# 16497  P19_T_0146    P19       T_cell        8044      Not cycling  Tumor
#
#       cell_subtype technology  n_cells patient               cancer_type sex  \
# 0        C10_Tumor        10x      119     P01  Hepatocellular Carcinoma   F
# 1        C10_Tumor        10x      119     P01  Hepatocellular Carcinoma   F
# 2            C4_NK        10x      119     P01  Hepatocellular Carcinoma   F
# 3        C10_Tumor        10x      119     P01  Hepatocellular Carcinoma   F
# 4        C17_Endo.        10x      119     P01  Hepatocellular Carcinoma   F
# ...            ...        ...      ...     ...                       ...  ..
# 16493     C1_Tcell        10x      147     P19  Hepatocellular Carcinoma   M
# 16494    C14_Tumor        10x      147     P19  Hepatocellular Carcinoma   M
# 16495    C14_Tumor        10x      147     P19  Hepatocellular Carcinoma   M
# 16496     C3_Tcell        10x      147     P19  Hepatocellular Carcinoma   M
# 16497     C1_Tcell        10x      147     P19  Hepatocellular Carcinoma   M
#
#        age disease_extent  sample_primary_met  site  treated_naive  \
# 0       58            NaN                 NaN   NaN            NaN
# 1       58            NaN                 NaN   NaN            NaN
# 2       58            NaN                 NaN   NaN            NaN
# 3       58            NaN                 NaN   NaN            NaN
# 4       58            NaN                 NaN   NaN            NaN
# ...    ...            ...                 ...   ...            ...
# 16493   45            NaN                 NaN   NaN            NaN
# 16494   45            NaN                 NaN   NaN            NaN
# 16495   45            NaN                 NaN   NaN            NaN
# 16496   45            NaN                 NaN   NaN            NaN
# 16497   45            NaN                 NaN   NaN            NaN
#
#             category                  study
# 0      Liver-Biliary  Sun2021_Liver-Biliary
# 1      Liver-Biliary  Sun2021_Liver-Biliary
# 2      Liver-Biliary  Sun2021_Liver-Biliary
# 3      Liver-Biliary  Sun2021_Liver-Biliary
# 4      Liver-Biliary  Sun2021_Liver-Biliary
# ...              ...                    ...
# 16493  Liver-Biliary  Sun2021_Liver-Biliary
# 16494  Liver-Biliary  Sun2021_Liver-Biliary
# 16495  Liver-Biliary  Sun2021_Liver-Biliary
# 16496  Liver-Biliary  Sun2021_Liver-Biliary
# 16497  Liver-Biliary  Sun2021_Liver-Biliary
#
# [16498 rows x 19 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Sun2021_Liver-Biliary.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Liver-Biliary/Data_Sun2021_Liver-Biliary.h5ad

# %% [markdown]
# #### 4. Zheng2017

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Zheng2017_Liver-Biliary"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5063 × 22902
#     obs: 'cell_name', 'sample', 'patient', 'source', 'cell_type', 'cell_subtype', 'complexity', 'technology', 'n_cells', 'cancer_type', 'sample_primary_met', 'age', 'sex'

# %%
adata.obs[''stage''].value_counts()
# Out:
# sorting
# CD3+, CD8+            1843
# CD3+, CD4+, CD25-     1613
# CD3+, CD4+, CD25hi    1607
# Name: count, dtype: int64

# %%
for col in ['patient_y', 'source_y', 'sorting','cluster', 'stage'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs['cell_cycle_phase'] = 'Not cycling'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['site'] = 'liver'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs
# Out:
#         cell_name    sample patient            source cell_type cell_subtype  \
# 0      PTC03-0205   P0205_P   P0205  Peripheral blood    T_cell         CD8+
# 1      PTC10-0205   P0205_P   P0205  Peripheral blood       NaN          NaN
# 2     PTC100-0205   P0205_P   P0205  Peripheral blood    T_cell         CD8+
# 3     PTC103-0205   P0205_P   P0205  Peripheral blood    T_cell         CD8+
# 4     PTC104-0205   P0205_P   P0205  Peripheral blood    T_cell         CD8+
# ...           ...       ...     ...               ...       ...          ...
# 5058   TTS47-1202  P1202t_T  P1202t             Tumor       NaN          NaN
# 5059   TTS48-1202  P1202t_T  P1202t             Tumor       NaN          NaN
# 5060    TTS5-1202  P1202t_T  P1202t             Tumor       NaN          NaN
# 5061    TTS7-1202  P1202t_T  P1202t             Tumor       NaN          NaN
# 5062    TTS8-1202  P1202t_T  P1202t             Tumor       NaN          NaN
#
#       complexity         technology  n_cells               cancer_type  \
# 0           2761         Smart-seq2      318  Hepatocellular Carcinoma
# 1           3200         Smart-seq2      318  Hepatocellular Carcinoma
# 2           3224         Smart-seq2      318  Hepatocellular Carcinoma
# 3           4850         Smart-seq2      318  Hepatocellular Carcinoma
# 4           3166         Smart-seq2      318  Hepatocellular Carcinoma
# ...          ...                ...      ...                       ...
# 5058        1935  Tang2010 protocol       86  Hepatocellular Carcinoma
# 5059        5254  Tang2010 protocol       86  Hepatocellular Carcinoma
# 5060        2435  Tang2010 protocol       86  Hepatocellular Carcinoma
# 5061        1145  Tang2010 protocol       86  Hepatocellular Carcinoma
# 5062        1849  Tang2010 protocol       86  Hepatocellular Carcinoma
#
#      sample_primary_met  age     sex cell_cycle_phase disease_extent   site  \
# 0               primary   53    Male      Not cycling            NaN  liver
# 1               primary   53    Male      Not cycling            NaN  liver
# 2               primary   53    Male      Not cycling            NaN  liver
# 3               primary   53    Male      Not cycling            NaN  liver
# 4               primary   53    Male      Not cycling            NaN  liver
# ...                 ...  ...     ...              ...            ...    ...
# 5058            primary   26  Female      Not cycling            NaN  liver
# 5059            primary   26  Female      Not cycling            NaN  liver
# 5060            primary   26  Female      Not cycling            NaN  liver
# 5061            primary   26  Female      Not cycling            NaN  liver
# 5062            primary   26  Female      Not cycling            NaN  liver
#
#      treated_naive       category                    study
# 0              NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# 1              NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# 2              NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# 3              NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# 4              NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# ...            ...            ...                      ...
# 5058           NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# 5059           NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# 5060           NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# 5061           NaN  Liver-Biliary  Zheng2017_Liver-Biliary
# 5062           NaN  Liver-Biliary  Zheng2017_Liver-Biliary
#
# [5063 rows x 19 columns]

# %%
adata.obs['category'] = 'Liver-Biliary'

# %%
adata.obs['study'] = 'Zheng2017_Liver-Biliary'

# %%
output_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Zheng2017_Liver-Biliary.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Liver-Biliary/Data_Zheng2017_Liver-Biliary.h5ad

# %% [markdown]
# #### 5.Zhang2019

# %%
# Set base path
base_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Zhang2019_Liver-Biliary"

# === Load 10X Data ===
path_10x = os.path.join(base_path, "10X")
adata_10x = sc.read_mtx(os.path.join(path_10x, "Exp_data_UMIcounts.mtx")).T  # Transpose to cells x genes
genes_10x = pd.read_csv(os.path.join(path_10x, "Genes.txt"), header=None)[0].tolist()
cells_10x = pd.read_csv(os.path.join(path_10x, "Cells.csv"), index_col=0)

adata_10x.var_names = genes_10x
adata_10x.obs = cells_10x
adata_10x.obs['technology'] = '10X'

# === Load SmartSeq2 Data ===
path_ss2 = os.path.join(base_path, "SmartSeq2")
adata_ss2 = sc.read_mtx(os.path.join(path_ss2, "Exp_data_UMIcounts.mtx")).T
genes_ss2 = pd.read_csv(os.path.join(path_ss2, "Genes.txt"), header=None)[0].tolist()
cells_ss2 = pd.read_csv(os.path.join(path_ss2, "Cells.csv"), index_col=0)

adata_ss2.var_names = genes_ss2
adata_ss2.obs = cells_ss2
adata_ss2.obs['technology'] = 'SmartSeq2'

# === Align by common genes ===
common_genes = adata_10x.var_names.intersection(adata_ss2.var_names)
adata_10x = adata_10x[:, common_genes].copy()
adata_ss2 = adata_ss2[:, common_genes].copy()

# === Concatenate ===
adata_combined = adata_10x.concatenate(
    adata_ss2,
    batch_key='batch',
    batch_categories=['10X', 'SmartSeq2'],
    index_unique=None
)

# === Check uniqueness ===
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# === Merge sample metadata ===
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

# Preserve and reset index
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]

# Merge with sample metadata
adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')
assert adata_combined.obs.shape[0] == adata_combined.shape[0], "Row count mismatch after metadata merge"

# Restore index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index.name = None

# === Save final object ===
#output_path = os.path.join(base_path, "Data_Jerby-Arnon2021_Sarcoma.h5ad")
#adata_combined.write(output_path)
#print(f"✅ AnnData object saved to: {output_path}")
# Out:
# /tmp/ipykernel_1158934/3011451183.py:30: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adata_10x.concatenate(

# %%
gc.collect()
# Out:
# 2007

# %%
adata = adata_combined

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 73261 × 24011
#     obs: 'sample', 'patient', 'source', 'site', 'cancer_type', 'cell_type', 'cell_subtype', 'complexity', 'technology', 'sorting', 'sex', 'age', 'sample_primary_met', 'treated_naive', 'cell_name', 'cell_cycle_phase', 'category', 'study'

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs = adata.obs.rename(columns={"location_x": "site"})

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"cancer_type_x": "cancer_type"})

# %%
adata.obs = adata.obs.rename(columns={"technology_x": "technology"})

# %%
adata.obs['cell_cycle_phase'] = 'Not cycling'

# %%
for col in ['patient_y', 'source_y', 'location_y', 'cancer_type_y', 'n_cells', 
            'technology_y', 'histology', 'hbv_infection', 'stage',
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['category'] = 'Liver-Biliary'

# %%
adata.obs['study'] = 'Zhang2019_Liver-Biliary'

# %%
del adata.obs['batch']

# %%
del adata.obs['sorting']

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs
# Out:
#                                      sample patient   source        site  \
# AAACCTGAGAGCCCAA-1-D20171109_A  D20171109_A   DSN09  ascites     ascites
# AAACCTGGTGCTAGCC-1-D20171109_A  D20171109_A   DSN09  ascites     ascites
# AAACGGGAGAGACTAT-1-D20171109_A  D20171109_A   DSN09  ascites     ascites
# AAACGGGAGCGTAATA-1-D20171109_A  D20171109_A   DSN09  ascites     ascites
# AAACGGGAGCTGAAAT-1-D20171109_A  D20171109_A   DSN09  ascites     ascites
# ...                                     ...     ...      ...         ...
# TP9-88-20171109                 D20171109_T   DSN09    tumor  tumor edge
# TP9-93-20171109                 D20171109_T   DSN09    tumor  tumor edge
# TP9-94-20171109                 D20171109_T   DSN09    tumor  tumor edge
# TP9-97-20171109                 D20171109_T   DSN09    tumor  tumor edge
# TP9-99-20171109                 D20171109_T   DSN09    tumor  tumor edge
#
#                                              cancer_type   cell_type  \
# AAACCTGAGAGCCCAA-1-D20171109_A  Hepatocellular Carcinoma  Macrophage
# AAACCTGGTGCTAGCC-1-D20171109_A  Hepatocellular Carcinoma      T_cell
# AAACGGGAGAGACTAT-1-D20171109_A  Hepatocellular Carcinoma      T_cell
# AAACGGGAGCGTAATA-1-D20171109_A  Hepatocellular Carcinoma  Macrophage
# AAACGGGAGCTGAAAT-1-D20171109_A  Hepatocellular Carcinoma   Dendritic
# ...                                                  ...         ...
# TP9-88-20171109                 Hepatocellular Carcinoma  Macrophage
# TP9-93-20171109                 Hepatocellular Carcinoma     NK_cell
# TP9-94-20171109                 Hepatocellular Carcinoma  Macrophage
# TP9-97-20171109                 Hepatocellular Carcinoma  Macrophage
# TP9-99-20171109                 Hepatocellular Carcinoma      B_cell
#
#                                cell_subtype  complexity technology   sex  age  \
# AAACCTGAGAGCCCAA-1-D20171109_A          Mac         890        10X  male   54
# AAACCTGGTGCTAGCC-1-D20171109_A          CD8         931        10X  male   54
# AAACGGGAGAGACTAT-1-D20171109_A      CD4/CD8         944        10X  male   54
# AAACGGGAGCGTAATA-1-D20171109_A          Mac        1592        10X  male   54
# AAACGGGAGCTGAAAT-1-D20171109_A           DC        1841        10X  male   54
# ...                                     ...         ...        ...   ...  ...
# TP9-88-20171109                         Mac        4275  SmartSeq2  male   54
# TP9-93-20171109                          NK        5482  SmartSeq2  male   54
# TP9-94-20171109                         Mac        5421  SmartSeq2  male   54
# TP9-97-20171109                         Mac        3310  SmartSeq2  male   54
# TP9-99-20171109                           B        2448  SmartSeq2  male   54
#
#                                sample_primary_met treated_naive  \
# AAACCTGAGAGCCCAA-1-D20171109_A                NaN         naive
# AAACCTGGTGCTAGCC-1-D20171109_A                NaN         naive
# AAACGGGAGAGACTAT-1-D20171109_A                NaN         naive
# AAACGGGAGCGTAATA-1-D20171109_A                NaN         naive
# AAACGGGAGCTGAAAT-1-D20171109_A                NaN         naive
# ...                                           ...           ...
# TP9-88-20171109                           primary         naive
# TP9-93-20171109                           primary         naive
# TP9-94-20171109                           primary         naive
# TP9-97-20171109                           primary         naive
# TP9-99-20171109                           primary         naive
#
#                                                      cell_name  \
# AAACCTGAGAGCCCAA-1-D20171109_A  AAACCTGAGAGCCCAA-1-D20171109_A
# AAACCTGGTGCTAGCC-1-D20171109_A  AAACCTGGTGCTAGCC-1-D20171109_A
# AAACGGGAGAGACTAT-1-D20171109_A  AAACGGGAGAGACTAT-1-D20171109_A
# AAACGGGAGCGTAATA-1-D20171109_A  AAACGGGAGCGTAATA-1-D20171109_A
# AAACGGGAGCTGAAAT-1-D20171109_A  AAACGGGAGCTGAAAT-1-D20171109_A
# ...                                                        ...
# TP9-88-20171109                                TP9-88-20171109
# TP9-93-20171109                                TP9-93-20171109
# TP9-94-20171109                                TP9-94-20171109
# TP9-97-20171109                                TP9-97-20171109
# TP9-99-20171109                                TP9-99-20171109
#
#                                cell_cycle_phase       category  \
# AAACCTGAGAGCCCAA-1-D20171109_A      Not cycling  Liver-Biliary
# AAACCTGGTGCTAGCC-1-D20171109_A      Not cycling  Liver-Biliary
# AAACGGGAGAGACTAT-1-D20171109_A      Not cycling  Liver-Biliary
# AAACGGGAGCGTAATA-1-D20171109_A      Not cycling  Liver-Biliary
# AAACGGGAGCTGAAAT-1-D20171109_A      Not cycling  Liver-Biliary
# ...                                         ...            ...
# TP9-88-20171109                     Not cycling  Liver-Biliary
# TP9-93-20171109                     Not cycling  Liver-Biliary
# TP9-94-20171109                     Not cycling  Liver-Biliary
# TP9-97-20171109                     Not cycling  Liver-Biliary
# TP9-99-20171109                     Not cycling  Liver-Biliary
#
#                                                   study disease_extent
# AAACCTGAGAGCCCAA-1-D20171109_A  Zhang2019_Liver-Biliary            NaN
# AAACCTGGTGCTAGCC-1-D20171109_A  Zhang2019_Liver-Biliary            NaN
# AAACGGGAGAGACTAT-1-D20171109_A  Zhang2019_Liver-Biliary            NaN
# AAACGGGAGCGTAATA-1-D20171109_A  Zhang2019_Liver-Biliary            NaN
# AAACGGGAGCTGAAAT-1-D20171109_A  Zhang2019_Liver-Biliary            NaN
# ...                                                 ...            ...
# TP9-88-20171109                 Zhang2019_Liver-Biliary            NaN
# TP9-93-20171109                 Zhang2019_Liver-Biliary            NaN
# TP9-94-20171109                 Zhang2019_Liver-Biliary            NaN
# TP9-97-20171109                 Zhang2019_Liver-Biliary            NaN
# TP9-99-20171109                 Zhang2019_Liver-Biliary            NaN
#
# [73261 rows x 18 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Zhang2019_Liver-Biliary.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Liver-Biliary/Data_Zhang2019_Liver-Biliary.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Ma2019_Liver-Biliary.h5ad",
    "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Sharma2020_Liver-Biliary.h5ad",
    "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Sun2021_Liver-Biliary.h5ad",
    "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Zhang2019_Liver-Biliary.h5ad",
    "/home/ubuntu/Downloads/Data_Liver-Biliary/Data_Zheng2017_Liver-Biliary.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Liver-Biliary/Liver-Biliary_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Liver-Biliary/Liver-Biliary_Combined.h5ad
