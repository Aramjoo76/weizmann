# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc
import scipy.io
from scipy.sparse import vstack

# %% [markdown]
# ## Ovarian

# %% [markdown]
# #### 1. Geistlinger2020_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Geistlinger2020_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect()
# Out:
# 40

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 41031 × 15328
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'cancer_type', 'technology', 'n_cells'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'hpca.celltype', 'encode.celltype', 'tumor_stage_x', 'subtype',
            'tumor_grade_x', 'ct_response_x', 'patient_y', 'tumor_stage_y', 'tumor_grade_y', 
            'ct_response_y', 'histology'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['subtype'].value_counts()
# Out:
# subtype
# DIF    30619
# MES     4590
# IMR     4078
# PRO     1744
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                       cell_name sample patient   cell_type cell_subtype  \
# 0          AAACCTGAGCTGCCCA-1_1    T59     T59  Macrophage   Macrophage
# 1          AAACCTGAGTCATCCA-1_2    T59     T59  Macrophage   Macrophage
# 2          AAACCTGCAAGCCCAC-1_3    T59     T59  Macrophage   Macrophage
# 3          AAACCTGCAAGCGCTC-1_4    T59     T59   Malignant    Malignant
# 4          AAACCTGCACGTAAGG-1_5    T59     T59   Malignant    Malignant
# ...                         ...    ...     ...         ...          ...
# 41026  TTTGTCACACAGCCCA-1_41027    T90     T90      T_cell       T_cell
# 41027  TTTGTCACATTCTTAC-1_41028    T90     T90   Malignant    Malignant
# 41028  TTTGTCAGTAGCTGCC-1_41029    T90     T90  Fibroblast   Fibroblast
# 41029  TTTGTCAGTTGAGGTG-1_41030    T90     T90  Fibroblast   Fibroblast
# 41030  TTTGTCATCTGTGCAA-1_41031    T90     T90      T_cell       T_cell
#
#        complexity cell_cycle_phase     cancer_type technology  n_cells  sex  \
# 0             799              NaN  Ovarian Cancer        10x    12659  NaN
# 1            1022      Not cycling  Ovarian Cancer        10x    12659  NaN
# 2            1036      Not cycling  Ovarian Cancer        10x    12659  NaN
# 3            2571             G1/S  Ovarian Cancer        10x    12659  NaN
# 4            3402     Intermediate  Ovarian Cancer        10x    12659  NaN
# ...           ...              ...             ...        ...      ...  ...
# 41026         908              NaN  Ovarian Cancer        10x     3630  NaN
# 41027        3321             G1/S  Ovarian Cancer        10x     3630  NaN
# 41028        2583      Not cycling  Ovarian Cancer        10x     3630  NaN
# 41029        3401      Not cycling  Ovarian Cancer        10x     3630  NaN
# 41030         962              NaN  Ovarian Cancer        10x     3630  NaN
#
#        age disease_extent sample_primary_met     site treated_naive source  \
# 0      NaN            NaN                NaN  Ovarian           NaN    NaN
# 1      NaN            NaN                NaN  Ovarian           NaN    NaN
# 2      NaN            NaN                NaN  Ovarian           NaN    NaN
# 3      NaN            NaN                NaN  Ovarian           NaN    NaN
# 4      NaN            NaN                NaN  Ovarian           NaN    NaN
# ...    ...            ...                ...      ...           ...    ...
# 41026  NaN            NaN                NaN  Ovarian           NaN    NaN
# 41027  NaN            NaN                NaN  Ovarian           NaN    NaN
# 41028  NaN            NaN                NaN  Ovarian           NaN    NaN
# 41029  NaN            NaN                NaN  Ovarian           NaN    NaN
# 41030  NaN            NaN                NaN  Ovarian           NaN    NaN
#
#                          study category
# 0      Geistlinger2020_Ovarian  Ovarian
# 1      Geistlinger2020_Ovarian  Ovarian
# 2      Geistlinger2020_Ovarian  Ovarian
# 3      Geistlinger2020_Ovarian  Ovarian
# 4      Geistlinger2020_Ovarian  Ovarian
# ...                        ...      ...
# 41026  Geistlinger2020_Ovarian  Ovarian
# 41027  Geistlinger2020_Ovarian  Ovarian
# 41028  Geistlinger2020_Ovarian  Ovarian
# 41029  Geistlinger2020_Ovarian  Ovarian
# 41030  Geistlinger2020_Ovarian  Ovarian
#
# [41031 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['site'] = 'Ovarian'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['study'] = 'Geistlinger2020_Ovarian'

# %%
adata.obs['category'] = 'Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Geistlinger2020_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Geistlinger2020_Ovarian.h5ad

# %% [markdown]
# #### 2.Izar2020_Ovarian

# %%
# Set base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Izar2020_Ovarian"

# === Load 10X Data ===
path_10x = os.path.join(base_path, "10X")
adata_10x = sc.read_mtx(os.path.join(path_10x, "Exp_data_TPM.mtx")).T  # Transpose to cells x genes
genes_10x = pd.read_csv(os.path.join(path_10x, "Genes.txt"), header=None)[0].tolist()
cells_10x = pd.read_csv(os.path.join(path_10x, "Cells.csv"), index_col=0)

adata_10x.var_names = genes_10x
adata_10x.obs = cells_10x
adata_10x.obs['technology'] = '10X'

# === Load SmartSeq2 Data ===
path_ss2 = os.path.join(base_path, "SmartSeq2")
adata_ss2 = sc.read_mtx(os.path.join(path_ss2, "Exp_data_TPM.mtx")).T
genes_ss2 = pd.read_csv(os.path.join(path_ss2, "Genes.txt"), header=None)[0].tolist()
cells_ss2 = pd.read_csv(os.path.join(path_ss2, "Cells.csv"), index_col=0)

adata_ss2.var_names = genes_ss2
adata_ss2.obs = cells_ss2
adata_ss2.obs['technology'] = 'SmartSeq2'

# === Align by common genes ===
common_genes = adata_10x.var_names.intersection(adata_ss2.var_names)
adata_10x = adata_10x[:, common_genes].copy()
adata_ss2 = adata_ss2[:, common_genes].copy()

# === Concatenate ===
adata_combined = adata_10x.concatenate(
    adata_ss2,
    batch_key='batch',
    batch_categories=['10X', 'SmartSeq2'],
    index_unique=None
)

# === Check uniqueness ===
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# === Merge sample metadata ===
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

# Preserve and reset index
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]

# Merge with sample metadata
adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')
assert adata_combined.obs.shape[0] == adata_combined.shape[0], "Row count mismatch after metadata merge"

# Restore index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index.name = None
# Out:
# /tmp/ipykernel_1522795/1900647769.py:30: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adata_10x.concatenate(

# %%
adata = adata_combined

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 10788 × 10869
#     obs: 'sample', 'patient', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive', 'source', 'cell_subtype', 'study', 'category'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS', 'cluster_old', 'cluster_new', 'batch', 'technology_y',
            'patient_y', 
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                               sample  patient   cell_type  complexity  \
# 10x_3288_t1_AAACATACCTTCCG-1  3288.1      5.0  Macrophage         839
# 10x_3288_t1_AAACATACTCCTAT-1  3288.1      5.0  Macrophage        1196
# 10x_3288_t1_AAACATTGAACTGC-1  3288.1      5.0  Macrophage        1343
# 10x_3288_t1_AAACATTGCTGACA-1  3288.1      5.0  Fibroblast        2358
# 10x_3288_t1_AAACCGTGACAGTC-1  3288.1      5.0  Fibroblast        2022
# ...                              ...      ...         ...         ...
# SS2_1293                         5.0      NaN   Malignant        5854
# SS2_1294                         5.0      NaN   Malignant        4373
# SS2_1295                         5.0      NaN   Malignant        6606
# SS2_1296                         5.0      NaN   Malignant        7352
# SS2_1297                         5.0      NaN   Malignant        8243
#
#                              cell_cycle_phase technology  n_cells  \
# 10x_3288_t1_AAACATACCTTCCG-1              NaN        10X     4929
# 10x_3288_t1_AAACATACTCCTAT-1      Not cycling        10X     4929
# 10x_3288_t1_AAACATTGAACTGC-1      Not cycling        10X     4929
# 10x_3288_t1_AAACATTGCTGACA-1      Not cycling        10X     4929
# 10x_3288_t1_AAACCGTGACAGTC-1      Not cycling        10X     4929
# ...                                       ...        ...      ...
# SS2_1293                          Not cycling  SmartSeq2      155
# SS2_1294                                 G1/S  SmartSeq2      155
# SS2_1295                                 G1/S  SmartSeq2      155
# SS2_1296                          Not cycling  SmartSeq2      155
# SS2_1297                          Not cycling  SmartSeq2      155
#
#                                  cancer_type    sex  age disease_extent  \
# 10x_3288_t1_AAACATACCTTCCG-1  Ovarian Cancer  False  NaN     metastatic
# 10x_3288_t1_AAACATACTCCTAT-1  Ovarian Cancer  False  NaN     metastatic
# 10x_3288_t1_AAACATTGAACTGC-1  Ovarian Cancer  False  NaN     metastatic
# 10x_3288_t1_AAACATTGCTGACA-1  Ovarian Cancer  False  NaN     metastatic
# 10x_3288_t1_AAACCGTGACAGTC-1  Ovarian Cancer  False  NaN     metastatic
# ...                                      ...    ...  ...            ...
# SS2_1293                      Ovarian Cancer  False  NaN     metastatic
# SS2_1294                      Ovarian Cancer  False  NaN     metastatic
# SS2_1295                      Ovarian Cancer  False  NaN     metastatic
# SS2_1296                      Ovarian Cancer  False  NaN     metastatic
# SS2_1297                      Ovarian Cancer  False  NaN     metastatic
#
#                              sample_primary_met     site treated_naive source  \
# 10x_3288_t1_AAACATACCTTCCG-1                met  ascites       treated    NaN
# 10x_3288_t1_AAACATACTCCTAT-1                met  ascites       treated    NaN
# 10x_3288_t1_AAACATTGAACTGC-1                met  ascites       treated    NaN
# 10x_3288_t1_AAACATTGCTGACA-1                met  ascites       treated    NaN
# 10x_3288_t1_AAACCGTGACAGTC-1                met  ascites       treated    NaN
# ...                                         ...      ...           ...    ...
# SS2_1293                                    met  ascites        naive     NaN
# SS2_1294                                    met  ascites        naive     NaN
# SS2_1295                                    met  ascites        naive     NaN
# SS2_1296                                    met  ascites        naive     NaN
# SS2_1297                                    met  ascites        naive     NaN
#
#                              cell_subtype             study category  \
# 10x_3288_t1_AAACATACCTTCCG-1          NaN  Izar2020_Ovarian  Ovarian
# 10x_3288_t1_AAACATACTCCTAT-1          NaN  Izar2020_Ovarian  Ovarian
# 10x_3288_t1_AAACATTGAACTGC-1          NaN  Izar2020_Ovarian  Ovarian
# 10x_3288_t1_AAACATTGCTGACA-1          NaN  Izar2020_Ovarian  Ovarian
# 10x_3288_t1_AAACCGTGACAGTC-1          NaN  Izar2020_Ovarian  Ovarian
# ...                                   ...               ...      ...
# SS2_1293                              NaN  Izar2020_Ovarian  Ovarian
# SS2_1294                              NaN  Izar2020_Ovarian  Ovarian
# SS2_1295                              NaN  Izar2020_Ovarian  Ovarian
# SS2_1296                              NaN  Izar2020_Ovarian  Ovarian
# SS2_1297                              NaN  Izar2020_Ovarian  Ovarian
#
#                                                  cell_name
# 10x_3288_t1_AAACATACCTTCCG-1  10x_3288_t1_AAACATACCTTCCG-1
# 10x_3288_t1_AAACATACTCCTAT-1  10x_3288_t1_AAACATACTCCTAT-1
# 10x_3288_t1_AAACATTGAACTGC-1  10x_3288_t1_AAACATTGAACTGC-1
# 10x_3288_t1_AAACATTGCTGACA-1  10x_3288_t1_AAACATTGCTGACA-1
# 10x_3288_t1_AAACCGTGACAGTC-1  10x_3288_t1_AAACCGTGACAGTC-1
# ...                                                    ...
# SS2_1293                                          SS2_1293
# SS2_1294                                          SS2_1294
# SS2_1295                                          SS2_1295
# SS2_1296                                          SS2_1296
# SS2_1297                                          SS2_1297
#
# [10788 rows x 19 columns]

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"technology_x": "technology"})

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['study'] = 'Izar2020_Ovarian'

# %%
adata.obs['category'] = 'Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Izar2020_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Izar2020_Ovarian.h5ad

# %% [markdown]
# #### 3.Nath2021_Ovarian

# %%
# Set base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Nath2021_Ovarian"

# === Load 10X Data ===
path_10x = os.path.join(base_path, "10X")
adata_10x = sc.read_mtx(os.path.join(path_10x, "Exp_data_UMIcounts.mtx")).T  # Transpose to cells x genes
genes_10x = pd.read_csv(os.path.join(path_10x, "Genes.txt"), header=None)[0].tolist()
cells_10x = pd.read_csv(os.path.join(path_10x, "Cells.csv"), index_col=0)

adata_10x.var_names = genes_10x
adata_10x.obs = cells_10x
adata_10x.obs['technology'] = '10X'

# === Load iCell8 Data ===
path_ss2 = os.path.join(base_path, "iCell8")
adata_ss2 = sc.read_mtx(os.path.join(path_ss2, "Exp_data_UMIcounts.mtx")).T
genes_ss2 = pd.read_csv(os.path.join(path_ss2, "Genes.txt"), header=None)[0].tolist()
cells_ss2 = pd.read_csv(os.path.join(path_ss2, "Cells.csv"), index_col=0)

adata_ss2.var_names = genes_ss2
adata_ss2.obs = cells_ss2
adata_ss2.obs['technology'] = 'iCell8'

# === Align by common genes ===
common_genes = adata_10x.var_names.intersection(adata_ss2.var_names)
adata_10x = adata_10x[:, common_genes].copy()
adata_ss2 = adata_ss2[:, common_genes].copy()

# === Concatenate ===
adata_combined = adata_10x.concatenate(
    adata_ss2,
    batch_key='batch',
    batch_categories=['10X', 'iCell8'],
    index_unique=None
)

# === Check uniqueness ===
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# === Merge sample metadata ===
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

# Preserve and reset index
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]

# Merge with sample metadata
adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')
assert adata_combined.obs.shape[0] == adata_combined.shape[0], "Row count mismatch after metadata merge"

# Restore index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index.name = None
# Out:
# /tmp/ipykernel_1522795/4212399279.py:30: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adata_10x.concatenate(

# %%
adata = adata_combined

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 41729 × 18392
#     obs: 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'technology_x', 'batch', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                            sample  cell_type cell_subtype  complexity  \
# P04_Time3_AAACCCAAGGCCTGAA    P04     T_cell  CD8+ T cell        1099
# P04_Time3_AAACGAAGTTCGTAAC    P04     T_cell  CD8+ T cell        1519
# P04_Time3_AAACGAATCTAGAGCT    P04     B_cell       B_cell        1931
# P04_Time3_AAACGCTCAGGCTCTG    P04     T_cell  CD8+ T cell        1148
# P04_Time3_AAACGCTTCCGATAGT    P04     T_cell  CD8+ T cell        1732
# ...                           ...        ...          ...         ...
# P03_Time1_C55_R42             P03  Malignant          NaN        1455
# P03_Time1_C56_R37             P03  Malignant          NaN        1657
# P03_Time1_C57_R00             P03  Malignant          NaN        1780
# P03_Time1_C58_R06             P03  Malignant          NaN        1416
# P03_Time1_C59_R05             P03  Malignant          NaN        1978
#
#                            cell_cycle_phase technology  n_cells patient  \
# P04_Time3_AAACCCAAGGCCTGAA      Not cycling        10X     5989     P04
# P04_Time3_AAACGAAGTTCGTAAC      Not cycling        10X     5989     P04
# P04_Time3_AAACGAATCTAGAGCT      Not cycling        10X     5989     P04
# P04_Time3_AAACGCTCAGGCTCTG      Not cycling        10X     5989     P04
# P04_Time3_AAACGCTTCCGATAGT      Not cycling        10X     5989     P04
# ...                                     ...        ...      ...     ...
# P03_Time1_C55_R42               Not cycling     iCell8       51     P03
# P03_Time1_C56_R37               Not cycling     iCell8       51     P03
# P03_Time1_C57_R00               Not cycling     iCell8       51     P03
# P03_Time1_C58_R06               Not cycling     iCell8       51     P03
# P03_Time1_C59_R05               Not cycling     iCell8       51     P03
#
#                                cancer_type     sex  age disease_extent  \
# P04_Time3_AAACCCAAGGCCTGAA  Ovarian Cancer  Female  NaN     metastatic
# P04_Time3_AAACGAAGTTCGTAAC  Ovarian Cancer  Female  NaN     metastatic
# P04_Time3_AAACGAATCTAGAGCT  Ovarian Cancer  Female  NaN     metastatic
# P04_Time3_AAACGCTCAGGCTCTG  Ovarian Cancer  Female  NaN     metastatic
# P04_Time3_AAACGCTTCCGATAGT  Ovarian Cancer  Female  NaN     metastatic
# ...                                    ...     ...  ...            ...
# P03_Time1_C55_R42           Ovarian Cancer  Female  NaN     metastatic
# P03_Time1_C56_R37           Ovarian Cancer  Female  NaN     metastatic
# P03_Time1_C57_R00           Ovarian Cancer  Female  NaN     metastatic
# P03_Time1_C58_R06           Ovarian Cancer  Female  NaN     metastatic
# P03_Time1_C59_R05           Ovarian Cancer  Female  NaN     metastatic
#
#                            sample_primary_met     site treated_naive  \
# P04_Time3_AAACCCAAGGCCTGAA                met  ascites       treated
# P04_Time3_AAACGAAGTTCGTAAC                met  ascites       treated
# P04_Time3_AAACGAATCTAGAGCT                met  ascites       treated
# P04_Time3_AAACGCTCAGGCTCTG                met  ascites       treated
# P04_Time3_AAACGCTTCCGATAGT                met  ascites       treated
# ...                                       ...      ...           ...
# P03_Time1_C55_R42                         met  ascites       treated
# P03_Time1_C56_R37                         met  ascites       treated
# P03_Time1_C57_R00                         met  ascites       treated
# P03_Time1_C58_R06                         met  ascites       treated
# P03_Time1_C59_R05                         met  ascites       treated
#
#                                              cell_name source category  \
# P04_Time3_AAACCCAAGGCCTGAA  P04_Time3_AAACCCAAGGCCTGAA    NaN  Ovarian
# P04_Time3_AAACGAAGTTCGTAAC  P04_Time3_AAACGAAGTTCGTAAC    NaN  Ovarian
# P04_Time3_AAACGAATCTAGAGCT  P04_Time3_AAACGAATCTAGAGCT    NaN  Ovarian
# P04_Time3_AAACGCTCAGGCTCTG  P04_Time3_AAACGCTCAGGCTCTG    NaN  Ovarian
# P04_Time3_AAACGCTTCCGATAGT  P04_Time3_AAACGCTTCCGATAGT    NaN  Ovarian
# ...                                                ...    ...      ...
# P03_Time1_C55_R42                    P03_Time1_C55_R42    NaN  Ovarian
# P03_Time1_C56_R37                    P03_Time1_C56_R37    NaN  Ovarian
# P03_Time1_C57_R00                    P03_Time1_C57_R00    NaN  Ovarian
# P03_Time1_C58_R06                    P03_Time1_C58_R06    NaN  Ovarian
# P03_Time1_C59_R05                    P03_Time1_C59_R05    NaN  Ovarian
#
#                                        study
# P04_Time3_AAACCCAAGGCCTGAA  Nath2021_Ovarian
# P04_Time3_AAACGAAGTTCGTAAC  Nath2021_Ovarian
# P04_Time3_AAACGAATCTAGAGCT  Nath2021_Ovarian
# P04_Time3_AAACGCTCAGGCTCTG  Nath2021_Ovarian
# P04_Time3_AAACGCTTCCGATAGT  Nath2021_Ovarian
# ...                                      ...
# P03_Time1_C55_R42           Nath2021_Ovarian
# P03_Time1_C56_R37           Nath2021_Ovarian
# P03_Time1_C57_R00           Nath2021_Ovarian
# P03_Time1_C58_R06           Nath2021_Ovarian
# P03_Time1_C59_R05           Nath2021_Ovarian
#
# [41729 rows x 19 columns]

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs = adata.obs.rename(columns={"technology_x": "technology"})

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Ovarian'

# %%
adata.obs['study'] = 'Nath2021_Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Nath2021_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Nath2021_Ovarian.h5ad

# %% [markdown]
# #### 4. Olalekan2021_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Olalekan2021_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 9885 × 16041
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                       cell_name       sample patient   cell_type  complexity  \
# 0     omentum2834__AAAAATATTACC  omentum2834    PT-6   Malignant        1050
# 1     omentum2834__AAAAATTCGAAC  omentum2834    PT-6  Fibroblast        1027
# 2     omentum2834__AAAACGGAATGT  omentum2834    PT-6  Fibroblast        1547
# 3     omentum2834__AAAACTCCGCAG  omentum2834    PT-6         ESC        1272
# 4     omentum2834__AAAATGACTGGA  omentum2834    PT-6  Fibroblast        1169
# ...                         ...          ...     ...         ...         ...
# 9880  omentum6885__TTTTATAAGTGA  omentum6885    PT-3  Fibroblast         799
# 9881  omentum6885__TTTTCAGCGCTC  omentum6885    PT-3  Fibroblast        1167
# 9882  omentum6885__TTTTGAACGGAC  omentum6885    PT-3  Fibroblast        1855
# 9883  omentum6885__TTTTGTCGACCG  omentum6885    PT-3   Malignant        2347
# 9884  omentum6885__TTTTTTCCCCAC  omentum6885    PT-3      Plasma         867
#
#      cell_cycle_phase technology  n_cells     cancer_type    sex  age  \
# 0         Not cycling   Drop-seq     1909  Ovarian Cancer  False   62
# 1         Not cycling   Drop-seq     1909  Ovarian Cancer  False   62
# 2         Not cycling   Drop-seq     1909  Ovarian Cancer  False   62
# 3         Not cycling   Drop-seq     1909  Ovarian Cancer  False   62
# 4         Not cycling   Drop-seq     1909  Ovarian Cancer  False   62
# ...               ...        ...      ...             ...    ...  ...
# 9880              NaN   Drop-seq     1071  Carcinosarcoma  False   66
# 9881      Not cycling   Drop-seq     1071  Carcinosarcoma  False   66
# 9882      Not cycling   Drop-seq     1071  Carcinosarcoma  False   66
# 9883      Not cycling   Drop-seq     1071  Carcinosarcoma  False   66
# 9884              NaN   Drop-seq     1071  Carcinosarcoma  False   66
#
#      disease_extent sample_primary_met     site treated_naive source  \
# 0        metastatic                met  omentum       treated    NaN
# 1        metastatic                met  omentum       treated    NaN
# 2        metastatic                met  omentum       treated    NaN
# 3        metastatic                met  omentum       treated    NaN
# 4        metastatic                met  omentum       treated    NaN
# ...             ...                ...      ...           ...    ...
# 9880     metastatic                met  omentum       treated    NaN
# 9881     metastatic                met  omentum       treated    NaN
# 9882     metastatic                met  omentum       treated    NaN
# 9883     metastatic                met  omentum       treated    NaN
# 9884     metastatic                met  omentum       treated    NaN
#
#      cell_subtype category                 study
# 0             NaN  Ovarian  Olalekan2021_Ovarian
# 1             NaN  Ovarian  Olalekan2021_Ovarian
# 2             NaN  Ovarian  Olalekan2021_Ovarian
# 3             NaN  Ovarian  Olalekan2021_Ovarian
# 4             NaN  Ovarian  Olalekan2021_Ovarian
# ...           ...      ...                   ...
# 9880          NaN  Ovarian  Olalekan2021_Ovarian
# 9881          NaN  Ovarian  Olalekan2021_Ovarian
# 9882          NaN  Ovarian  Olalekan2021_Ovarian
# 9883          NaN  Ovarian  Olalekan2021_Ovarian
# 9884          NaN  Ovarian  Olalekan2021_Ovarian
#
# [9885 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['category'] = 'Ovarian'

# %%
adata.obs['study'] = 'Olalekan2021_Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Olalekan2021_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Olalekan2021_Ovarian.h5ad

# %% [markdown]
# #### 5.Olbrecht2021_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Olbrecht2021_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 15528 × 33694
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'sample_site', 'patient_y', 'cancer_type', 'cancer_subtype', 'n_cells', 'technology', 'sex.', 'age__at_sampling', 'primary_met', 'site', 'Necrosis', 'treated_naive'

# %%
adata.obs['T_sampling'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'extent_sampling.',
            'diagnosis_recurrence', 'AJCC_sampling', 'T_sampling', 'N_sampling', 'M_sampling',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'size', 
            'histology', 'hist_subtype', 'subtype_details', 'mutation_status', 'Grade',
            'recent_rx_modality', 'recent_rx_regimen', 'recent_rx_response', 'time_on_recent_rx',
            'on_off_rx', 'prior_chemotherapy', 'chemotherapy_regimen', 'chemotherapy_response',
            'prior_targeted_rx', 'targeted_rx_regimen', 'targeted_rx_response', 'prior_ICI',
            'ICI_regimen', 'ICI_response', 'prior_chemo_ICI', 'chemo_ICI_regimen', 'chemo_ICI_response', 'prior_ET',
            'ET_Regimen', 'ET_response', 'subsqnt_rx', 'subsqnt_rx_modality', 'subsqnt_rx_regimen',
            'subsqnt_rx_response', 'PFS_DFS', 'OS', 'patient_y', 'Necrosis', 'site'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                       cell_name               sample patient    cell_type  \
# 0      AAACCTGTCTCTAAGG_SOL1303     P1_omentum_tumor      P1   Fibroblast
# 1      AAACGGGCAGCTCCGA_SOL1303     P1_omentum_tumor      P1  Endothelial
# 2      AAACGGGGTATAAACG_SOL1303     P1_omentum_tumor      P1   Fibroblast
# 3      AAACGGGTCTTGCCGT_SOL1303     P1_omentum_tumor      P1   Fibroblast
# 4      AAAGCAAGTCGCGGTT_SOL1303     P1_omentum_tumor      P1   Fibroblast
# ...                         ...                  ...     ...          ...
# 15523   TTTGGTTAGAACAATC_SOL016  P7_peritoneum_tumor      P7    Malignant
# 15524   TTTGGTTAGGAACTGC_SOL016  P7_peritoneum_tumor      P7    Malignant
# 15525   TTTGGTTAGGCTAGCA_SOL016  P7_peritoneum_tumor      P7    Malignant
# 15526   TTTGGTTCATCACGAT_SOL016  P7_peritoneum_tumor      P7    Malignant
# 15527   TTTGTCAAGTGAACGC_SOL016  P7_peritoneum_tumor      P7    Malignant
#
#       cell_subtype  complexity cell_cycle_phase source        site  \
# 0       Fibroblast        3892      Not cycling  tumor     omentum
# 1      Endothelial        5666      Not cycling  tumor     omentum
# 2       Fibroblast        2726      Not cycling  tumor     omentum
# 3       Fibroblast        2604      Not cycling  tumor     omentum
# 4       Fibroblast        3432      Not cycling  tumor     omentum
# ...            ...         ...              ...    ...         ...
# 15523    Malignant        1314      Not cycling  tumor  peritoneum
# 15524    Malignant        1124      Not cycling  tumor  peritoneum
# 15525    Malignant        2473      Not cycling  tumor  peritoneum
# 15526    Malignant        1266      Not cycling  tumor  peritoneum
# 15527    Malignant        1330      Not cycling  tumor  peritoneum
#
#           cancer_type cancer_subtype  n_cells technology sex    age  \
# 0      Ovarian Cancer         HGSTOC     1403        10X   F  70-79
# 1      Ovarian Cancer         HGSTOC     1403        10X   F  70-79
# 2      Ovarian Cancer         HGSTOC     1403        10X   F  70-79
# 3      Ovarian Cancer         HGSTOC     1403        10X   F  70-79
# 4      Ovarian Cancer         HGSTOC     1403        10X   F  70-79
# ...               ...            ...      ...        ...  ..    ...
# 15523  Ovarian Cancer         HGSTOC     1472        10X   F  60-69
# 15524  Ovarian Cancer         HGSTOC     1472        10X   F  60-69
# 15525  Ovarian Cancer         HGSTOC     1472        10X   F  60-69
# 15526  Ovarian Cancer         HGSTOC     1472        10X   F  60-69
# 15527  Ovarian Cancer         HGSTOC     1472        10X   F  60-69
#
#        sample_primary_met treated_naive                 study category
# 0                     NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# 1                     NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# 2                     NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# 3                     NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# 4                     NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# ...                   ...           ...                   ...      ...
# 15523                 NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# 15524                 NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# 15525                 NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# 15526                 NaN         Naive  Olbrecht2021_Ovarian  Ovarian
# 15527                 NaN         Naive  Olbrecht2021_Ovarian  Ovarian
#
# [15528 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"sex.": "sex"})

# %%
adata.obs = adata.obs.rename(columns={"age__at_sampling": "age"})

# %%
adata.obs = adata.obs.rename(columns={"primary_met": "sample_primary_met"})

# %%
adata.obs = adata.obs.rename(columns={"sample_site": "site"})

# %%
adata.obs['study'] = 'Olbrecht2021_Ovarian'

# %%
adata.obs['category'] = 'Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Olbrecht2021_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Olbrecht2021_Ovarian.h5ad

# %% [markdown]
# #### 6.Qian2020_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Qian2020_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 16951 × 22276
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'source', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                         cell_name  sample    cell_type  complexity  \
# 0         BT1303_AAACCTGAGTGCAAGC      11   Fibroblast        1405
# 1         BT1303_AAACCTGAGTGGTAGC      11   Fibroblast        1035
# 2         BT1303_AAACCTGTCTCTAAGG      11   Fibroblast        3832
# 3         BT1303_AAACGGGCAGCTCCGA      11  Endothelial        5557
# 4         BT1303_AAACGGGCAGGCTGAA      11   Macrophage        1504
# ...                           ...     ...          ...         ...
# 16946  scrSOL004_TTTGTCAGTTCGCGAC      14    Malignant        3041
# 16947  scrSOL004_TTTGTCATCACGAAGG      14    Malignant        2519
# 16948  scrSOL004_TTTGTCATCCAACCAA      14    Malignant        2441
# 16949  scrSOL004_TTTGTCATCCGAACGC      14  Endothelial        3087
# 16950  scrSOL004_TTTGTCATCGCAAACT      14    Malignant        5303
#
#       cell_cycle_phase      source technology  n_cells patient  \
# 0          Not cycling     Omentum        10x     7063   OvC_1
# 1          Not cycling     Omentum        10x     7063   OvC_1
# 2          Not cycling     Omentum        10x     7063   OvC_1
# 3          Not cycling     Omentum        10x     7063   OvC_1
# 4          Not cycling     Omentum        10x     7063   OvC_1
# ...                ...         ...        ...      ...     ...
# 16946             G1/S  Peritoneum        10x     4232   OvC_4
# 16947             G1/S  Peritoneum        10x     4232   OvC_4
# 16948      Not cycling  Peritoneum        10x     4232   OvC_4
# 16949      Not cycling  Peritoneum        10x     4232   OvC_4
# 16950      Not cycling  Peritoneum        10x     4232   OvC_4
#
#           cancer_type     sex  age  disease_extent sample_primary_met  site  \
# 0      Ovarian Cancer  Female  NaN             NaN            primary   NaN
# 1      Ovarian Cancer  Female  NaN             NaN            primary   NaN
# 2      Ovarian Cancer  Female  NaN             NaN            primary   NaN
# 3      Ovarian Cancer  Female  NaN             NaN            primary   NaN
# 4      Ovarian Cancer  Female  NaN             NaN            primary   NaN
# ...               ...     ...  ...             ...                ...   ...
# 16946  Ovarian Cancer  Female  NaN             NaN            primary   NaN
# 16947  Ovarian Cancer  Female  NaN             NaN            primary   NaN
# 16948  Ovarian Cancer  Female  NaN             NaN            primary   NaN
# 16949  Ovarian Cancer  Female  NaN             NaN            primary   NaN
# 16950  Ovarian Cancer  Female  NaN             NaN            primary   NaN
#
#       treated_naive
# 0             naive
# 1             naive
# 2             naive
# 3             naive
# 4             naive
# ...             ...
# 16946         naive
# 16947         naive
# 16948         naive
# 16949         naive
# 16950         naive
#
# [16951 rows x 16 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['category'] = 'Ovarian'

# %%
adata.obs['study'] = 'Qian2020_Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Qian2020_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Qian2020_Ovarian.h5ad

# %% [markdown]
# #### 7.Regner2021_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Regner2021_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 65144 × 24516
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'disease', 'histology_x', 'source_x', 'stage_x', 'cancer_type', 'technology', 'n_cells', 'histology_y', 'source_y', 'stage_y', 'grade', 'age_at_diagnosis', 'race', 'bmi'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'histology_x','stage_x','histology_y', 'source_y', 'stage_y', 'grade',
            'race', 'bmi','disease'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                    cell_name  sample    cell_type            cell_subtype  \
# 0       AAACCCACATTGACAC-1_1       1    Malignant  Unciliated epithelia 1
# 1       AAACCCAGTGACTAAA-1_1       1       B_cell                  B cell
# 2       AAACCCATCTCCGCAT-1_1       1  Endothelial              Endothelia
# 3       AAACGAAAGGTTCAGG-1_1       1  Endothelial              Endothelia
# 4       AAACGAAGTTAAGTCC-1_1       1      Myocyte     Smooth muscle cells
# ...                      ...     ...          ...                     ...
# 65139  TTTGTTGGTCCTTGTC-1_11       9    Malignant         Epithelial cell
# 65140  TTTGTTGGTCTTTCAT-1_11       9   Fibroblast              Fibroblast
# 65141  TTTGTTGGTTCCGTTC-1_11       9    Malignant         Epithelial cell
# 65142  TTTGTTGTCATGAGGG-1_11       9   Macrophage              Macrophage
# 65143  TTTGTTGTCCGTCAAA-1_11       9    Malignant         Epithelial cell
#
#        complexity cell_cycle_phase     source_x         cancer_type  \
# 0            4226      Not cycling  Endometrium  Endometrial Cancer
# 1            1519      Not cycling  Endometrium  Endometrial Cancer
# 2            1731      Not cycling  Endometrium  Endometrial Cancer
# 3            2311      Not cycling  Endometrium  Endometrial Cancer
# 4            1036      Not cycling  Endometrium  Endometrial Cancer
# ...           ...              ...          ...                 ...
# 65139        4028      Not cycling        Ovary      Ovarian Cancer
# 65140        3066      Not cycling        Ovary      Ovarian Cancer
# 65141        1110      Not cycling        Ovary      Ovarian Cancer
# 65142        1240      Not cycling        Ovary      Ovarian Cancer
# 65143        3183      Not cycling        Ovary      Ovarian Cancer
#
#       technology  n_cells  age  patient  sex disease_extent  \
# 0            10x     4202   70        1  NaN            NaN
# 1            10x     4202   70        1  NaN            NaN
# 2            10x     4202   70        1  NaN            NaN
# 3            10x     4202   70        1  NaN            NaN
# 4            10x     4202   70        1  NaN            NaN
# ...          ...      ...  ...      ...  ...            ...
# 65139        10x     5928   59        9  NaN            NaN
# 65140        10x     5928   59        9  NaN            NaN
# 65141        10x     5928   59        9  NaN            NaN
# 65142        10x     5928   59        9  NaN            NaN
# 65143        10x     5928   59        9  NaN            NaN
#
#       sample_primary_met treated_naive site
# 0                    NaN           NaN  NaN
# 1                    NaN           NaN  NaN
# 2                    NaN           NaN  NaN
# 3                    NaN           NaN  NaN
# 4                    NaN           NaN  NaN
# ...                  ...           ...  ...
# 65139                NaN           NaN  NaN
# 65140                NaN           NaN  NaN
# 65141                NaN           NaN  NaN
# 65142                NaN           NaN  NaN
# 65143                NaN           NaN  NaN
#
# [65144 rows x 17 columns]

# %%
adata.obs['patient'] = adata.obs['sample'].copy()

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs = adata.obs.rename(columns={"age_at_diagnosis": "age"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['site'] = 'NaN'

# %%
adata.obs['category'] = 'Ovarian'

# %%
adata.obs['study'] = 'Regner2021_Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Regner2021_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Regner2021_Ovarian.h5ad

# %% [markdown]
# #### 8.Shih2018_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Shih2018_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3066 × 26364
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'source_x', 'cancer_type_x', 'complexity', 'site', 'technology', 'n_cells', 'sex', 'age', 'neoadjuvant_treatment'

# %%
for col in ['patient_y', 'source_y','cancer_type_y', 'histology',
             'race', 'stage', 'previous_hx_breast_cancer', 
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"cancer_type_x": "cancer_type"})

# %%
adata.obs['treated_naive'] = adata.obs['neoadjuvant_treatment'].map({
    'no': 'naive',
    'yes': 'treated'
})

# %%
del adata.obs['neoadjuvant_treatment']

# %%
adata.obs['neoadjuvant_treatment'].value_counts()
# Out:
# neoadjuvant_treatment
# no     3001
# yes      65
# Name: count, dtype: int64

# %%
adata.obs['disease_extent'] = adata.obs['source'].copy()

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['cell_cycle_phase'] = 'NaN'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs
# Out:
#                      cell_name sample patient cell_type      source  \
# 0     PN1-P_aacagctgaattagcacg  PN1-P     PN1       NaN     primary
# 1     PN1-P_aagccactaggtaacagc  PN1-P     PN1       NaN     primary
# 2     PN1-P_aagccatcgcctgagctt  PN1-P     PN1       NaN     primary
# 3     PN1-P_aagtatcagacttccaag  PN1-P     PN1       NaN     primary
# 4     PN1-P_acaaggtgagacagatgt  PN1-P     PN1       NaN     primary
# ...                        ...    ...     ...       ...         ...
# 3061  HG1-M_gtttcaccacgccaccac  HG1-M     HG1       NaN  metastasis
# 3062  HG1-M_ttaagagcgaattgagac  HG1-M     HG1       NaN  metastasis
# 3063  HG1-M_atccggatccggcggtcc  HG1-M     HG1       NaN  metastasis
# 3064  HG1-M_gtcctatccaagtgtgta  HG1-M     HG1       NaN  metastasis
# 3065  HG1-M_tgttcgtcagtgtcgcct  HG1-M     HG1       NaN  metastasis
#
#             cancer_type  complexity     site  technology  n_cells     sex  \
# 0     Peritoneal Cancer         286    ovary         NaN      100  female
# 1     Peritoneal Cancer          61    ovary         NaN      100  female
# 2     Peritoneal Cancer         133    ovary         NaN      100  female
# 3     Peritoneal Cancer         138    ovary         NaN      100  female
# 4     Peritoneal Cancer         393    ovary         NaN      100  female
# ...                 ...         ...      ...         ...      ...     ...
# 3061     Ovarian Cancer         197  omentum         NaN      330  female
# 3062     Ovarian Cancer         235  omentum         NaN      330  female
# 3063     Ovarian Cancer         197  omentum         NaN      330  female
# 3064     Ovarian Cancer         230  omentum         NaN      330  female
# 3065     Ovarian Cancer         215  omentum         NaN      330  female
#
#       age treated_naive disease_extent sample_primary_met  \
# 0      55         naive        primary                NaN
# 1      55         naive        primary                NaN
# 2      55         naive        primary                NaN
# 3      55         naive        primary                NaN
# 4      55         naive        primary                NaN
# ...   ...           ...            ...                ...
# 3061   70         naive     metastasis                NaN
# 3062   70         naive     metastasis                NaN
# 3063   70         naive     metastasis                NaN
# 3064   70         naive     metastasis                NaN
# 3065   70         naive     metastasis                NaN
#
#                       study category cell_subtype cell_cycle_phase
# 0     Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# 1     Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# 2     Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# 3     Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# 4     Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# ...                     ...      ...          ...              ...
# 3061  Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# 3062  Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# 3063  Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# 3064  Data_Shih2018_Ovarian  Ovarian          NaN              NaN
# 3065  Data_Shih2018_Ovarian  Ovarian          NaN              NaN
#
# [3066 rows x 19 columns]

# %%
adata.obs['category'] = 'Ovarian'

# %%
adata.obs['study'] = 'Data_Shih2018_Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Shih2018_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Shih2018_Ovarian.h5ad

# %% [markdown]
# #### 9.Tang-Huau2018_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Tang-Huau2018_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 8404 × 20939
#     obs: 'cell_name', 'sample', 'patient_x', 'source_x', 'cancer_type_x', 'sorting', 'cell_type', 'complexity', 'patient_y', 'source_y', 'cancer_type_y', 'n_cells', 'technology'

# %%
for col in ['sorting', 'patient_y', 'source_y', 'cancer_type_y', 
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                cell_name sample patient          source cancer_type  \
# 0     AAACCTGCATCTCCCA-1     d1      d1   healthy blood      Normal
# 1     AAACGGGCAACTGCGC-1     d1      d1   healthy blood      Normal
# 2     AAAGTAGCAATCACAC-1     d1      d1   healthy blood      Normal
# 3     AAATGCCCATGTCGAT-1     d1      d1   healthy blood      Normal
# 4     AACACGTTCACATACG-1     d1      d1   healthy blood      Normal
# ...                  ...    ...     ...             ...         ...
# 8399  TTTGTCACACTGTTAG-5   donD    donD  healthy tonsil      Normal
# 8400  TTTGTCAGTGTGTGCC-5   donD    donD  healthy tonsil      Normal
# 8401  TTTGTCATCATTTGGG-5   donD    donD  healthy tonsil      Normal
# 8402  TTTGTCATCCGCAGTG-5   donD    donD  healthy tonsil      Normal
# 8403  TTTGTCATCGTGGTCG-5   donD    donD  healthy tonsil      Normal
#
#       cell_type  complexity  n_cells technology category  \
# 0      Monocyte        1664      425        10x  Ovarian
# 1      Monocyte         478      425        10x  Ovarian
# 2      Monocyte        1118      425        10x  Ovarian
# 3      Monocyte         752      425        10x  Ovarian
# 4      Monocyte        1126      425        10x  Ovarian
# ...         ...         ...      ...        ...      ...
# 8399  Dendritic        6476     2739        10x  Ovarian
# 8400  Dendritic        2559     2739        10x  Ovarian
# 8401  Dendritic        2286     2739        10x  Ovarian
# 8402  Dendritic        2147     2739        10x  Ovarian
# 8403  Dendritic        2110     2739        10x  Ovarian
#
#                       study
# 0     Tang-Huau2018_Ovarian
# 1     Tang-Huau2018_Ovarian
# 2     Tang-Huau2018_Ovarian
# 3     Tang-Huau2018_Ovarian
# 4     Tang-Huau2018_Ovarian
# ...                     ...
# 8399  Tang-Huau2018_Ovarian
# 8400  Tang-Huau2018_Ovarian
# 8401  Tang-Huau2018_Ovarian
# 8402  Tang-Huau2018_Ovarian
# 8403  Tang-Huau2018_Ovarian
#
# [8404 rows x 11 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"cancer_type_x": "cancer_type"})

# %%
adata.obs['category'] = 'Ovarian'

# %%
adata.obs['study'] = 'Tang-Huau2018_Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Tang-Huau2018_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Tang-Huau2018_Ovarian.h5ad

# %% [markdown]
# #### 10.Zhang2019_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Zhang2019_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4848 × 24410
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'complexity', 'cell_cycle_phase', 'source', 'cancer_type', 'technology', 'n_cells'

# %%
for col in [ 'umap1', 'umap2', 'g1s_score', 'g2m_score',
             'mp_top_score', 'mp_top', 'mp_assignment', 'patient_y', 'source_y'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs
# Out:
#                        cell_name     sample   patient   cell_type  complexity  \
# 0     AAACCTGAGAGACGAA_VOA11543L  VOA11543L  VOA11543  Fibroblast        4714
# 1     AAACCTGAGAGTCTGG_VOA11543L  VOA11543L  VOA11543  Fibroblast        2103
# 2     AAACCTGAGATCCCGC_VOA11543L  VOA11543L  VOA11543   Malignant        5107
# 3     AAACCTGCACAGGAGT_VOA11543L  VOA11543L  VOA11543   Malignant        4820
# 4     AAACCTGGTACTTGAC_VOA11543L  VOA11543L  VOA11543      T_cell        3452
# ...                          ...        ...       ...         ...         ...
# 4843  TTTGGTTGTGTAACGG_VOA11543R  VOA11543R  VOA11543   Malignant        2946
# 4844  TTTGGTTGTTCATGGT_VOA11543R  VOA11543R  VOA11543   Malignant        4321
# 4845  TTTGGTTTCATAGCAC_VOA11543R  VOA11543R  VOA11543   Malignant        5292
# 4846  TTTGGTTTCTTGTCAT_VOA11543R  VOA11543R  VOA11543   Malignant        4157
# 4847  TTTGTCATCGTAGATC_VOA11543R  VOA11543R  VOA11543   Malignant        5891
#
#      cell_cycle_phase       source     cancer_type technology  n_cells
# 0         Not cycling   Left ovary  Ovarian Cancer        10x     2707
# 1         Not cycling   Left ovary  Ovarian Cancer        10x     2707
# 2         Not cycling   Left ovary  Ovarian Cancer        10x     2707
# 3         Not cycling   Left ovary  Ovarian Cancer        10x     2707
# 4                 NaN   Left ovary  Ovarian Cancer        10x     2707
# ...               ...          ...             ...        ...      ...
# 4843      Not cycling  Right ovary  Ovarian Cancer        10x     2141
# 4844      Not cycling  Right ovary  Ovarian Cancer        10x     2141
# 4845      Not cycling  Right ovary  Ovarian Cancer        10x     2141
# 4846      Not cycling  Right ovary  Ovarian Cancer        10x     2141
# 4847      Not cycling  Right ovary  Ovarian Cancer        10x     2141
#
# [4848 rows x 10 columns]

# %%
adata.obs['site'] = adata.obs['source']

# %%
adata.obs['category'] = 'Ovarian'

# %%
adata.obs['study'] = 'Data_Zhang2019_Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Zhang2019_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Zhang2019_Ovarian.h5ad

# %% [markdown]
# #### 11.Zhang2022_Ovarian

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Zhang2022_Ovarian"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 51786 × 32847
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'treatment_phase_x', 'anatomical_location_x', 'cancer_type', 'technology', 'n_cells'

# %%
for col in [ 'umap1', 'umap2', 'g1s_score', 'g2m_score',
             'mp_top_score', 'mp_top', 'mp_assignment', 'patient_y',
             'nCount_RNA', 'nFeature_RNA', 'percent.mt',
             'treatment_phase_y', 'anatomical_location_y', 'histology'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['treatment_phase_x'].value_counts()
# Out:
# treatment_phase_x
# post-NACT          30025
# treatment-naive    21761
# Name: count, dtype: int64

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"treatment_phase_x": "treated_naive"})

# %%
adata.obs = adata.obs.rename(columns={"anatomical_location_x": "site"})

# %%
adata.obs
# Out:
#                           cell_name                     sample patient  \
# 0      AAACCTGCAGGTTTCA-EOC372_pPer  EOC372_primary_Peritoneum  EOC372
# 1      AAACCTGGTCCGAATT-EOC372_pPer  EOC372_primary_Peritoneum  EOC372
# 2      AAAGATGCATCTGGTA-EOC372_pPer  EOC372_primary_Peritoneum  EOC372
# 3      AAAGTAGTCGCTTAGA-EOC372_pPer  EOC372_primary_Peritoneum  EOC372
# 4      AAATGCCAGGTGCACA-EOC372_pPer  EOC372_primary_Peritoneum  EOC372
# ...                             ...                        ...     ...
# 51781  TTTGCGCCACATCCAA-EOC443_pOme     EOC443_primary_Omentum  EOC443
# 51782  TTTGCGCCACGTCAGC-EOC443_pOme     EOC443_primary_Omentum  EOC443
# 51783  TTTGCGCCATTCACTT-EOC443_pOme     EOC443_primary_Omentum  EOC443
# 51784  TTTGTCACATTGGGCC-EOC443_pOme     EOC443_primary_Omentum  EOC443
# 51785  TTTGTCAGTAAGGATT-EOC443_pOme     EOC443_primary_Omentum  EOC443
#
#         cell_type  cell_subtype  complexity cell_cycle_phase    treated_naive  \
# 0       Malignant       EOC_C11        5700      Not cycling  treatment-naive
# 1       Malignant       EOC_C12        3196      Not cycling  treatment-naive
# 2       Malignant        EOC_C5        2148      Not cycling  treatment-naive
# 3       Malignant        EOC_C4        3438      Not cycling  treatment-naive
# 4       Malignant        EOC_C5        2839             G1/S  treatment-naive
# ...           ...           ...         ...              ...              ...
# 51781      Plasma  Plasma-cells        1398      Not cycling  treatment-naive
# 51782  Macrophage   Macrophages        1283      Not cycling  treatment-naive
# 51783      Plasma  Plasma-cells        1395      Not cycling  treatment-naive
# 51784      T_cell       T-cells         699              NaN  treatment-naive
# 51785      T_cell       T-cells         704              NaN  treatment-naive
#
#              site     cancer_type technology  n_cells
# 0      Peritoneum  Ovarian Cancer        10x      711
# 1      Peritoneum  Ovarian Cancer        10x      711
# 2      Peritoneum  Ovarian Cancer        10x      711
# 3      Peritoneum  Ovarian Cancer        10x      711
# 4      Peritoneum  Ovarian Cancer        10x      711
# ...           ...             ...        ...      ...
# 51781     Omentum  Ovarian Cancer        10x     2122
# 51782     Omentum  Ovarian Cancer        10x     2122
# 51783     Omentum  Ovarian Cancer        10x     2122
# 51784     Omentum  Ovarian Cancer        10x     2122
# 51785     Omentum  Ovarian Cancer        10x     2122
#
# [51786 rows x 12 columns]

# %%
adata.obs['category'] = 'Ovarian'

# %%
adata.obs['study'] = 'Zhang2022_Ovarian'

# %%
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Data_Zhang2022_Ovarian.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Ovarian/Data_Zhang2022_Ovarian.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Geistlinger2020_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Izar2020_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Nath2021_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Olalekan2021_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Olbrecht2021_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Qian2020_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Regner2021_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Shih2018_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Tang-Huau2018_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Zhang2019_Ovarian.h5ad",
    "/home/ubuntu/Downloads/Data_Ovarian/Data_Zhang2022_Ovarian.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

gc.collect()
# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

gc.collect()
# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

gc.collect()
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Ovarian/Ovarian_Combined.h5ad

# %%
adata_merged
# Out:
# AnnData object with n_obs × n_vars = 269160 × 51957
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'cancer_type', 'technology', 'n_cells', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive', 'source', 'study', 'category'

# %%
del adata_merged.obs['cancer_subtype']

# %%
# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Ovarian/Ovarian_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Ovarian/Ovarian_Combined.h5ad
