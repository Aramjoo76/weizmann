# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc
import scipy.io
from scipy.sparse import vstack

# %% [markdown]
# ## Breast

# %% [markdown]
# #### 1. Azizi2018_Breast

# %%
import os
import pandas as pd
import scanpy as sc

# === Set base path ===
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Azizi2018_Breast"

# === Load 10X Data ===
path_10x = os.path.join(base_path, "10X")
adata_10x = sc.read_mtx(os.path.join(path_10x, "Exp_data_UMIcounts.mtx")).T  # Transpose to cells x genes
genes_10x = pd.read_csv(os.path.join(path_10x, "Genes.txt"), header=None)[0].tolist()
cells_10x = pd.read_csv(os.path.join(path_10x, "Cells.csv"), index_col=0)
cells_10x.index = cells_10x.index.astype(str)  # Ensure string index

adata_10x.var_names = genes_10x
adata_10x.obs = cells_10x
adata_10x.obs_names = cells_10x.index  # Set obs_names to ensure match
adata_10x.obs['technology'] = '10X'

# === Load InDrop Data ===
path_ss2 = os.path.join(base_path, "InDrop")
adata_ss2 = sc.read_mtx(os.path.join(path_ss2, "Exp_data_UMIcounts.mtx")).T
genes_ss2 = pd.read_csv(os.path.join(path_ss2, "Genes.txt"), header=None)[0].tolist()
cells_ss2 = pd.read_csv(os.path.join(path_ss2, "Cells.csv"), index_col=0)
cells_ss2.index = cells_ss2.index.astype(str)

adata_ss2.var_names = genes_ss2
adata_ss2.obs = cells_ss2
adata_ss2.obs_names = cells_ss2.index
adata_ss2.obs['technology'] = 'InDrop'

# === Align by common genes ===
common_genes = adata_10x.var_names.intersection(adata_ss2.var_names)
adata_10x = adata_10x[:, common_genes].copy()
adata_ss2 = adata_ss2[:, common_genes].copy()

# === Concatenate datasets ===
adata_combined = adata_10x.concatenate(
    adata_ss2,
    batch_key='batch',
    batch_categories=['10X', 'InDrop'],
    index_unique=None
)

# === Check for unique cell names ===
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# === Merge sample metadata ===
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

# Preserve original index
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]  # This is the original cell ID column

# Merge metadata by 'sample' column
adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')

# Check merge consistency
assert adata_combined.obs.shape[0] == adata_combined.shape[0], "Row count mismatch after metadata merge"

# Restore cell IDs as index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index = adata_combined.obs.index.astype(str)  # Ensure string index
adata_combined.obs.index.name = None

# === Final AnnData object ===
print(adata_combined)
# Out:
# /tmp/ipykernel_1576295/1667277684.py:38: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adata_10x.concatenate(
# AnnData object with n_obs × n_vars = 75029 × 11253
#     obs: 'sample', 'patient_x', 'source_x', 'cell_type', 'cell_subtype', 'cluster', 'complexity', 'technology_x', 'cluster_annotation', 'batch', 'patient_y', 'source_y', 'n_cells', 'technology_y', 'sorting', 'cancer_type', 'sample_type', 'size', 'metastases', 'grade', 'er', 'pr', 'her2', 'post_menopause', 'age', 'subtype', 'brca_deficiency'

# %%
adata = adata_combined

# %%
for col in ['cluster', 'batch', 'patient_y', 'source_y', 'cluster_annotation', 'subtype', 'sample_type',
            'technology_y', 'sorting','size', 'grade', 'er', 'pr', 'her2', 'post_menopause','brca_deficiency'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                             sample patient        source cell_type  \
# s1_AAACCTGAGCAGACTG-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# s1_AAACCTGAGGTCGGAT-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# s1_AAACCTGAGTGTACCT-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# s1_AAACCTGAGTGTACTC-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# s1_AAACCTGAGTTAAGTG-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# ...                            ...     ...           ...       ...
# 56541                  BC01_TUMOR4    BC01  breast tumor    T_cell
# 56630                  BC01_TUMOR4    BC01  breast tumor    T_cell
# 57031                  BC01_TUMOR4    BC01  breast tumor    T_cell
# 56235                  BC01_TUMOR4    BC01  breast tumor    T_cell
# 56693                  BC01_TUMOR4    BC01  breast tumor   NK_cell
#
#                       cell_subtype  complexity technology  n_cells  \
# s1_AAACCTGAGCAGACTG-1   CD8 T cell        1684        10X     6710
# s1_AAACCTGAGGTCGGAT-1   CD8 T cell        1653        10X     6710
# s1_AAACCTGAGTGTACCT-1        T-reg        1326        10X     6710
# s1_AAACCTGAGTGTACTC-1   CD8 T cell        1463        10X     6710
# s1_AAACCTGAGTTAAGTG-1   CD4 T cell        1288        10X     6710
# ...                            ...         ...        ...      ...
# 56541                   CD8 T cell         224     InDrop     1191
# 56630                   CD8 T cell         336     InDrop     1191
# 57031                   CD8 T cell         347     InDrop     1191
# 56235                   CD4 T cell         349     InDrop     1191
# 56693                      NK cell         349     InDrop     1191
#
#                          cancer_type  metastases  age              cell_name  \
# s1_AAACCTGAGCAGACTG-1  Breast Cancer           0   65  s1_AAACCTGAGCAGACTG-1
# s1_AAACCTGAGGTCGGAT-1  Breast Cancer           0   65  s1_AAACCTGAGGTCGGAT-1
# s1_AAACCTGAGTGTACCT-1  Breast Cancer           0   65  s1_AAACCTGAGTGTACCT-1
# s1_AAACCTGAGTGTACTC-1  Breast Cancer           0   65  s1_AAACCTGAGTGTACTC-1
# s1_AAACCTGAGTTAAGTG-1  Breast Cancer           0   65  s1_AAACCTGAGTTAAGTG-1
# ...                              ...         ...  ...                    ...
# 56541                  Breast Cancer           0   38                  56541
# 56630                  Breast Cancer           0   38                  56630
# 57031                  Breast Cancer           0   38                  57031
# 56235                  Breast Cancer           0   38                  56235
# 56693                  Breast Cancer           0   38                  56693
#
#                        disease_extent
# s1_AAACCTGAGCAGACTG-1  non metastatic
# s1_AAACCTGAGGTCGGAT-1  non metastatic
# s1_AAACCTGAGTGTACCT-1  non metastatic
# s1_AAACCTGAGTGTACTC-1  non metastatic
# s1_AAACCTGAGTTAAGTG-1  non metastatic
# ...                               ...
# 56541                  non metastatic
# 56630                  non metastatic
# 57031                  non metastatic
# 56235                  non metastatic
# 56693                  non metastatic
#
# [75029 rows x 13 columns]

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"technology_x": "technology"})

# %%
adata.obs['metastases'].value_counts()
# Out:
# metastases
# 0    47077
# 1    27952
# Name: count, dtype: int64

# %%
adata.obs['disease_extent'] = adata.obs['metastases'].astype(str).map({
    '0': 'non metastatic',
    '1': 'metastatic',
})

# %%
del adata.obs['metastases']

# %%
adata.obs
# Out:
#                             sample patient        source cell_type  \
# s1_AAACCTGAGCAGACTG-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# s1_AAACCTGAGGTCGGAT-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# s1_AAACCTGAGTGTACCT-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# s1_AAACCTGAGTGTACTC-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# s1_AAACCTGAGTTAAGTG-1  BC09_TUMOR1    BC09  breast tumor    T_cell
# ...                            ...     ...           ...       ...
# 56541                  BC01_TUMOR4    BC01  breast tumor    T_cell
# 56630                  BC01_TUMOR4    BC01  breast tumor    T_cell
# 57031                  BC01_TUMOR4    BC01  breast tumor    T_cell
# 56235                  BC01_TUMOR4    BC01  breast tumor    T_cell
# 56693                  BC01_TUMOR4    BC01  breast tumor   NK_cell
#
#                       cell_subtype  complexity technology  n_cells  \
# s1_AAACCTGAGCAGACTG-1   CD8 T cell        1684        10X     6710
# s1_AAACCTGAGGTCGGAT-1   CD8 T cell        1653        10X     6710
# s1_AAACCTGAGTGTACCT-1        T-reg        1326        10X     6710
# s1_AAACCTGAGTGTACTC-1   CD8 T cell        1463        10X     6710
# s1_AAACCTGAGTTAAGTG-1   CD4 T cell        1288        10X     6710
# ...                            ...         ...        ...      ...
# 56541                   CD8 T cell         224     InDrop     1191
# 56630                   CD8 T cell         336     InDrop     1191
# 57031                   CD8 T cell         347     InDrop     1191
# 56235                   CD4 T cell         349     InDrop     1191
# 56693                      NK cell         349     InDrop     1191
#
#                          cancer_type  age              cell_name  \
# s1_AAACCTGAGCAGACTG-1  Breast Cancer   65  s1_AAACCTGAGCAGACTG-1
# s1_AAACCTGAGGTCGGAT-1  Breast Cancer   65  s1_AAACCTGAGGTCGGAT-1
# s1_AAACCTGAGTGTACCT-1  Breast Cancer   65  s1_AAACCTGAGTGTACCT-1
# s1_AAACCTGAGTGTACTC-1  Breast Cancer   65  s1_AAACCTGAGTGTACTC-1
# s1_AAACCTGAGTTAAGTG-1  Breast Cancer   65  s1_AAACCTGAGTTAAGTG-1
# ...                              ...  ...                    ...
# 56541                  Breast Cancer   38                  56541
# 56630                  Breast Cancer   38                  56630
# 57031                  Breast Cancer   38                  57031
# 56235                  Breast Cancer   38                  56235
# 56693                  Breast Cancer   38                  56693
#
#                        disease_extent
# s1_AAACCTGAGCAGACTG-1  non metastatic
# s1_AAACCTGAGGTCGGAT-1  non metastatic
# s1_AAACCTGAGTGTACCT-1  non metastatic
# s1_AAACCTGAGTGTACTC-1  non metastatic
# s1_AAACCTGAGTTAAGTG-1  non metastatic
# ...                               ...
# 56541                  non metastatic
# 56630                  non metastatic
# 57031                  non metastatic
# 56235                  non metastatic
# 56693                  non metastatic
#
# [75029 rows x 12 columns]

# %%
adata.obs['study'] = 'Azizi2018_Breast'

# %%
adata.obs['category'] = 'Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Azizi2018_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Azizi2018_Breast.h5ad

# %% [markdown]
# #### 2.Bassez2021_Breast

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Bassez2021_Breast"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 226635 × 22567
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'expansion', 'BC_type', 'cohort', 'technology', 'n_cells', 'patient', 'cancer_type', 'sample_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'treated_naive', 'site'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'timepoint', 'nCount_RNA', 'nFeature_RNA',
            'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'recent_treatment', 'recent_treatment_response', 'time_elapsed_from_recent_treatment',
            'prior_chemotherapy', 'chemotherapy_response', 'prior_targeted_rx', 'targeted_rx_response',
            'prior_chemoICB', 'chemoICB_response', 'prior_ET', 'ET_response', 'subsequent_treatment',
            'subsequent_treatment_response', 'PFS_DFS', 'OS', 'expansion', 'BC_type', 'cohort', 'sample_type',
            'mutation_hormonal_subtype', 'prior_ICB', 'ICB_response'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                               cell_name    sample   cell_type cell_subtype  \
# 0        BIOKEY_1_On_AAACCTGGTAGCAAAT-1  BIOKEY_1      T_cell       CD4_EM
# 1        BIOKEY_1_On_AAACCTGGTCATACTG-1  BIOKEY_1   Malignant          NaN
# 2        BIOKEY_1_On_AAACCTGGTCTAGGTT-1  BIOKEY_1  Fibroblast          NaN
# 3        BIOKEY_1_On_AAACCTGGTTGGACCC-1  BIOKEY_1  Fibroblast          NaN
# 4        BIOKEY_1_On_AAACCTGTCACGATGT-1  BIOKEY_1   Malignant          NaN
# ...                                 ...       ...         ...          ...
# 226630  BIOKEY_9_Pre_TTTGTCACAAACGTGG-1  BIOKEY_9      B_cell          NaN
# 226631  BIOKEY_9_Pre_TTTGTCACAGTACACT-1  BIOKEY_9  Fibroblast          NaN
# 226632  BIOKEY_9_Pre_TTTGTCAGTCGGATCC-1  BIOKEY_9      T_cell          NaN
# 226633  BIOKEY_9_Pre_TTTGTCAGTTCCGTCT-1  BIOKEY_9   Malignant          NaN
# 226634  BIOKEY_9_Pre_TTTGTCATCAGTTCGA-1  BIOKEY_9   Malignant          NaN
#
#         complexity cell_cycle_phase technology  n_cells   patient  \
# 0              430              NaN        10X     9789  BIOKEY_1
# 1              700              NaN        10X     9789  BIOKEY_1
# 2              330              NaN        10X     9789  BIOKEY_1
# 3             2637      Not cycling        10X     9789  BIOKEY_1
# 4              874              NaN        10X     9789  BIOKEY_1
# ...            ...              ...        ...      ...       ...
# 226630         246              NaN        10X     4076  BIOKEY_9
# 226631        1447      Not cycling        10X     4076  BIOKEY_9
# 226632        2131      Not cycling        10X     4076  BIOKEY_9
# 226633        3148      Not cycling        10X     4076  BIOKEY_9
# 226634        2509      Not cycling        10X     4076  BIOKEY_9
#
#           cancer_type    sex    age    disease_extent sample_primary_met  \
# 0       Breast Cancer  False  41-50             early            primary
# 1       Breast Cancer  False  41-50             early            primary
# 2       Breast Cancer  False  41-50             early            primary
# 3       Breast Cancer  False  41-50             early            primary
# 4       Breast Cancer  False  41-50             early            primary
# ...               ...    ...    ...               ...                ...
# 226630  Breast Cancer  False  41-50  locally advanced            primary
# 226631  Breast Cancer  False  41-50  locally advanced            primary
# 226632  Breast Cancer  False  41-50  locally advanced            primary
# 226633  Breast Cancer  False  41-50  locally advanced            primary
# 226634  Breast Cancer  False  41-50  locally advanced            primary
#
#                                             treated_naive    site  \
# 0       sample """"pre"""" - prior to ICB treatment \n...  Breast
# 1       sample """"pre"""" - prior to ICB treatment \n...  Breast
# 2       sample """"pre"""" - prior to ICB treatment \n...  Breast
# 3       sample """"pre"""" - prior to ICB treatment \n...  Breast
# 4       sample """"pre"""" - prior to ICB treatment \n...  Breast
# ...                                                   ...     ...
# 226630  sample """"pre"""" - prior to ICB treatment \n...  Breast
# 226631  sample """"pre"""" - prior to ICB treatment \n...  Breast
# 226632  sample """"pre"""" - prior to ICB treatment \n...  Breast
# 226633  sample """"pre"""" - prior to ICB treatment \n...  Breast
# 226634  sample """"pre"""" - prior to ICB treatment \n...  Breast
#
#                     study category
# 0       Bassez2021_Breast   Breast
# 1       Bassez2021_Breast   Breast
# 2       Bassez2021_Breast   Breast
# 3       Bassez2021_Breast   Breast
# 4       Bassez2021_Breast   Breast
# ...                   ...      ...
# 226630  Bassez2021_Breast   Breast
# 226631  Bassez2021_Breast   Breast
# 226632  Bassez2021_Breast   Breast
# 226633  Bassez2021_Breast   Breast
# 226634  Bassez2021_Breast   Breast
#
# [226635 rows x 18 columns]

# %%
adata.obs['study'] = 'Bassez2021_Breast'

# %%
adata.obs['category'] = 'Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Bassez2021_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Bassez2021_Breast.h5ad

# %% [markdown]
# #### 3.Chung2017_Breast

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Chung2017_Breast"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/utils.py:268: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD113-1', 'SNORD113-2', 'SNORD113-3', 'SNORD113-4', 'SNORD113-5']
#   warnings.warn(
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 515 × 57915
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#     cell_name sample  cell_type  complexity cell_cycle_phase technology  \
# 0     BC01_02   BC01  Malignant        9172      Not cycling  SmartSeq2
# 1     BC01_03   BC01  Malignant        9507     Intermediate  SmartSeq2
# 2     BC01_04   BC01  Malignant        7457      Not cycling  SmartSeq2
# 3     BC01_05   BC01  Malignant        8245      Not cycling  SmartSeq2
# 4     BC01_06   BC01  Malignant        7815      Not cycling  SmartSeq2
# ..        ...    ...        ...         ...              ...        ...
# 510   BC06_43   BC06    Stromal        4473              NaN  SmartSeq2
# 511   BC06_58   BC06     B_cell        2261      Not cycling  SmartSeq2
# 512   BC06_60   BC06  Malignant        7311      Not cycling  SmartSeq2
# 513   BC06_61   BC06     B_cell        2583      Not cycling  SmartSeq2
# 514   BC06_74   BC06  Malignant        6482      Not cycling  SmartSeq2
#
#      n_cells patient    cancer_type    sex  age disease_extent  \
# 0         22    BC01  Breast Cancer  False   66          local
# 1         22    BC01  Breast Cancer  False   66          local
# 2         22    BC01  Breast Cancer  False   66          local
# 3         22    BC01  Breast Cancer  False   66          local
# 4         22    BC01  Breast Cancer  False   66          local
# ..       ...     ...            ...    ...  ...            ...
# 510       18    BC06  Breast Cancer  False   67  node positive
# 511       18    BC06  Breast Cancer  False   67  node positive
# 512       18    BC06  Breast Cancer  False   67  node positive
# 513       18    BC06  Breast Cancer  False   67  node positive
# 514       18    BC06  Breast Cancer  False   67  node positive
#
#     sample_primary_met    site treated_naive
# 0              primary  Breast         naive
# 1              primary  Breast         naive
# 2              primary  Breast         naive
# 3              primary  Breast         naive
# 4              primary  Breast         naive
# ..                 ...     ...           ...
# 510            primary  Breast         naive
# 511            primary  Breast         naive
# 512            primary  Breast         naive
# 513            primary  Breast         naive
# 514            primary  Breast         naive
#
# [515 rows x 15 columns]

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Chung2017_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Chung2017_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Chung2017_Breast.h5ad

# %% [markdown]
# #### 4. Gulati2020_Breast

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Gulati2020_Breast"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1902 × 42132
#     obs: 'cell_name', 'sample', 'patient', 'source', 'cell_type', 'cell_subtype', 'complexity', 'cancer_type', 'technology', 'n_cells', 'sex'

# %%
for col in ['source_y', 'clinical_type', 'clinical_subtype','stage', 'hormone_receptor_status', 'grade','patient_y'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"gender": "sex"})

# %%
adata.obs
# Out:
#            cell_name   sample patient  source   cell_type        cell_subtype  \
# 0      A10_004_SU2_N    SU2_N     SU2  Normal  Epithelial               Basal
# 1       A1_004_SU2_N    SU2_N     SU2  Normal  Epithelial      Mature luminal
# 2       A1_005_SU2_T    SU2_T     SU2   Tumor   Malignant  Luminal progenitor
# 3      A11_004_SU2_N    SU2_N     SU2  Normal  Epithelial      Mature luminal
# 4      A12_004_SU2_N    SU2_N     SU2  Normal  Epithelial      Mature luminal
# ...              ...      ...     ...     ...         ...                 ...
# 1897  G5_061_COH69_T  COH69_T   COH69   Tumor   Malignant  Luminal progenitor
# 1898  G6_061_COH69_T  COH69_T   COH69   Tumor   Malignant  Luminal progenitor
# 1899  G7_062_COH69_T  COH69_T   COH69   Tumor   Malignant  Luminal progenitor
# 1900  G8_062_COH69_T  COH69_T   COH69   Tumor   Malignant  Luminal progenitor
# 1901    H3_031_SU4_T    SU4_T     SU4   Tumor   Malignant               Basal
#
#       complexity    cancer_type technology  n_cells     sex category  \
# 0           4986  Breast Cancer  SmartSeq2       75  Female   Breast
# 1           2314  Breast Cancer  SmartSeq2       75  Female   Breast
# 2           1859  Breast Cancer  SmartSeq2       80  Female   Breast
# 3           2906  Breast Cancer  SmartSeq2       75  Female   Breast
# 4           4906  Breast Cancer  SmartSeq2       75  Female   Breast
# ...          ...            ...        ...      ...     ...      ...
# 1897        1854  Breast Cancer  SmartSeq2       83  Female   Breast
# 1898        4756  Breast Cancer  SmartSeq2       83  Female   Breast
# 1899        1755  Breast Cancer  SmartSeq2       83  Female   Breast
# 1900        1541  Breast Cancer  SmartSeq2       83  Female   Breast
# 1901        1183  Breast Cancer  SmartSeq2       68  Female   Breast
#
#                   study    site
# 0     Gulati2020_Breast  Breast
# 1     Gulati2020_Breast  Breast
# 2     Gulati2020_Breast  Breast
# 3     Gulati2020_Breast  Breast
# 4     Gulati2020_Breast  Breast
# ...                 ...     ...
# 1897  Gulati2020_Breast  Breast
# 1898  Gulati2020_Breast  Breast
# 1899  Gulati2020_Breast  Breast
# 1900  Gulati2020_Breast  Breast
# 1901  Gulati2020_Breast  Breast
#
# [1902 rows x 14 columns]

# %%
adata.obs['site'] = 'Breast'

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Gulati2020_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Gulati2020_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Gulati2020_Breast.h5ad

# %% [markdown]
# #### 5.Karaayvas2018_Breast

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Karaayvas2018_Breast"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1534 × 21785
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                cell_name  sample   cell_type  complexity cell_cycle_phase  \
# 0           PT089_P1_A01      89  Epithelial        3556      Not cycling
# 1           PT089_P1_A02      89  Epithelial        3372      Not cycling
# 2           PT089_P1_A03      89  Epithelial        2577      Not cycling
# 3           PT089_P1_A04      89  Macrophage        2260      Not cycling
# 4           PT089_P1_A05      89  Macrophage        2658      Not cycling
# ...                  ...     ...         ...         ...              ...
# 1529  PT039_P10_H08_S284      39  Macrophage        3564      Not cycling
# 1530  PT039_P10_H09_S285      39   Malignant        6862             G1/S
# 1531  PT039_P10_H10_S286      39         NaN         518              NaN
# 1532  PT039_P10_H11_S287      39  Epithelial         992              NaN
# 1533  PT039_P10_H12_S288      39   Malignant       12942             G1/S
#
#      technology  n_cells  patient    cancer_type    sex  age  disease_extent  \
# 0     SmartSeq2      333       89  Breast Cancer  False   44             NaN
# 1     SmartSeq2      333       89  Breast Cancer  False   44             NaN
# 2     SmartSeq2      333       89  Breast Cancer  False   44             NaN
# 3     SmartSeq2      333       89  Breast Cancer  False   44             NaN
# 4     SmartSeq2      333       89  Breast Cancer  False   44             NaN
# ...         ...      ...      ...            ...    ...  ...             ...
# 1529  SmartSeq2      341       39  Breast Cancer  False   64             NaN
# 1530  SmartSeq2      341       39  Breast Cancer  False   64             NaN
# 1531  SmartSeq2      341       39  Breast Cancer  False   64             NaN
# 1532  SmartSeq2      341       39  Breast Cancer  False   64             NaN
# 1533  SmartSeq2      341       39  Breast Cancer  False   64             NaN
#
#      sample_primary_met    site treated_naive category                 study
# 0               primary  breast         naive   Breast  Karaayvas2018_Breast
# 1               primary  breast         naive   Breast  Karaayvas2018_Breast
# 2               primary  breast         naive   Breast  Karaayvas2018_Breast
# 3               primary  breast         naive   Breast  Karaayvas2018_Breast
# 4               primary  breast         naive   Breast  Karaayvas2018_Breast
# ...                 ...     ...           ...      ...                   ...
# 1529            primary  breast         naive   Breast  Karaayvas2018_Breast
# 1530            primary  breast         naive   Breast  Karaayvas2018_Breast
# 1531            primary  breast         naive   Breast  Karaayvas2018_Breast
# 1532            primary  breast         naive   Breast  Karaayvas2018_Breast
# 1533            primary  breast         naive   Breast  Karaayvas2018_Breast
#
# [1534 rows x 17 columns]

# %%
adata.obs['study'] = 'Karaayvas2018_Breast'

# %%
adata.obs['category'] = 'Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Karaayvas2018_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Karaayvas2018_Breast.h5ad

# %% [markdown]
# #### 6.Kim2018_Breast

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Kim2018_Breast"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2472 × 12472
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'treated_naive', 'age', 'cancer_type', 'cancer_subtype', 'technology', 'n_cells'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY',  'time_point','histology_x',
            'tnm_stage_x', 'grade_x', 'patient_y',
            'treatment_y', 'histology_y', 'age_y', 'tnm_stage_y', 'grade_y'      
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"treatment_x": "treated_naive"})

# %%
adata.obs = adata.obs.rename(columns={"age_x": "age"})

# %%
adata.obs
# Out:
#            cell_name    sample patient  cell_type cell_subtype  complexity  \
# 0     KTN1290cell435    P2_pre      P2     T_cell       CD8Tex         625
# 1     KTN1290cell234    P2_pre      P2     T_cell       CD8Tex         514
# 2     KTN1290cell110    P2_pre      P2     T_cell       CD8Tex         706
# 3     KTN1290cell147    P2_pre      P2     T_cell       CD8Tex         632
# 4     KTN1290cell106    P2_pre      P2     T_cell       CD8Tex         664
# ...              ...       ...     ...        ...          ...         ...
# 2467  KTN1322cell101   P12_mid     P12  Malignant    Malignant         527
# 2468  KTN1520cell416   P14_pre     P14  Malignant    Malignant        1971
# 2469  KTN1260cell172    P1_pre      P1  Malignant    Malignant         555
# 2470  KTN152OPcell19  P14_post     P14  Malignant    Malignant        1184
# 2471  KTN1520cell257   P14_pre     P14  Malignant    Malignant        1821
#
#       cell_cycle_phase                                      treated_naive  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                  NaN                                                NaN
# ...                ...                                                ...
# 2467               NaN                    2 cycles epirubicin + docetaxel
# 2468               NaN                                                NaN
# 2469               NaN                                                NaN
# 2470               NaN  2 cycles epirubicin + docetaxel, then 4 cycles...
# 2471               NaN                                                NaN
#
#       age    cancer_type cancer_subtype technology  n_cells category  \
# 0      46  Breast Cancer           TNBC   Nanogrid       98   Breast
# 1      46  Breast Cancer           TNBC   Nanogrid       98   Breast
# 2      46  Breast Cancer           TNBC   Nanogrid       98   Breast
# 3      46  Breast Cancer           TNBC   Nanogrid       98   Breast
# 4      46  Breast Cancer           TNBC   Nanogrid       98   Breast
# ...   ...            ...            ...        ...      ...      ...
# 2467   40  Breast Cancer           TNBC   Nanogrid      164   Breast
# 2468   38  Breast Cancer           TNBC   Nanogrid      474   Breast
# 2469   44  Breast Cancer           TNBC   Nanogrid      141   Breast
# 2470   38  Breast Cancer           TNBC   Nanogrid      373   Breast
# 2471   38  Breast Cancer           TNBC   Nanogrid      474   Breast
#
#                study
# 0     Kim2018_Breast
# 1     Kim2018_Breast
# 2     Kim2018_Breast
# 3     Kim2018_Breast
# 4     Kim2018_Breast
# ...              ...
# 2467  Kim2018_Breast
# 2468  Kim2018_Breast
# 2469  Kim2018_Breast
# 2470  Kim2018_Breast
# 2471  Kim2018_Breast
#
# [2472 rows x 15 columns]

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Kim2018_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Kim2018_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Kim2018_Breast.h5ad

# %% [markdown]
# #### 7.Qian2020_Breast

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Qian2020_Breast"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 16537 × 22276
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS',   
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                          cell_name  sample  cell_type  complexity  \
# 0      sc5rJUQ026_AAACCTGCATCTCGCT      42     T_cell        2138
# 1      sc5rJUQ026_AAACCTGGTTCTCATT      42     T_cell        2085
# 2      sc5rJUQ026_AAACCTGTCAAGAAGT      42     T_cell        1767
# 3      sc5rJUQ026_AAACCTGTCTCGCATC      42     T_cell        2016
# 4      sc5rJUQ026_AAACGGGAGTTATCGC      42     T_cell        1595
# ...                            ...     ...        ...         ...
# 16532  sc5rJUQ064_TTTGGTTTCTGCCCTA      54  Malignant        2324
# 16533  sc5rJUQ064_TTTGTCAAGCCAGAAC      54  Malignant        2964
# 16534  sc5rJUQ064_TTTGTCAAGGACGAAA      54  Malignant        1814
# 16535  sc5rJUQ064_TTTGTCAGTCTTGTCC      54  Malignant        2464
# 16536  sc5rJUQ064_TTTGTCATCCGGGTGT      54        NaN        1091
#
#       cell_cycle_phase technology  n_cells patient    cancer_type     sex  \
# 0          Not cycling        10x     1805    BC_2  Breast Cancer  Female
# 1          Not cycling        10x     1805    BC_2  Breast Cancer  Female
# 2          Not cycling        10x     1805    BC_2  Breast Cancer  Female
# 3          Not cycling        10x     1805    BC_2  Breast Cancer  Female
# 4          Not cycling        10x     1805    BC_2  Breast Cancer  Female
# ...                ...        ...      ...     ...            ...     ...
# 16532      Not cycling        10x     3717   BC_14  Breast Cancer  Female
# 16533      Not cycling        10x     3717   BC_14  Breast Cancer  Female
# 16534      Not cycling        10x     3717   BC_14  Breast Cancer  Female
# 16535      Not cycling        10x     3717   BC_14  Breast Cancer  Female
# 16536              NaN        10x     3717   BC_14  Breast Cancer  Female
#
#        age  disease_extent  sample_primary_met  site treated_naive category  \
# 0      NaN             NaN                 NaN   NaN         naive   Breast
# 1      NaN             NaN                 NaN   NaN         naive   Breast
# 2      NaN             NaN                 NaN   NaN         naive   Breast
# 3      NaN             NaN                 NaN   NaN         naive   Breast
# 4      NaN             NaN                 NaN   NaN         naive   Breast
# ...    ...             ...                 ...   ...           ...      ...
# 16532  NaN             NaN                 NaN   NaN         naive   Breast
# 16533  NaN             NaN                 NaN   NaN         naive   Breast
# 16534  NaN             NaN                 NaN   NaN         naive   Breast
# 16535  NaN             NaN                 NaN   NaN         naive   Breast
# 16536  NaN             NaN                 NaN   NaN         naive   Breast
#
#                  study
# 0      Qian2020_Breast
# 1      Qian2020_Breast
# 2      Qian2020_Breast
# 3      Qian2020_Breast
# 4      Qian2020_Breast
# ...                ...
# 16532  Qian2020_Breast
# 16533  Qian2020_Breast
# 16534  Qian2020_Breast
# 16535  Qian2020_Breast
# 16536  Qian2020_Breast
#
# [16537 rows x 17 columns]

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Qian2020_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Qian2020_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Qian2020_Breast.h5ad

# %% [markdown]
# #### 8.Savas2018_Breast

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Savas2018_Breast"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6311 × 24410
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'patient_y', 'cancer_type', 'technology', 'n_cells', 'subtype', 'sorting', 'sample_primary_met'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score','sorting', 
            
            'mp_top_score', 'mp_top', 'mp_assignment', 'patient_y','subtype',
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                  cell_name  sample  patient cell_type  complexity  \
# 0     AAACCTGCAAACAACA-1_1       1        1    T_cell         828
# 1     AAACCTGCACTACAGT-1_1       1        1    T_cell        1126
# 2     AAACCTGCAGCTGGCT-1_1       1        1    T_cell         712
# 3     AAACCTGCATGTCGAT-1_1       1        1       NaN         491
# 4     AAACCTGGTGAGCGAT-1_1       1        1    T_cell         663
# ...                    ...     ...      ...       ...         ...
# 6306  TTTCCTCAGCTACCTA-1_2       2        2    T_cell        1434
# 6307  TTTCCTCTCCCAAGTA-1_2       2        2    T_cell        1545
# 6308  TTTGCGCAGAGGTAGA-1_2       2        2    T_cell        1247
# 6309  TTTGCGCAGGAATGGA-1_2       2        2    T_cell        1070
# 6310  TTTGTCACAAGGTTTC-1_2       2        2    T_cell        1490
#
#      cell_cycle_phase    cancer_type technology  n_cells sample_primary_met  \
# 0                 NaN  Breast Cancer        10x     5174            primary
# 1         Not cycling  Breast Cancer        10x     5174            primary
# 2                 NaN  Breast Cancer        10x     5174            primary
# 3                 NaN  Breast Cancer        10x     5174            primary
# 4                 NaN  Breast Cancer        10x     5174            primary
# ...               ...            ...        ...      ...                ...
# 6306      Not cycling  Breast Cancer        10x     1137            primary
# 6307      Not cycling  Breast Cancer        10x     1137            primary
# 6308      Not cycling  Breast Cancer        10x     1137            primary
# 6309      Not cycling  Breast Cancer        10x     1137            primary
# 6310      Not cycling  Breast Cancer        10x     1137            primary
#
#         site
# 0     breast
# 1     breast
# 2     breast
# 3     breast
# 4     breast
# ...      ...
# 6306  breast
# 6307  breast
# 6308  breast
# 6309  breast
# 6310  breast
#
# [6311 rows x 11 columns]

# %%
adata.obs['site'] = 'breast'

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Savas2018_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Savas2018_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Savas2018_Breast.h5ad

# %% [markdown]
# #### 9.Wu2021_Breast

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Wu2021_Breast"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# /tmp/ipykernel_1576295/2472588876.py:14: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 100064 × 29733
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'celltype_subset', 'disease', 'gender_x', 'age_x', 'cancer_type_x', 'treatment_x', 'technology', 'n_cells'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score',
            'mp_top_score', 'mp_top', 'mp_assignment','grade_x', 'celltype_subset', 'disease',
            'ER_x', 'PR_x', 'HER2_IHC_x', 'HER2_ISH_ratio_x', 'Ki67_x', 'subtype_IHC_x',
            'details_treatment_x', 'notable_pathological_features_x', 'stage_x', 'cancer_type_y',
            'patient_y', 'gender_y', 'age_y', 'grade_y', 'cancer_type.1', 'ER_y', 'PR_y', 'HER2_IHC_y', 'HER2_ISH_ratio_y',
            'Ki67_y', 'subtype_IHC_y', 'treatment_y', 'details_treatment_y', 'notable_pathological_features_y', 'stage_y', 'histology'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                        cell_name   sample  patient    cell_type  \
# 0       CID3586_AAGACCTCAGCATGAG  CID3586  CID3586  Endothelial
# 1       CID3586_AAGGTTCGTAGTACCT  CID3586  CID3586  Endothelial
# 2       CID3586_ACCAGTAGTTGTGGCC  CID3586  CID3586  Endothelial
# 3       CID3586_ACCCACTAGATGTCGG  CID3586  CID3586  Endothelial
# 4       CID3586_ACTGATGGTCAACTGT  CID3586  CID3586  Endothelial
# ...                          ...      ...      ...          ...
# 100059  CID4398_TCAGGTAGTACTCAAC  CID4398  CID4398    Dendritic
# 100060  CID4398_TCTATTGTCGCCATAA  CID4398  CID4398    Dendritic
# 100061  CID4398_TCTTTCCCAGTAAGCG  CID4398  CID4398    Dendritic
# 100062  CID4398_TGCCCATGTTACGGAG  CID4398  CID4398    Dendritic
# 100063  CID4398_TTGAACGTCCTATTCA  CID4398  CID4398    Dendritic
#
#              cell_subtype  complexity cell_cycle_phase     sex   age  \
# 0       Endothelial ACKR1        1689      Not cycling  Female  43.0
# 1       Endothelial ACKR1         779              NaN  Female  43.0
# 2       Endothelial ACKR1         514              NaN  Female  43.0
# 3       Endothelial ACKR1         609              NaN  Female  43.0
# 4       Endothelial ACKR1         807              NaN  Female  43.0
# ...                   ...         ...              ...     ...   ...
# 100059                DCs        1251      Not cycling  Female  52.0
# 100060                DCs         719              NaN  Female  52.0
# 100061                DCs         887              NaN  Female  52.0
# 100062                DCs         870              NaN  Female  52.0
# 100063                DCs        1231      Not cycling  Female  52.0
#
#        cancer_type treated_naive technology  n_cells    site          study
# 0              IDC         Naïve        10x     6178  breast  Wu2021_Breast
# 1              IDC         Naïve        10x     6178  breast  Wu2021_Breast
# 2              IDC         Naïve        10x     6178  breast  Wu2021_Breast
# 3              IDC         Naïve        10x     6178  breast  Wu2021_Breast
# 4              IDC         Naïve        10x     6178  breast  Wu2021_Breast
# ...            ...           ...        ...      ...     ...            ...
# 100059         IDC       Treated        10x     4451  breast  Wu2021_Breast
# 100060         IDC       Treated        10x     4451  breast  Wu2021_Breast
# 100061         IDC       Treated        10x     4451  breast  Wu2021_Breast
# 100062         IDC       Treated        10x     4451  breast  Wu2021_Breast
# 100063         IDC       Treated        10x     4451  breast  Wu2021_Breast
#
# [100064 rows x 15 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"gender_x": "sex"})

# %%
adata.obs = adata.obs.rename(columns={"cancer_type_x": "cancer_type"})

# %%
adata.obs = adata.obs.rename(columns={"age_x": "age"})

# %%
adata.obs = adata.obs.rename(columns={"treatment_x": "treated_naive"})

# %%
adata.obs['site'] = 'breast'

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Wu2021_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Wu2021_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Wu2021_Breast.h5ad

# %% [markdown]
# #### 10.Gao2021_Breast

# %%
import os
import pandas as pd
import scanpy as sc

# === Set base path ===
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Gao2021_Breast"

# === Define cancer type folders and human-readable labels ===
cancer_types = {
    "BC": "Breast",
    "BTC": "Breast_and_thyroid"
}

# === Load sample metadata ===
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

# === Load expression datasets ===
adatas = []

for folder, label in cancer_types.items():
    path = os.path.join(base_path, folder)
    
    # Load expression matrix
    adata = sc.read_mtx(os.path.join(path, "Exp_data_UMIcounts.mtx")).T  # Transpose to cells x genes
    
    # Load gene and cell information
    genes = pd.read_csv(os.path.join(path, "Genes.txt"), header=None)[0].tolist()
    cells = pd.read_csv(os.path.join(path, "Cells.csv"), index_col=0)
    
    # Ensure unique cell names by prefixing with folder name
    cells.index = [f"{folder}_{idx}" for idx in cells.index]
    
    # Assign gene names and cell metadata
    adata.var_names = genes
    adata.obs = cells
    adata.obs_names = cells.index
    adata.obs['cancer_folder'] = folder
    adata.obs['cancer_type'] = label
    
    adatas.append(adata)

# === Find common genes ===
common_genes = adatas[0].var_names
for ad in adatas[1:]:
    common_genes = common_genes.intersection(ad.var_names)

# === Subset all datasets to common genes ===
adatas = [ad[:, common_genes].copy() for ad in adatas]

# === Concatenate all datasets with batch labels ===
adata_combined = adatas[0].concatenate(
    *adatas[1:],
    batch_key='batch',
    batch_categories=list(cancer_types.keys()),
    index_unique=None  # Cell names are already unique from above
)

# === Ensure unique cell names ===
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# === Merge with sample metadata ===
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]

adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')

# Check merge integrity
assert adata_combined.shape[0] == adata_combined.obs.shape[0], "Mismatch after sample merge"

# Restore cell index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index = adata_combined.obs.index.astype(str)
adata_combined.obs.index.name = None

# === Final AnnData object ready ===
print(adata_combined)
# Out:
# /tmp/ipykernel_1576295/2357108725.py:51: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adatas[0].concatenate(
# AnnData object with n_obs × n_vars = 29992 × 22164
#     obs: 'sample', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'cancer_folder', 'cancer_type_x', 'batch', 'technology', 'n_cells', 'patient', 'cancer_type_y', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
adata = adata_combined

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 29992 × 22164
#     obs: 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'cancer_folder', 'cancer_type', 'technology', 'n_cells', 'patient', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 'patient_y',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'batch',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS','cancer_type_y'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"cancer_type_x": "cancer_type"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs
# Out:
#                      sample    cell_type  complexity cell_cycle_phase  \
# BC_AAACCTGCAGTGACAG   DCIS1    Malignant        2740      Not cycling
# BC_AAACCTGGTCGAGATG   DCIS1   Epithelial        3079      Not cycling
# BC_AAACCTGTCACCGGGT   DCIS1  Endothelial        3243      Not cycling
# BC_AAACGGGGTGCACTTA   DCIS1    Malignant        3373      Not cycling
# BC_AAACGGGTCACGGTTA   DCIS1    Malignant        4162      Not cycling
# ...                     ...          ...         ...              ...
# BTC_TTTGGAGGTGTTCGTA  TNBC5    Malignant        6232      Not cycling
# BTC_TTTGGTTGTAGCTTTG  TNBC5    Malignant        7478             G1/S
# BTC_TTTGTTGAGCGTATGG  TNBC5       T_cell        1146      Not cycling
# BTC_TTTGTTGCAGGATTCT  TNBC5    Malignant        4643      Not cycling
# BTC_TTTGTTGTCCTCAGGG  TNBC5    Malignant        3901      Not cycling
#
#                      cancer_folder         cancer_type technology  n_cells  \
# BC_AAACCTGCAGTGACAG             BC              Breast        10X     1480
# BC_AAACCTGGTCGAGATG             BC              Breast        10X     1480
# BC_AAACCTGTCACCGGGT             BC              Breast        10X     1480
# BC_AAACGGGGTGCACTTA             BC              Breast        10X     1480
# BC_AAACGGGTCACGGTTA             BC              Breast        10X     1480
# ...                            ...                 ...        ...      ...
# BTC_TTTGGAGGTGTTCGTA           BTC  Breast_and_thyroid        10X     3225
# BTC_TTTGGTTGTAGCTTTG           BTC  Breast_and_thyroid        10X     3225
# BTC_TTTGTTGAGCGTATGG           BTC  Breast_and_thyroid        10X     3225
# BTC_TTTGTTGCAGGATTCT           BTC  Breast_and_thyroid        10X     3225
# BTC_TTTGTTGTCCTCAGGG           BTC  Breast_and_thyroid        10X     3225
#
#                      patient  sex  age  disease_extent  sample_primary_met  \
# BC_AAACCTGCAGTGACAG    DCIS1  NaN  NaN             NaN                 NaN
# BC_AAACCTGGTCGAGATG    DCIS1  NaN  NaN             NaN                 NaN
# BC_AAACCTGTCACCGGGT    DCIS1  NaN  NaN             NaN                 NaN
# BC_AAACGGGGTGCACTTA    DCIS1  NaN  NaN             NaN                 NaN
# BC_AAACGGGTCACGGTTA    DCIS1  NaN  NaN             NaN                 NaN
# ...                      ...  ...  ...             ...                 ...
# BTC_TTTGGAGGTGTTCGTA   TNBC5  NaN  NaN             NaN                 NaN
# BTC_TTTGGTTGTAGCTTTG   TNBC5  NaN  NaN             NaN                 NaN
# BTC_TTTGTTGAGCGTATGG   TNBC5  NaN  NaN             NaN                 NaN
# BTC_TTTGTTGCAGGATTCT   TNBC5  NaN  NaN             NaN                 NaN
# BTC_TTTGTTGTCCTCAGGG   TNBC5  NaN  NaN             NaN                 NaN
#
#                       site treated_naive             cell_name category  \
# BC_AAACCTGCAGTGACAG    NaN         naive   BC_AAACCTGCAGTGACAG   Breast
# BC_AAACCTGGTCGAGATG    NaN         naive   BC_AAACCTGGTCGAGATG   Breast
# BC_AAACCTGTCACCGGGT    NaN         naive   BC_AAACCTGTCACCGGGT   Breast
# BC_AAACGGGGTGCACTTA    NaN         naive   BC_AAACGGGGTGCACTTA   Breast
# BC_AAACGGGTCACGGTTA    NaN         naive   BC_AAACGGGTCACGGTTA   Breast
# ...                    ...           ...                   ...      ...
# BTC_TTTGGAGGTGTTCGTA   NaN         naive  BTC_TTTGGAGGTGTTCGTA   Breast
# BTC_TTTGGTTGTAGCTTTG   NaN         naive  BTC_TTTGGTTGTAGCTTTG   Breast
# BTC_TTTGTTGAGCGTATGG   NaN         naive  BTC_TTTGTTGAGCGTATGG   Breast
# BTC_TTTGTTGCAGGATTCT   NaN         naive  BTC_TTTGTTGCAGGATTCT   Breast
# BTC_TTTGTTGTCCTCAGGG   NaN         naive  BTC_TTTGTTGTCCTCAGGG   Breast
#
#                                study
# BC_AAACCTGCAGTGACAG   Gao2021_Breast
# BC_AAACCTGGTCGAGATG   Gao2021_Breast
# BC_AAACCTGTCACCGGGT   Gao2021_Breast
# BC_AAACGGGGTGCACTTA   Gao2021_Breast
# BC_AAACGGGTCACGGTTA   Gao2021_Breast
# ...                              ...
# BTC_TTTGGAGGTGTTCGTA  Gao2021_Breast
# BTC_TTTGGTTGTAGCTTTG  Gao2021_Breast
# BTC_TTTGTTGAGCGTATGG  Gao2021_Breast
# BTC_TTTGTTGCAGGATTCT  Gao2021_Breast
# BTC_TTTGTTGTCCTCAGGG  Gao2021_Breast
#
# [29992 rows x 18 columns]

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Gao2021_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Gao2021_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Gao2021_Breast.h5ad

# %% [markdown]
# #### 11.Griffiths2021_Breast

# %%
# Set base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Griffiths2021_Breast"

# === Load 10X Data ===
path_10x = os.path.join(base_path, "10X")
adata_10x = sc.read_mtx(os.path.join(path_10x, "Exp_data_UMIcounts.mtx")).T  # Transpose to cells x genes
genes_10x = pd.read_csv(os.path.join(path_10x, "Genes.txt"), header=None)[0].tolist()
cells_10x = pd.read_csv(os.path.join(path_10x, "Cells.csv"), index_col=0)

adata_10x.var_names = genes_10x
adata_10x.obs = cells_10x
adata_10x.obs['technology'] = '10X'

# === Load iCell8 Data ===
path_ss2 = os.path.join(base_path, "iCell8")
adata_ss2 = sc.read_mtx(os.path.join(path_ss2, "Exp_data_UMIcounts.mtx")).T
genes_ss2 = pd.read_csv(os.path.join(path_ss2, "Genes.txt"), header=None)[0].tolist()
cells_ss2 = pd.read_csv(os.path.join(path_ss2, "Cells.csv"), index_col=0)

adata_ss2.var_names = genes_ss2
adata_ss2.obs = cells_ss2
adata_ss2.obs['technology'] = 'iCell8'

# === Align by common genes ===
common_genes = adata_10x.var_names.intersection(adata_ss2.var_names)
adata_10x = adata_10x[:, common_genes].copy()
adata_ss2 = adata_ss2[:, common_genes].copy()

# === Concatenate ===
adata_combined = adata_10x.concatenate(
    adata_ss2,
    batch_key='batch',
    batch_categories=['10X', 'iCell8'],
    index_unique=None
)

# === Check uniqueness ===
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# === Merge sample metadata ===
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

# Preserve and reset index
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]

# Merge with sample metadata
adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')
assert adata_combined.obs.shape[0] == adata_combined.shape[0], "Row count mismatch after metadata merge"

# Restore index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index.name = None
# Out:
# /tmp/ipykernel_1576295/2240299642.py:30: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adata_10x.concatenate(

# %%
adata = adata_combined

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 111372 × 15691
#     obs: 'sample', 'patient_x', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'time_point_x', 'days_treated_x', 'treatment_arm_x', 'treatment_x', 'ribociclib_schedule_x', 'response_x', 'technology_x', 'batch', 'cancer_type', 'technology_y', 'n_cells', 'patient_y', 'time_point_y', 'days_treated_y', 'treatment_arm_y', 'treatment_y', 'ribociclib_schedule_y', 'response_y'

# %%
for col in [ 'umap1', 'umap2', 'g1s_score', 'g2m_score',
             'mp_top_score', 'mp_top', 'mp_assignment', 'time_point_x', 
             'days_treated_x', 'treatment_arm_x','ribociclib_schedule_x', 'response_x',
             'nCount_RNA', 'nFeature_RNA', 'percent.mt','batch',
             'technology_y', 'patient_y', 'time_point_y', 'days_treated_y',
             'treatment_arm_y', 'treatment_y', 'ribociclib_schedule_y', 'response_y'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['treatment_x'].value_counts()
# Out:
# treatment_x
# letrozole + ribociclib    63966
# letrozole                 47406
# Name: count, dtype: int64

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"treatment_x": "treated_naive"})

# %%
adata.obs = adata.obs.rename(columns={"technology_x": "technology"})

# %%
adata.obs
# Out:
#                        sample patient  cell_type  complexity cell_cycle_phase  \
# P11_M_AAACGAACACAAGTGG  P11_M     P11  Malignant        2361      Not cycling
# P11_M_AAACGCTGTTAAGAAC  P11_M     P11  Malignant        2123      Not cycling
# P11_M_AAAGTGAAGAGGACTC  P11_M     P11  Malignant        1795      Not cycling
# P11_M_AAATGGAGTGTTAACC  P11_M     P11  Malignant        2904      Not cycling
# P11_M_AACAACCGTCCTCCTA  P11_M     P11  Malignant        3415      Not cycling
# ...                       ...     ...        ...         ...              ...
# P09_M_C68_R24           P09_M     P09  Malignant        2167      Not cycling
# P09_M_C68_R55           P09_M     P09  Malignant        3116      Not cycling
# P09_M_C69_R26           P09_M     P09  Malignant        3104      Not cycling
# P09_M_C69_R60           P09_M     P09  Malignant        3188      Not cycling
# P09_M_C71_R23           P09_M     P09  Malignant        2427      Not cycling
#
#                                  treated_naive technology    cancer_type  \
# P11_M_AAACGAACACAAGTGG  letrozole + ribociclib        10X  Breast Cancer
# P11_M_AAACGCTGTTAAGAAC  letrozole + ribociclib        10X  Breast Cancer
# P11_M_AAAGTGAAGAGGACTC  letrozole + ribociclib        10X  Breast Cancer
# P11_M_AAATGGAGTGTTAACC  letrozole + ribociclib        10X  Breast Cancer
# P11_M_AACAACCGTCCTCCTA  letrozole + ribociclib        10X  Breast Cancer
# ...                                        ...        ...            ...
# P09_M_C68_R24           letrozole + ribociclib     iCell8  Breast Cancer
# P09_M_C68_R55           letrozole + ribociclib     iCell8  Breast Cancer
# P09_M_C69_R26           letrozole + ribociclib     iCell8  Breast Cancer
# P09_M_C69_R60           letrozole + ribociclib     iCell8  Breast Cancer
# P09_M_C71_R23           letrozole + ribociclib     iCell8  Breast Cancer
#
#                         n_cells               cell_name    site category  \
# P11_M_AAACGAACACAAGTGG      780  P11_M_AAACGAACACAAGTGG  breast   Breast
# P11_M_AAACGCTGTTAAGAAC      780  P11_M_AAACGCTGTTAAGAAC  breast   Breast
# P11_M_AAAGTGAAGAGGACTC      780  P11_M_AAAGTGAAGAGGACTC  breast   Breast
# P11_M_AAATGGAGTGTTAACC      780  P11_M_AAATGGAGTGTTAACC  breast   Breast
# P11_M_AACAACCGTCCTCCTA      780  P11_M_AACAACCGTCCTCCTA  breast   Breast
# ...                         ...                     ...     ...      ...
# P09_M_C68_R24                79           P09_M_C68_R24  breast   Breast
# P09_M_C68_R55                79           P09_M_C68_R55  breast   Breast
# P09_M_C69_R26                79           P09_M_C69_R26  breast   Breast
# P09_M_C69_R60                79           P09_M_C69_R60  breast   Breast
# P09_M_C71_R23                79           P09_M_C71_R23  breast   Breast
#
#                                        study
# P11_M_AAACGAACACAAGTGG  Griffiths2021_Breast
# P11_M_AAACGCTGTTAAGAAC  Griffiths2021_Breast
# P11_M_AAAGTGAAGAGGACTC  Griffiths2021_Breast
# P11_M_AAATGGAGTGTTAACC  Griffiths2021_Breast
# P11_M_AACAACCGTCCTCCTA  Griffiths2021_Breast
# ...                                      ...
# P09_M_C68_R24           Griffiths2021_Breast
# P09_M_C68_R55           Griffiths2021_Breast
# P09_M_C69_R26           Griffiths2021_Breast
# P09_M_C69_R60           Griffiths2021_Breast
# P09_M_C71_R23           Griffiths2021_Breast
#
# [111372 rows x 13 columns]

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs['site'] = 'breast'

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Griffiths2021_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Griffiths2021_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Griffiths2021_Breast.h5ad

# %% [markdown]
# #### 11.Pal2021_Breast

# %%
import os
import pandas as pd
import scanpy as sc
import scipy.io
import gc
from scipy.sparse import vstack

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Breast/Data_Pal2021_Breast"

# Step 1: Read gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
gene_names = genes[0].values

# Step 2: Read and concatenate expression matrices and cell metadata
all_exprs = []
all_cells = []

for i in range(1, 6):  # Group1 to Group5
    group_path = os.path.join(base_path, f"Group{i}")
    
    # Load matrix
    mtx_path = os.path.join(group_path, f"Exp_data_UMIcounts{i}.mtx")
    expr = sc.read_mtx(mtx_path).T  # transpose: cells x genes
    all_exprs.append(expr.X)
    
    # Load cell metadata
    cells_path = os.path.join(group_path, f"Cells{i}.csv")
    cells_df = pd.read_csv(cells_path)
    all_cells.append(cells_df)

# Combine all groups
combined_expr = vstack(all_exprs)
combined_cells = pd.concat(all_cells, ignore_index=True)

# Create AnnData object
adata = sc.AnnData(X=combined_expr)
adata.var_names = gene_names
adata.var_names_make_unique()
adata.obs = combined_cells

# Step 3: Read and merge sample metadata
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))
adata.obs = adata.obs.merge(samples, on="sample", how="left")

gc.collect()
# Out:
# 4498

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 305224 × 33538
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'timepoint', 'nCount_RNA', 'nFeature_RNA',
            'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'recent_treatment', 'recent_treatment_response', 'time_elapsed_from_recent_treatment',
            'prior_chemotherapy', 'chemotherapy_response', 'prior_targeted_rx', 'targeted_rx_response',
            'prior_chemoICB', 'chemoICB_response', 'prior_ET', 'ET_response', 'subsequent_treatment',
            'subsequent_treatment_response', 'PFS_DFS', 'OS',
            'chemotherapy_exposed', 'targeted_rx_exposed', 'ICB_exposed', 'ICB_response', 'ET_exposed',
            'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response'
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                                             cell_name  \
# 0        BRCA1_pre_neoplastic_0023_AAACCTGAGAGACTAT-1
# 1        BRCA1_pre_neoplastic_0023_AAACCTGAGGGCTCTC-1
# 2        BRCA1_pre_neoplastic_0023_AAACCTGCAATAACGA-1
# 3        BRCA1_pre_neoplastic_0023_AAACCTGCAGACGTAG-1
# 4        BRCA1_pre_neoplastic_0023_AAACCTGCAGCTTCGG-1
# ...                                               ...
# 305219  Triple_negative_BRCA1_4031_TTTGTCAAGTGAACAT-1
# 305220  Triple_negative_BRCA1_4031_TTTGTCACATCCTTGC-1
# 305221  Triple_negative_BRCA1_4031_TTTGTCAGTCCATCCT-1
# 305222  Triple_negative_BRCA1_4031_TTTGTCATCAACGGGA-1
# 305223  Triple_negative_BRCA1_4031_TTTGTCATCATTCACT-1
#
#                             sample  cell_type  complexity cell_cycle_phase  \
# 0        BRCA1_pre_neoplastic_0023        NaN         753              NaN
# 1        BRCA1_pre_neoplastic_0023        NaN         464              NaN
# 2        BRCA1_pre_neoplastic_0023        NaN         782              NaN
# 3        BRCA1_pre_neoplastic_0023        NaN         595              NaN
# 4        BRCA1_pre_neoplastic_0023        NaN         922              NaN
# ...                            ...        ...         ...              ...
# 305219  Triple_negative_BRCA1_4031  Malignant        2303             G2/M
# 305220  Triple_negative_BRCA1_4031  Malignant        2551      Not cycling
# 305221  Triple_negative_BRCA1_4031        NaN         432              NaN
# 305222  Triple_negative_BRCA1_4031  Malignant        3758             G2/M
# 305223  Triple_negative_BRCA1_4031  Malignant        2539      Not cycling
#
#        technology  n_cells                     patient    cancer_type sex  \
# 0             10X     5932   BRCA1_pre_neoplastic_0023         Normal   F
# 1             10X     5932   BRCA1_pre_neoplastic_0023         Normal   F
# 2             10X     5932   BRCA1_pre_neoplastic_0023         Normal   F
# 3             10X     5932   BRCA1_pre_neoplastic_0023         Normal   F
# 4             10X     5932   BRCA1_pre_neoplastic_0023         Normal   F
# ...           ...      ...                         ...            ...  ..
# 305219        10X     5581  Triple_negative_BRCA1_4031  Breast Cancer   F
# 305220        10X     5581  Triple_negative_BRCA1_4031  Breast Cancer   F
# 305221        10X     5581  Triple_negative_BRCA1_4031  Breast Cancer   F
# 305222        10X     5581  Triple_negative_BRCA1_4031  Breast Cancer   F
# 305223        10X     5581  Triple_negative_BRCA1_4031  Breast Cancer   F
#
#          age  disease_extent sample_primary_met    site treated_naive category
# 0       42.0             NaN                  P     NaN           NaN   Breast
# 1       42.0             NaN                  P     NaN           NaN   Breast
# 2       42.0             NaN                  P     NaN           NaN   Breast
# 3       42.0             NaN                  P     NaN           NaN   Breast
# 4       42.0             NaN                  P     NaN           NaN   Breast
# ...      ...             ...                ...     ...           ...      ...
# 305219  25.0             NaN                  P  breast         NAIVE   Breast
# 305220  25.0             NaN                  P  breast         NAIVE   Breast
# 305221  25.0             NaN                  P  breast         NAIVE   Breast
# 305222  25.0             NaN                  P  breast         NAIVE   Breast
# 305223  25.0             NaN                  P  breast         NAIVE   Breast
#
# [305224 rows x 16 columns]

# %%
adata.obs['category'] = 'Breast'

# %%
adata.obs['study'] = 'Pal2021_Breast'

# %%
output_path = "/home/ubuntu/Downloads/Data_Breast/Data_Pal2021_Breast.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Breast/Data_Pal2021_Breast.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Breast/Data_Azizi2018_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Bassez2021_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Chung2017_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Gao2021_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Griffiths2021_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Gulati2020_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Karaayvas2018_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Kim2018_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Pal2021_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Qian2020_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Savas2018_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Wu2021_Breast.h5ad"
]

gc.collect()
# Load datasets
adatas = [sc.read(file) for file in files]

gc.collect()
# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

gc.collect()
# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

gc.collect()
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(

# %%
import scanpy as sc
import anndata
import gc
from functools import reduce

# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Breast/Data_Azizi2018_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Bassez2021_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Chung2017_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Gao2021_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Griffiths2021_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Gulati2020_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Karaayvas2018_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Kim2018_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Pal2021_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Qian2020_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Savas2018_Breast.h5ad",
    "/home/ubuntu/Downloads/Data_Breast/Data_Wu2021_Breast.h5ad"
]

# Load and clean datasets
adatas = []

for file in files:
    print(f"Reading {file}...")
    adata = sc.read(file)
    
    # Convert object columns to strings to avoid h5py write issues
    for col in adata.obs.columns:
        if adata.obs[col].dtype == 'object':
            adata.obs[col] = adata.obs[col].astype(str)
    
    adatas.append(adata)
    del adata
    gc.collect()

# Merge in pairs to avoid memory issues
def safe_merge_pairwise(adatas):
    while len(adatas) > 1:
        new_adatas = []
        for i in range(0, len(adatas), 2):
            if i + 1 < len(adatas):
                print(f"Merging dataset {i} and {i+1}...")
                merged = anndata.concat([adatas[i], adatas[i + 1]], join="outer", fill_value=0)
            else:
                merged = adatas[i]
            gc.collect()
            new_adatas.append(merged)
        adatas = new_adatas
    return adatas[0]

# Merge all datasets
print("Starting final merge...")
adata_merged = safe_merge_pairwise(adatas)
gc.collect()
# Out:
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Azizi2018_Breast.h5ad...
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Bassez2021_Breast.h5ad...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Chung2017_Breast.h5ad...
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Gao2021_Breast.h5ad...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Griffiths2021_Breast.h5ad...
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Gulati2020_Breast.h5ad...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Karaayvas2018_Breast.h5ad...
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Kim2018_Breast.h5ad...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Pal2021_Breast.h5ad...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Qian2020_Breast.h5ad...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Savas2018_Breast.h5ad...
# Reading /home/ubuntu/Downloads/Data_Breast/Data_Wu2021_Breast.h5ad...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# Starting final merge...
# Merging dataset 0 and 1...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# Merging dataset 2 and 3...
# Merging dataset 4 and 5...
# Merging dataset 6 and 7...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# Merging dataset 8 and 9...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# Merging dataset 10 and 11...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# Merging dataset 0 and 1...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# Merging dataset 2 and 3...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# Merging dataset 4 and 5...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# Merging dataset 0 and 1...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# Merging dataset 0 and 1...
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 59
#      56 gc.collect()
#      58 # Optional: Save to disk
# ---> 59 adata_merged.write("/home/ubuntu/Downloads/Data_Breast/adata_merged_all_breast.h5ad")
#      60 print("Merged dataset saved.")
#
# File ~/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1871, in AnnData.write_h5ad(self, filename, compression, compression_opts, as_dense, convert_strings_to_categoricals)
#    1868 if filename is None:
#    1869     filename = self.filename
# -> 1871 write_h5ad(
#    1872     Path(filename),
#    1873     self,
#    1874     convert_strings_to_categoricals=convert_strings_to_categoricals,
#    1875     compression=compression,
#    1876     compression_opts=compression_opts,
#    1877     as_dense=as_dense,
#    1878 )
#    1880 if self.isbacked:
#    1881     self.file.filename = filename
#
# File ~/.local/lib/python3.10/site-packages/anndata/_io/h5ad.py:79, in write_h5ad(filepath, adata, as_dense, convert_strings_to_categoricals, dataset_kwargs, **kwargs)
#      76 if adata.isbacked:  # close so that we can reopen below
#      77     adata.file.close()
# ---> 79 with h5py.File(filepath, mode) as f:
#      80     # TODO: Use spec writing system for this
#      81     # Currently can't use write_dispatched here because this function is also called to do an
#      82     # inplace update of a backed object, which would delete "/"
#      83     f = f["/"]
#      84     f.attrs.setdefault("encoding-type", "anndata")
#
# File ~/.local/lib/python3.10/site-packages/h5py/_hl/files.py:564, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     555     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     556                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     557                      alignment_threshold=alignment_threshold,
#     558                      alignment_interval=alignment_interval,
#     559                      meta_block_size=meta_block_size,
#     560                      **kwds)
#     561     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     562                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                      fs_page_size=fs_page_size)
# --> 564     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     566 if isinstance(libver, tuple):
#     567     self._libver = libver
#
# File ~/.local/lib/python3.10/site-packages/h5py/_hl/files.py:244, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     242     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     243 elif mode == 'w':
# --> 244     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     245 elif mode == 'a':
#     246     # Open in append mode (read/write).
#     247     # If that fails, create a new file only if it won't clobber an
#     248     # existing one (ACC_EXCL)
#     249     try:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:122, in h5py.h5f.create()
#
# OSError: Unable to synchronously create file (unable to truncate a file which is already open)

# %%
adata_merged
# Out:
# AnnData object with n_obs × n_vars = 877587 × 75798
#     obs: 'sample', 'patient', 'source', 'cell_type', 'cell_subtype', 'complexity', 'technology', 'n_cells', 'cancer_type', 'age', 'cell_name', 'disease_extent', 'study', 'category', 'cell_cycle_phase', 'sex', 'sample_primary_met', 'treated_naive', 'site', 'cancer_folder', 'cancer_subtype'

# %%
adata_merged.obs
# Out:
#                             sample  patient        source  cell_type  \
# s1_AAACCTGAGCAGACTG-1  BC09_TUMOR1     BC09  breast tumor     T_cell
# s1_AAACCTGAGGTCGGAT-1  BC09_TUMOR1     BC09  breast tumor     T_cell
# s1_AAACCTGAGTGTACCT-1  BC09_TUMOR1     BC09  breast tumor     T_cell
# s1_AAACCTGAGTGTACTC-1  BC09_TUMOR1     BC09  breast tumor     T_cell
# s1_AAACCTGAGTTAAGTG-1  BC09_TUMOR1     BC09  breast tumor     T_cell
# ...                            ...      ...           ...        ...
# 100059                     CID4398  CID4398           nan  Dendritic
# 100060                     CID4398  CID4398           nan  Dendritic
# 100061                     CID4398  CID4398           nan  Dendritic
# 100062                     CID4398  CID4398           nan  Dendritic
# 100063                     CID4398  CID4398           nan  Dendritic
#
#                       cell_subtype complexity technology n_cells  \
# s1_AAACCTGAGCAGACTG-1   CD8 T cell       1684        10X    6710
# s1_AAACCTGAGGTCGGAT-1   CD8 T cell       1653        10X    6710
# s1_AAACCTGAGTGTACCT-1        T-reg       1326        10X    6710
# s1_AAACCTGAGTGTACTC-1   CD8 T cell       1463        10X    6710
# s1_AAACCTGAGTTAAGTG-1   CD4 T cell       1288        10X    6710
# ...                            ...        ...        ...     ...
# 100059                         DCs       1251        10x    4451
# 100060                         DCs        719        10x    4451
# 100061                         DCs        887        10x    4451
# 100062                         DCs        870        10x    4451
# 100063                         DCs       1231        10x    4451
#
#                          cancer_type   age                 cell_name  \
# s1_AAACCTGAGCAGACTG-1  Breast Cancer    65     s1_AAACCTGAGCAGACTG-1
# s1_AAACCTGAGGTCGGAT-1  Breast Cancer    65     s1_AAACCTGAGGTCGGAT-1
# s1_AAACCTGAGTGTACCT-1  Breast Cancer    65     s1_AAACCTGAGTGTACCT-1
# s1_AAACCTGAGTGTACTC-1  Breast Cancer    65     s1_AAACCTGAGTGTACTC-1
# s1_AAACCTGAGTTAAGTG-1  Breast Cancer    65     s1_AAACCTGAGTTAAGTG-1
# ...                              ...   ...                       ...
# 100059                           IDC  52.0  CID4398_TCAGGTAGTACTCAAC
# 100060                           IDC  52.0  CID4398_TCTATTGTCGCCATAA
# 100061                           IDC  52.0  CID4398_TCTTTCCCAGTAAGCG
# 100062                           IDC  52.0  CID4398_TGCCCATGTTACGGAG
# 100063                           IDC  52.0  CID4398_TTGAACGTCCTATTCA
#
#                        disease_extent             study category  \
# s1_AAACCTGAGCAGACTG-1  non metastatic  Azizi2018_Breast   Breast
# s1_AAACCTGAGGTCGGAT-1  non metastatic  Azizi2018_Breast   Breast
# s1_AAACCTGAGTGTACCT-1  non metastatic  Azizi2018_Breast   Breast
# s1_AAACCTGAGTGTACTC-1  non metastatic  Azizi2018_Breast   Breast
# s1_AAACCTGAGTTAAGTG-1  non metastatic  Azizi2018_Breast   Breast
# ...                               ...               ...      ...
# 100059                            nan     Wu2021_Breast      nan
# 100060                            nan     Wu2021_Breast      nan
# 100061                            nan     Wu2021_Breast      nan
# 100062                            nan     Wu2021_Breast      nan
# 100063                            nan     Wu2021_Breast      nan
#
#                       cell_cycle_phase     sex sample_primary_met  \
# s1_AAACCTGAGCAGACTG-1              nan    <NA>                nan
# s1_AAACCTGAGGTCGGAT-1              nan    <NA>                nan
# s1_AAACCTGAGTGTACCT-1              nan    <NA>                nan
# s1_AAACCTGAGTGTACTC-1              nan    <NA>                nan
# s1_AAACCTGAGTTAAGTG-1              nan    <NA>                nan
# ...                                ...     ...                ...
# 100059                     Not cycling  Female                nan
# 100060                             nan  Female                nan
# 100061                             nan  Female                nan
# 100062                             nan  Female                nan
# 100063                     Not cycling  Female                nan
#
#                       treated_naive    site
# s1_AAACCTGAGCAGACTG-1           nan     nan
# s1_AAACCTGAGGTCGGAT-1           nan     nan
# s1_AAACCTGAGTGTACCT-1           nan     nan
# s1_AAACCTGAGTGTACTC-1           nan     nan
# s1_AAACCTGAGTTAAGTG-1           nan     nan
# ...                             ...     ...
# 100059                      Treated  breast
# 100060                      Treated  breast
# 100061                      Treated  breast
# 100062                      Treated  breast
# 100063                      Treated  breast
#
# [877587 rows x 19 columns]

# %%
del adata_merged.obs['cancer_folder']

# %%
del adata_merged.obs['cancer_subtype']

# %%
# Ensure all obs columns are string-safe
for col in adata_merged.obs.columns:
    try:
        # Convert to string, including categorical or object types
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)
    except Exception as e:
        print(f"Warning: Failed to convert column {col} to string. Error: {e}")
        adata_merged.obs.drop(columns=[col], inplace=True)

# %%
# Optional: Save to disk
adata_merged.write("/home/ubuntu/Downloads/Data_Breast/Breast_Combined.h5ad")
print("Merged dataset saved.")
# Out:
# Merged dataset saved.

# %%
adata_merged.obs['study'].value_counts()
# Out:
# study
# Pal2021_Breast          305224
# Bassez2021_Breast       226635
# Griffiths2021_Breast    111372
# Wu2021_Breast           100064
# Azizi2018_Breast         75029
# Gao2021_Breast           29992
# Qian2020_Breast          16537
# Savas2018_Breast          6311
# Kim2018_Breast            2472
# Gulati2020_Breast         1902
# Karaayvas2018_Breast      1534
# Chung2017_Breast           515
# Name: count, dtype: int64
