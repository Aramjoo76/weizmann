# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc

# %% [markdown]
# ## Kidney

# %% [markdown]
# #### 1. Bi2021

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Bi2021_Kidney"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 34326 × 32718
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'gender', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive', 'study', 'category'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'treatment_exposure', 'treatment_response', 'cell_lineage',
            'smoking_status', 'PY', 'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['source'].value_counts()
# Out:
# source
# kidney        22879
# abdomen        4637
# lung           3744
# lymph node     3066
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                    cell_name sample cell_type         cell_subtype  \
# 0       AAACCTGAGAATAGGG.p55    P55    T_cell  41BB-Hi CD8+ T cell
# 1       AAACCTGAGGCTAGGT.p55    P55    T_cell  41BB-Hi CD8+ T cell
# 2       AAACCTGCACTGTGTA.p55    P55    T_cell  41BB-Hi CD8+ T cell
# 3       AAACCTGCAGTCCTTC.p55    P55    T_cell    MitoHigh T-Helper
# 4       AAACCTGGTAAATGTG.p55    P55    T_cell  41BB-Lo CD8+ T cell
# ...                      ...    ...       ...                  ...
# 34321  TTGGAACGTGAGGGAG.p916   P916    T_cell    Effector T-Helper
# 34322  TTGTAGGGTATGAAAC.p916   P916    T_cell  41BB-Lo CD8+ T cell
# 34323  TTTACTGCACACATGT.p916   P916    T_cell  41BB-Hi CD8+ T cell
# 34324  TTTGTCAAGAGCAATT.p916   P916    T_cell    Effector T-Helper
# 34325  TTTGTCAAGCGTTTAC.p916   P916    T_cell  41BB-Lo CD8+ T cell
#
#        complexity cell_cycle_phase      source technology  n_cells patient  \
# 0             768              NaN     abdomen        10x     4637     P55
# 1             864              NaN     abdomen        10x     4637     P55
# 2             982              NaN     abdomen        10x     4637     P55
# 3             367              NaN     abdomen        10x     4637     P55
# 4            1185      Not cycling     abdomen        10x     4637     P55
# ...           ...              ...         ...        ...      ...     ...
# 34321         893              NaN  lymph node        10x      316    P916
# 34322        2280      Not cycling  lymph node        10x      316    P916
# 34323        1961      Not cycling  lymph node        10x      316    P916
# 34324        1363      Not cycling  lymph node        10x      316    P916
# 34325        1651      Not cycling  lymph node        10x      316    P916
#
#                            cancer_type sex  age disease_extent  \
# 0      Clear Cell Renal Cell Carcinoma   M   57     metastatic
# 1      Clear Cell Renal Cell Carcinoma   M   57     metastatic
# 2      Clear Cell Renal Cell Carcinoma   M   57     metastatic
# 3      Clear Cell Renal Cell Carcinoma   M   57     metastatic
# 4      Clear Cell Renal Cell Carcinoma   M   57     metastatic
# ...                                ...  ..  ...            ...
# 34321  Clear Cell Renal Cell Carcinoma   M   61     metastatic
# 34322  Clear Cell Renal Cell Carcinoma   M   61     metastatic
# 34323  Clear Cell Renal Cell Carcinoma   M   61     metastatic
# 34324  Clear Cell Renal Cell Carcinoma   M   61     metastatic
# 34325  Clear Cell Renal Cell Carcinoma   M   61     metastatic
#
#       sample_primary_met            site treated_naive               study  \
# 0                    met  Abdominal Mass       treated  Data_Bi2021_Kidney
# 1                    met  Abdominal Mass       treated  Data_Bi2021_Kidney
# 2                    met  Abdominal Mass       treated  Data_Bi2021_Kidney
# 3                    met  Abdominal Mass       treated  Data_Bi2021_Kidney
# 4                    met  Abdominal Mass       treated  Data_Bi2021_Kidney
# ...                  ...             ...           ...                 ...
# 34321                met      Lymph node         naive  Data_Bi2021_Kidney
# 34322                met      Lymph node         naive  Data_Bi2021_Kidney
# 34323                met      Lymph node         naive  Data_Bi2021_Kidney
# 34324                met      Lymph node         naive  Data_Bi2021_Kidney
# 34325                met      Lymph node         naive  Data_Bi2021_Kidney
#
#       category
# 0       Kidney
# 1       Kidney
# 2       Kidney
# 3       Kidney
# 4       Kidney
# ...        ...
# 34321   Kidney
# 34322   Kidney
# 34323   Kidney
# 34324   Kidney
# 34325   Kidney
#
# [34326 rows x 19 columns]

# %%
del adata.obs['disease']

# %%
del adata.obs['sample_type']

# %%
del adata.obs['gender']

# %%
adata.obs['study'] = 'Data_Bi2021_Kidney'

# %%
adata.obs['category'] = 'Kidney'

# %%
output_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Bi2021_Kidney.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Kidney/Data_Bi2021_Kidney.h5ad

# %% [markdown]
# #### 2.Sharma2020

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Krishna2021_Kidney"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 167283 × 15588
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'site', 'source', 'treated_naive', 'cancer_type', 'technology', 'n_cells', 'age', 'sex', 'disease_extent', 'sample_primary_met', 'study', 'category'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'cluster', 'patient_y', 'source_y', 'type_y', 'treatment_y'    
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['treated_naive'].value_counts()
# Out:
# treated_naive
# Ipi/Nivo mixed response       38660
# Ipi/Nivo resistant            35427
# Nivo-exposed                  30547
# Untreated 1                   26177
# Ipi/Nivo complete response    23259
# Untreated 2                   13213
# Name: count, dtype: int64

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"type_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "site"})

# %%
adata.obs = adata.obs.rename(columns={"treatment_x": "treated_naive"})

# %%
adata.obs
# Out:
#                             cell_name      sample patient cell_type  \
# 0       AAACCTGAGCGTTGCC_1_UT1_Center  UT1_Center     UT1    T_cell
# 1       AAACCTGAGCTGCCCA_1_UT1_Center  UT1_Center     UT1    T_cell
# 2       AAACCTGAGTGGACGT_1_UT1_Center  UT1_Center     UT1    T_cell
# 3       AAACCTGCAGGTCGTC_1_UT1_Center  UT1_Center     UT1   NK_cell
# 4       AAACCTGCAGGTCTCG_1_UT1_Center  UT1_Center     UT1    T_cell
# ...                               ...         ...     ...       ...
# 167278     TTTGTCATCCATGAAC_1_t4_PBMC     t4_PBMC      t4    T_cell
# 167279     TTTGTCATCGCGGATC_1_t4_PBMC     t4_PBMC      t4   NK_cell
# 167280     TTTGTCATCTCAAACG_1_t4_PBMC     t4_PBMC      t4    T_cell
# 167281     TTTGTCATCTGTCTCG_1_t4_PBMC     t4_PBMC      t4   NK_cell
# 167282     TTTGTCATCTGTTGAG_1_t4_PBMC     t4_PBMC      t4    T_cell
#
#                  cell_subtype  complexity cell_cycle_phase    site source  \
# 0               CD8A+ NK-like        1513      Not cycling  Center  Tumor
# 1         CD8A+ Proliferating        1652      Not cycling  Center  Tumor
# 2         CD8A+ Exhausted IEG        1356      Not cycling  Center  Tumor
# 3             Conventional NK        1016      Not cycling  Center  Tumor
# 4       CD8A+ Tissue-resident         902              NaN  Center  Tumor
# ...                       ...         ...              ...     ...    ...
# 167278             CD4+ Naive         582              NaN    PBMC   PBMC
# 167279        Conventional NK         622              NaN    PBMC   PBMC
# 167280             CD4+ Naive         641              NaN    PBMC   PBMC
# 167281        Conventional NK         495              NaN    PBMC   PBMC
# 167282          CD8A+ NK-like         472              NaN    PBMC   PBMC
#
#                      treated_naive                      cancer_type  \
# 0                      Untreated 1  Clear Cell Renal Cell Carcinoma
# 1                      Untreated 1  Clear Cell Renal Cell Carcinoma
# 2                      Untreated 1  Clear Cell Renal Cell Carcinoma
# 3                      Untreated 1  Clear Cell Renal Cell Carcinoma
# 4                      Untreated 1  Clear Cell Renal Cell Carcinoma
# ...                            ...                              ...
# 167278  Ipi/Nivo complete response  Clear Cell Renal Cell Carcinoma
# 167279  Ipi/Nivo complete response  Clear Cell Renal Cell Carcinoma
# 167280  Ipi/Nivo complete response  Clear Cell Renal Cell Carcinoma
# 167281  Ipi/Nivo complete response  Clear Cell Renal Cell Carcinoma
# 167282  Ipi/Nivo complete response  Clear Cell Renal Cell Carcinoma
#
#        technology  n_cells  age  sex disease_extent sample_primary_met  \
# 0             10x     5545  NaN  NaN            NaN                NaN
# 1             10x     5545  NaN  NaN            NaN                NaN
# 2             10x     5545  NaN  NaN            NaN                NaN
# 3             10x     5545  NaN  NaN            NaN                NaN
# 4             10x     5545  NaN  NaN            NaN                NaN
# ...           ...      ...  ...  ...            ...                ...
# 167278        10x    10860  NaN  NaN            NaN                NaN
# 167279        10x    10860  NaN  NaN            NaN                NaN
# 167280        10x    10860  NaN  NaN            NaN                NaN
# 167281        10x    10860  NaN  NaN            NaN                NaN
# 167282        10x    10860  NaN  NaN            NaN                NaN
#
#                           study category
# 0       Data_Krishna2021_Kidney   Kidney
# 1       Data_Krishna2021_Kidney   Kidney
# 2       Data_Krishna2021_Kidney   Kidney
# 3       Data_Krishna2021_Kidney   Kidney
# 4       Data_Krishna2021_Kidney   Kidney
# ...                         ...      ...
# 167278  Data_Krishna2021_Kidney   Kidney
# 167279  Data_Krishna2021_Kidney   Kidney
# 167280  Data_Krishna2021_Kidney   Kidney
# 167281  Data_Krishna2021_Kidney   Kidney
# 167282  Data_Krishna2021_Kidney   Kidney
#
# [167283 rows x 19 columns]

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['study'] = 'Data_Krishna2021_Kidney'

# %%
adata.obs['category'] = 'Kidney'

# %%
output_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Krishna2021_Kidney.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Kidney/Data_Krishna2021_Kidney.h5ad

# %% [markdown]
# #### 3.Obradovic2021

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Obradovic2021_Kidney"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 19781 × 19234
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'source', 'clusters_by_authors', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['site'].value_counts()
# Out:
# site
# kidney     18348
# kidney      1433
# Name: count, dtype: int64

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['category'] = 'Kidney'

# %%
adata.obs['study'] = 'Data_Obradovic2021_Kidney'

# %%
del adata.obs['clusters_by_authors']

# %%
adata.obs
# Out:
#                       cell_name    sample    cell_type  complexity  \
# 0      AAACCTGGTAGCACGA_2_1_1_1  Patient1  Endothelial        2988
# 1      AAACGGGCACCTCGGA_2_1_1_1  Patient1    Malignant         746
# 2      AAAGCAAGTGTTAAGA_2_1_1_1  Patient1  Endothelial        1767
# 3      AAAGTAGGTCCCTTGT_2_1_1_1  Patient1    Malignant        1481
# 4      AAAGTAGGTCTCTTAT_2_1_1_1  Patient1   Fibroblast        1772
# ...                         ...       ...          ...         ...
# 19776     TTTCGATGTAGTCCTA_13_1  Patient8  Endothelial        1582
# 19777     TTTCGATTCCTTCTAA_13_1  Patient8  Endothelial        2245
# 19778     TTTGGAGAGCCGCACT_13_1  Patient8  Endothelial        2122
# 19779     TTTGTTGAGTGGGAAA_13_1  Patient8  Endothelial        2702
# 19780     TTTGTTGTCGGTCAGC_13_1  Patient8  Endothelial        1765
#
#       cell_cycle_phase  source technology  n_cells   patient  \
# 0          Not cycling   Tumor        10x      957  Patient1
# 1                  NaN   Tumor        10x      957  Patient1
# 2          Not cycling   Tumor        10x      957  Patient1
# 3          Not cycling   Tumor        10x      957  Patient1
# 4          Not cycling   Tumor        10x      957  Patient1
# ...                ...     ...        ...      ...       ...
# 19776      Not cycling  Normal        10x     1433  Patient8
# 19777      Not cycling  Normal        10x     1433  Patient8
# 19778      Not cycling  Normal        10x     1433  Patient8
# 19779      Not cycling  Normal        10x     1433  Patient8
# 19780      Not cycling  Normal        10x     1433  Patient8
#
#                            cancer_type  sex  age disease_extent  \
# 0      Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# 1      Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# 2      Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# 3      Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# 4      Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# ...                                ...  ...  ...            ...
# 19776  Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# 19777  Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# 19778  Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# 19779  Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
# 19780  Clear Cell Renal Cell Carcinoma  NaN  NaN            NaN
#
#       sample_primary_met     site treated_naive cell_subtype category  \
# 0                primary   kidney         naive          NaN   Kidney
# 1                primary   kidney         naive          NaN   Kidney
# 2                primary   kidney         naive          NaN   Kidney
# 3                primary   kidney         naive          NaN   Kidney
# 4                primary   kidney         naive          NaN   Kidney
# ...                  ...      ...           ...          ...      ...
# 19776            primary  kidney          naive          NaN   Kidney
# 19777            primary  kidney          naive          NaN   Kidney
# 19778            primary  kidney          naive          NaN   Kidney
# 19779            primary  kidney          naive          NaN   Kidney
# 19780            primary  kidney          naive          NaN   Kidney
#
#                            study
# 0      Data_Obradovic2021_Kidney
# 1      Data_Obradovic2021_Kidney
# 2      Data_Obradovic2021_Kidney
# 3      Data_Obradovic2021_Kidney
# 4      Data_Obradovic2021_Kidney
# ...                          ...
# 19776  Data_Obradovic2021_Kidney
# 19777  Data_Obradovic2021_Kidney
# 19778  Data_Obradovic2021_Kidney
# 19779  Data_Obradovic2021_Kidney
# 19780  Data_Obradovic2021_Kidney
#
# [19781 rows x 19 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Obradovic2021_Kidney.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Kidney/Data_Obradovic2021_Kidney.h5ad

# %% [markdown]
# #### 4. Young2018

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Young2018_Kidney"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 125139 × 33694
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'is_tumor', 'cell_compartment', 'cluster_assignment', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive', 'source'

# %%
adata.obs['source'].value_counts()
# Out:
# source
# Indistinct    52638
# normal        48347
# tumor         24154
# Name: count, dtype: int64

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'cell_QCpass', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['source'] = adata.obs['is_tumor'].map({
    'NO': 'normal',
    'YES': 'tumor',
    'Indistinct': 'Indistinct'
})

# %%
del adata.obs['is_tumor']

# %%
del adata.obs['cell_compartment']

# %%
del adata.obs['cluster_assignment']

# %%
adata.obs
# Out:
#                                  cell_name                  sample  \
# 0       4602STDY7018923___AAACGGGGTCCAACTA  Wilms3_Kid_N_C_ldc_1_1
# 1       4602STDY7018923___AAAGATGAGGAGTACC  Wilms3_Kid_N_C_ldc_1_1
# 2       4602STDY7018923___AAAGATGGTGAACCTT  Wilms3_Kid_N_C_ldc_1_1
# 3       4602STDY7018923___AAAGTAGTCCCTTGTG  Wilms3_Kid_N_C_ldc_1_1
# 4       4602STDY7018923___AAATGCCCAGTAAGAT  Wilms3_Kid_N_C_ldc_1_1
# ...                                    ...                     ...
# 125134  4834STDY7002886___TCTCTAAGTGGACGAT       F17_Kid_N_neg_1_1
# 125135  4834STDY7002886___TTCTTAGAGTTTGCGT       F17_Kid_N_neg_1_1
# 125136  4834STDY7002886___TTGGCAATCAACACGT       F17_Kid_N_neg_1_1
# 125137  4834STDY7002886___TTTATGCGTAACGCGA       F17_Kid_N_neg_1_1
# 125138  4834STDY7002886___TTTATGCTCAAACAAG       F17_Kid_N_neg_1_1
#
#           cell_type        cell_subtype  complexity cell_cycle_phase  \
# 0        Epithelial  Nephron_epithelium         346              NaN
# 1       Endothelial         Endothelium        1376      Not cycling
# 2        Epithelial  Nephron_epithelium         238              NaN
# 3        Epithelial  Nephron_epithelium        3048      Not cycling
# 4        Epithelial  Nephron_epithelium        2032      Not cycling
# ...             ...                 ...         ...              ...
# 125134          NaN                 NaN         172              NaN
# 125135          NaN                 NaN         151              NaN
# 125136          NaN                 NaN         198              NaN
# 125137          NaN                 NaN        2175              NaN
# 125138          NaN                 NaN         748              NaN
#
#        technology  n_cells patient  cancer_type  sex               age  \
# 0             10x     6595  Wilms3  Wilms Tumor  NaN  2 years 6 months
# 1             10x     6595  Wilms3  Wilms Tumor  NaN  2 years 6 months
# 2             10x     6595  Wilms3  Wilms Tumor  NaN  2 years 6 months
# 3             10x     6595  Wilms3  Wilms Tumor  NaN  2 years 6 months
# 4             10x     6595  Wilms3  Wilms Tumor  NaN  2 years 6 months
# ...           ...      ...     ...          ...  ...               ...
# 125134        10x     1732     NaN       Normal  NaN               NaN
# 125135        10x     1732     NaN       Normal  NaN               NaN
# 125136        10x     1732     NaN       Normal  NaN               NaN
# 125137        10x     1732     NaN       Normal  NaN               NaN
# 125138        10x     1732     NaN       Normal  NaN               NaN
#
#         disease_extent sample_primary_met    site  treated_naive      source  \
# 0                  NaN           primary   kidney            NaN      normal
# 1                  NaN           primary   kidney            NaN      normal
# 2                  NaN           primary   kidney            NaN      normal
# 3                  NaN           primary   kidney            NaN      normal
# 4                  NaN           primary   kidney            NaN      normal
# ...                ...                ...     ...            ...         ...
# 125134             NaN                NaN     NaN            NaN  Indistinct
# 125135             NaN                NaN     NaN            NaN  Indistinct
# 125136             NaN                NaN     NaN            NaN  Indistinct
# 125137             NaN                NaN     NaN            NaN  Indistinct
# 125138             NaN                NaN     NaN            NaN  Indistinct
#
#        category                  study
# 0        Kidney  Data_Young2018_Kidney
# 1        Kidney  Data_Young2018_Kidney
# 2        Kidney  Data_Young2018_Kidney
# 3        Kidney  Data_Young2018_Kidney
# 4        Kidney  Data_Young2018_Kidney
# ...         ...                    ...
# 125134   Kidney  Data_Young2018_Kidney
# 125135   Kidney  Data_Young2018_Kidney
# 125136   Kidney  Data_Young2018_Kidney
# 125137   Kidney  Data_Young2018_Kidney
# 125138   Kidney  Data_Young2018_Kidney
#
# [125139 rows x 19 columns]

# %%
adata.obs['category'] = 'Kidney'

# %%
adata.obs['study'] = 'Data_Young2018_Kidney'

# %%
output_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Young2018_Kidney.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Kidney/Data_Young2018_Kidney.h5ad

# %% [markdown]
# #### 5.Zhang202

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Zhang2021_Kidney"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
gc.collect()
# Out:
# 28

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 29474 × 33694
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'disease', 'patient_y', 'n_cells', 'technology', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'additional_tumor_characterisics', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS', 'source'

# %%
adata.obs['source'].value_counts()
# Out:
# source
# tumor     23328
# normal     6146
# Name: count, dtype: int64

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'patient_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                          cell_name    sample  patient    cell_type  \
# 0      SI_18854_AAACCTGCAAGTAGTA-1  SI_18854  SS_2005    Malignant
# 1      SI_18854_AAACCTGTCCACTGGG-1  SI_18854  SS_2005    Malignant
# 2      SI_18854_AAACCTGTCCTTTCTC-1  SI_18854  SS_2005    Malignant
# 3      SI_18854_AAACGGGCAAACTGCT-1  SI_18854  SS_2005   Macrophage
# 4      SI_18854_AAACGGGCAAGGTTTC-1  SI_18854  SS_2005    Malignant
# ...                            ...       ...      ...          ...
# 29469  SI_23843_TTTGTCAAGTTGTCGT-1  SI_23843  SS_2026  Endothelial
# 29470  SI_23843_TTTGTCACAAGTCTAC-1  SI_23843  SS_2026   Macrophage
# 29471  SI_23843_TTTGTCAGTTCCGTCT-1  SI_23843  SS_2026  Endothelial
# 29472  SI_23843_TTTGTCATCTCTTATG-1  SI_23843  SS_2026    Malignant
# 29473  SI_23843_TTTGTCATCTTCATGT-1  SI_23843  SS_2026   Macrophage
#
#       cell_subtype  complexity cell_cycle_phase  n_cells technology  \
# 0        Malignant        3255      Not cycling     1665        10x
# 1        Malignant        3807             G1/S     1665        10x
# 2        Malignant        2770      Not cycling     1665        10x
# 3       Macrophage        2185      Not cycling     1665        10x
# 4        Malignant        2741      Not cycling     1665        10x
# ...            ...         ...              ...      ...        ...
# 29469   Endo_ACKR1        1355      Not cycling     3551        10x
# 29470   Macrophage        2326      Not cycling     3551        10x
# 29471   Endo_PLVAP        1603      Not cycling     3551        10x
# 29472    Malignant        3070      Not cycling     3551        10x
# 29473   Macrophage        2157      Not cycling     3551        10x
#
#                            cancer_type   sex  age  disease_extent  \
# 0      Clear Cell Renal Cell Carcinoma  Male   71             NaN
# 1      Clear Cell Renal Cell Carcinoma  Male   71             NaN
# 2      Clear Cell Renal Cell Carcinoma  Male   71             NaN
# 3      Clear Cell Renal Cell Carcinoma  Male   71             NaN
# 4      Clear Cell Renal Cell Carcinoma  Male   71             NaN
# ...                                ...   ...  ...             ...
# 29469  Clear Cell Renal Cell Carcinoma  Male   71             NaN
# 29470  Clear Cell Renal Cell Carcinoma  Male   71             NaN
# 29471  Clear Cell Renal Cell Carcinoma  Male   71             NaN
# 29472  Clear Cell Renal Cell Carcinoma  Male   71             NaN
# 29473  Clear Cell Renal Cell Carcinoma  Male   71             NaN
#
#       sample_primary_met  site  treated_naive source                  study  \
# 0                primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# 1                primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# 2                primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# 3                primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# 4                primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# ...                  ...   ...            ...    ...                    ...
# 29469            primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# 29470            primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# 29471            primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# 29472            primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
# 29473            primary   NaN            NaN  tumor  Data_Zhang2021_Kidney
#
#       category
# 0       Kidney
# 1       Kidney
# 2       Kidney
# 3       Kidney
# 4       Kidney
# ...        ...
# 29469   Kidney
# 29470   Kidney
# 29471   Kidney
# 29472   Kidney
# 29473   Kidney
#
# [29474 rows x 19 columns]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
del adata.obs['disease']

# %%
del adata.obs['additional_tumor_characterisics']

# %%
adata.obs['study'] = 'Data_Zhang2021_Kidney'

# %%
adata.obs['category'] = 'Kidney'

# %%
output_path = "/home/ubuntu/Downloads/Data_Kidney/Data_Zhang2021_Kidney.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Kidney/Data_Zhang2021_Kidney.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Kidney/Data_Bi2021_Kidney.h5ad",
    "/home/ubuntu/Downloads/Data_Kidney/Data_Krishna2021_Kidney.h5ad",
    "/home/ubuntu/Downloads/Data_Kidney/Data_Obradovic2021_Kidney.h5ad",
    "/home/ubuntu/Downloads/Data_Kidney/Data_Young2018_Kidney.h5ad",
    "/home/ubuntu/Downloads/Data_Kidney/Data_Zhang2021_Kidney.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Kidney/Kidney_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Kidney/Kidney_Combined.h5ad
