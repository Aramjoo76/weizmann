# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc

# %% [markdown]
# ## Brain

# %% [markdown]
# #### 1. Choudhury2022_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Choudhury2022_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 58843 × 33538
#     obs: 'cell_name', 'sample', 'patient_x', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source_x', 'cancer_type', 'technology', 'n_cells', 'age'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'patient_y', 'source_y',         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['source_y'].value_counts()
# Out:
# source_y
# Meningioma                          35405
# Meningioma brain-tumor interface    21739
# Dura                                 1699
# Name: count, dtype: int64

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs
# Out:
#                        cell_name    sample  patient    cell_type  \
# 0          MSC1_AAACCCACAATATCCG      MSC1        1    Malignant
# 1          MSC1_AAACCCACATCTTAGG      MSC1        1    Malignant
# 2          MSC1_AAACGAACAACCTATG      MSC1        1    Malignant
# 3          MSC1_AAACGAACACCGCTAG      MSC1        1    Malignant
# 4          MSC1_AAACGCTCATCTCATT      MSC1        1     Monocyte
# ...                          ...       ...      ...          ...
# 58838  MSC6-BTI_TTTGTTGTCAAGGTGG  MSC6-BTI        6    Malignant
# 58839  MSC6-BTI_TTTGTTGTCGACATAC  MSC6-BTI        6    Malignant
# 58840  MSC6-BTI_TTTGTTGTCTCAATCT  MSC6-BTI        6     Monocyte
# 58841  MSC6-BTI_TTTGTTGTCTGCTTAT  MSC6-BTI        6    Malignant
# 58842  MSC6-BTI_TTTGTTGTCTGGGATT  MSC6-BTI        6  Endothelial
#
#                                cell_subtype  complexity cell_cycle_phase  \
# 0                          Meningioma cells         952              NaN
# 1                          Meningioma cells         940              NaN
# 2                 G1 phase meningioma cells        7134      Not cycling
# 3           ECM remodeling meningioma cells        3521      Not cycling
# 4                           CD163 monocytes        1855      Not cycling
# ...                                     ...         ...              ...
# 58838  Cycling G2M phase meningioma cells 1         899              NaN
# 58839  Cycling G2M phase meningioma cells 1        4827             G2/M
# 58840                      Active monocytes        2009      Not cycling
# 58841      Cycling S phase meningioma cells        1881      Not cycling
# 58842                        Vascular cells         835              NaN
#
#                                  source cancer_type technology  n_cells   age  \
# 0                            Meningioma  Meningioma        10x     2538  44.3
# 1                            Meningioma  Meningioma        10x     2538  44.3
# 2                            Meningioma  Meningioma        10x     2538  44.3
# 3                            Meningioma  Meningioma        10x     2538  44.3
# 4                            Meningioma  Meningioma        10x     2538  44.3
# ...                                 ...         ...        ...      ...   ...
# 58838  Meningioma brain-tumor interface  Meningioma        10x    13171  71.0
# 58839  Meningioma brain-tumor interface  Meningioma        10x    13171  71.0
# 58840  Meningioma brain-tumor interface  Meningioma        10x    13171  71.0
# 58841  Meningioma brain-tumor interface  Meningioma        10x    13171  71.0
# 58842  Meningioma brain-tumor interface  Meningioma        10x    13171  71.0
#
#       disease_extent  sex sample_primary_met treated_naive   site  \
# 0                NaN  NaN                NaN           NaN  brain
# 1                NaN  NaN                NaN           NaN  brain
# 2                NaN  NaN                NaN           NaN  brain
# 3                NaN  NaN                NaN           NaN  brain
# 4                NaN  NaN                NaN           NaN  brain
# ...              ...  ...                ...           ...    ...
# 58838            NaN  NaN                NaN           NaN  brain
# 58839            NaN  NaN                NaN           NaN  brain
# 58840            NaN  NaN                NaN           NaN  brain
# 58841            NaN  NaN                NaN           NaN  brain
# 58842            NaN  NaN                NaN           NaN  brain
#
#                      study category
# 0      Choudhury2022_Brain    Brain
# 1      Choudhury2022_Brain    Brain
# 2      Choudhury2022_Brain    Brain
# 3      Choudhury2022_Brain    Brain
# 4      Choudhury2022_Brain    Brain
# ...                    ...      ...
# 58838  Choudhury2022_Brain    Brain
# 58839  Choudhury2022_Brain    Brain
# 58840  Choudhury2022_Brain    Brain
# 58841  Choudhury2022_Brain    Brain
# 58842  Choudhury2022_Brain    Brain
#
# [58843 rows x 19 columns]

# %%
adata.obs['disease_extent'] = 'NaN'

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['site'] = 'brain'

# %%
adata.obs['study'] = 'Choudhury2022_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Choudhury2022_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Choudhury2022_Brain.h5ad

# %% [markdown]
# #### 2.Couturier2020_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Couturier2020_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 100335 × 33694
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['treated_naive'].value_counts()
# Out:
# treated_naive
# naive    64012
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#                  cell_name        sample  cell_type cell_cycle_phase  \
# 0       AAACCTGAGAAGGTTT-1         BT322        NaN              NaN
# 1       AAACCTGAGAGACTTA-1  HFA571_cd133        NaN              NaN
# 2       AAACCTGAGCGTTGCC-1         BT322        NaN              NaN
# 3       AAACCTGCAACACCTA-1    BT363_1of2  Malignant      Not cycling
# 4       AAACCTGGTAAGTGGC-1         BT322        NaN              NaN
# ...                    ...           ...        ...              ...
# 100330  TTTGGTTCACAAGACG-1    NSC1_cd133        NaN              NaN
# 100331  TTTGGTTCAGCTCGCA-1    NSC1_cd133        NaN              NaN
# 100332  TTTGTCAAGCTAGCCC-1    NSC1_cd133        NaN              NaN
# 100333  TTTGTCACATGAAGTA-1    NSC1_cd133        NaN              NaN
# 100334  TTTGTCAGTTCCGTCT-1    NSC1_cd133        NaN              NaN
#
#        technology  n_cells patient   cancer_type  sex  age disease_extent  \
# 0             10x     3066   BT322  Glioblastoma  NaN  NaN          local
# 1             10x     7716     NaN        Normal  NaN  NaN            NaN
# 2             10x     3066   BT322  Glioblastoma  NaN  NaN          local
# 3             10x     3882   BT363  Glioblastoma  NaN  NaN          local
# 4             10x     3066   BT322  Glioblastoma  NaN  NaN          local
# ...           ...      ...     ...           ...  ...  ...            ...
# 100330        10x     1717     NaN        Normal  NaN  NaN            NaN
# 100331        10x     1717     NaN        Normal  NaN  NaN            NaN
# 100332        10x     1717     NaN        Normal  NaN  NaN            NaN
# 100333        10x     1717     NaN        Normal  NaN  NaN            NaN
# 100334        10x     1717     NaN        Normal  NaN  NaN            NaN
#
#        sample_primary_met            site treated_naive cell_subtype  \
# 0                 primary  Right temporal         naive          NaN
# 1                     NaN             NaN           NaN          NaN
# 2                 primary  Right temporal         naive          NaN
# 3                 primary    Left frontal         naive          NaN
# 4                 primary  Right temporal         naive          NaN
# ...                   ...             ...           ...          ...
# 100330                NaN             NaN           NaN          NaN
# 100331                NaN             NaN           NaN          NaN
# 100332                NaN             NaN           NaN          NaN
# 100333                NaN             NaN           NaN          NaN
# 100334                NaN             NaN           NaN          NaN
#
#        complexity category source                study
# 0             NaN    Brain    NaN  Couturier2020_Brain
# 1             NaN    Brain    NaN  Couturier2020_Brain
# 2             NaN    Brain    NaN  Couturier2020_Brain
# 3             NaN    Brain    NaN  Couturier2020_Brain
# 4             NaN    Brain    NaN  Couturier2020_Brain
# ...           ...      ...    ...                  ...
# 100330        NaN    Brain    NaN  Couturier2020_Brain
# 100331        NaN    Brain    NaN  Couturier2020_Brain
# 100332        NaN    Brain    NaN  Couturier2020_Brain
# 100333        NaN    Brain    NaN  Couturier2020_Brain
# 100334        NaN    Brain    NaN  Couturier2020_Brain
#
# [100335 rows x 19 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['complexity'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['category'] = 'Brain'

# %%
adata.obs['study'] = 'Couturier2020_Brain'

# %%
adata.obs
# Out:
#                  cell_name        sample  cell_type cell_cycle_phase  \
# 0       AAACCTGAGAAGGTTT-1         BT322        NaN              NaN
# 1       AAACCTGAGAGACTTA-1  HFA571_cd133        NaN              NaN
# 2       AAACCTGAGCGTTGCC-1         BT322        NaN              NaN
# 3       AAACCTGCAACACCTA-1    BT363_1of2  Malignant      Not cycling
# 4       AAACCTGGTAAGTGGC-1         BT322        NaN              NaN
# ...                    ...           ...        ...              ...
# 100330  TTTGGTTCACAAGACG-1    NSC1_cd133        NaN              NaN
# 100331  TTTGGTTCAGCTCGCA-1    NSC1_cd133        NaN              NaN
# 100332  TTTGTCAAGCTAGCCC-1    NSC1_cd133        NaN              NaN
# 100333  TTTGTCACATGAAGTA-1    NSC1_cd133        NaN              NaN
# 100334  TTTGTCAGTTCCGTCT-1    NSC1_cd133        NaN              NaN
#
#        technology  n_cells patient   cancer_type  sex  age disease_extent  \
# 0             10x     3066   BT322  Glioblastoma  NaN  NaN          local
# 1             10x     7716     NaN        Normal  NaN  NaN            NaN
# 2             10x     3066   BT322  Glioblastoma  NaN  NaN          local
# 3             10x     3882   BT363  Glioblastoma  NaN  NaN          local
# 4             10x     3066   BT322  Glioblastoma  NaN  NaN          local
# ...           ...      ...     ...           ...  ...  ...            ...
# 100330        10x     1717     NaN        Normal  NaN  NaN            NaN
# 100331        10x     1717     NaN        Normal  NaN  NaN            NaN
# 100332        10x     1717     NaN        Normal  NaN  NaN            NaN
# 100333        10x     1717     NaN        Normal  NaN  NaN            NaN
# 100334        10x     1717     NaN        Normal  NaN  NaN            NaN
#
#        sample_primary_met            site treated_naive cell_subtype  \
# 0                 primary  Right temporal         naive          NaN
# 1                     NaN             NaN           NaN          NaN
# 2                 primary  Right temporal         naive          NaN
# 3                 primary    Left frontal         naive          NaN
# 4                 primary  Right temporal         naive          NaN
# ...                   ...             ...           ...          ...
# 100330                NaN             NaN           NaN          NaN
# 100331                NaN             NaN           NaN          NaN
# 100332                NaN             NaN           NaN          NaN
# 100333                NaN             NaN           NaN          NaN
# 100334                NaN             NaN           NaN          NaN
#
#        complexity category source                study
# 0             NaN    Brain    NaN  Couturier2020_Brain
# 1             NaN    Brain    NaN  Couturier2020_Brain
# 2             NaN    Brain    NaN  Couturier2020_Brain
# 3             NaN    Brain    NaN  Couturier2020_Brain
# 4             NaN    Brain    NaN  Couturier2020_Brain
# ...           ...      ...    ...                  ...
# 100330        NaN    Brain    NaN  Couturier2020_Brain
# 100331        NaN    Brain    NaN  Couturier2020_Brain
# 100332        NaN    Brain    NaN  Couturier2020_Brain
# 100333        NaN    Brain    NaN  Couturier2020_Brain
# 100334        NaN    Brain    NaN  Couturier2020_Brain
#
# [100335 rows x 19 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Couturier2020_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Couturier2020_Brain.h5ad

# %% [markdown]
# #### 3. Darmanis2017_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Darmanis2017_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "normalized_Exp_data_TPM.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3589 × 23368
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'source', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
adata.obs['source'].value_counts()
# Out:
# source
# Tumor        2343
# Periphery    1189
# Distant        57
# Name: count, dtype: int64

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'cell_QCpass', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#           cell_name sample        cell_type  complexity cell_cycle_phase  \
# 0     1001000173.G8  BT_S2        Malignant        2145      Not cycling
# 1     1001000173.D4  BT_S2  Oligodendrocyte        1037      Not cycling
# 2     1001000173.B4  BT_S2        Malignant        5829      Not cycling
# 3     1001000173.A2  BT_S2        Malignant        4066      Not cycling
# 4     1001000173.E2  BT_S2        Malignant        2310      Not cycling
# ...             ...    ...              ...         ...              ...
# 3584  1001000271.F1  BT_S6         Vascular         681              NaN
# 3585  1001000271.D4  BT_S6          Myeloid        2247      Not cycling
# 3586  1001000271.C1  BT_S6         Vascular        4099      Not cycling
# 3587  1001000271.H7  BT_S6         Vascular         700              NaN
# 3588  1001000271.H2  BT_S6         Vascular        3240      Not cycling
#
#      source technology  n_cells patient   cancer_type  sex  age  \
# 0     Tumor  SmartSeq2     1169   BT_S2  Glioblastoma  NaN   54
# 1     Tumor  SmartSeq2     1169   BT_S2  Glioblastoma  NaN   54
# 2     Tumor  SmartSeq2     1169   BT_S2  Glioblastoma  NaN   54
# 3     Tumor  SmartSeq2     1169   BT_S2  Glioblastoma  NaN   54
# 4     Tumor  SmartSeq2     1169   BT_S2  Glioblastoma  NaN   54
# ...     ...        ...      ...     ...           ...  ...  ...
# 3584  Tumor  SmartSeq2      389   BT_S6  Glioblastoma  NaN   48
# 3585  Tumor  SmartSeq2      389   BT_S6  Glioblastoma  NaN   48
# 3586  Tumor  SmartSeq2      389   BT_S6  Glioblastoma  NaN   48
# 3587  Tumor  SmartSeq2      389   BT_S6  Glioblastoma  NaN   48
# 3588  Tumor  SmartSeq2      389   BT_S6  Glioblastoma  NaN   48
#
#      disease_extent sample_primary_met   site  treated_naive cell_subtype  \
# 0             local            primary  brain            NaN          NaN
# 1             local            primary  brain            NaN          NaN
# 2             local            primary  brain            NaN          NaN
# 3             local            primary  brain            NaN          NaN
# 4             local            primary  brain            NaN          NaN
# ...             ...                ...    ...            ...          ...
# 3584          local            primary  brain            NaN          NaN
# 3585          local            primary  brain            NaN          NaN
# 3586          local            primary  brain            NaN          NaN
# 3587          local            primary  brain            NaN          NaN
# 3588          local            primary  brain            NaN          NaN
#
#      category                    study
# 0       Brain  Data_Darmanis2017_Brain
# 1       Brain  Data_Darmanis2017_Brain
# 2       Brain  Data_Darmanis2017_Brain
# 3       Brain  Data_Darmanis2017_Brain
# 4       Brain  Data_Darmanis2017_Brain
# ...       ...                      ...
# 3584    Brain  Data_Darmanis2017_Brain
# 3585    Brain  Data_Darmanis2017_Brain
# 3586    Brain  Data_Darmanis2017_Brain
# 3587    Brain  Data_Darmanis2017_Brain
# 3588    Brain  Data_Darmanis2017_Brain
#
# [3589 rows x 19 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['category'] = 'Brain'

# %%
adata.obs['study'] = 'Data_Darmanis2017_Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Darmanis2017_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Darmanis2017_Brain.h5ad

# %% [markdown]
# #### 4.Filbin2018_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Filbin2018_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2587 × 23686
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
adata.obs['opc_variable'].value_counts()
# Out:
# opc_variable
# -0.573399    1
# -1.018730    1
# -0.938586    1
# -0.870725    1
# -0.444017    1
#             ..
# -0.815809    1
# -0.759807    1
# -1.217047    1
# -1.463382    1
# -1.050888    1
# Name: count, Length: 2259, dtype: int64

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'housekeeping_gene_expression', 'opc_variable', 'oc_like', 'ac_like', 'opc_like',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#             cell_name   sample        cell_type  complexity cell_cycle_phase  \
# 0     BCH1126-P01-A01  BCH1126        Malignant        4064      Not cycling
# 1     BCH1126-P01-A02  BCH1126        Malignant        5162      Not cycling
# 2     BCH1126-P01-A04  BCH1126        Malignant        3583      Not cycling
# 3     BCH1126-P01-A07  BCH1126        Malignant        4743      Not cycling
# 4     BCH1126-P01-A08  BCH1126        Malignant        4015      Not cycling
# ...               ...      ...              ...         ...              ...
# 2582    Oligo-P22-H03    Oligo  Oligodendrocyte        5547      Not cycling
# 2583    Oligo-P22-H05    Oligo  Oligodendrocyte        2991      Not cycling
# 2584    Oligo-P22-H06    Oligo  Oligodendrocyte        2977      Not cycling
# 2585    Oligo-P22-H08    Oligo  Oligodendrocyte        2885      Not cycling
# 2586    Oligo-P22-H09    Oligo  Oligodendrocyte        3006      Not cycling
#
#      technology  n_cells  patient    cancer_type  sex   age disease_extent  \
# 0     SmartSeq2      298  BCH1126  H3K27M Glioma    F  10.0          local
# 1     SmartSeq2      298  BCH1126  H3K27M Glioma    F  10.0          local
# 2     SmartSeq2      298  BCH1126  H3K27M Glioma    F  10.0          local
# 3     SmartSeq2      298  BCH1126  H3K27M Glioma    F  10.0          local
# 4     SmartSeq2      298  BCH1126  H3K27M Glioma    F  10.0          local
# ...         ...      ...      ...            ...  ...   ...            ...
# 2582  SmartSeq2      138      NaN         Normal  NaN   NaN            NaN
# 2583  SmartSeq2      138      NaN         Normal  NaN   NaN            NaN
# 2584  SmartSeq2      138      NaN         Normal  NaN   NaN            NaN
# 2585  SmartSeq2      138      NaN         Normal  NaN   NaN            NaN
# 2586  SmartSeq2      138      NaN         Normal  NaN   NaN            NaN
#
#      sample_primary_met  site treated_naive
# 0               primary  Pons         naive
# 1               primary  Pons         naive
# 2               primary  Pons         naive
# 3               primary  Pons         naive
# 4               primary  Pons         naive
# ...                 ...   ...           ...
# 2582                NaN   NaN           NaN
# 2583                NaN   NaN           NaN
# 2584                NaN   NaN           NaN
# 2585                NaN   NaN           NaN
# 2586                NaN   NaN           NaN
#
# [2587 rows x 15 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['study'] = 'Data_Filbin2018_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Filbin2018_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Filbin2018_Brain.h5ad

# %% [markdown]
# #### 5.Gojo2020_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Gojo2020_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6739 × 20447
#     obs: 'cell_name', 'sample', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'housekeeping_gene_expression', 'opc_variable', 'oc_like', 'ac_like', 'opc_like',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#               cell_name      sample  cell_type       cell_subtype  complexity  \
# 0         BT1030.P1.A01      BT1030  Malignant         ST-Midline        4734
# 1         BT1030.P1.A03      BT1030  Malignant         ST-Midline        2988
# 2         BT1030.P1.A04      BT1030  Malignant  ST-Ependymal-like        4686
# 3         BT1030.P1.A06      BT1030  Malignant  ST-Ependymal-like        5845
# 4         BT1030.P1.A07      BT1030        NaN                NaN        3057
# ...                 ...         ...        ...                ...         ...
# 6734  MUV043Nuc3.P1.H08  MUV043Nuc3        NaN                NaN        2879
# 6735  MUV043Nuc3.P1.H09  MUV043Nuc3        NaN                NaN        3867
# 6736  MUV043Nuc3.P1.H10  MUV043Nuc3        NaN                NaN        3519
# 6737  MUV043Nuc3.P1.H11  MUV043Nuc3        NaN                NaN        3616
# 6738  MUV043Nuc3.P1.H12  MUV043Nuc3        NaN                NaN        3897
#
#      cell_cycle_phase technology  n_cells patient cancer_type sex   age  \
# 0         Not cycling  SmartSeq2      233  BT1030  Ependymoma   M  16.1
# 1         Not cycling  SmartSeq2      233  BT1030  Ependymoma   M  16.1
# 2         Not cycling  SmartSeq2      233  BT1030  Ependymoma   M  16.1
# 3         Not cycling  SmartSeq2      233  BT1030  Ependymoma   M  16.1
# 4                 NaN  SmartSeq2      233  BT1030  Ependymoma   M  16.1
# ...               ...        ...      ...     ...         ...  ..   ...
# 6734              NaN  SmartSeq2      294  MUV043  Ependymoma   M  21.6
# 6735              NaN  SmartSeq2      294  MUV043  Ependymoma   M  21.6
# 6736              NaN  SmartSeq2      294  MUV043  Ependymoma   M  21.6
# 6737              NaN  SmartSeq2      294  MUV043  Ependymoma   M  21.6
# 6738              NaN  SmartSeq2      294  MUV043  Ependymoma   M  21.6
#
#       disease_extent sample_primary_met                 site treated_naive  \
# 0                NaN            primary     temporal/midline         naive
# 1                NaN            primary     temporal/midline         naive
# 2                NaN            primary     temporal/midline         naive
# 3                NaN            primary     temporal/midline         naive
# 4                NaN            primary     temporal/midline         naive
# ...              ...                ...                  ...           ...
# 6734             NaN            primary  postcentral-central         naive
# 6735             NaN            primary  postcentral-central         naive
# 6736             NaN            primary  postcentral-central         naive
# 6737             NaN            primary  postcentral-central         naive
# 6738             NaN            primary  postcentral-central         naive
#
#      source           study category
# 0       NaN  Gojo2020_Brain    Brain
# 1       NaN  Gojo2020_Brain    Brain
# 2       NaN  Gojo2020_Brain    Brain
# 3       NaN  Gojo2020_Brain    Brain
# 4       NaN  Gojo2020_Brain    Brain
# ...     ...             ...      ...
# 6734    NaN  Gojo2020_Brain    Brain
# 6735    NaN  Gojo2020_Brain    Brain
# 6736    NaN  Gojo2020_Brain    Brain
# 6737    NaN  Gojo2020_Brain    Brain
# 6738    NaN  Gojo2020_Brain    Brain
#
# [6739 rows x 19 columns]

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['study'] = 'Gojo2020_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Gojo2020_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Gojo2020_Brain.h5ad

# %% [markdown]
# #### 6.Hovestadt2019_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Hovestadt2019_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 8691 × 23686
#     obs: 'cell_name', 'sample', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'source', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'housekeeping_gene_expression', 'opc_variable', 'oc_like', 'ac_like', 'opc_like',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#            cell_name  sample  complexity cell_cycle_phase   source technology  \
# 0     BCH807.P02.A01  BCH807        7777      Not cycling  Patient  SmartSeq2
# 1     BCH807.P02.A02  BCH807        6117      Not cycling  Patient  SmartSeq2
# 2     BCH807.P02.A03  BCH807        5717      Not cycling  Patient  SmartSeq2
# 3     BCH807.P02.A04  BCH807        6813             G2/M  Patient  SmartSeq2
# 4     BCH807.P02.A05  BCH807        6338      Not cycling  Patient  SmartSeq2
# ...              ...     ...         ...              ...      ...        ...
# 8686  RCMB24.P10.G12  RCMB24        4276      Not cycling      PDX  SmartSeq2
# 8687  RCMB24.P10.H02  RCMB24        2876      Not cycling      PDX  SmartSeq2
# 8688  RCMB24.P10.H09  RCMB24        2934      Not cycling      PDX  SmartSeq2
# 8689  RCMB24.P10.H10  RCMB24        2698      Not cycling      PDX  SmartSeq2
# 8690  RCMB24.P10.H11  RCMB24        4137             G1/S      PDX  SmartSeq2
#
#       n_cells patient      cancer_type sex   age disease_extent  \
# 0         307  BCH807  Medulloblastoma   M  12.0     metastatic
# 1         307  BCH807  Medulloblastoma   M  12.0     metastatic
# 2         307  BCH807  Medulloblastoma   M  12.0     metastatic
# 3         307  BCH807  Medulloblastoma   M  12.0     metastatic
# 4         307  BCH807  Medulloblastoma   M  12.0     metastatic
# ...       ...     ...              ...  ..   ...            ...
# 8686      137     PDX  Medulloblastoma   M  12.0            NaN
# 8687      137     PDX  Medulloblastoma   M  12.0            NaN
# 8688      137     PDX  Medulloblastoma   M  12.0            NaN
# 8689      137     PDX  Medulloblastoma   M  12.0            NaN
# 8690      137     PDX  Medulloblastoma   M  12.0            NaN
#
#      sample_primary_met  site treated_naive cell_type cell_subtype  \
# 0                   met   NaN         naive       NaN          NaN
# 1                   met   NaN         naive       NaN          NaN
# 2                   met   NaN         naive       NaN          NaN
# 3                   met   NaN         naive       NaN          NaN
# 4                   met   NaN         naive       NaN          NaN
# ...                 ...   ...           ...       ...          ...
# 8686                NaN   NaN           NaN       NaN          NaN
# 8687                NaN   NaN           NaN       NaN          NaN
# 8688                NaN   NaN           NaN       NaN          NaN
# 8689                NaN   NaN           NaN       NaN          NaN
# 8690                NaN   NaN           NaN       NaN          NaN
#
#                     study category
# 0     Hovestadt2019_Brain    Brain
# 1     Hovestadt2019_Brain    Brain
# 2     Hovestadt2019_Brain    Brain
# 3     Hovestadt2019_Brain    Brain
# 4     Hovestadt2019_Brain    Brain
# ...                   ...      ...
# 8686  Hovestadt2019_Brain    Brain
# 8687  Hovestadt2019_Brain    Brain
# 8688  Hovestadt2019_Brain    Brain
# 8689  Hovestadt2019_Brain    Brain
# 8690  Hovestadt2019_Brain    Brain
#
# [8691 rows x 19 columns]

# %%
adata.obs['cell_type'] = 'NaN'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['study'] = 'Hovestadt2019_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Hovestadt2019_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Hovestadt2019_Brain.h5ad

# %% [markdown]
# #### 7.Neftel2019_Brain

# %%
import os
import pandas as pd
import scanpy as sc
import gc

# === Set base path ===
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Neftel2019_Brain"

# === Load 10X Data ===
path_10x = os.path.join(base_path, "10X")
adata_10x = sc.read_mtx(os.path.join(path_10x, "Exp_data_UMIcounts.mtx")).T  # Transpose to cells x genes
genes_10x = pd.read_csv(os.path.join(path_10x, "Genes.txt"), header=None)[0].tolist()
cells_10x = pd.read_csv(os.path.join(path_10x, "Cells.csv"), index_col=0)

adata_10x.var_names = genes_10x
adata_10x.var_names_make_unique()
adata_10x.obs = cells_10x
adata_10x.obs['technology'] = '10X'

# === Load SmartSeq2 Data ===
path_ss2 = os.path.join(base_path, "SmartSeq2")
adata_ss2 = sc.read_mtx(os.path.join(path_ss2, "Exp_data_UMIcounts.mtx")).T
genes_ss2 = pd.read_csv(os.path.join(path_ss2, "Genes.txt"), header=None)[0].tolist()
cells_ss2 = pd.read_csv(os.path.join(path_ss2, "Cells.csv"), index_col=0)

adata_ss2.var_names = genes_ss2
adata_ss2.var_names_make_unique()
adata_ss2.obs = cells_ss2
adata_ss2.obs['technology'] = 'SmartSeq2'

# === Align by common genes ===
common_genes = adata_10x.var_names.intersection(adata_ss2.var_names)
adata_10x = adata_10x[:, common_genes].copy()
adata_ss2 = adata_ss2[:, common_genes].copy()

# === Concatenate ===
adata_combined = adata_10x.concatenate(
    adata_ss2,
    batch_key='batch',
    batch_categories=['10X', 'SmartSeq2'],
    index_unique=None
)

# === Check uniqueness ===
assert adata_combined.obs_names.is_unique, "Cell names are not unique after concatenation"

# === Merge sample metadata ===
samples_df = pd.read_csv(os.path.join(base_path, "Samples.csv")).drop_duplicates(subset=['sample'])

# Preserve and reset index
adata_combined.obs = adata_combined.obs.reset_index()
original_index = adata_combined.obs.columns[0]

# Merge with sample metadata
adata_combined.obs = adata_combined.obs.merge(samples_df, how='left', on='sample')
assert adata_combined.obs.shape[0] == adata_combined.shape[0], "Row count mismatch after metadata merge"

# Restore index
adata_combined.obs = adata_combined.obs.set_index(original_index)
adata_combined.obs.index.name = None

# === Save final object ===
#output_path = os.path.join(base_path, "Data_Neftel2019_Brain.h5ad")
#adata_combined.write(output_path)
#print(f"✅ AnnData object saved to: {output_path}")

# Optional cleanup
gc.collect()
# Out:
# /tmp/ipykernel_1295399/966841246.py:37: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_combined = adata_10x.concatenate(
# 3568

# %%
adata = adata_combined

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 24131 × 19135
#     obs: 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology_x', 'malignant', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'age_group', 'cross_section', 'genes_expressed', 'MESlike2',
            'MESlike1', 'AClike', 'OPClike', 'NPClike1', 'NPClike2', 'batch', 'technology_y', 
            'smoking_status', 'PY', 
            'housekeeping_gene_expression', 'opc_variable', 'oc_like', 'ac_like', 'opc_like',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['malignant'].value_counts()
# Out:
# malignant
# yes    6855
# no      776
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#               sample  cell_type  complexity cell_cycle_phase technology  \
# 102_1            102  Malignant        3101      Not cycling        10X
# 102_2            102  Malignant        2366             G1/S        10X
# 102_4            102  Malignant        1217      Not cycling        10X
# 102_5            102  Malignant        2285      Not cycling        10X
# 102_7            102  Malignant        1725      Not cycling        10X
# ...              ...        ...         ...              ...        ...
# MGH66-P08-H06  MGH66  Malignant        7432             G1/S  SmartSeq2
# MGH66-P08-H07  MGH66  Malignant        5164      Not cycling  SmartSeq2
# MGH66-P08-H08  MGH66  Malignant        6954             G1/S  SmartSeq2
# MGH66-P08-H10  MGH66  Malignant        5014      Not cycling  SmartSeq2
# MGH66-P08-H11  MGH66  Malignant        5640      Not cycling  SmartSeq2
#
#                n_cells patient   cancer_type sex age disease_extent  \
# 102_1             1822     102  Glioblastoma   M  65          local
# 102_2             1822     102  Glioblastoma   M  65          local
# 102_4             1822     102  Glioblastoma   M  65          local
# 102_5             1822     102  Glioblastoma   M  65          local
# 102_7             1822     102  Glioblastoma   M  65          local
# ...                ...     ...           ...  ..  ..            ...
# MGH66-P08-H06      436   MGH66  Glioblastoma   M  67          local
# MGH66-P08-H07      436   MGH66  Glioblastoma   M  67          local
# MGH66-P08-H08      436   MGH66  Glioblastoma   M  67          local
# MGH66-P08-H10      436   MGH66  Glioblastoma   M  67          local
# MGH66-P08-H11      436   MGH66  Glioblastoma   M  67          local
#
#               sample_primary_met           site treated_naive      cell_name  \
# 102_1                    primary  Left temporal         naive          102_1
# 102_2                    primary  Left temporal         naive          102_2
# 102_4                    primary  Left temporal         naive          102_4
# 102_5                    primary  Left temporal         naive          102_5
# 102_7                    primary  Left temporal         naive          102_7
# ...                          ...            ...           ...            ...
# MGH66-P08-H06            primary   Left frontal         naive  MGH66-P08-H06
# MGH66-P08-H07            primary   Left frontal         naive  MGH66-P08-H07
# MGH66-P08-H08            primary   Left frontal         naive  MGH66-P08-H08
# MGH66-P08-H10            primary   Left frontal         naive  MGH66-P08-H10
# MGH66-P08-H11            primary   Left frontal         naive  MGH66-P08-H11
#
#               cell_subtype             study category     source
# 102_1                  NaN  Neftel2019_Brain    Brain        NaN
# 102_2                  NaN  Neftel2019_Brain    Brain        NaN
# 102_4                  NaN  Neftel2019_Brain    Brain        NaN
# 102_5                  NaN  Neftel2019_Brain    Brain        NaN
# 102_7                  NaN  Neftel2019_Brain    Brain        NaN
# ...                    ...               ...      ...        ...
# MGH66-P08-H06          NaN  Neftel2019_Brain    Brain  malignant
# MGH66-P08-H07          NaN  Neftel2019_Brain    Brain  malignant
# MGH66-P08-H08          NaN  Neftel2019_Brain    Brain  malignant
# MGH66-P08-H10          NaN  Neftel2019_Brain    Brain  malignant
# MGH66-P08-H11          NaN  Neftel2019_Brain    Brain  malignant
#
# [24131 rows x 19 columns]

# %%
adata.obs['cell_name'] = adata.obs_names

# %%
adata.obs = adata.obs.rename(columns={"technology_x": "technology"})

# %%
adata.obs['source'] = adata.obs['malignant'].map({
    'no': 'not malignant',
    'yes': 'malignant',
    'Indistinct': 'Indistinct'
})

# %%
del adata.obs['malignant']

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['study'] = 'Neftel2019_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Neftel2019_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Neftel2019_Brain.h5ad

# %% [markdown]
# #### 8.Tirosh2016_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Tirosh2016_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4347 × 23686
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive', 'source'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'housekeeping_gene_expression', 'opc_variable', 'oc_like', 'ac_like', 'opc_like',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'Differentiation', 'Stemness', 
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['source'] = adata.obs['malignant'].map({
    'no': 'not malignant',
    'yes': 'malignant',
    'Indistinct': 'Indistinct'
})

# %%
del adata.obs['malignant']

# %%
adata.obs['source'].value_counts()
# Out:
# source
# malignant        4044
# not malignant     280
# Name: count, dtype: int64

# %%
adata.obs
# Out:
#           cell_name sample   cell_type  complexity cell_cycle_phase  \
# 0      MGH36_P6_A12  MGH36  Macrophage        4990      Not cycling
# 1      MGH36_P6_H09  MGH36  Macrophage        3031      Not cycling
# 2      MGH53_P4_G04  MGH53  Macrophage        3842      Not cycling
# 3     MGH36_P10_G12  MGH36  Macrophage        4312      Not cycling
# 4      MGH53_P2_H12  MGH53  Macrophage        5549      Not cycling
# ...             ...    ...         ...         ...              ...
# 4342      93_P8_H06  MGH93   Malignant        5364      Not cycling
# 4343      93_P9_C07  MGH93   Malignant        5550      Not cycling
# 4344      93_P8_A12  MGH93   Malignant        5634      Not cycling
# 4345      93_P8_C01  MGH93   Malignant        4641      Not cycling
# 4346      93_P9_F06  MGH93   Malignant        5126      Not cycling
#
#      technology  n_cells patient        cancer_type     sex  age  \
# 0     SmartSeq2      788   MGH36  Oligodendroglioma    Male   67
# 1     SmartSeq2      788   MGH36  Oligodendroglioma    Male   67
# 2     SmartSeq2      861   MGH53  Oligodendroglioma    Male   31
# 3     SmartSeq2      788   MGH36  Oligodendroglioma    Male   67
# 4     SmartSeq2      861   MGH53  Oligodendroglioma    Male   31
# ...         ...      ...     ...                ...     ...  ...
# 4342  SmartSeq2      445   MGH93  Oligodendroglioma  Female   65
# 4343  SmartSeq2      445   MGH93  Oligodendroglioma  Female   65
# 4344  SmartSeq2      445   MGH93  Oligodendroglioma  Female   65
# 4345  SmartSeq2      445   MGH93  Oligodendroglioma  Female   65
# 4346  SmartSeq2      445   MGH93  Oligodendroglioma  Female   65
#
#      disease_extent sample_primary_met                        site  \
# 0             local            primary  Right frontotemporoinsular
# 1             local            primary  Right frontotemporoinsular
# 2             local            primary                Left frontal
# 3             local            primary  Right frontotemporoinsular
# 4             local            primary                Left frontal
# ...             ...                ...                         ...
# 4342          local            primary              Right temporal
# 4343          local            primary              Right temporal
# 4344          local            primary              Right temporal
# 4345          local            primary              Right temporal
# 4346          local            primary              Right temporal
#
#      treated_naive         source cell_subtype             study category
# 0            naive  not malignant          NaN  Tirosh2016_Brain    Brain
# 1            naive  not malignant          NaN  Tirosh2016_Brain    Brain
# 2            naive  not malignant          NaN  Tirosh2016_Brain    Brain
# 3            naive  not malignant          NaN  Tirosh2016_Brain    Brain
# 4            naive  not malignant          NaN  Tirosh2016_Brain    Brain
# ...            ...            ...          ...               ...      ...
# 4342         naive      malignant          NaN  Tirosh2016_Brain    Brain
# 4343         naive      malignant          NaN  Tirosh2016_Brain    Brain
# 4344         naive      malignant          NaN  Tirosh2016_Brain    Brain
# 4345         naive      malignant          NaN  Tirosh2016_Brain    Brain
# 4346         naive      malignant          NaN  Tirosh2016_Brain    Brain
#
# [4347 rows x 19 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['study'] = 'Tirosh2016_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Tirosh2016_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Tirosh2016_Brain.h5ad

# %% [markdown]
# #### 10. Venteicher2017_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Venteicher2017_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6341 × 23686
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'housekeeping_gene_expression', 'opc_variable', 'oc_like', 'ac_like', 'opc_like',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'Differentiation', 'Stemness', 
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#          cell_name sample   cell_type  complexity cell_cycle_phase technology  \
# 0       57-P14-A02  MGH57  Macrophage        3888      Not cycling  SmartSeq2
# 1       57-P14-A04  MGH57  Macrophage        2854      Not cycling  SmartSeq2
# 2       57-P14-A05  MGH57  Macrophage        3542      Not cycling  SmartSeq2
# 3       57-P14-A06  MGH57  Macrophage        3483      Not cycling  SmartSeq2
# 4       57-P14-A07  MGH57         NaN        3845              NaN  SmartSeq2
# ...            ...    ...         ...         ...              ...        ...
# 6336  MGH64-P6-H05  MGH64   Malignant        5242      Not cycling  SmartSeq2
# 6337  MGH64-P6-H08  MGH64   Malignant        7069      Not cycling  SmartSeq2
# 6338  MGH64-P6-H09  MGH64   Malignant        3974      Not cycling  SmartSeq2
# 6339  MGH64-P6-H10  MGH64         NaN        5925              NaN  SmartSeq2
# 6340  MGH64-P6-H12  MGH64   Malignant        7434      Not cycling  SmartSeq2
#
#       n_cells patient  cancer_type     sex  age disease_extent  \
# 0         415   MGH57  Astrocytoma  female   47          local
# 1         415   MGH57  Astrocytoma  female   47          local
# 2         415   MGH57  Astrocytoma  female   47          local
# 3         415   MGH57  Astrocytoma  female   47          local
# 4         415   MGH57  Astrocytoma  female   47          local
# ...       ...     ...          ...     ...  ...            ...
# 6336      795   MGH64  Astrocytoma  female   47          local
# 6337      795   MGH64  Astrocytoma  female   47          local
# 6338      795   MGH64  Astrocytoma  female   47          local
# 6339      795   MGH64  Astrocytoma  female   47          local
# 6340      795   MGH64  Astrocytoma  female   47          local
#
#      sample_primary_met   site treated_naive
# 0               primary  brain         naive
# 1               primary  brain         naive
# 2               primary  brain         naive
# 3               primary  brain         naive
# 4               primary  brain         naive
# ...                 ...    ...           ...
# 6336            primary  brain         naive
# 6337            primary  brain         naive
# 6338            primary  brain         naive
# 6339            primary  brain         naive
# 6340            primary  brain         naive
#
# [6341 rows x 15 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['study'] = 'Venteicher2017_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Venteicher2017_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Venteicher2017_Brain.h5ad

# %% [markdown]
# #### 10. Wang2019_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Wang2019_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 16317 × 33545
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 
            'housekeeping_gene_expression', 'opc_variable', 'oc_like', 'ac_like', 'opc_like',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'Differentiation', 'Stemness', 
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                         cell_name   sample        cell_type  complexity  \
# 0      SF10022_AAACCCAAGAAGGTAG-1  SF10022        Malignant        2804
# 1      SF10022_AAACCCAAGACCTCCG-1  SF10022        Malignant        2365
# 2      SF10022_AAACCCACAACTTGGT-1  SF10022        Malignant        4567
# 3      SF10022_AAACCCAGTCTACGAT-1  SF10022  Oligodendrocyte        2680
# 4      SF10022_AAACCCAGTTATCTTC-1  SF10022        Malignant        4157
# ...                           ...      ...              ...         ...
# 16312  SF9259S_TTTCCTCTCCCTTGGT-1  SF9259S  Oligodendrocyte        3399
# 16313  SF9259S_TTTGGAGTCAACACCA-1  SF9259S  Oligodendrocyte        1188
# 16314  SF9259S_TTTGGTTGTCGTTATG-1  SF9259S  Oligodendrocyte        2190
# 16315  SF9259S_TTTGTTGAGCTCTTCC-1  SF9259S  Oligodendrocyte        3070
# 16316  SF9259S_TTTGTTGCATCTGGGC-1  SF9259S  Oligodendrocyte        2159
#
#        cell_cycle_phase technology  n_cells  patient   cancer_type  age  \
# 0                   NaN        10x     2888  SF10022  Glioblastoma  NaN
# 1                   NaN        10x     2888  SF10022  Glioblastoma  NaN
# 2                   NaN        10x     2888  SF10022  Glioblastoma  NaN
# 3                   NaN        10x     2888  SF10022  Glioblastoma  NaN
# 4                   NaN        10x     2888  SF10022  Glioblastoma  NaN
# ...                 ...        ...      ...      ...           ...  ...
# 16312               NaN        10x      849   SF9259  Glioblastoma  NaN
# 16313               NaN        10x      849   SF9259  Glioblastoma  NaN
# 16314               NaN        10x      849   SF9259  Glioblastoma  NaN
# 16315               NaN        10x      849   SF9259  Glioblastoma  NaN
# 16316               NaN        10x      849   SF9259  Glioblastoma  NaN
#
#       disease_extent sample_primary_met   site treated_naive cell_subtype  \
# 0              local            primary  Brain         naive          NaN
# 1              local            primary  Brain         naive          NaN
# 2              local            primary  Brain         naive          NaN
# 3              local            primary  Brain         naive          NaN
# 4              local            primary  Brain         naive          NaN
# ...              ...                ...    ...           ...          ...
# 16312          local            primary  Brain         naive          NaN
# 16313          local            primary  Brain         naive          NaN
# 16314          local            primary  Brain         naive          NaN
# 16315          local            primary  Brain         naive          NaN
# 16316          local            primary  Brain         naive          NaN
#
#       source           study category  sex
# 0        NaN  Wang2019_Brain    Brain  NaN
# 1        NaN  Wang2019_Brain    Brain  NaN
# 2        NaN  Wang2019_Brain    Brain  NaN
# 3        NaN  Wang2019_Brain    Brain  NaN
# 4        NaN  Wang2019_Brain    Brain  NaN
# ...      ...             ...      ...  ...
# 16312    NaN  Wang2019_Brain    Brain  NaN
# 16313    NaN  Wang2019_Brain    Brain  NaN
# 16314    NaN  Wang2019_Brain    Brain  NaN
# 16315    NaN  Wang2019_Brain    Brain  NaN
# 16316    NaN  Wang2019_Brain    Brain  NaN
#
# [16317 rows x 19 columns]

# %%
adata.obs['sex'].value_counts()
# Out:
# sex
# False    693
# Name: count, dtype: int64

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['study'] = 'Wang2019_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
del adata.obs['sex']

# %%
adata.obs['sex'] = 'NaN'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Wang2019_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Wang2019_Brain.h5ad

# %% [markdown]
# #### 11.Yuan2018_Brain

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Brain/Data_Yuan2018_Brain"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 23793 × 58828
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'cell_cycle_phase', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'disease_extent', 'sample_primary_met', 'site', 'treated_naive'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'smoking_status', 'PY', 'clusters', 'clusters_malignant_cells',
            'housekeeping_gene_expression', 'opc_variable', 'oc_like', 'ac_like', 'opc_like',
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'Differentiation', 'Stemness', 
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#        cell_name sample  cell_type  complexity cell_cycle_phase  \
# 0              1  PJ016  Malignant        6837     Intermediate
# 1              2  PJ016  Malignant        7378     Intermediate
# 2              3  PJ016  Malignant        6846      Not cycling
# 3              4  PJ016  Malignant        6931      Not cycling
# 4              5  PJ016  Malignant        6807      Not cycling
# ...          ...    ...        ...         ...              ...
# 23788      23789  PJ048  Malignant         361              NaN
# 23789      23790  PJ048  Malignant         348              NaN
# 23790      23791  PJ048  Malignant         413              NaN
# 23791      23792  PJ048  Malignant         370              NaN
# 23792      23793  PJ048  Malignant         386              NaN
#
#                            technology  n_cells patient   cancer_type sex  age  \
# 0      Microwell array-based platform     3085   PJ016           NaN   F  NaN
# 1      Microwell array-based platform     3085   PJ016           NaN   F  NaN
# 2      Microwell array-based platform     3085   PJ016           NaN   F  NaN
# 3      Microwell array-based platform     3085   PJ016           NaN   F  NaN
# 4      Microwell array-based platform     3085   PJ016           NaN   F  NaN
# ...                               ...      ...     ...           ...  ..  ...
# 23788  Microwell array-based platform     3084   PJ048  Glioblastoma   M  NaN
# 23789  Microwell array-based platform     3084   PJ048  Glioblastoma   M  NaN
# 23790  Microwell array-based platform     3084   PJ048  Glioblastoma   M  NaN
# 23791  Microwell array-based platform     3084   PJ048  Glioblastoma   M  NaN
# 23792  Microwell array-based platform     3084   PJ048  Glioblastoma   M  NaN
#
#       disease_extent sample_primary_met            site treated_naive
# 0              local            primary  right frontal          naive
# 1              local            primary  right frontal          naive
# 2              local            primary  right frontal          naive
# 3              local            primary  right frontal          naive
# 4              local            primary  right frontal          naive
# ...              ...                ...             ...           ...
# 23788          local            primary  right parietal         naive
# 23789          local            primary  right parietal         naive
# 23790          local            primary  right parietal         naive
# 23791          local            primary  right parietal         naive
# 23792          local            primary  right parietal         naive
#
# [23793 rows x 15 columns]

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['study'] = 'Yuan2018_Brain'

# %%
adata.obs['category'] = 'Brain'

# %%
output_path = "/home/ubuntu/Downloads/Data_Brain/Data_Yuan2018_Brain.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Brain/Data_Yuan2018_Brain.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os

# %%
# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Brain/Data_Choudhury2022_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Couturier2020_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Darmanis2017_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Filbin2018_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Gojo2020_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Hovestadt2019_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Neftel2019_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Tirosh2016_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Venteicher2017_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Wang2019_Brain.h5ad",
    "/home/ubuntu/Downloads/Data_Brain/Data_Yuan2018_Brain.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Brain/Brain_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/merge.py:1349: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   concat_annot = pd.concat(
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Brain/Brain_Combined.h5ad

# %%
adata_merged.obs
# Out:
#                    cell_name sample patient  cell_type  \
# 0      MSC1_AAACCCACAATATCCG   MSC1       1  Malignant
# 1      MSC1_AAACCCACATCTTAGG   MSC1       1  Malignant
# 2      MSC1_AAACGAACAACCTATG   MSC1       1  Malignant
# 3      MSC1_AAACGAACACCGCTAG   MSC1       1  Malignant
# 4      MSC1_AAACGCTCATCTCATT   MSC1       1   Monocyte
# ...                      ...    ...     ...        ...
# 23788                  23789  PJ048   PJ048  Malignant
# 23789                  23790  PJ048   PJ048  Malignant
# 23790                  23791  PJ048   PJ048  Malignant
# 23791                  23792  PJ048   PJ048  Malignant
# 23792                  23793  PJ048   PJ048  Malignant
#
#                           cell_subtype complexity cell_cycle_phase  \
# 0                     Meningioma cells        952              NaN
# 1                     Meningioma cells        940              NaN
# 2            G1 phase meningioma cells       7134      Not cycling
# 3      ECM remodeling meningioma cells       3521      Not cycling
# 4                      CD163 monocytes       1855      Not cycling
# ...                                ...        ...              ...
# 23788                              NaN        361              NaN
# 23789                              NaN        348              NaN
# 23790                              NaN        413              NaN
# 23791                              NaN        370              NaN
# 23792                              NaN        386              NaN
#
#            source   cancer_type                      technology  n_cells  \
# 0      Meningioma    Meningioma                             10x     2538
# 1      Meningioma    Meningioma                             10x     2538
# 2      Meningioma    Meningioma                             10x     2538
# 3      Meningioma    Meningioma                             10x     2538
# 4      Meningioma    Meningioma                             10x     2538
# ...           ...           ...                             ...      ...
# 23788         NaN  Glioblastoma  Microwell array-based platform     3084
# 23789         NaN  Glioblastoma  Microwell array-based platform     3084
# 23790         NaN  Glioblastoma  Microwell array-based platform     3084
# 23791         NaN  Glioblastoma  Microwell array-based platform     3084
# 23792         NaN  Glioblastoma  Microwell array-based platform     3084
#
#         age disease_extent  sex sample_primary_met treated_naive  \
# 0      44.3            NaN  NaN                NaN           NaN
# 1      44.3            NaN  NaN                NaN           NaN
# 2      44.3            NaN  NaN                NaN           NaN
# 3      44.3            NaN  NaN                NaN           NaN
# 4      44.3            NaN  NaN                NaN           NaN
# ...     ...            ...  ...                ...           ...
# 23788   nan          local    M            primary         naive
# 23789   nan          local    M            primary         naive
# 23790   nan          local    M            primary         naive
# 23791   nan          local    M            primary         naive
# 23792   nan          local    M            primary         naive
#
#                  site                study category
# 0               brain  Choudhury2022_Brain    Brain
# 1               brain  Choudhury2022_Brain    Brain
# 2               brain  Choudhury2022_Brain    Brain
# 3               brain  Choudhury2022_Brain    Brain
# 4               brain  Choudhury2022_Brain    Brain
# ...               ...                  ...      ...
# 23788  right parietal       Yuan2018_Brain    Brain
# 23789  right parietal       Yuan2018_Brain    Brain
# 23790  right parietal       Yuan2018_Brain    Brain
# 23791  right parietal       Yuan2018_Brain    Brain
# 23792  right parietal       Yuan2018_Brain    Brain
#
# [255713 rows x 19 columns]
