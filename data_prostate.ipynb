# %%
import os
import pandas as pd
import scanpy as sc
import anndata
import gc

# %% [markdown]
# ## Prostate

# %% [markdown]
# #### 1. Chen2021

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Prostate/Data_Chen2021_Prostate"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 36424 × 25044
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                  cell_name  sample  cell_type  complexity cell_cycle_phase  \
# 0       GAACCTAAGGTCATCT.1       1  Malignant        2643      Not cycling
# 1       TTGACTTTCGGACAAG.1       1  Malignant        2543      Not cycling
# 2       ATTACTCAGGAGCGAG.1       1  Malignant        3240      Not cycling
# 3       GCAGTTAAGCAGGCTA.1       1  Malignant        3307      Not cycling
# 4       GTCGGGTTCCTGTACC.1       1  Malignant        3601      Not cycling
# ...                    ...     ...        ...         ...              ...
# 36419  ATAAGAGTCACAGGCC.13      13       Mast        2097      Not cycling
# 36420  ACGAGCCTCATGTGGT.13      13        NaN         325              NaN
# 36421  ACAGCTAGTAGCGTGA.13      13       Mast        1501      Not cycling
# 36422  AAGTCTGTCATAGCAC.13      13       Mast        1054      Not cycling
# 36423  AAACGGGTCATGTAGC.13      13        NaN         525              NaN
#
#       technology  n_cells  patient      cancer_type sex  age  disease_extent  \
# 0            10x     1554        1  Prostate Cancer   M   81             NaN
# 1            10x     1554        1  Prostate Cancer   M   81             NaN
# 2            10x     1554        1  Prostate Cancer   M   81             NaN
# 3            10x     1554        1  Prostate Cancer   M   81             NaN
# 4            10x     1554        1  Prostate Cancer   M   81             NaN
# ...          ...      ...      ...              ...  ..  ...             ...
# 36419        10x     1277       13  Prostate Cancer   M   68             NaN
# 36420        10x     1277       13  Prostate Cancer   M   68             NaN
# 36421        10x     1277       13  Prostate Cancer   M   68             NaN
# 36422        10x     1277       13  Prostate Cancer   M   68             NaN
# 36423        10x     1277       13  Prostate Cancer   M   68             NaN
#
#       sample_primary_met  site treated_naive                   study  \
# 0                primary   NaN         naive  Data_Chen2021_Prostate
# 1                primary   NaN         naive  Data_Chen2021_Prostate
# 2                primary   NaN         naive  Data_Chen2021_Prostate
# 3                primary   NaN         naive  Data_Chen2021_Prostate
# 4                primary   NaN         naive  Data_Chen2021_Prostate
# ...                  ...   ...           ...                     ...
# 36419            primary   NaN         naive  Data_Chen2021_Prostate
# 36420            primary   NaN         naive  Data_Chen2021_Prostate
# 36421            primary   NaN         naive  Data_Chen2021_Prostate
# 36422            primary   NaN         naive  Data_Chen2021_Prostate
# 36423            primary   NaN         naive  Data_Chen2021_Prostate
#
#        category source
# 0      Prostate    NaN
# 1      Prostate    NaN
# 2      Prostate    NaN
# 3      Prostate    NaN
# 4      Prostate    NaN
# ...         ...    ...
# 36419  Prostate    NaN
# 36420  Prostate    NaN
# 36421  Prostate    NaN
# 36422  Prostate    NaN
# 36423  Prostate    NaN
#
# [36424 rows x 18 columns]

# %%
adata.obs['study'] = 'Data_Chen2021_Prostate'

# %%
adata.obs['category'] = 'Prostate'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
output_path = "/home/ubuntu/Downloads/Data_Prostate/Data_Chen2021_Prostate.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Prostate/Data_Chen2021_Prostate.h5ad

# %% [markdown]
# #### 2.Dong2020

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Prostate/Data_Dong2020_Prostate"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 21292 × 15709
#     obs: 'cell_name', 'sample', 'cell_type', 'complexity', 'umap1', 'umap2', 'g1s_score', 'g2m_score', 'cell_cycle_phase', 'mp_top_score', 'mp_top', 'mp_assignment', 'technology', 'n_cells', 'patient', 'cancer_type', 'sex', 'age', 'smoking_status', 'PY', 'diagnosis_recurrence', 'disease_extent', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage', 'sample_primary_met', 'size', 'site', 'histology', 'genetic_hormonal_features', 'grade', 'KI67', 'treated_naive', 'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed', 'targeted_rx_response', 'ICB_exposed', 'ICB_response', 'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed', 'post_sampling_rx_response', 'PFS_DFS', 'OS'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'technology_y', 'smoking_status', 'PY', 
            'diagnosis_recurrence', 'AJCC_T', 'AJCC_N', 'AJCC_M', 'AJCC_stage',
            'size',  'histology', 'genetic_hormonal_features', 'grade', 'KI67',
            'chemotherapy_exposed', 'chemotherapy_response', 'targeted_rx_exposed',
            'targeted_rx_response', 'ICB_exposed', 'ICB_response',
            'ET_exposed', 'ET_response', 'time_end_of_rx_to_sampling', 'post_sampling_rx_exposed',
            'post_sampling_rx_response', 'PFS_DFS', 'OS'         
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs
# Out:
#                   cell_name      sample   cell_type  complexity  \
# 0      AAACCTGAGTGTTTGC.1_1  patient #1  Epithelial        2617
# 1      AAACCTGCAGTCAGCC.1_1  patient #1   Malignant        4624
# 2      AAACCTGGTACATGTC.1_1  patient #1   Malignant        2531
# 3      AAACCTGGTCGGCATC.1_1  patient #1  Epithelial        3196
# 4      AAACCTGGTGCAGACA.1_1  patient #1  Epithelial        2851
# ...                     ...         ...         ...         ...
# 21287  TTTGTTGGTTAGAAGT.1_6  patient #6   Malignant        3921
# 21288  TTTGTTGTCAAACCCA.1_6  patient #6   Malignant        1301
# 21289  TTTGTTGTCAGACTGT.1_6  patient #6   Malignant        3966
# 21290  TTTGTTGTCCTCACGT.1_6  patient #6   Malignant        2579
# 21291  TTTGTTGTCGTGCGAC.1_6  patient #6   Malignant        1782
#
#       cell_cycle_phase technology  n_cells     patient      cancer_type sex  \
# 0          Not cycling        10x     3022  patient #1  Prostate Cancer   M
# 1         Intermediate        10x     3022  patient #1  Prostate Cancer   M
# 2          Not cycling        10x     3022  patient #1  Prostate Cancer   M
# 3          Not cycling        10x     3022  patient #1  Prostate Cancer   M
# 4          Not cycling        10x     3022  patient #1  Prostate Cancer   M
# ...                ...        ...      ...         ...              ...  ..
# 21287             G1/S        10x     6603  patient #6  Prostate Cancer   M
# 21288      Not cycling        10x     6603  patient #6  Prostate Cancer   M
# 21289             G1/S        10x     6603  patient #6  Prostate Cancer   M
# 21290      Not cycling        10x     6603  patient #6  Prostate Cancer   M
# 21291      Not cycling        10x     6603  patient #6  Prostate Cancer   M
#
#        age disease_extent sample_primary_met      site treated_naive  \
# 0       82          local            primary  prostate       treated
# 1       82          local            primary  prostate       treated
# 2       82          local            primary  prostate       treated
# 3       82          local            primary  prostate       treated
# 4       82          local            primary  prostate       treated
# ...    ...            ...                ...       ...           ...
# 21287   70     metastatic            primary  prostate       treated
# 21288   70     metastatic            primary  prostate       treated
# 21289   70     metastatic            primary  prostate       treated
# 21290   70     metastatic            primary  prostate       treated
# 21291   70     metastatic            primary  prostate       treated
#
#                         study  category cell_subtype source
# 0      Data_Dong2020_Prostate  Prostate          NaN    NaN
# 1      Data_Dong2020_Prostate  Prostate          NaN    NaN
# 2      Data_Dong2020_Prostate  Prostate          NaN    NaN
# 3      Data_Dong2020_Prostate  Prostate          NaN    NaN
# 4      Data_Dong2020_Prostate  Prostate          NaN    NaN
# ...                       ...       ...          ...    ...
# 21287  Data_Dong2020_Prostate  Prostate          NaN    NaN
# 21288  Data_Dong2020_Prostate  Prostate          NaN    NaN
# 21289  Data_Dong2020_Prostate  Prostate          NaN    NaN
# 21290  Data_Dong2020_Prostate  Prostate          NaN    NaN
# 21291  Data_Dong2020_Prostate  Prostate          NaN    NaN
#
# [21292 rows x 19 columns]

# %%
adata.obs['study'] = 'Data_Dong2020_Prostate'

# %%
adata.obs['category'] = 'Prostate'

# %%
adata.obs['cell_subtype'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
output_path = "/home/ubuntu/Downloads/Data_Prostate/Data_Dong2020_Prostate.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Prostate/Data_Dong2020_Prostate.h5ad

# %% [markdown]
# #### 3.He2021

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Prostate/Data_He2021_Prostate"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2170 × 45895
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'disease', 'source', 'metastasis_x', 'sex', 'cancer_type', 'technology', 'n_cells'

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'prior_enzalutamide_x', 'prior_abiraterone_x', 
            'prior_taxane_x', 'prior_platinum_x', 'prior_sipuleucel_T_x', 'purity_x', 
            'has_bulk_RNA_x', 'patient_y', 'source_y', 'metastasis_y', 'sex_y',
            'prior_enzalutamide_y', 'prior_abiraterone_y', 'prior_taxane_y', 
            'prior_platinum_y', 'prior_sipuleucel_T_y', 'purity_y', 'has_bulk_RNA_y'      
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs['metastasis_x'].value_counts()
# Out:
# metastasis_x
# True    2170
# Name: count, dtype: int64

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"sex_x": "sex"})

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['source'] = 'NaN'

# %%
adata.obs['site'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['category'] = 'Prostate'

# %%
adata.obs['study'] = 'He2021_prostate'

# %%
adata.obs['disease_extent'] = 'metastatic'

# %%
del adata.obs['cancer_type']

# %%
del adata.obs['metastasis_x']

# %%
adata.obs = adata.obs.rename(columns={"disease": "cancer_type"})

# %%
adata
# Out:
#       cell_name       sample  patient    cell_type          cell_subtype  \
# 0             0  01115149-TC  1115149    Malignant  prostate cancer cell
# 1             1  01115149-TC  1115149       B_cell           plasmablast
# 2             2  01115149-TC  1115149    Malignant  prostate cancer cell
# 3             3  01115149-TC  1115149    Malignant  prostate cancer cell
# 4             4  01115149-TC  1115149       T_cell           CD4+ T cell
# ...         ...          ...      ...          ...                   ...
# 2165       2165     09171144  9171144  Erythrocyte        erythroid cell
# 2166       2166     09171144  9171144  Erythrocyte        erythroid cell
# 2167       2167     09171144  9171144  Erythrocyte        erythroid cell
# 2168       2168     09171144  9171144  Erythrocyte        erythroid cell
# 2169       2169     09171144  9171144  Erythrocyte        erythroid cell
#
#       complexity cell_cycle_phase                    cancer_type source   sex  \
# 0           1890      Not cycling  metastatic prostate carcinoma    NaN  male
# 1           1194      Not cycling  metastatic prostate carcinoma    NaN  male
# 2            727              NaN  metastatic prostate carcinoma    NaN  male
# 3           1815      Not cycling  metastatic prostate carcinoma    NaN  male
# 4           2900      Not cycling  metastatic prostate carcinoma    NaN  male
# ...          ...              ...                            ...    ...   ...
# 2165        2825             G2/M  metastatic prostate carcinoma    NaN  male
# 2166        1320      Not cycling  metastatic prostate carcinoma    NaN  male
# 2167        3240             G1/S  metastatic prostate carcinoma    NaN  male
# 2168        1290      Not cycling  metastatic prostate carcinoma    NaN  male
# 2169         725              NaN  metastatic prostate carcinoma    NaN  male
#
#      technology  n_cells  Age disease_extent site sample_primary_met  \
# 0     SmartSeq2      261  NaN     metastatic  NaN                NaN
# 1     SmartSeq2      261  NaN     metastatic  NaN                NaN
# 2     SmartSeq2      261  NaN     metastatic  NaN                NaN
# 3     SmartSeq2      261  NaN     metastatic  NaN                NaN
# 4     SmartSeq2      261  NaN     metastatic  NaN                NaN
# ...         ...      ...  ...            ...  ...                ...
# 2165  SmartSeq2      437  NaN     metastatic  NaN                NaN
# 2166  SmartSeq2      437  NaN     metastatic  NaN                NaN
# 2167  SmartSeq2      437  NaN     metastatic  NaN                NaN
# 2168  SmartSeq2      437  NaN     metastatic  NaN                NaN
# 2169  SmartSeq2      437  NaN     metastatic  NaN                NaN
#
#      treated_naive  category   study
# 0              NaN  Prostate  He2021
# 1              NaN  Prostate  He2021
# 2              NaN  Prostate  He2021
# 3              NaN  Prostate  He2021
# 4              NaN  Prostate  He2021
# ...            ...       ...     ...
# 2165           NaN  Prostate  He2021
# 2166           NaN  Prostate  He2021
# 2167           NaN  Prostate  He2021
# 2168           NaN  Prostate  He2021
# 2169           NaN  Prostate  He2021
#
# [2170 rows x 19 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Prostate/Data_He2021_Prostate.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Prostate/Data_He2021_Prostate.h5ad

# %%
adata = sc.read("/home/ubuntu/Downloads/Data_Prostate/Data_He2021_Prostate.h5ad")

# %%
adata.obs = adata.obs.rename(columns={"Age": "age"})

# %% [markdown]
# #### 4. Song2022

# %%
# Base path
base_path = "/home/ubuntu/Downloads/Data_Prostate/Data_Song2022_Prostate"

# Step 1: Read expression matrix
adata = sc.read_mtx(os.path.join(base_path, "Exp_data_UMIcounts.mtx"))
adata = adata.transpose()  # Transpose to shape: cells × genes

# Step 2: Add gene names
genes = pd.read_csv(os.path.join(base_path, "Genes.txt"), header=None)
adata.var_names = genes[0].values
adata.var_names_make_unique()

# Step 3: Read and merge cell + sample metadata
cells = pd.read_csv(os.path.join(base_path, "Cells.csv"))
samples = pd.read_csv(os.path.join(base_path, "Samples.csv"))

# Merge on the shared 'sample' column
cells_merged = cells.merge(samples, on="sample", how="left")

# Assign merged metadata to AnnData
adata.obs = cells_merged

gc.collect

# Final check
#print(adata)
#print(adata.obs.head())
# Out:
# <function gc.collect(generation=2)>

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 21743 × 21877
#     obs: 'cell_name', 'sample', 'patient', 'cell_type', 'cell_subtype', 'complexity', 'cell_cycle_phase', 'source', 'cancer_cell_state', 'site', 'disease_extent', 'cancer_type', 'technology', 'n_cells', 'sex', 'age', 'sample_primary_met', 'treated_naive', 'category', 'study'

# %%
adata.obs['metastatic_workup_x'].value_counts()
# Out:
# metastatic_workup_x
# CT a/p negative        2495
# Bone scan negative     1993
# Bone scan equivocal     763
# Name: count, dtype: int64

# %%
for col in ['umap1', 'umap2', 'g1s_score', 'g2m_score', 'mp_top_score', 'mp_top', 
            'mp_assignment', 'PSA_x', 'ERG_status_x', 'cores_x', 'post_op_gleason_score_x',
            'margins_x', 'LVI_x', 'PNI_x', 'TRUS_x', 'MRI_x', 'post_op_psa_x', 'PSA_follow_up_x',
            'time_to_follow_up_x', 'patient_y', 'source_y', 'PSA_y', 'source_region_y', 'gleason_score_y', 
            'ERG_status_y', 'cores_y', 'post_op_gleason_score_y', 'margins_y', 
            'LVI_y', 'PNI_y', 'TRUS_y', 'MRI_y', 'metastatic_workup_y', 
            'post_op_psa_y', 'PSA_follow_up_y', 'time_to_follow_up_y', 'cancer_type'    
           ]:
    if col in adata.obs.columns:
        del adata.obs[col]

# %%
adata.obs = adata.obs.rename(columns={"patient_x": "patient"})

# %%
adata.obs = adata.obs.rename(columns={"source_x": "source"})

# %%
adata.obs = adata.obs.rename(columns={"source_region_x": "site"})

# %%
adata.obs = adata.obs.rename(columns={"disease": "cancer_type"})

# %%
adata.obs = adata.obs.rename(columns={"metastatic_workup_x": "disease_extent"})

# %%
adata.obs['sex'] = 'NaN'

# %%
adata.obs['age'] = 'NaN'

# %%
adata.obs['sample_primary_met'] = 'NaN'

# %%
adata.obs['treated_naive'] = 'NaN'

# %%
adata.obs['category'] = 'Prostate'

# %%
adata.obs['study'] = 'Song2022_Prostate'

# %%
del adata.obs['gleason_score_x']

# %%
del adata.obs['cancer_cell_state']

# %%
adata.obs
# Out:
#          cell_name   sample   patient      cell_type   cell_subtype  \
# 0          AUG_PB1  AUG_PB1  Patient1     Epithelial     Epithelial
# 1        AUG_PB1_1  AUG_PB1  Patient1     Epithelial     Epithelial
# 2        AUG_PB1_2  AUG_PB1  Patient1     Epithelial     Epithelial
# 3        AUG_PB1_3  AUG_PB1  Patient1     Epithelial     Epithelial
# 4        AUG_PB1_4  AUG_PB1  Patient1     Epithelial     Epithelial
# ...            ...      ...       ...            ...            ...
# 21738  PR5199_1020   PR5199  Patient6     Fibroblast     Fibroblast
# 21739  PR5199_1021   PR5199  Patient6  Smooth_muscle  Smooth_muscle
# 21740  PR5199_1022   PR5199  Patient6  Smooth_muscle  Smooth_muscle
# 21741  PR5199_1023   PR5199  Patient6        Myeloid        Myeloid
# 21742  PR5199_1024   PR5199  Patient6        Myeloid        Myeloid
#
#        complexity cell_cycle_phase source      site disease_extent  \
# 0            6755      Not cycling  Tumor  left-mid            NaN
# 1            7285      Not cycling  Tumor  left-mid            NaN
# 2            8204      Not cycling  Tumor  left-mid            NaN
# 3            7234      Not cycling  Tumor  left-mid            NaN
# 4            6291      Not cycling  Tumor  left-mid            NaN
# ...           ...              ...    ...       ...            ...
# 21738         453              NaN  Tumor       NaN            NaN
# 21739         412              NaN  Tumor       NaN            NaN
# 21740         382              NaN  Tumor       NaN            NaN
# 21741         423              NaN  Tumor       NaN            NaN
# 21742         348              NaN  Tumor       NaN            NaN
#
#            cancer_type   technology  n_cells  sex  age sample_primary_met  \
# 0      Prostate cancer  Seq-Well S3      933  NaN  NaN                NaN
# 1      Prostate cancer  Seq-Well S3      933  NaN  NaN                NaN
# 2      Prostate cancer  Seq-Well S3      933  NaN  NaN                NaN
# 3      Prostate cancer  Seq-Well S3      933  NaN  NaN                NaN
# 4      Prostate cancer  Seq-Well S3      933  NaN  NaN                NaN
# ...                ...          ...      ...  ...  ...                ...
# 21738  Prostate cancer  Seq-Well S3     1025  NaN  NaN                NaN
# 21739  Prostate cancer  Seq-Well S3     1025  NaN  NaN                NaN
# 21740  Prostate cancer  Seq-Well S3     1025  NaN  NaN                NaN
# 21741  Prostate cancer  Seq-Well S3     1025  NaN  NaN                NaN
# 21742  Prostate cancer  Seq-Well S3     1025  NaN  NaN                NaN
#
#       treated_naive  category              study
# 0               NaN  Prostate  Song2022_Prostate
# 1               NaN  Prostate  Song2022_Prostate
# 2               NaN  Prostate  Song2022_Prostate
# 3               NaN  Prostate  Song2022_Prostate
# 4               NaN  Prostate  Song2022_Prostate
# ...             ...       ...                ...
# 21738           NaN  Prostate  Song2022_Prostate
# 21739           NaN  Prostate  Song2022_Prostate
# 21740           NaN  Prostate  Song2022_Prostate
# 21741           NaN  Prostate  Song2022_Prostate
# 21742           NaN  Prostate  Song2022_Prostate
#
# [21743 rows x 19 columns]

# %%
output_path = "/home/ubuntu/Downloads/Data_Prostate/Data_Song2022_Prostate.h5ad"
adata.write(output_path)
print(f"✅ data saved to: {output_path}")
# Out:
# ✅ data saved to: /home/ubuntu/Downloads/Data_Prostate/Data_Song2022_Prostate.h5ad

# %% [markdown]
# #### Data Merging

# %%
import scanpy as sc
import anndata
import os


# Define file paths
files = [
    "/home/ubuntu/Downloads/Data_Prostate/Data_Chen2021_Prostate.h5ad",
    "/home/ubuntu/Downloads/Data_Prostate/Data_Dong2020_Prostate.h5ad",
    "/home/ubuntu/Downloads/Data_Prostate/Data_He2021_Prostate.h5ad",
    "/home/ubuntu/Downloads/Data_Prostate/Data_Song2022_Prostate.h5ad"
]

# Load datasets
adatas = [sc.read(file) for file in files]

# Merge all AnnData objects
adata_merged = anndata.concat(adatas, join="outer", fill_value=0)

# Fix non-string columns (e.g. 'sample') to avoid h5py write errors
for col in adata_merged.obs.columns:
    if adata_merged.obs[col].dtype == 'object':
        adata_merged.obs[col] = adata_merged.obs[col].astype(str)

# Save merged dataset
output_path = "/home/ubuntu/Downloads/Data_Prostate/Prostate_Combined.h5ad"
adata_merged.write(output_path)

print(f"✅ Merged and saved to: {output_path}")
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/ubuntu/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# ✅ Merged and saved to: /home/ubuntu/Downloads/Data_Prostate/Prostate_Combined.h5ad
